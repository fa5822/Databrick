-- %%
DECLARE InsertStr STRING;
DECLARE DeleteStr STRING;
DECLARE ColumnStr STRING;

SET VAR DeleteStr  = " delete from apachedataingestion.nr.widetable_5g_vonr_dy_gold2 where CalendarDate = date_format(date_add(now()," || :days || "),'yyyy-MM-dd')";

EXECUTE IMMEDIATE DeleteStr;

SET VAR ColumnStr = "
					  SUM(SEA_VoNR_DRBSetupFailureRate_5QI1_Num) SEA_VoNR_DRBSetupFailureRate_5QI1_Num,
					  SUM(SEA_VoNR_DRBSetupFailureRate_5QI1_Denom) SEA_VoNR_DRBSetupFailureRate_5QI1_Denom,
					  SUM(SEA_VoNR_DRBSetupFailureRate_5QI5_Num) SEA_VoNR_DRBSetupFailureRate_5QI5_Num,
					  SUM(SEA_VoNR_DRBSetupFailureRate_5QI5_Denom) SEA_VoNR_DRBSetupFailureRate_5QI5_Denom,
					  SUM(SEA_VoNR_DRBDropRate_5QI1_Num) SEA_VoNR_DRBDropRate_5QI1_Num,
					  SUM(SEA_VoNR_DRBDropRate_5QI1_Denom) SEA_VoNR_DRBDropRate_5QI1_Denom,
					  SUM(SEA_VoNR_DRBDropRate_5QI5_Num) SEA_VoNR_DRBDropRate_5QI5_Num,
					  SUM(SEA_VoNR_DRBDropRate_5QI5_Denom) SEA_VoNR_DRBDropRate_5QI5_Denom,
					  SUM(IntraGnbVoNR_HOFR_pct_Num) IntraGnbVoNR_HOFR_pct_Num,
					  SUM(IntraGnbVoNR_HOFR_pct_Denom) IntraGnbVoNR_HOFR_pct_Denom,
					  SUM(InterXnVoNR_HOFR_pct_Num) InterXnVoNR_HOFR_pct_Num,
					  SUM(InterXnVoNR_HOFR_pct_Denom) InterXnVoNR_HOFR_pct_Denom,
					  SUM(InterNgVoNR_HOFR_pct_Num) InterNgVoNR_HOFR_pct_Num,
					  SUM(InterNgVoNR_HOFR_pct_Denom) InterNgVoNR_HOFR_pct_Denom,
					  SUM(Avg_IntraGnbVoNRHoTime_Num) Avg_IntraGnbVoNRHoTime_Num,
					  SUM(Avg_IntraGnbVoNRHoTime_Denom) Avg_IntraGnbVoNRHoTime_Denom,
					  SUM(Avg_InterNgVoNR_HoTime_Num) Avg_InterNgVoNR_HoTime_Num,
					  SUM(Avg_InterNgVoNR_HoTime_Denom) Avg_InterNgVoNR_HoTime_Denom,
					  SUM(Avg_InterXnVoNR_HoTime_Num) Avg_InterXnVoNR_HoTime_Num,
					  SUM(Avg_InterXnVoNR_HoTime_Denom) Avg_InterXnVoNR_HoTime_Denom,
					  SUM(SEA_VoNR_EPCFallback_HO_Time_Avg_Num) SEA_VoNR_EPCFallback_HO_Time_Avg_Num,
					  SUM(SEA_VoNR_EPCFallback_HO_Time_Avg_Denom) SEA_VoNR_EPCFallback_HO_Time_Avg_Denom,
					  SUM(SEA_VoNR_PuschTypeARepetitionAvgUsers_Num) SEA_VoNR_PuschTypeARepetitionAvgUsers_Num,
					  SUM(SEA_VoNR_PuschTypeARepetitionAvgUsers_Denom) SEA_VoNR_PuschTypeARepetitionAvgUsers_Denom,
					  SUM(SEA_VoNR_PuschTypeARepetitionPRBUtilization_pct_Num) SEA_VoNR_PuschTypeARepetitionPRBUtilization_pct_Num,
					  SUM(SEA_VoNR_PuschTypeARepetitionPRBUtilization_pct_Denom) SEA_VoNR_PuschTypeARepetitionPRBUtilization_pct_Denom,
					  SUM(SEA_VoNR_PuschTypeARepetitionActivationRate_pct_Num) SEA_VoNR_PuschTypeARepetitionActivationRate_pct_Num,
					  SUM(SEA_VoNR_PuschTypeARepetitionActivationRate_pct_Denom) SEA_VoNR_PuschTypeARepetitionActivationRate_pct_Denom,
					  SUM(SEA_VoNR_PuschTypeARepetitionDeActivationRate_pct_Num) SEA_VoNR_PuschTypeARepetitionDeActivationRate_pct_Num,
					  SUM(SEA_VoNR_PuschTypeARepetitionDeActivationRate_pct_Denom) SEA_VoNR_PuschTypeARepetitionDeActivationRate_pct_Denom,
					  SUM(SEA_VoNR_AvgNoERAB_5QI1_Num) SEA_VoNR_AvgNoERAB_5QI1_Num,
					  SUM(SEA_VoNR_AvgNoERAB_5QI1_Denom) SEA_VoNR_AvgNoERAB_5QI1_Denom,
					  SUM(SEA_VoNR_AvgNoERAB_5QI5_Num) SEA_VoNR_AvgNoERAB_5QI5_Num,
					  SUM(SEA_VoNR_AvgNoERAB_5QI5_Denom) SEA_VoNR_AvgNoERAB_5QI5_Denom,
					  MAX(SEA_VoNR_MaxNoERAB_5QI1) SEA_VoNR_MaxNoERAB_5QI1,
					  SUM(SEA_VoNR_DLRLCLayDataVol_5QI1_MB) SEA_VoNR_DLRLCLayDataVol_5QI1_MB,
					  SUM(SEA_VoNR_DLRLCLayDataVol_5QI5_MB) SEA_VoNR_DLRLCLayDataVol_5QI5_MB,
					  SUM(SEA_VoNR_ULRLCLayerDataVol_5QI1_MB) SEA_VoNR_ULRLCLayerDataVol_5QI1_MB,
					  SUM(SEA_VoNR_ULRLCLayerDataVol_5QI5_MB) SEA_VoNR_ULRLCLayerDataVol_5QI5_MB,
					  SUM(SEA_VoNR_DL_PRB_Used_5QI1) SEA_VoNR_DL_PRB_Used_5QI1,
					  SUM(SEA_VoNR_UL_PRB_Used_5QI1) SEA_VoNR_UL_PRB_Used_5QI1,
					  SUM(SEA_VoNR_DL_PRB_Utilization_Rate_Num) SEA_VoNR_DL_PRB_Utilization_Rate_Num,
					  SUM(SEA_VoNR_DL_PRB_Utilization_Rate_Denom) SEA_VoNR_DL_PRB_Utilization_Rate_Denom,
					  SUM(SEA_VoNR_UL_PRB_Utilization_Rate_Num) SEA_VoNR_UL_PRB_Utilization_Rate_Num,
					  SUM(SEA_VoNR_UL_PRB_Utilization_Rate_Denom) SEA_VoNR_UL_PRB_Utilization_Rate_Denom,
					  SUM(SEA_VoNR_DL_HARQ_Init_Fail_pct_5QI1) SEA_VoNR_DL_HARQ_Init_Fail_pct_5QI1,
					  SUM(SEA_VoNR_DL_rBLER_5QI1) SEA_VoNR_DL_rBLER_5QI1,
					  SUM(SEA_VoNR_DL_HARQ_Success_5QI1) SEA_VoNR_DL_HARQ_Success_5QI1,
					  SUM(SEA_VoNR_DL_Residual_BLER_Rate_5QI1_Num) SEA_VoNR_DL_Residual_BLER_Rate_5QI1_Num,
					  SUM(SEA_VoNR_DL_Residual_BLER_Rate_5QI1_Denom) SEA_VoNR_DL_Residual_BLER_Rate_5QI1_Denom,
					  SUM(SEA_VoNR_UL_HARQ_Fail_5QI1) SEA_VoNR_UL_HARQ_Fail_5QI1,
					  SUM(SEA_VoNR_UL_HARQ_Fail_Rate_5QI1_Num) SEA_VoNR_UL_HARQ_Fail_Rate_5QI1_Num,
					  SUM(SEA_VoNR_UL_HARQ_Fail_Rate_5QI1_Denom) SEA_VoNR_UL_HARQ_Fail_Rate_5QI1_Denom,
					  SUM(SEA_VoNR_UL_HARQ_Init_Fail_pct_5QI1_Num) SEA_VoNR_UL_HARQ_Init_Fail_pct_5QI1_Num,
					  SUM(SEA_VoNR_UL_HARQ_Init_Fail_pct_5QI1_Denom) SEA_VoNR_UL_HARQ_Init_Fail_pct_5QI1_Denom,
					  SUM(SEA_VoNR_UL_HARQ_Success_5QI1) SEA_VoNR_UL_HARQ_Success_5QI1,
					  SUM(SEA_VoNR_UL_Residual_BLER_Rate_5QI1_Num) SEA_VoNR_UL_Residual_BLER_Rate_5QI1_Num,
					  SUM(SEA_VoNR_UL_Residual_BLER_Rate_5QI1_Denom) SEA_VoNR_UL_Residual_BLER_Rate_5QI1_Denom,
					  SUM(SEA_VoNR_AverageCQI_Num) SEA_VoNR_AverageCQI_Num,
					  SUM(SEA_VoNR_AverageCQI_Denom) SEA_VoNR_AverageCQI_Denom,
					  SUM(SEA_VoNR_PdcpsdudelayDL_5QI1_ms_Num) SEA_VoNR_PdcpsdudelayDL_5QI1_ms_Num,
					  SUM(SEA_VoNR_PdcpsdudelayDL_5QI1_ms_Denom) SEA_VoNR_PdcpsdudelayDL_5QI1_ms_Denom,
					  SUM(SEA_VoNR_PdcpsdudelayDL_5QI5_ms_Num) SEA_VoNR_PdcpsdudelayDL_5QI5_ms_Num,
					  SUM(SEA_VoNR_PdcpsdudelayDL_5QI5_ms_Denom) SEA_VoNR_PdcpsdudelayDL_5QI5_ms_Denom,
					  SUM(SEA_VoNR_ULPDCPPacketLossRate_5QI1_Num) SEA_VoNR_ULPDCPPacketLossRate_5QI1_Num,
					  SUM(SEA_VoNR_ULPDCPPacketLossRate_5QI1_Denom) SEA_VoNR_ULPDCPPacketLossRate_5QI1_Denom,
					  SUM(SEA_VoNR_PdcpIpLatencyDL_5QI1_ms_CellLevel_Num) SEA_VoNR_PdcpIpLatencyDL_5QI1_ms_CellLevel_Num,
					  SUM(SEA_VoNR_PdcpIpLatencyDL_5QI1_ms_CellLevel_Denom) SEA_VoNR_PdcpIpLatencyDL_5QI1_ms_CellLevel_Denom,
					  SUM(SEA_VoNR_PdcpIpLatencyDL_5QI5_ms_CellLevel_Num) SEA_VoNR_PdcpIpLatencyDL_5QI5_ms_CellLevel_Num,
					  SUM(SEA_VoNR_PdcpIpLatencyDL_5QI5_ms_CellLevel_Denom) SEA_VoNR_PdcpIpLatencyDL_5QI5_ms_CellLevel_Denom,
					  SUM(SEA_VoNR_DL_Quality_Defect) SEA_VoNR_DL_Quality_Defect,
					  SUM(SEA_VoNR_UL_Quality_Defect) SEA_VoNR_UL_Quality_Defect,
					  SUM(SEA_VoNR_RTP_GAP_Duration_sec) SEA_VoNR_RTP_GAP_Duration_sec,
					  SUM(SEA_VoNR_RTP_SESSION_Duration_Sec) SEA_VoNR_RTP_SESSION_Duration_Sec,
					  SUM(SEA_VoNR_EPCFallback_success_rate_Num) SEA_VoNR_EPCFallback_success_rate_Num,
					  SUM(SEA_VoNR_EPCFallback_success_rate_Denom) SEA_VoNR_EPCFallback_success_rate_Denom	 
					";
SET VAR InsertStr  = "
                      Insert into apachedataingestion.nr.widetable_5g_vonr_dy_gold2
                      with v_widetable_5g_vonr_hr_gold2 as (
                        select * from apachedataingestion.nr.widetable_5g_vonr_hr_gold2 where CalendarDate = date_format(date_add(now(), " || :days ||"),'yyyy-MM-dd')  
                      )
                      select 
						  '24hr' MW_BH,
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME,
                          "|| ColumnStr ||"
					  from  v_widetable_5g_vonr_hr_gold2
					  group by 
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME
                union all
                      select 
                        'MW_Excluded' MW_BH,
                        frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME,
                          "|| ColumnStr ||"
					  from  v_widetable_5g_vonr_hr_gold2
					  where Hour24 >= 6
					  group by 
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME
                union all
                      select 
                        'FBH_20' MW_BH,
                        frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME,
                          "|| ColumnStr ||"
					  from  v_widetable_5g_vonr_hr_gold2
					  where Hour24=20
					  group by 
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME
                union all
                      select 
                        'FBH_15' MW_BH,
                        frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME,
                          "|| ColumnStr ||"
					  from  v_widetable_5g_vonr_hr_gold2
					  where Hour24=15
					  group by 
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME
                      ";


EXECUTE IMMEDIATE InsertStr;
