-- %%
delete from hive_metastore.default.widetable_5g_cell_hr_tmp1;

insert into hive_metastore.default.widetable_5g_cell_hr_tmp1 
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	-- select count(distinct concat(GNODEB_ID,'_',DU_ID,'_',GCELL_ID)) --514527
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							-- select count(*)
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
)
select 
CalendarDate ,
Hour24 ,
GNODEB_ID,
du_id ,
GCELL_ID ,
MARKET_NAME ,
case when length(du_id)=14 then 
	case when substring(du_id, 7, 1)=0 then 'FR2' 	 when substring(du_id, 7, 1)=9 then 
				case when substring(du_id, 11, 1)=2 then 'FR1/LS3' when substring(du_id, 11, 1)=3 then 'FR1/LS6' 
				end
	end
else '' end NR_TYPE,
substring(du_id,4,3) SUB_MARKET_ID,
SUB_MARKET_NAME ,
max(ENDC_Drop_Rate_NUM) ENDC_Drop_Rate_NUM,
max(ENDC_Drop_Rate_DENOM) ENDC_Drop_Rate_DENOM,
max(S5NR_ReConfigurationFailureRate_PCT_22A_Num) S5NR_ReConfigurationFailureRate_PCT_22A_Num,
max(S5NR_ReConfigurationFailureRate_PCT_22A_Denom) S5NR_ReConfigurationFailureRate_PCT_22A_Denom,
max(S5NR_AdditionFailureRate_NoResources_PCT_22A_Num) S5NR_AdditionFailureRate_NoResources_PCT_22A_Num,
max(S5NR_AdditionFailureRate_NoResources_PCT_22A_Denom) S5NR_AdditionFailureRate_NoResources_PCT_22A_Denom,
max(S5NR_IntragNBHOFailRate_PCT_Num) S5NR_IntragNBHOFailRate_PCT_Num,
max(S5NR_IntragNBHOFailRate_PCT_Denom) S5NR_IntragNBHOFailRate_PCT_Denom,
max(S5NR_IntergNBHOFailRate_PCT_Num) S5NR_IntergNBHOFailRate_PCT_Num,
max(S5NR_IntergNBHOFailRate_PCT_Denom) S5NR_IntergNBHOFailRate_PCT_Denom,
max(S5NR_AvgRRCconnectedUsersPerCell_Num) S5NR_AvgRRCconnectedUsersPerCell_Num,
max(S5NR_AvgRRCconnectedUsersPerCell_Denom) S5NR_AvgRRCconnectedUsersPerCell_Denom,
max(S5NR_DLMACLayerDataVolume_MB) S5NR_DLMACLayerDataVolume_MB,
max(S5NR_ULMACLayerDataVolume_MB) S5NR_ULMACLayerDataVolume_MB,
max(S5NR_DLUserPerceivedTput_Mbps_Num) S5NR_DLUserPerceivedTput_Mbps_Num,
max(S5NR_DLUserPerceivedTput_Mbps_DENOM) S5NR_DLUserPerceivedTput_Mbps_DENOM,
max(S5NR_ULUserPerceivedTput_Mbps_NUM) S5NR_ULUserPerceivedTput_Mbps_NUM,
max(S5NR_ULUserPerceivedTput_Mbps_DENOM) S5NR_ULUserPerceivedTput_Mbps_DENOM,
max(S5NR_CA_AvgNumCC_NUM) S5NR_CA_AvgNumCC_NUM,
max(S5NR_CA_AvgNumCC_DENOM) S5NR_CA_AvgNumCC_DENOM,
max(S5NR_TotalERABSetupFailureRate_PCT_Num) S5NR_TotalERABSetupFailureRate_PCT_Num,
max(S5NR_TotalERABSetupFailureRate_PCT_Denom) S5NR_TotalERABSetupFailureRate_PCT_Denom,
max(S5NR_MaxRRCconnectedUsersPerCell) S5NR_MaxRRCconnectedUsersPerCell,
max(S5NR_TotalDLRLCLayerDataVolume_MB) S5NR_TotalDLRLCLayerDataVolume_MB,
max(S5NR_TotalULRLCLayerDataVolume_MB) S5NR_TotalULRLCLayerDataVolume_MB,
max(S5NR_DLMACcellAggregateTput_Mbps_Num) S5NR_DLMACcellAggregateTput_Mbps_Num,
max(S5NR_DLMACcellAggregateTput_Mbps_Denom) S5NR_DLMACcellAggregateTput_Mbps_Denom,
max(S5NR_ULMACcellAggregateTput_Mbps_Num) S5NR_ULMACcellAggregateTput_Mbps_Num,
max(S5NR_ULMACcellAggregateTput_Mbps_Denom) S5NR_ULMACcellAggregateTput_Mbps_Denom,
max(S5NR_DLTTIUtilization_Pct_Num) S5NR_DLTTIUtilization_Pct_Num,
max(S5NR_DLTTIUtilization_Pct_Denom) S5NR_DLTTIUtilization_Pct_Denom,
max(S5NR_ULTTIUtilization_PCT_Num) S5NR_ULTTIUtilization_PCT_Num,
max(S5NR_ULTTIUtilization_PCT_Denom) S5NR_ULTTIUtilization_PCT_Denom,
max(S5NR_DLRLCReTx_PCT_Num) S5NR_DLRLCReTx_PCT_Num,
max(S5NR_DLRLCReTx_PCT_Denom) S5NR_DLRLCReTx_PCT_Denom,
max(AIR_MAC_BYTES_AirMacDLByte) AIR_MAC_BYTES_AirMacDLByte,
max(AIR_MAC_BYTES_AirMacULByte) AIR_MAC_BYTES_AirMacULByte,
max(UL_MIMO_ULNumPuschAvailableSlots) UL_MIMO_ULNumPuschAvailableSlots,
max(DL_MIMO_DLNumPdschAvailableSlots) DL_MIMO_DLNumPdschAvailableSlots,
max(CaUeNum_perCC8Tot) CaUeNum_perCC8Tot,
max(CaUeNum_perCC8Cnt) CaUeNum_perCC8Cnt,
max(CaUeNum_perCC7Tot) CaUeNum_perCC7Tot,
max(CaUeNum_perCC7Cnt) CaUeNum_perCC7Cnt,
max(CaUeNum_perCC6Tot) CaUeNum_perCC6Tot,
max(CaUeNum_perCC6Cnt) CaUeNum_perCC6Cnt,
max(CaUeNum_perCC5Tot) CaUeNum_perCC5Tot,
max(CaUeNum_perCC5Cnt) CaUeNum_perCC5Cnt,
max(CaUeNum_perCC4Tot) CaUeNum_perCC4Tot,
max(CaUeNum_perCC4Cnt) CaUeNum_perCC4Cnt,
max(CaUeNum_perCC3Tot) CaUeNum_perCC3Tot,
max(CaUeNum_perCC3Cnt) CaUeNum_perCC3Cnt,
max(CaUeNum_perCC2Tot) CaUeNum_perCC2Tot,
max(CaUeNum_perCC2Cnt) CaUeNum_perCC2Cnt,
max(CaUeNum_perCC1Tot) CaUeNum_perCC1Tot,
max(CaUeNum_perCC1Cnt) CaUeNum_perCC1Cnt,
max(ULNumSuRank2UEs) ULNumSuRank2UEs,
max(ULNumScheduledUEs) ULNumScheduledUEs,
max(ULNumMuMimoUEs) ULNumMuMimoUEs,
-- add
max(S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Num) S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Num,
max(S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Denom) S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Denom,
max(S5NR_AvgNumMuMimoUePerSlot_UL_Num) S5NR_AvgNumMuMimoUePerSlot_UL_Num,
max(S5NR_AvgNumMuMimoUePerSlot_UL_Denom) S5NR_AvgNumMuMimoUePerSlot_UL_Denom,
max(S5NR_MuMimoUsedPrbRatio_UL_PCT_Num) S5NR_MuMimoUsedPrbRatio_UL_PCT_Num,
max(S5NR_MuMimoUsedPrbRatio_UL_PCT_Denom) S5NR_MuMimoUsedPrbRatio_UL_PCT_Denom,
max(S5NR_AvgNumLayerPerSlot_UL_Num) S5NR_AvgNumLayerPerSlot_UL_Num,
max(S5NR_AvgNumLayerPerSlot_UL_Denom) S5NR_AvgNumLayerPerSlot_UL_Denom,
-- add qci
max(S5NR_TotalDLRLCLayerDataVolume_MB_QCI8) S5NR_TotalDLRLCLayerDataVolume_MB_QCI8,
max(S5NR_TotalDLRLCLayerDataVolume_MB_QCI132) S5NR_TotalDLRLCLayerDataVolume_MB_QCI132,
max(S5NR_TotalULRLCLayerDataVolume_MB_QCI8) S5NR_TotalULRLCLayerDataVolume_MB_QCI8,
max(S5NR_TotalULRLCLayerDataVolume_MB_QCI132) S5NR_TotalULRLCLayerDataVolume_MB_QCI132,
max(S5NR_DLUserPerceivedTput_Mbps_QCI8_Num) S5NR_DLUserPerceivedTput_Mbps_QCI8_Num,
max(S5NR_DLUserPerceivedTput_Mbps_QCI8_Denom) S5NR_DLUserPerceivedTput_Mbps_QCI8_Denom,
max(S5NR_DLUserPerceivedTput_Mbps_QCI132_Num) S5NR_DLUserPerceivedTput_Mbps_QCI132_Num,
max(S5NR_DLUserPerceivedTput_Mbps_QCI132_Denom) S5NR_DLUserPerceivedTput_Mbps_QCI132_Denom,
max(DLNumScheduledUEs) DLNumScheduledUEs,
--Added new counters on 1/23/2025 DENG-2659
max(S5NC_ERABSetupFailureRate_PCT_Mobility_Num) S5NC_ERABSetupFailureRate_PCT_Mobility_Num,
max(S5NC_ERABSetupFailureRate_PCT_Mobility_Denom) S5NC_ERABSetupFailureRate_PCT_Mobility_Denom
from (
			select 
			COALESCE(M0.CalendarDate,T1.CalendarDate,T2.CalendarDate,T3.CalendarDate,T4.CalendarDate,T5.CalendarDate,T6.CalendarDate,T7.CalendarDate,T8.CalendarDate,T9.CalendarDate,T10.CalendarDate,T11.CalendarDate,T12.CalendarDate) CalendarDate,
			COALESCE(M0.Hour24,T1.Hour24,T2.Hour24,T3.Hour24,T4.Hour24,T5.Hour24,T6.Hour24,T7.Hour24,T8.Hour24,T9.Hour24,T10.Hour24,T11.Hour24,T12.Hour24) Hour24,
			COALESCE(M0.GNODEB_ID,T1.GNODEB_ID,T2.GNODEB_ID,T3.GNODEB_ID,T4.GNODEB_ID,T5.GNODEB_ID,T6.GNODEB_ID,T7.GNODEB_ID,T8.GNODEB_ID,T9.GNODEB_ID,T10.GNODEB_ID,T11.GNODEB_ID,T12.GNODEB_ID) GNODEB_ID,
			COALESCE(M0.du_id,T1.du_id,T2.du_id,T3.du_id,T4.du_id,T5.du_id,T6.du_id,T7.du_id,T8.du_id,T9.du_id,T10.du_id,T11.du_id,T12.du_id) du_id,
			COALESCE(M0.GCELL_ID,T1.GCELL_ID,T2.GCELL_ID,T3.GCELL_ID,T4.GCELL_ID,T5.GCELL_ID,T6.GCELL_ID,T7.GCELL_ID,T8.GCELL_ID,T9.GCELL_ID,T10.GCELL_ID,T11.GCELL_ID,T12.GCELL_ID) GCELL_ID,
			COALESCE(M0.MARKET_NAME,T1.MARKET_NAME,T2.MARKET_NAME,T3.MARKET_NAME,T4.MARKET_NAME,T5.MARKET_NAME,T6.MARKET_NAME,T7.MARKET_NAME,T8.MARKET_NAME,T9.MARKET_NAME,T10.MARKET_NAME,T11.MARKET_NAME,T12.MARKET_NAME) MARKET_NAME,
			COALESCE(M0.SUB_MARKET_NAME,T1.SUB_MARKET_NAME,T2.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T4.SUB_MARKET_NAME,T5.SUB_MARKET_NAME,T6.SUB_MARKET_NAME,T7.SUB_MARKET_NAME,T8.SUB_MARKET_NAME,T9.SUB_MARKET_NAME,T10.SUB_MARKET_NAME,T11.SUB_MARKET_NAME,T12.SUB_MARKET_NAME) SUB_MARKET_NAME,
			/*Total_CRR_NUM ENDC_Drop_Rate_NUM,
			Total_CRR_DENOM+nvl(EndcIntraChgSucc,0) ENDC_Drop_Rate_DENOM, */
			nvl(Total_CRR_NUM,0) ENDC_Drop_Rate_NUM,			
			nvl(Total_CRR_DENOM,0)+nvl(EndcIntraChgSucc,0) ENDC_Drop_Rate_DENOM,
			(EndcAddAtt - EndcAddSucc) S5NR_ReConfigurationFailureRate_PCT_22A_Num,
			(EndcAddAtt) S5NR_ReConfigurationFailureRate_PCT_22A_Denom,
            (EndcAddPrepFail_CpFail+EndcAddPrepFail_UpFail+EndcAddPrepFail_DuFail) S5NR_AdditionFailureRate_NoResources_PCT_22A_Num,
            (EndcAddAtt) S5NR_AdditionFailureRate_NoResources_PCT_22A_Denom,
            (EndcIntraChgAtt-EndcIntraChgSucc)  S5NR_IntragNBHOFailRate_PCT_Num,
            (EndcIntraChgAtt)  S5NR_IntragNBHOFailRate_PCT_Denom,
            (EndcInterChgSrcAtt-EndcInterChgSrcSucc) S5NR_IntergNBHOFailRate_PCT_Num,
            (EndcInterChgSrcAtt)  S5NR_IntergNBHOFailRate_PCT_Denom,
            (UeNoTot)	S5NR_AvgRRCconnectedUsersPerCell_Num,
            (UeNoCnt)   S5NR_AvgRRCconnectedUsersPerCell_Denom,
			AirMacDLByte/1000 S5NR_DLMACLayerDataVolume_MB, 
			AirMacULByte/1000 S5NR_ULMACLayerDataVolume_MB,
			(8 * DLUeThruVol/1000) S5NR_DLUserPerceivedTput_Mbps_NUM,
			(DLUeThruTime/  power(10,6)) S5NR_DLUserPerceivedTput_Mbps_DENOM,
			(8 * ULUeThruVol/1000) S5NR_ULUserPerceivedTput_Mbps_NUM,
			(ULUeThruTime/ 8000)  S5NR_ULUserPerceivedTput_Mbps_DENOM,
			S5NR_CA_AvgNumCC_NUM,
			S5NR_CA_AvgNumCC_DENOM,
			ErabAddAtt-ErabAddSucc S5NR_TotalERABSetupFailureRate_PCT_Num, 
			ErabAddAtt  S5NR_TotalERABSetupFailureRate_PCT_Denom,
			UeNoMax S5NR_MaxRRCconnectedUsersPerCell,
			RlcDLByte/1000 S5NR_TotalDLRLCLayerDataVolume_MB,
			RlcULByte/1000 S5NR_TotalULRLCLayerDataVolume_MB,
			(0.8 * 8 * AirMacDLByte / 1000) S5NR_DLMACcellAggregateTput_Mbps_Num,
			DLNumScheduledSlots / 8000 S5NR_DLMACcellAggregateTput_Mbps_Denom,
			(0.2 * 8 * AirMacULByte / 1000) S5NR_ULMACcellAggregateTput_Mbps_Num,
			ULNumScheduledSlots / 8000 S5NR_ULMACcellAggregateTput_Mbps_Denom,
			DLNumScheduledSlots	 S5NR_DLTTIUtilization_Pct_Num,
			DLNumPdschAvailableSlots S5NR_DLTTIUtilization_Pct_Denom,			
			ULNumScheduledSlots	S5NR_ULTTIUtilization_PCT_Num,
			ULNumPuschAvailableSlots S5NR_ULTTIUtilization_PCT_Denom,
			RlcDLRePktCnt	S5NR_DLRLCReTx_PCT_Num,
			RlcDLPktCnt S5NR_DLRLCReTx_PCT_Denom,
			AirMacDLByte		  AIR_MAC_BYTES_AirMacDLByte,         
			AirMacULByte		  AIR_MAC_BYTES_AirMacULByte,                    
			ULNumPuschAvailableSlots  UL_MIMO_ULNumPuschAvailableSlots,   
			DLNumPdschAvailableSlots  DL_MIMO_DLNumPdschAvailableSlots,
			CaUeNum_perCC8Tot, 
			CaUeNum_perCC8Cnt, 
			CaUeNum_perCC7Tot, 
			CaUeNum_perCC7Cnt, 
			CaUeNum_perCC6Tot, 
			CaUeNum_perCC6Cnt, 
			CaUeNum_perCC5Tot, 
			CaUeNum_perCC5Cnt, 
			CaUeNum_perCC4Tot, 
			CaUeNum_perCC4Cnt, 
			CaUeNum_perCC3Tot, 
			CaUeNum_perCC3Cnt, 
			CaUeNum_perCC2Tot, 
			CaUeNum_perCC2Cnt, 
			CaUeNum_perCC1Tot, 
			CaUeNum_perCC1Cnt,
			ULNumSuRank2UEs,
			ULNumScheduledUEs,
			ULNumMuMimoUEs,
			-- add
			(2*ULNum2LayerAlloc+3*ULNum3LayerAlloc+4*ULNum4LayerAlloc+5*ULNum5LayerAlloc+6*ULNum6LayerAlloc+7*ULNum7LayerAlloc+8*ULNum8LayerAlloc)	S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Num,
			(ULNum2LayerAlloc+ULNum3LayerAlloc+ULNum4LayerAlloc+ULNum5LayerAlloc+ULNum6LayerAlloc+ULNum7LayerAlloc+ULNum8LayerAlloc) S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Denom,
			ULNumMuMimoUEs	S5NR_AvgNumMuMimoUePerSlot_UL_Num,
			ULNumScheduledSlots S5NR_AvgNumMuMimoUePerSlot_UL_Denom,
			(ULNumUsedPRBs2L + ULNumUsedPRBs3L + ULNumUsedPRBs4L + ULNumUsedPRBs5L + ULNumUsedPRBs6L + ULNumUsedPRBs7L + ULNumUsedPRBs8L) 	S5NR_MuMimoUsedPrbRatio_UL_PCT_Num,			
			(ULNumUsedPRBs1L + ULNumUsedPRBs2L + ULNumUsedPRBs3L + ULNumUsedPRBs4L + ULNumUsedPRBs5L + ULNumUsedPRBs6L + ULNumUsedPRBs7L + ULNumUsedPRBs8L) S5NR_MuMimoUsedPrbRatio_UL_PCT_Denom,
			(1*ULNum1LayerAlloc+2*ULNum2LayerAlloc+3*ULNum3LayerAlloc+4*ULNum4LayerAlloc+5*ULNum5LayerAlloc+6*ULNum6LayerAlloc+7*ULNum7LayerAlloc+8*ULNum8LayerAlloc)	S5NR_AvgNumLayerPerSlot_UL_Num,
			(ULNum1LayerAlloc+ULNum2LayerAlloc+ULNum3LayerAlloc+ULNum4LayerAlloc+ULNum5LayerAlloc+ULNum6LayerAlloc+ULNum7LayerAlloc+ULNum8LayerAlloc) S5NR_AvgNumLayerPerSlot_UL_Denom,
			-- add qci
			RlcDLByte_QCI8/1000 S5NR_TotalDLRLCLayerDataVolume_MB_QCI8,
			RlcDLByte_QCI132/1000 S5NR_TotalDLRLCLayerDataVolume_MB_QCI132,
			RlcULByte_QCI8/1000 S5NR_TotalULRLCLayerDataVolume_MB_QCI8,
			RlcULByte_QCI132/1000 S5NR_TotalULRLCLayerDataVolume_MB_QCI132,
			(8 * DLUeThruVol_QCI8/1000) S5NR_DLUserPerceivedTput_Mbps_QCI8_NUM,
			(DLUeThruTime_QCI8/  power(10,6)) S5NR_DLUserPerceivedTput_Mbps_QCI8_DENOM,
			(8 * DLUeThruVol_QCI132/1000) S5NR_DLUserPerceivedTput_Mbps_QCI132_NUM,
			(DLUeThruTime_QCI132/  power(10,6)) S5NR_DLUserPerceivedTput_Mbps_QCI132_DENOM,
			DLNumScheduledUEs,
			--Added new counters on 1/23/2025 DENG-2659
			((ErabAddAtt - ErabAddSucc) - (ErabAddAtt_QCI132 - ErabAddSucc_QCI132)) S5NC_ERABSetupFailureRate_PCT_Mobility_Num,
			(ErabAddAtt - ErabAddAtt_QCI132) S5NC_ERABSetupFailureRate_PCT_Mobility_Denom
			
			from (
					select CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
							SUM(EndcIntraChgAtt) EndcIntraChgAtt, 
							SUM(EndcIntraChgSucc) EndcIntraChgSucc 
					from (
								SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
									SUM(EndcIntraChgAtt_count_SUM) EndcIntraChgAtt, 
									SUM(EndcIntraChgSucc_count_SUM) EndcIntraChgSucc 
									-- select *
								from apachedataingestion.nr.intrasnpscellchangepergnb_nr_hr_silver a
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[1],'SrcCellIdentity','')=b.gcell_id                      
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
							union all
								SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
									SUM(EndcIntraChgAtt_count_SUM) EndcIntraChgAtt, 
									SUM(EndcIntraChgSucc_count_SUM) EndcIntraChgSucc 
								from apachedataingestion.nr.intrasnpscellchangepergnbwithduidentifier_nr_hr_silver  a
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
					) x GROUP BY CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) M0 
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,  
						sum(
							_0x1000_CauseInternalTmOutRrcConnectionReconfig_count_SUM+ _0x1001_CauseInternalTmOutF1UeContextSetup_count_SUM+ _0x1002_CauseInternalTmOutE1BearerSetup_count_SUM+ _0x1003_CauseInternalTmOutE1BearerContextModification_count_SUM+ _0x1004_CauseInternalTmOutF1UeContextModification_count_SUM+ _0x1005_CauseInternalTmOutF1UeContextRelease_count_SUM+ _0x1006_CauseInternalTmOutX2SgnbReconfigurationComplete_count_SUM+ _0x1007_CauseInternalTmOutX2ModificationConfirm_count_SUM+ _0x1008_CauseInternalTmOutInternalResourceSetup_count_SUM+ _0x1009_CauseInternalF1SctpOutOfService_count_SUM+ _0x100A_CauseInternalE1SctpOutOfService_count_SUM+ _0x100B_CauseInternalX2SctpOutOfService_count_SUM+ _0x100C_CauseInternalMDSSendFail_count_SUM+ _0x100D_CauseInternalCacCallCountOver_count_SUM+ _0x100E_CauseInternalNotSupportedQci_count_SUM+ _0x100F_CauseInternalInvalidCallContext_count_SUM+ _0x1010_CauseInternalResourceAllocFail_count_SUM+ _0x1013_CauseInternalCellRelease_count_SUM+ _0x1014_CauseInternalCallAllocationFail_count_SUM+ _0x1015_CauseInternalUpAllocationFail_count_SUM+ _0x1016_CauseInternalInvalidCallId_count_SUM+ _0x1017_CauseInternalInvalidPlmn_count_SUM+ _0x1019_CauseInternalT310Expiry_count_SUM+ _0x101A_CauseInternalRandomAccessProblem_count_SUM+ _0x101B_CauseInternalRlcMaxNumRetx_count_SUM+ _0x101C_CauseInternalScgChangeFailure_count_SUM+ _0x101D_CauseInternalScgReconfigFailure_count_SUM+ _0x101E_CauseInternalSrb3IntegrityFailure_count_SUM+ _0x2000_CauseF1apRadioUnspecified_count_SUM+ _0x2001_CauseF1apRadioRLFailure_count_SUM+ _0x2002_CauseF1apRadioUnknownOrAlreadyAllocatedCuUeF1apId_count_SUM+ _0x2003_CauseF1apRadioUnknownOrAlreadyAllocatedDuUeF1apId_count_SUM+ _0x2004_CauseF1apRadioUnknownInconsistentPairOfUeF1apId_count_SUM+ _0x2005_CauseF1apRadioInteraction_count_SUM+ _0x2006_CauseF1apRadioNotSupportedQCI_count_SUM+ _0x2007_CauseF1apRadioDesirableRadioReasons_count_SUM+ _0x2008_CauseF1apRadioUnavailableRadioReasons_count_SUM+ _0x2009_CauseF1apRadioProcedureCancelled_count_SUM+ _0x200A_CauseF1apRadioNormalRelease_count_SUM+ _0x200B_CauseF1apRadioCellNotAvailable_count_SUM+ _0x200C_CauseF1apRadioRLFailureothers_count_SUM+ _0x200D_CauseF1apRadioUeRejection_count_SUM+ _0x200E_CauseF1apRadioResourcesNotAvailableForTheSlice_count_SUM+ _0x2100_CauseF1apTransportUnspecified_count_SUM+ _0x2101_CauseF1apTransportResourceUnavailable_count_SUM+ _0x2200_CauseF1apProtocolTransferSyntaxError_count_SUM+ _0x2201_CauseF1apProtocolAbstractSyntaxErrorReject_count_SUM+ _0x2202_CauseF1apProtocolAbstractSyntaxErrorIgnore_count_SUM+ _0x2203_CauseF1apProtocolMessageNotCompatible_count_SUM+ _0x2204_CauseF1apProtocolSemanticError_count_SUM+ _0x2205_CauseF1apProtocolAbstractSyntaxError_count_SUM+ _0x2206_CauseF1apProtocolUnspecified_count_SUM+ _0x2300_CauseF1apMiscControlProcessingOverload_count_SUM+ _0x2301_CauseF1apMiscUnavailableResources_count_SUM+ _0x2302_CauseF1apMiscHardwareFailure_count_SUM+ _0x2304_CauseF1apMiscUnspecifiedFailure_count_SUM+ _0x4004_CauseX2apRadioNetworkLayerPartialHandover_count_SUM+ _0x4005_CauseX2apRadioNetworkLayerUnknownNewEnbUeX2apId_count_SUM+ _0x4006_CauseX2apRadioNetworkLayerUnknownOldEnbUeX2apId_count_SUM+ _0x4007_CauseX2apRadioNetworkLayerUnknownPairOfUeX2apId_count_SUM+ _0x4008_CauseX2apRadioNetworkLayerHoTargetNotAllowed_count_SUM+ _0x4009_CauseX2apRadioNetworkLayerTx2relocoverallExpiry_count_SUM+ _0x400A_CauseX2apRadioNetworkLayerTrelocoverallExpiry_count_SUM+ _0x400B_CauseX2apRadioNetworkLayerCellNotAvailable_count_SUM+ _0x400C_CauseX2apRadioNetworkLayerNoRadioResourcesAvailableInTargetCell_count_SUM+ _0x400D_CauseX2apRadioNetworkLayerInvalidMMEGroupID_count_SUM+ _0x400E_CauseX2apRadioNetworkLayerUnknownMMECode_count_SUM+ _0x400F_CauseX2apRadioNetworkLayerEncryptionAndOrIntegrityProtectionAlgorithmsNotSupported_count_SUM+ _0x4010_CauseX2apRadioNetworkLayerReportCharacteristicsEmpty_count_SUM+ _0x4011_CauseX2apRadioNetworkLayerNoReportPeriodicity_count_SUM+ _0x4012_CauseX2apRadioNetworkLayerExistingMeasurementID_count_SUM+ _0x4013_CauseX2apRadioNetworkLayerUnknownEnbMeasurementID_count_SUM+ _0x4014_CauseX2apRadioNetworkLayerMeasurementTemporarilyNotAvailable_count_SUM+ _0x4016_CauseX2apRadioNetworkLayerLoadBalancing_count_SUM+ _0x4017_CauseX2apRadioNetworkLayerHandoverOptimisation_count_SUM+ _0x4018_CauseX2apRadioNetworkLayerValueOutOfAllowedRange_count_SUM+ _0x4019_CauseX2apRadioNetworkLayerMultipleErabIdInstances_count_SUM+ _0x401A_CauseX2apRadioNetworkLayerSwitchOffOngoing_count_SUM+ _0x401B_CauseX2apRadioNetworkLayerNotSupportedQciValue_count_SUM+ _0x401C_CauseX2apRadioNetworkLayerMeasurementNotSupportedForTheObject_count_SUM+ _0x401D_CauseX2apRadioNetworkLayerTdcoverallExpiry_count_SUM+ _0x4020_CauseX2apRadioNetworkLayerReduceLoad_count_SUM+ _0x4021_CauseX2apRadioNetworkLayerResourceOptimisation_count_SUM+ _0x4023_CauseX2apRadioNetworkLayerTargetNotAllowed_count_SUM+ _0x4024_CauseX2apRadioNetworkLayerNoRadioResourcesAvailable_count_SUM+ _0x4025_CauseX2apRadioNetworkLayerInvalidQosCombination_count_SUM+ _0x4026_CauseX2apRadioNetworkLayerEncryptionAlgorithmsNotSupported_count_SUM+ _0x4027_CauseX2apRadioNetworkLayerProcedureCancelled_count_SUM+ _0x4028_CauseX2apRadioNetworkLayerRrmPurpose_count_SUM+ _0x4029_CauseX2apRadioNetworkLayerImproveUserBitRate_count_SUM+ _0x402D_CauseX2apRadioNetworkLayerBearerOptionNotSupported_count_SUM+ _0x4030_CauseX2apRadioNetworkLayerCountReachesMaxValue_count_SUM+ _0x4031_CauseX2apRadioNetworkLayerUnknownOldEngnbUeX2apId_count_SUM+ _0x4032_CauseX2apRadioNetworkLayerPdcpOverload_count_SUM+ _0x4100_CauseX2apTransportNetworkLayerTransportResourceUnavailable_count_SUM+ _0x4101_CauseX2apTransportNetworkLayerUnspecified_count_SUM+ _0x4200_CauseX2apProtocolTransferSyntaxError_count_SUM+ _0x4201_CauseX2apProtocolAbstractSyntaxErrorReject_count_SUM+ _0x4202_CauseX2apProtocolAbstractSyntaxErrorIgnoreAndNotify_count_SUM+ _0x4204_CauseX2apProtocolSemanticError_count_SUM+ _0x4205_CauseX2apProtocolUnspecified_count_SUM+ _0x4206_CauseX2apProtocolAbstractSyntaxErrorFalselyConstructedMessage_count_SUM+ _0x4300_CauseX2apMiscControlProcessingOverload_count_SUM+ _0x4301_CauseX2apMiscHardwareFailure_count_SUM+ _0x4303_CauseX2apMiscNotEnoughUserPlaneProcessingResources_count_SUM+ _0x3000_CauseE1apRadioNetworkLayerUnspecified_count_SUM+ _0x3001_CauseE1apRadioNetworkLayerUnknownOrAlreadyAllocatedGnbCuCpUeE1apId_count_SUM+ _0x3002_CauseE1apRadioNetworkLayerUnknownOrAlreadyAllocatedGnbCuUpUeE1apId_count_SUM+ _0x3003_CauseE1apRadioNetworkLayerUnknownOrInconsistentPairOfUeE1apId_count_SUM+ _0x3004_CauseE1apRadioNetworkLayerInteractionWithOtherProcedure_count_SUM+ _0x3005_CauseE1apRadioNetworkLayerPdcpCountWrapAround_count_SUM+ _0x3006_CauseE1apRadioNetworkLayerNotSupportedQciValue_count_SUM+ _0x3007_CauseE1apRadioNetworkLayerNotSupported5QiValue_count_SUM+ _0x3008_CauseE1apRadioNetworkLayerEncryptionAlgorithmsNotSupported_count_SUM+ _0x3009_CauseE1apRadioNetworkLayerIntegrityProtectionAlgorithmsNotSupported_count_SUM+ _0x300A_CauseE1apRadioNetworkLayerUpIntegrityProtectionNotPossible_count_SUM+ _0x300B_CauseE1apRadioNetworkLayerUpConfidentialityProtectionNotPossible_count_SUM+ _0x300C_CauseE1apRadioNetworkLayerMultiplePduSessionIdInstances_count_SUM+ _0x300D_CauseE1apRadioNetworkLayerUnknownPduSessionId_count_SUM+ _0x300E_CauseE1apRadioNetworkLayerMultipleQosFlowIdInstances_count_SUM+ _0x300F_CauseE1apRadioNetworkLayerUnknownQosFlowId_count_SUM+ _0x3010_CauseE1apRadioNetworkLayerMultipleDrbIdInstances_count_SUM+ _0x3011_CauseE1apRadioNetworkLayerUnknownDrbId_count_SUM+ _0x3012_CauseE1apRadioNetworkLayerInvalidQosCombination_count_SUM+ _0x3013_CauseE1apRadioNetworkLayerProcedureCancelled_count_SUM+ _0x3014_CauseE1apRadioNetworkLayerNormalRelease_count_SUM+ _0x3015_CauseE1apRadioNetworkLayerNoRadioResourcesAvailable_count_SUM+ _0x3016_CauseE1apRadioNetworkLayerActionDesirableForRadioReasons_count_SUM+ _0x3017_CauseE1apRadioNetworkLayerResourcesNotAvailableForTheSlice_count_SUM+ _0x3018_CauseE1apRadioNetworkLayerPdcpConfigurationNotSupported_count_SUM+ _0x3100_CauseE1apTransportLayerUnspecified_count_SUM+ _0x3101_CauseE1apTransportLayerTransportResourceUnavailable_count_SUM+ _0x3200_CauseE1apProtocolTransferSyntaxError_count_SUM+ _0x3201_CauseE1apProtocolAbstractSyntaxErrorReject_count_SUM+ _0x3202_CauseE1apProtocolAbstractSyntaxErrorIgnoreAndNotify_count_SUM+ _0x3203_CauseE1apProtocolMessageNotCompatibleWithReceiverState_count_SUM+ _0x3204_CauseE1apProtocolSemanticError_count_SUM+ _0x3205_CauseE1apProtocolAbstractSyntaxErrorFalselyConstructedMessage_count_SUM+ _0x3206_CauseE1apProtocolUnspecified_count_SUM+ _0x3300_CauseE1apMiscControlProcessingOverload_count_SUM+ _0x3301_CauseE1apMiscNotEnoughUserPlaneProcessingResources_count_SUM+ _0x3302_CauseE1apMiscHardwareFailure_count_SUM+ _0x3304_CauseE1apMiscUnspecified_count_SUM+ _0x1021_CauseInternalDuULRadioLinkFailure_count_SUM+ _0x1022_CauseInternalDuRlcMaxNumRetx_count_SUM+ _0x1023_CauseInternalCpSrb3IntegrityFailure_count_SUM+ _0x1024_CauseInternalCuOverload_count_SUM+ _0x1025_CauseInternalStoreRrcMessageError_count_SUM+ _0x1026_CauseInternalStoreE1MessageError_count_SUM+ _0x1027_CauseInternalStoreF1MessageError_count_SUM+ _0x1028_CauseInternalSendRrcMessageError_count_SUM+ _0x1029_CauseInternalSendE1MessageError_count_SUM+ _0x102A_CauseInternalSendF1MessageError_count_SUM+ _0x102B_CauseInternalStoreX2MessageError_count_SUM+ _0x102C_CauseInternalSendX2MessageError_count_SUM+ _0x102D_CauseInternalTmOutX2ChangeConfirm_count_SUM+ _0x102E_CauseInternalTmOutX2SNStatusTransfer_count_SUM+ _0x102F_CauseInternalSpCellSelectionFail_count_SUM+ _0x1030_CauseInternalInvalidCellId_count_SUM+ _0x200F_CauseF1apRadioAmfInitiatedAbnormalRelease_count_SUM+ _0x2010_CauseF1apRadioReleaseDueToPreEmption_count_SUM+ _0x2011_CauseF1apRadioPlmnNotServedByTheGnbCu_count_SUM+ _0x3019_CauseE1apRadioNetworkLayerUeDlMaxIPDataRateReason_count_SUM+ _0x301A_CauseE1apRadioNetworkLayerUpIntegrityProtectionFailure_count_SUM+ _0x301B_CauseE1apRadioNetworkLayerReleaseDueToPreEmption_count_SUM+ _0x1031_CauseInternalTmOutResumeForMrBased_count_SUM+ _0x1032_CauseInternalSynchReconfigFailureScg_count_SUM+ _0x1036_CauseInternalCpSrbIntegrityFailure_count_SUM+ _0x1037_CauseInternalRandomAccessProblemAfterInitialAccess_count_SUM
						)  Total_CRR_NUM,
						sum(
							_0x0000_NoFault_count_SUM+_0x1000_CauseInternalTmOutRrcConnectionReconfig_count_SUM+_0x1001_CauseInternalTmOutF1UeContextSetup_count_SUM+_0x1002_CauseInternalTmOutE1BearerSetup_count_SUM+_0x1003_CauseInternalTmOutE1BearerContextModification_count_SUM+_0x1004_CauseInternalTmOutF1UeContextModification_count_SUM+_0x1005_CauseInternalTmOutF1UeContextRelease_count_SUM+_0x1006_CauseInternalTmOutX2SgnbReconfigurationComplete_count_SUM+_0x1007_CauseInternalTmOutX2ModificationConfirm_count_SUM+_0x1008_CauseInternalTmOutInternalResourceSetup_count_SUM+_0x1009_CauseInternalF1SctpOutOfService_count_SUM+_0x100A_CauseInternalE1SctpOutOfService_count_SUM+_0x100B_CauseInternalX2SctpOutOfService_count_SUM+_0x100C_CauseInternalMDSSendFail_count_SUM+_0x100D_CauseInternalCacCallCountOver_count_SUM+_0x100E_CauseInternalNotSupportedQci_count_SUM+_0x100F_CauseInternalInvalidCallContext_count_SUM+_0x1010_CauseInternalResourceAllocFail_count_SUM+_0x1011_CauseInternalOMIntervention_count_SUM+_0x1012_CauseInternalVmScaleIn_count_SUM+_0x1013_CauseInternalCellRelease_count_SUM+_0x1014_CauseInternalCallAllocationFail_count_SUM+_0x1015_CauseInternalUpAllocationFail_count_SUM+_0x1016_CauseInternalInvalidCallId_count_SUM+_0x1017_CauseInternalInvalidPlmn_count_SUM+_0x1018_CauseInternalUserInactivity_count_SUM+_0x1019_CauseInternalT310Expiry_count_SUM+_0x101A_CauseInternalRandomAccessProblem_count_SUM+_0x101B_CauseInternalRlcMaxNumRetx_count_SUM+_0x101C_CauseInternalScgChangeFailure_count_SUM+_0x101D_CauseInternalScgReconfigFailure_count_SUM+_0x101E_CauseInternalSrb3IntegrityFailure_count_SUM+_0x101F_CauseInternalScgMobility_count_SUM+_0x1020_CauseInternalMeasurementReportBasedRelease_count_SUM+_0x2000_CauseF1apRadioUnspecified_count_SUM+_0x2001_CauseF1apRadioRLFailure_count_SUM+_0x2002_CauseF1apRadioUnknownOrAlreadyAllocatedCuUeF1apId_count_SUM+_0x2003_CauseF1apRadioUnknownOrAlreadyAllocatedDuUeF1apId_count_SUM+_0x2004_CauseF1apRadioUnknownInconsistentPairOfUeF1apId_count_SUM+_0x2005_CauseF1apRadioInteraction_count_SUM+_0x2006_CauseF1apRadioNotSupportedQCI_count_SUM+_0x2007_CauseF1apRadioDesirableRadioReasons_count_SUM+_0x2008_CauseF1apRadioUnavailableRadioReasons_count_SUM+_0x2009_CauseF1apRadioProcedureCancelled_count_SUM+_0x200A_CauseF1apRadioNormalRelease_count_SUM+_0x200B_CauseF1apRadioCellNotAvailable_count_SUM+_0x200C_CauseF1apRadioRLFailureothers_count_SUM+_0x200D_CauseF1apRadioUeRejection_count_SUM+_0x200E_CauseF1apRadioResourcesNotAvailableForTheSlice_count_SUM+_0x2100_CauseF1apTransportUnspecified_count_SUM+_0x2101_CauseF1apTransportResourceUnavailable_count_SUM+_0x2200_CauseF1apProtocolTransferSyntaxError_count_SUM+_0x2201_CauseF1apProtocolAbstractSyntaxErrorReject_count_SUM+_0x2202_CauseF1apProtocolAbstractSyntaxErrorIgnore_count_SUM+_0x2203_CauseF1apProtocolMessageNotCompatible_count_SUM+_0x2204_CauseF1apProtocolSemanticError_count_SUM+_0x2205_CauseF1apProtocolAbstractSyntaxError_count_SUM+_0x2206_CauseF1apProtocolUnspecified_count_SUM+_0x2300_CauseF1apMiscControlProcessingOverload_count_SUM+_0x2301_CauseF1apMiscUnavailableResources_count_SUM+_0x2302_CauseF1apMiscHardwareFailure_count_SUM+_0x2303_CauseF1apMiscOMIntervention_count_SUM+_0x2304_CauseF1apMiscUnspecifiedFailure_count_SUM+_0x4000_CauseX2apRadioNetworkLayerHandoverDesirableForRadioReasons_count_SUM+_0x4001_CauseX2apRadioNetworkLayerTimeCriticalHandover_count_SUM+_0x4002_CauseX2apRadioNetworkLayerResourceOptimisationHandover_count_SUM+_0x4003_CauseX2apRadioNetworkLayerReduceLoadInServingCell_count_SUM+_0x4004_CauseX2apRadioNetworkLayerPartialHandover_count_SUM+_0x4005_CauseX2apRadioNetworkLayerUnknownNewEnbUeX2apId_count_SUM+_0x4006_CauseX2apRadioNetworkLayerUnknownOldEnbUeX2apId_count_SUM+_0x4007_CauseX2apRadioNetworkLayerUnknownPairOfUeX2apId_count_SUM+_0x4008_CauseX2apRadioNetworkLayerHoTargetNotAllowed_count_SUM+_0x4009_CauseX2apRadioNetworkLayerTx2relocoverallExpiry_count_SUM+_0x400A_CauseX2apRadioNetworkLayerTrelocoverallExpiry_count_SUM+_0x400B_CauseX2apRadioNetworkLayerCellNotAvailable_count_SUM+_0x400C_CauseX2apRadioNetworkLayerNoRadioResourcesAvailableInTargetCell_count_SUM+_0x400D_CauseX2apRadioNetworkLayerInvalidMMEGroupID_count_SUM+_0x400E_CauseX2apRadioNetworkLayerUnknownMMECode_count_SUM+_0x400F_CauseX2apRadioNetworkLayerEncryptionAndOrIntegrityProtectionAlgorithmsNotSupported_count_SUM+_0x4010_CauseX2apRadioNetworkLayerReportCharacteristicsEmpty_count_SUM+_0x4011_CauseX2apRadioNetworkLayerNoReportPeriodicity_count_SUM+_0x4012_CauseX2apRadioNetworkLayerExistingMeasurementID_count_SUM+_0x4013_CauseX2apRadioNetworkLayerUnknownEnbMeasurementID_count_SUM+_0x4014_CauseX2apRadioNetworkLayerMeasurementTemporarilyNotAvailable_count_SUM+_0x4015_CauseX2apRadioNetworkLayerUnspecified_count_SUM+_0x4016_CauseX2apRadioNetworkLayerLoadBalancing_count_SUM+_0x4017_CauseX2apRadioNetworkLayerHandoverOptimisation_count_SUM+_0x4018_CauseX2apRadioNetworkLayerValueOutOfAllowedRange_count_SUM+_0x4019_CauseX2apRadioNetworkLayerMultipleErabIdInstances_count_SUM+_0x401A_CauseX2apRadioNetworkLayerSwitchOffOngoing_count_SUM+_0x401B_CauseX2apRadioNetworkLayerNotSupportedQciValue_count_SUM+_0x401C_CauseX2apRadioNetworkLayerMeasurementNotSupportedForTheObject_count_SUM+_0x401D_CauseX2apRadioNetworkLayerTdcoverallExpiry_count_SUM+_0x401E_CauseX2apRadioNetworkLayerTdcprepExpiry_count_SUM+_0x401F_CauseX2apRadioNetworkLayerActionDesirableForRadioReasons_count_SUM+_0x4020_CauseX2apRadioNetworkLayerReduceLoad_count_SUM+_0x4021_CauseX2apRadioNetworkLayerResourceOptimisation_count_SUM+_0x4022_CauseX2apRadioNetworkLayerTimeCriticalAction_count_SUM+_0x4023_CauseX2apRadioNetworkLayerTargetNotAllowed_count_SUM+_0x4024_CauseX2apRadioNetworkLayerNoRadioResourcesAvailable_count_SUM+_0x4025_CauseX2apRadioNetworkLayerInvalidQosCombination_count_SUM+_0x4026_CauseX2apRadioNetworkLayerEncryptionAlgorithmsNotSupported_count_SUM+_0x4027_CauseX2apRadioNetworkLayerProcedureCancelled_count_SUM+_0x4028_CauseX2apRadioNetworkLayerRrmPurpose_count_SUM+_0x4029_CauseX2apRadioNetworkLayerImproveUserBitRate_count_SUM+_0x402A_CauseX2apRadioNetworkLayerUserInactivity_count_SUM+_0x402B_CauseX2apRadioNetworkLayerRadioConnectionWithUeLost_count_SUM+_0x402C_CauseX2apRadioNetworkLayerFailureInTheRadioInterfaceProcedure_count_SUM+_0x402D_CauseX2apRadioNetworkLayerBearerOptionNotSupported_count_SUM+_0x402E_CauseX2apRadioNetworkLayerMcgMobility_count_SUM+_0x402F_CauseX2apRadioNetworkLayerScgMobility_count_SUM+_0x4030_CauseX2apRadioNetworkLayerCountReachesMaxValue_count_SUM+_0x4031_CauseX2apRadioNetworkLayerUnknownOldEngnbUeX2apId_count_SUM+_0x4032_CauseX2apRadioNetworkLayerPdcpOverload_count_SUM+_0x4100_CauseX2apTransportNetworkLayerTransportResourceUnavailable_count_SUM+_0x4101_CauseX2apTransportNetworkLayerUnspecified_count_SUM+_0x4200_CauseX2apProtocolTransferSyntaxError_count_SUM+_0x4201_CauseX2apProtocolAbstractSyntaxErrorReject_count_SUM+_0x4202_CauseX2apProtocolAbstractSyntaxErrorIgnoreAndNotify_count_SUM+_0x4203_CauseX2apProtocolMessageNotCompatibleWithReceiverState_count_SUM+_0x4204_CauseX2apProtocolSemanticError_count_SUM+_0x4205_CauseX2apProtocolUnspecified_count_SUM+_0x4206_CauseX2apProtocolAbstractSyntaxErrorFalselyConstructedMessage_count_SUM+_0x4300_CauseX2apMiscControlProcessingOverload_count_SUM+_0x4301_CauseX2apMiscHardwareFailure_count_SUM+_0x4302_CauseX2apMiscOMIntervention_count_SUM+_0x4303_CauseX2apMiscNotEnoughUserPlaneProcessingResources_count_SUM+_0x4304_CauseX2apMiscUnspecified_count_SUM+_0x3000_CauseE1apRadioNetworkLayerUnspecified_count_SUM+_0x3001_CauseE1apRadioNetworkLayerUnknownOrAlreadyAllocatedGnbCuCpUeE1apId_count_SUM+_0x3002_CauseE1apRadioNetworkLayerUnknownOrAlreadyAllocatedGnbCuUpUeE1apId_count_SUM+_0x3003_CauseE1apRadioNetworkLayerUnknownOrInconsistentPairOfUeE1apId_count_SUM+_0x3004_CauseE1apRadioNetworkLayerInteractionWithOtherProcedure_count_SUM+_0x3005_CauseE1apRadioNetworkLayerPdcpCountWrapAround_count_SUM+_0x3006_CauseE1apRadioNetworkLayerNotSupportedQciValue_count_SUM+_0x3007_CauseE1apRadioNetworkLayerNotSupported5QiValue_count_SUM+_0x3008_CauseE1apRadioNetworkLayerEncryptionAlgorithmsNotSupported_count_SUM+_0x3009_CauseE1apRadioNetworkLayerIntegrityProtectionAlgorithmsNotSupported_count_SUM+_0x300A_CauseE1apRadioNetworkLayerUpIntegrityProtectionNotPossible_count_SUM+_0x300B_CauseE1apRadioNetworkLayerUpConfidentialityProtectionNotPossible_count_SUM+_0x300C_CauseE1apRadioNetworkLayerMultiplePduSessionIdInstances_count_SUM+_0x300D_CauseE1apRadioNetworkLayerUnknownPduSessionId_count_SUM+_0x300E_CauseE1apRadioNetworkLayerMultipleQosFlowIdInstances_count_SUM+_0x300F_CauseE1apRadioNetworkLayerUnknownQosFlowId_count_SUM+_0x3010_CauseE1apRadioNetworkLayerMultipleDrbIdInstances_count_SUM+_0x3011_CauseE1apRadioNetworkLayerUnknownDrbId_count_SUM+_0x3012_CauseE1apRadioNetworkLayerInvalidQosCombination_count_SUM+_0x3013_CauseE1apRadioNetworkLayerProcedureCancelled_count_SUM+_0x3014_CauseE1apRadioNetworkLayerNormalRelease_count_SUM+_0x3015_CauseE1apRadioNetworkLayerNoRadioResourcesAvailable_count_SUM+_0x3016_CauseE1apRadioNetworkLayerActionDesirableForRadioReasons_count_SUM+_0x3017_CauseE1apRadioNetworkLayerResourcesNotAvailableForTheSlice_count_SUM+_0x3018_CauseE1apRadioNetworkLayerPdcpConfigurationNotSupported_count_SUM+_0x3100_CauseE1apTransportLayerUnspecified_count_SUM+_0x3101_CauseE1apTransportLayerTransportResourceUnavailable_count_SUM+_0x3200_CauseE1apProtocolTransferSyntaxError_count_SUM+_0x3201_CauseE1apProtocolAbstractSyntaxErrorReject_count_SUM+_0x3202_CauseE1apProtocolAbstractSyntaxErrorIgnoreAndNotify_count_SUM+_0x3203_CauseE1apProtocolMessageNotCompatibleWithReceiverState_count_SUM+_0x3204_CauseE1apProtocolSemanticError_count_SUM+_0x3205_CauseE1apProtocolAbstractSyntaxErrorFalselyConstructedMessage_count_SUM+_0x3206_CauseE1apProtocolUnspecified_count_SUM+_0x3300_CauseE1apMiscControlProcessingOverload_count_SUM+_0x3301_CauseE1apMiscNotEnoughUserPlaneProcessingResources_count_SUM+_0x3302_CauseE1apMiscHardwareFailure_count_SUM+_0x3303_CauseE1apMiscOMIntervention_count_SUM+_0x3304_CauseE1apMiscUnspecified_count_SUM+_0x1021_CauseInternalDuULRadioLinkFailure_count_SUM+_0x1022_CauseInternalDuRlcMaxNumRetx_count_SUM+_0x1023_CauseInternalCpSrb3IntegrityFailure_count_SUM+_0x1024_CauseInternalCuOverload_count_SUM+_0x1025_CauseInternalStoreRrcMessageError_count_SUM+_0x1026_CauseInternalStoreE1MessageError_count_SUM+_0x1027_CauseInternalStoreF1MessageError_count_SUM+_0x1028_CauseInternalSendRrcMessageError_count_SUM+_0x1029_CauseInternalSendE1MessageError_count_SUM+_0x102A_CauseInternalSendF1MessageError_count_SUM+_0x102B_CauseInternalStoreX2MessageError_count_SUM+_0x102C_CauseInternalSendX2MessageError_count_SUM+_0x102D_CauseInternalTmOutX2ChangeConfirm_count_SUM+_0x102E_CauseInternalTmOutX2SNStatusTransfer_count_SUM+_0x102F_CauseInternalSpCellSelectionFail_count_SUM+_0x1030_CauseInternalInvalidCellId_count_SUM+_0x200F_CauseF1apRadioAmfInitiatedAbnormalRelease_count_SUM+_0x2010_CauseF1apRadioReleaseDueToPreEmption_count_SUM+_0x2011_CauseF1apRadioPlmnNotServedByTheGnbCu_count_SUM+_0x3019_CauseE1apRadioNetworkLayerUeDlMaxIPDataRateReason_count_SUM+_0x301A_CauseE1apRadioNetworkLayerUpIntegrityProtectionFailure_count_SUM+_0x301B_CauseE1apRadioNetworkLayerReleaseDueToPreEmption_count_SUM+_0x1031_CauseInternalTmOutResumeForMrBased_count_SUM+_0x1032_CauseInternalSynchReconfigFailureScg_count_SUM+_0x1033_CauseInternalX2UEContextRelease_count_SUM+_0x1034_CauseInternalT312Expiry_count_SUM+_0x1035_CauseInternalBeamFailureRecoveryFailure_count_SUM+_0x2012_CauseF1apRadioMultipleDrbIdInstances_count_SUM+_0x2013_CauseF1apRadioUnknownDrbId_count_SUM+_0x2014_CauseF1apRadioMultipleBhRlcChIdInstances_count_SUM+_0x2015_CauseF1apRadioUnknownBhRlcChId_count_SUM+_0x2016_CauseF1apRadioChoCpcResourcesToBeChanged_count_SUM+_0x2017_CauseF1apRadioNpnNotSupported_count_SUM+_0x2018_CauseF1apRadioNpnAccessDenied_count_SUM+_0x2019_CauseF1apRadioGnbCuCellCapacityExceeded_count_SUM+_0x201A_CauseF1apRadioReportCharacteristicsEmpty_count_SUM+_0x201B_CauseF1apRadioExistingMeasurementID_count_SUM+_0x201C_CauseF1apRadioMeasurementTemporarilyNotAvailable_count_SUM+_0x201D_CauseF1apRadioMeasurementNotSupportedForTheObject_count_SUM+_0x201E_CauseF1apRadioUnknownBAPAddress_count_SUM+_0x201F_CauseF1apRadioUnknownBAPRoutingID_count_SUM+_0x2020_CauseF1apRadioInsufficientUeCapabilities_count_SUM+_0x2102_CauseF1apTransportUnknownTNLAddressForIAB_count_SUM+_0x2103_CauseF1apTransportUnknownUPTNLInformationForIAB_count_SUM+_0x301C_CauseE1apRadioNetworkLayerRSNNotAvailableForTheUP_count_SUM+_0x301D_CauseE1apRadioNetworkLayerNPNNotSupported_count_SUM+_0x301E_CauseE1apRadioNetworkLayerReportCharacteristicsEmpty_count_SUM+_0x301F_CauseE1apRadioNetworkLayerExistingMeasurementID_count_SUM+_0x3020_CauseE1apRadioNetworkLayerMeasurementTemporarilyNotAvailable_count_SUM+_0x3021_CauseE1apRadioNetworkLayerMeasurementNotSupportedForTheObject_count_SUM+_0x3102_CauseE1apTransportLayerUnknownTNLAddressForIAB_count_SUM+_0x4033_CauseX2apRadioNetworkLayerCHOCPCResourcesToBeChanged_count_SUM+_0x4034_CauseX2apRadioNetworkLayerUEPowerSaving_count_SUM+_0x4035_CauseX2apRadioNetworkLayerInsufficientUeCapabilities_count_SUM+_0x4036_CauseX2apRadioNetworkLayerNormalRelease_count_SUM+_0x1036_CauseInternalCpSrbIntegrityFailure_count_SUM+_0x1037_CauseInternalRandomAccessProblemAfterInitialAccess_count_SUM
						) as Total_CRR_DENOM
					from apachedataingestion.nr.cucpcslpergnbhexa_nr_hr_silver  a
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[1],'CellIdentity','')=b.gcell_id
					WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
					GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T1 on M0.CalendarDate=T1.CalendarDate and M0.Hour24=T1.Hour24 and M0.du_id=T1.du_id and M0.GCELL_ID=T1.GCELL_ID  
			full join  (
					select CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									SUM(EndcAddAtt) EndcAddAtt,
									SUM(EndcAddSucc) EndcAddSucc,
                                    SUM(EndcAddPrepFail_CpFail) EndcAddPrepFail_CpFail,
                                    SUM(EndcAddPrepFail_UpFail) EndcAddPrepFail_UpFail,
                                    SUM(EndcAddPrepFail_DuFail) EndcAddPrepFail_DuFail
					FROM (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									SUM(EndcAddAtt_count_SUM) EndcAddAtt,
									SUM(EndcAddSucc_count_SUM) EndcAddSucc,
                                    SUM(EndcAddPrepFail_CpFail_count_SUM) EndcAddPrepFail_CpFail,
                                    SUM(EndcAddPrepFail_UpFail_count_SUM) EndcAddPrepFail_UpFail,
                                    SUM(EndcAddPrepFail_DuFail_count_SUM) EndcAddPrepFail_DuFail
								from apachedataingestion.nr.sgnbadditionpergnb_nr_hr_silver a
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[1],'CellIdentityWithInvalid','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
							UNION ALL 
							--select * from hive_metastore.default.xx_sgnbadditionpergnbwithduidentifier_hr_jwktmp
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									SUM(EndcAddAtt_count_SUM) EndcAddAtt,
									SUM(EndcAddSucc_count_SUM) EndcAddSucc,
                                    SUM(EndcAddPrepFail_CpFail_count_SUM) EndcAddPrepFail_CpFail,
                                    SUM(EndcAddPrepFail_UpFail_count_SUM) EndcAddPrepFail_UpFail,
                                    SUM(EndcAddPrepFail_DuFail_count_SUM) EndcAddPrepFail_DuFail
								from apachedataingestion.nr.sgnbadditionpergnbwithduidentifier_hr_silver a
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentityWithInvalid','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
					) x GROUP BY CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T2 on M0.CalendarDate=T2.CalendarDate and M0.Hour24=T2.Hour24 and M0.du_id=T2.du_id and M0.GCELL_ID=T2.GCELL_ID 
            full join  (
                        select CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
							SUM(EndcInterChgSrcAtt) EndcInterChgSrcAtt, 
							SUM(EndcInterChgSrcSucc) EndcInterChgSrcSucc 
					from (
								SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									SUM(EndcInterChgSrcAtt_count_SUM) EndcInterChgSrcAtt, 
									SUM(EndcInterChgSrcSucc_count_SUM) EndcInterChgSrcSucc 
									-- select *
								from apachedataingestion.nr.intersnpscellchangepergnb_nr_hr_silver a
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[1],'SrcCellIdentity','')=b.gcell_id                      
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
							union all
								SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
									SUM(EndcInterChgSrcAtt_count_SUM) EndcInterChgSrcAtt, 
									SUM(EndcInterChgSrcSucc_count_SUM) EndcInterChgSrcSucc
                                    -- select *
								from apachedataingestion.nr.intersnpscellchangepergnbwithduidentifier_nr_hr_silver  a
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
					) x GROUP BY CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
            ) T3 on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID 
            full join  (
                    select CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
							SUM(UeNoTot) UeNoTot, 
							SUM(UeNoCnt) UeNoCnt,
							Max(UeNoMax) UeNoMax 
					from (
								SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									SUM(UeNoTot) UeNoTot, 
									SUM(UeNoCnt) UeNoCnt,
									Max(UeNoMax) UeNoMax
									-- select *
								from apachedataingestion.nr.ueconnectionnumberpergnbperduidpercell_nr_hr_silver a
								--inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'SrcCellIdentity','')=b.gcell_id                      
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[2],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
							union all
								SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									SUM(UeNoTot_count_SUM) UeNoTot, 
									SUM(UeNoCnt_count_SUM) UeNoCnt,
									Max(UeNoMax_count_MAX) UeNoMax
                                    -- select *
								from apachedataingestion.nr.ueconnectionnumberpergnbwithduidentifier_nr_hr_silver  a
								--inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[2],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
					) x GROUP BY CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME            
            ) T4 on M0.CalendarDate=T4.CalendarDate and M0.Hour24=T4.Hour24 and M0.du_id=T4.du_id and M0.GCELL_ID=T4.GCELL_ID 
			full join  (
						select Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
							sum(AirMacDLByte_Kbytes_SUM)  AirMacDLByte, 
							sum(AirMacULByte_Kbytes_SUM)  AirMacULByte
						from  apachedataingestion.nr.airmacpacket_nr_hr_silver a
						inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(a.LOCATION,'CellIdentity','')=b.gcell_id
						WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
						GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T5 on M0.CalendarDate=T5.CalendarDate and M0.Hour24=T5.Hour24 and M0.du_id=T5.du_id and M0.GCELL_ID=T5.GCELL_ID 
			full join  (
						select Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
							SUM(DLUeThruVol_Kbytes_SUM) DLUeThruVol,
							SUM(DLUeThruTime_us_SUM) DLUeThruTime,
							sum(case when split(LOCATION,'/')[1] in ('QCI8') then DLUeThruVol_Kbytes_SUM end )  DLUeThruVol_QCI8,
							sum(case when split(LOCATION,'/')[1] in ('QCI132') then DLUeThruVol_Kbytes_SUM end )  DLUeThruVol_QCI132,
							sum(case when split(LOCATION,'/')[1] in ('QCI8') then DLUeThruTime_us_SUM end )  DLUeThruTime_QCI8,
							sum(case when split(LOCATION,'/')[1] in ('QCI132') then DLUeThruTime_us_SUM end )  DLUeThruTime_QCI132
							-- select *
						from  apachedataingestion.nr.downlinkuethroughput_nr_hr_silver a
						inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
						WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
						GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T6 on M0.CalendarDate=T6.CalendarDate and M0.Hour24=T6.Hour24 and M0.du_id=T6.du_id and M0.GCELL_ID=T6.GCELL_ID 
			full join  (
						select Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
							SUM(ULUeThruVol_Kbytes_SUM) ULUeThruVol,  
							SUM(ULUeThruTime_slots_SUM) ULUeThruTime
							-- select ULUeThruVol_Kbytes_SUM_
						from apachedataingestion.nr.uplinkuethroughput_nr_hr_silver a
						inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
						WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
						GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T7 on M0.CalendarDate=T7.CalendarDate and M0.Hour24=T7.Hour24 and M0.du_id=T7.du_id and M0.GCELL_ID=T7.GCELL_ID 
			full join  (
						select Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
							SUM(CaUeNum_perCC1Tot_count_SUM * 1 + CaUeNum_perCC2Tot_count_SUM * 2 + CaUeNum_perCC3Tot_count_SUM * 3 + CaUeNum_perCC4Tot_count_SUM * 4 + CaUeNum_perCC5Tot_count_SUM * 5 + CaUeNum_perCC6Tot_count_SUM * 6 + CaUeNum_perCC7Tot_count_SUM * 7 + CaUeNum_perCC8Tot_count_SUM * 8) S5NR_CA_AvgNumCC_NUM,
							SUM(CaUeNum_perCC1Tot_count_SUM + CaUeNum_perCC2Tot_count_SUM + CaUeNum_perCC3Tot_count_SUM + CaUeNum_perCC4Tot_count_SUM + CaUeNum_perCC5Tot_count_SUM + CaUeNum_perCC6Tot_count_SUM + CaUeNum_perCC7Tot_count_SUM + CaUeNum_perCC8Tot_count_SUM) S5NR_CA_AvgNumCC_DENOM,
							sum(CaUeNum_perCC8Tot_count_SUM) CaUeNum_perCC8Tot,
							sum(CaUeNum_perCC8Cnt_count_SUM) CaUeNum_perCC8Cnt,
							sum(CaUeNum_perCC7Tot_count_SUM) CaUeNum_perCC7Tot,
							sum(CaUeNum_perCC7Cnt_count_SUM) CaUeNum_perCC7Cnt,
							sum(CaUeNum_perCC6Tot_count_SUM) CaUeNum_perCC6Tot,
							sum(CaUeNum_perCC6Cnt_count_SUM) CaUeNum_perCC6Cnt,
							sum(CaUeNum_perCC5Tot_count_SUM) CaUeNum_perCC5Tot,
							sum(CaUeNum_perCC5Cnt_count_SUM) CaUeNum_perCC5Cnt,
							sum(CaUeNum_perCC4Tot_count_SUM) CaUeNum_perCC4Tot,
							sum(CaUeNum_perCC4Cnt_count_SUM) CaUeNum_perCC4Cnt,
							sum(CaUeNum_perCC3Tot_count_SUM) CaUeNum_perCC3Tot,
							sum(CaUeNum_perCC3Cnt_count_SUM) CaUeNum_perCC3Cnt,
							sum(CaUeNum_perCC2Tot_count_SUM) CaUeNum_perCC2Tot,
							sum(CaUeNum_perCC2Cnt_count_SUM) CaUeNum_perCC2Cnt,
							sum(CaUeNum_perCC1Tot_count_SUM) CaUeNum_perCC1Tot,
							sum(CaUeNum_perCC1Cnt_count_SUM) CaUeNum_perCC1Cnt
                    from apachedataingestion.nr.uenumberpernumberofcomponentcarriers_hr_silver a 
                    inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(a.LOCATION,'CellIdentity','')=b.gcell_id
                    WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
                    GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T8 on M0.CalendarDate=T8.CalendarDate and M0.Hour24=T8.Hour24 and M0.du_id=T8.du_id and M0.GCELL_ID=T8.GCELL_ID 
			full join  (
					select CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						SUM(ErabAddAtt) ErabAddAtt, 
						SUM(ErabAddSucc) ErabAddSucc,
					--Added new counters on 1/23/2025 DENG-2659
						sum(ErabAddAtt_QCI132) ErabAddAtt_QCI132,
						sum(ErabAddSucc_QCI132) ErabAddSucc_QCI132
												
					from (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
								SUM(ErabAddAtt_count_SUM) ErabAddAtt,
								SUM(ErabAddSucc_count_SUM) ErabAddSucc,
								--Added null counters on 1/23/2025 DENG-2659
								NULL AS ErabAddAtt_QCI132,
								NULL AS ErabAddSucc_QCI132
								from apachedataingestion.nr.erabadditionpergnb_hr_silver a
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[1],'CellIdentity','')=b.gcell_id
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
								union all
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
								SUM(ErabAddAtt_count_SUM) ErabAddAtt,
								SUM(ErabAddSucc_count_SUM) ErabAddSucc,
								--Added new counters on 1/23/2025 DENG-2659
								SUM(CASE when split(a.LOCATION,'/')[3]='QCI132' Then ErabAddAtt_count_SUM END) ErabAddAtt_QCI132,
								SUM(CASE when split(a.LOCATION,'/')[3]='QCI132' Then ErabAddSucc_count_SUM END) ErabAddSucc_QCI132
								from apachedataingestion.nr.erabadditionpergnbwithduidentifier_hr_silver a
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
					) x GROUP BY CalendarDate,Hour24,du_id,GNODEB_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME 
			) T9 on M0.CalendarDate=T9.CalendarDate and M0.Hour24=T9.Hour24 and M0.du_id=T9.du_id and M0.GCELL_ID=T9.GCELL_ID 
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						SUM(RlcDLByte_Kbytes_SUM) RlcDLByte,
						SUM(RlcULByte_Kbytes_SUM) RlcULByte,
						SUM(RlcDLRePktCnt_count_SUM) RlcDLRePktCnt,
						SUM(RlcDLPktCnt_count_SUM) RlcDLPktCnt,
						sum(case when split(LOCATION,'/')[1] in ('QCI8') then RlcDLByte_Kbytes_SUM end )  RlcDLByte_QCI8,
						sum(case when split(LOCATION,'/')[1] in ('QCI132') then RlcDLByte_Kbytes_SUM end )  RlcDLByte_QCI132,
						sum(case when split(LOCATION,'/')[1] in ('QCI8') then RlcULByte_Kbytes_SUM end )  RlcULByte_QCI8,
						sum(case when split(LOCATION,'/')[1] in ('QCI132') then RlcULByte_Kbytes_SUM end )  RlcULByte_QCI132						
						-- select *
				from apachedataingestion.nr.rlcpacket_hr_silver a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T10 on M0.CalendarDate=T10.CalendarDate and M0.Hour24=T10.Hour24 and M0.du_id=T10.du_id and M0.GCELL_ID=T10.GCELL_ID 	
			full join  (	
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
					sum(DLNumPdschAvailableSlots_count_SUM) DLNumPdschAvailableSlots,
					SUM(DLNumScheduledSlots_count_SUM) DLNumScheduledSlots,
					sum(DLNumMuMimoUEs_A6_count_SUM) DLNumMuMimoUEs_A6,
					Sum(DLMuMimoLayers_A6_count_SUM) DLMuMimoLayers_A6,
					Sum(DLNumScheduledUEs_count_SUM) DLNumScheduledUEs  
					-- select 					*	
					from apachedataingestion.nr.downlinkmimo_nr_hr_silver a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(a.LOCATION,'CellIdentity','')=b.gcell_id
					WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME		
			) T11 on M0.CalendarDate=T11.CalendarDate and M0.Hour24=T11.Hour24 and M0.du_id=T11.du_id and M0.GCELL_ID=T11.GCELL_ID 	
			full join  (				
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
					SUM(ULNumScheduledSlots_TTI_SUM) ULNumScheduledSlots,
					SUM(ULNumPuschAvailableSlots_TTI_SUM) ULNumPuschAvailableSlots,
					sum(ULNumSuRank2UEs_count_SUM) ULNumSuRank2UEs,
					sum(ULNumScheduledUEs_count_SUM) ULNumScheduledUEs,
					sum(ULNumMuMimoUEs_count_SUM) ULNumMuMimoUEs,					
					sum(ULNum1LayerAlloc_count_SUM) ULNum1LayerAlloc ,
					sum(ULNum2LayerAlloc_count_SUM) ULNum2LayerAlloc ,
					sum(ULNum3LayerAlloc_count_SUM) ULNum3LayerAlloc ,
					sum(ULNum4LayerAlloc_count_SUM) ULNum4LayerAlloc ,
					sum(ULNum5LayerAlloc_count_SUM) ULNum5LayerAlloc ,
					sum(ULNum6LayerAlloc_count_SUM) ULNum6LayerAlloc ,
					sum(ULNum7LayerAlloc_count_SUM) ULNum7LayerAlloc ,
					sum(ULNum8LayerAlloc_count_SUM) ULNum8LayerAlloc ,
					sum(ULNumUsedPRBs1L_count_SUM) ULNumUsedPRBs1L ,
					sum(ULNumUsedPRBs2L_count_SUM) ULNumUsedPRBs2L ,
					sum(ULNumUsedPRBs3L_count_SUM) ULNumUsedPRBs3L ,
					sum(ULNumUsedPRBs4L_count_SUM) ULNumUsedPRBs4L ,
					sum(ULNumUsedPRBs5L_count_SUM) ULNumUsedPRBs5L ,
					sum(ULNumUsedPRBs6L_count_SUM) ULNumUsedPRBs6L ,
					sum(ULNumUsedPRBs7L_count_SUM) ULNumUsedPRBs7L ,
					sum(ULNumUsedPRBs8L_count_SUM) ULNumUsedPRBs8L
					--select *
					from apachedataingestion.nr.uplinkmimo_nr_hr_silver a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(a.LOCATION,'CellIdentity','')=b.gcell_id
					WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T12 on M0.CalendarDate=T12.CalendarDate and M0.Hour24=T12.Hour24 and M0.du_id=T12.du_id and M0.GCELL_ID=T12.GCELL_ID 	
) X
GROUP BY CalendarDate,Hour24,GNODEB_ID,du_id,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME;

/**
--Added as on 03/25/2025 DENG-3078
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp0 ADD COLUMN Release_by_CAC DOUBLE
*/

delete from hive_metastore.default.widetable_5g_cell_hr_tmp0;

insert into hive_metastore.default.widetable_5g_cell_hr_tmp0
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	-- select count(distinct concat(GNODEB_ID,'_',DU_ID,'_',GCELL_ID)) --514527
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							-- select count(*)
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
)
select 
CalendarDate ,
Hour24 ,
GNODEB_ID,
du_id ,
GCELL_ID ,
MARKET_NAME ,
case when length(du_id)=14 then 
	case when substring(du_id, 7, 1)=0 then 'FR2' 	 when substring(du_id, 7, 1)=9 then 
				case when substring(du_id, 11, 1)=2 then 'FR1/LS3' when substring(du_id, 11, 1)=3 then 'FR1/LS6' 
				end
	end
else '' end NR_TYPE,
substring(du_id,4,3) SUB_MARKET_ID,
SUB_MARKET_NAME ,
--Added new columns on 12/26/2024 JIRA:DENG-2463
max(NSA_ERAB_Drop_Rate_FWA_PCT_Num) NSA_ERAB_Drop_Rate_FWA_PCT_Num,
max(NSA_ERAB_Drop_Rate_FWA_PCT_Denom) NSA_ERAB_Drop_Rate_FWA_PCT_Denom,
max(NSA_ERAB_Drop_Rate_Mobility_PCT_Num) NSA_ERAB_Drop_Rate_Mobility_PCT_Num,
max(NSA_ERAB_Drop_Rate_Mobility_PCT_Denom) NSA_ERAB_Drop_Rate_Mobility_PCT_Denom,
max(NSA_ERAB_Drop_Rate_Overall_PCT_Num) NSA_ERAB_Drop_Rate_Overall_PCT_Num,
max(NSA_ERAB_Drop_Rate_Overall_PCT_Denom) NSA_ERAB_Drop_Rate_Overall_PCT_Denom,

--Added on 1/23/2025 DENG-2659
max(Avg_NRDC_Users_MN_Num) Avg_NRDC_Users_MN_Num,
max(Avg_NRDC_Users_MN_Denom) Avg_NRDC_Users_MN_Denom,
max(Max_NRDC_Users_MN) Max_NRDC_Users_MN,
max(Avg_NRDC_Users_SN_Num) Avg_NRDC_Users_SN_Num,
max(Avg_NRDC_Users_SN_Denom) Avg_NRDC_Users_SN_Denom,
max(Max_NRDC_Users_SN) Max_NRDC_Users_SN,
max(S5NR_AirIF_Delay_UL_ms_Num) S5NR_AirIF_Delay_UL_ms_Num,
max(S5NR_AirIF_Delay_UL_ms_Denom) S5NR_AirIF_Delay_UL_ms_Denom,
max(5G_ASEU_NSA_CELL) 5G_ASEU_NSA_CELL,
max(5G_ASEU_SA_CELL) 5G_ASEU_SA_CELL,
max(5G_ASEU_NSA_QCI) 5G_ASEU_NSA_QCI,
max(5G_ASEU_SA_5QI) 5G_ASEU_SA_5QI,
max(5G_ASEU_NSA_SPID) 5G_ASEU_NSA_SPID,
max(5G_ASEU_SA_RFSP) 5G_ASEU_SA_RFSP,
max(S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Num) S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Num,
max(S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Denom) S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Denom,
max(S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Num) S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Num,
max(S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Denom) S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Denom,
max(S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Num) S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Num,
max(S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Denom) S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Denom,
max(S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Num) S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Num,
max(S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Denom) S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Denom,

--Added on 1/29/2025 DENG-DENG-2689
max(5GNC_DRBSetupFail_Mobility_PCT_Num) 5GNC_DRBSetupFail_Mobility_PCT_Num,
max(5GNC_DRBSetupFail_Mobility_PCT_Denom) 5GNC_DRBSetupFail_Mobility_PCT_Denom,
max(S5NC_AvgRRC_Mobility_Num) S5NC_AvgRRC_Mobility_Num,
max(S5NC_AvgRRC_Mobility_Denom) S5NC_AvgRRC_Mobility_Denom,
max(S5NC_MaxRRC_Mobility) S5NC_MaxRRC_Mobility,
max(S5ND_TotalMACDataVolumeDL_MB_Mobility) S5ND_TotalMACDataVolumeDL_MB_Mobility,
max(S5ND_TotalMACDataVolumeUL_MB_Mobility) S5ND_TotalMACDataVolumeUL_MB_Mobility,
max(S5ND_DLUeThru_Mbps_Mobility_Num) S5ND_DLUeThru_Mbps_Mobility_Num,
max(S5ND_DLUeThru_Mbps_Mobility_Denom) S5ND_DLUeThru_Mbps_Mobility_Denom,
max(S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Num) S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Num,
max(S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Denom) S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Denom,
max(S5NC_DRBDrop_PCT_5QI133_Slicing_Num) S5NC_DRBDrop_PCT_5QI133_Slicing_Num,
max(S5NC_DRBDrop_PCT_5QI133_Slicing_Denom) S5NC_DRBDrop_PCT_5QI133_Slicing_Denom,
max(S5ND_RLCDataVol_DL_SA_MB_5QI133) S5ND_RLCDataVol_DL_SA_MB_5QI133,
max(S5ND_RLCDataVol_UL_SA_MB_5QI133) S5ND_RLCDataVol_UL_SA_MB_5QI133,
max(S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Num) S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Num,
max(S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Denom) S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Denom,
max(S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Num) S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Num,
max(S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Denom) S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Denom,
max(SAM_5G_SA_Celllvl_Paging_Discard_Rate_Num) SAM_5G_SA_Celllvl_Paging_Discard_Rate_Num,	
max(SAM_5G_SA_Celllvl_Paging_Discard_Rate_Denom) SAM_5G_SA_Celllvl_Paging_Discard_Rate_Denom,
max(SAM_5G_SA_Celllvl_Paging_Attempts) SAM_5G_SA_Celllvl_Paging_Attempts,
--Added as on 03/25/2025 DENG-3078
max(Release_by_CAC) Release_by_CAC
from (

	select 
			COALESCE(M0.CalendarDate,T1.CalendarDate,T2.CalendarDate,T3.CalendarDate,T4.CalendarDate,T5.CalendarDate,T6.CalendarDate,T7.CalendarDate,T8.CalendarDate,T9.CalendarDate,T10.CalendarDate,T11.CalendarDate,T12.CalendarDate,T13.CalendarDate,T14.CalendarDate,T15.CalendarDate,T16.CalendarDate,T17.CalendarDate,T18.CalendarDate,T19.CalendarDate,T20.CalendarDate,T21.CalendarDate) CalendarDate,
			COALESCE(M0.Hour24,T1.Hour24,T2.Hour24,T3.Hour24,T4.Hour24,T5.Hour24,T6.Hour24,T7.Hour24,T8.Hour24,T9.Hour24,T10.Hour24,T11.Hour24,T12.Hour24,T13.Hour24,T14.Hour24,T15.Hour24,T16.Hour24,T17.Hour24,T18.Hour24,T19.Hour24,T20.Hour24,T21.Hour24) Hour24,
			COALESCE(M0.GNODEB_ID,T1.GNODEB_ID,T2.GNODEB_ID,T3.GNODEB_ID,T4.GNODEB_ID,T5.GNODEB_ID,T6.GNODEB_ID,T7.GNODEB_ID,T8.GNODEB_ID,T9.GNODEB_ID,T10.GNODEB_ID,T11.GNODEB_ID,T12.GNODEB_ID,T13.GNODEB_ID,T14.GNODEB_ID,T15.GNODEB_ID,T16.GNODEB_ID,T17.GNODEB_ID,T18.GNODEB_ID,T19.GNODEB_ID,T20.GNODEB_ID,T21.GNODEB_ID) GNODEB_ID,
			COALESCE(M0.du_id,T1.du_id,T2.du_id,T3.du_id,T4.du_id,T5.du_id,T6.du_id,T7.du_id,T8.du_id,T9.du_id,T10.du_id,T11.du_id,T12.du_id,T13.du_id,T14.du_id,T15.du_id,T16.du_id,T17.du_id,T18.du_id,T19.du_id,T20.du_id,T21.du_id) du_id,
			COALESCE(M0.GCELL_ID,T1.GCELL_ID,T2.GCELL_ID,T3.GCELL_ID,T4.GCELL_ID,T5.GCELL_ID,T6.GCELL_ID,T7.GCELL_ID,T8.GCELL_ID,T9.GCELL_ID,T10.GCELL_ID,T11.GCELL_ID,T12.GCELL_ID,T13.GCELL_ID,T14.GCELL_ID,T15.GCELL_ID,T16.GCELL_ID,T17.GCELL_ID,T18.GCELL_ID,T19.GCELL_ID,T20.GCELL_ID,T21.GCELL_ID) GCELL_ID,
			COALESCE(M0.MARKET_NAME,T1.MARKET_NAME,T2.MARKET_NAME,T3.MARKET_NAME,T4.MARKET_NAME,T5.MARKET_NAME,T6.MARKET_NAME,T7.MARKET_NAME,T8.MARKET_NAME,T9.MARKET_NAME,T10.MARKET_NAME,T11.MARKET_NAME,T12.MARKET_NAME,T13.MARKET_NAME,T14.MARKET_NAME,T15.MARKET_NAME,T16.MARKET_NAME,T17.MARKET_NAME,T18.MARKET_NAME,T19.MARKET_NAME,T20.MARKET_NAME,T21.MARKET_NAME) MARKET_NAME,						
			COALESCE(M0.SUB_MARKET_NAME,T1.SUB_MARKET_NAME,T2.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T4.SUB_MARKET_NAME,T5.SUB_MARKET_NAME,T6.SUB_MARKET_NAME,T7.SUB_MARKET_NAME,T8.SUB_MARKET_NAME,T9.SUB_MARKET_NAME,T10.SUB_MARKET_NAME,T11.SUB_MARKET_NAME,T12.SUB_MARKET_NAME,T13.SUB_MARKET_NAME,T14.SUB_MARKET_NAME,T15.SUB_MARKET_NAME,T16.SUB_MARKET_NAME,T17.SUB_MARKET_NAME,T18.SUB_MARKET_NAME,T19.SUB_MARKET_NAME,T20.SUB_MARKET_NAME,T21.SUB_MARKET_NAME) SUB_MARKET_NAME,
            --Added new columns on 12/26/2024 JIRA:DENG-2463
			(ErabRel_DL_t310Expiry_QCI132_+
				 ErabRel_DL_syncReconfFailure_QCI132_+
				 ErabRel_DL_randomAccessProblem_QCI132_+
				 ErabRel_DL_rlcMaxNumRetx_QCI132_+
				 ErabRel_DL_srb3IntegrityFailure_QCI132_+
				 ErabRel_DL_scgReconfFailure_QCI132_+
				 ErabRel_UL_outOfSync_QCI132_+
				 ErabRel_UL_rlcMaxNumRetx_QCI132_+
				 ErabRel_UL_srb3IntegrityFailure_QCI132_+
				 ErabRel_MrBasedSuspendResume_QCI132_+
				 ErabRel_T312Expiry_QCI132_+
				 ErabRel_BeamFailureRecoveryFailure_QCI132_+
				 ErabRel_OtherR16FailCauses_QCI132_+
				 ErabRel_DL_randomAccessProblem_AfterInitialAccess_QCI132_+
				 ErabRel_SwitchOffOngoing_QCI132_
			) NSA_ERAB_Drop_Rate_FWA_PCT_NUM,
			(ErabRelbyEnbQciTot_QCI132 + ErabRelbyGnbQciTot_QCI132 - ErabRelNormalbyGnbQci_IntraSNMobility_QCI132 - 		ErabRelNormalbyGnbQci_InterSNMobility_QCI132
            ) NSA_ERAB_Drop_Rate_FWA_PCT_Denom,
			
			(ErabRel_DL_t310Expiry_NotQCI132+
				ErabRel_DL_syncReconfFailure_NotQCI132+
				ErabRel_DL_randomAccessProblem_NotQCI132+
				ErabRel_DL_rlcMaxNumRetx_NotQCI132+
				ErabRel_DL_srb3IntegrityFailure_NotQCI132+
				ErabRel_DL_scgReconfFailure_NotQCI132+
				ErabRel_UL_outOfSync_NotQCI132+
				ErabRel_UL_rlcMaxNumRetx_NotQCI132+
				ErabRel_UL_srb3IntegrityFailure_NotQCI132+
				ErabRel_MrBasedSuspendResume_NotQCI132+
				ErabRel_T312Expiry_NotQCI132+
				ErabRel_BeamFailureRecoveryFailure_NotQCI132+
				ErabRel_OtherR16FailCauses_NotQCI132+
				ErabRel_DL_randomAccessProblem_AfterInitialAccess_NotQCI132+
				ErabRel_SwitchOffOngoing_NotQCI132
			) NSA_ERAB_Drop_Rate_Mobility_PCT_NUM,
			(ErabRelbyEnbQciTot_NotQCI132 + ErabRelbyGnbQciTot_NotQCI132 - ErabRelNormalbyGnbQci_IntraSNMobility_NotQCI132 - ErabRelNormalbyGnbQci_InterSNMobility_NotQCI132
			) NSA_ERAB_Drop_Rate_Mobility_PCT_Denom,
			
			(	ErabRel_DL_t310Expiry+
				ErabRel_DL_syncReconfFailure+
				ErabRel_DL_randomAccessProblem+
				ErabRel_DL_rlcMaxNumRetx+
				ErabRel_DL_srb3IntegrityFailure+
				ErabRel_DL_scgReconfFailure+
				ErabRel_UL_outOfSync+
				ErabRel_UL_rlcMaxNumRetx+
				ErabRel_UL_srb3IntegrityFailure+
				ErabRel_MrBasedSuspendResume+
				ErabRel_T312Expiry+
				ErabRel_BeamFailureRecoveryFailure+
				ErabRel_OtherR16FailCauses+
				ErabRel_DL_randomAccessProblem_AfterInitialAccess+
				ErabRel_SwitchOffOngoing
			) NSA_ERAB_Drop_Rate_Overall_PCT_NUM,
			(ErabRelbyEnbQciTot + ErabRelbyGnbQciTot - ErabRelNormalbyGnbQci_IntraSNMobility - ErabRelNormalbyGnbQci_InterSNMobility) NSA_ERAB_Drop_Rate_Overall_PCT_Denom,
					
			--Added on 1/23/2025 DENG-2659
			NrdcMnConnNoTot	Avg_NRDC_Users_MN_Num,
			NrdcMnConnNoCnt Avg_NRDC_Users_MN_Denom,
			NrdcMnConnNoMax Max_NRDC_Users_MN,
			NrdcSnConnNoTot Avg_NRDC_Users_SN_Num,
			NrdcSnConnNoCnt Avg_NRDC_Users_SN_Denom,
			NrdcSnConnNoMax Max_NRDC_Users_SN,
			AirIfDelayUlTot S5NR_AirIF_Delay_UL_ms_Num,
			AirIfDelayUlCnt S5NR_AirIF_Delay_UL_ms_Denom,
			TotalDLActiveUETime_NSA/(3600*1000) 5G_ASEU_NSA_CELL,
			TotalDLActiveUETime_SA/(3600*1000) 5G_ASEU_SA_CELL,
			TotalDLActiveDRBTime_NSA_QCI/(3600*1000) 5G_ASEU_NSA_QCI,
			TotalDLActiveDRBTime_SA_5QI/(3600*1000) 5G_ASEU_SA_5QI,
			TotalDLActiveDRBTime_NSA_SPID/(3600*1000) 5G_ASEU_NSA_SPID,
			TotalDLActiveDRBTime_SA_RFSP/(3600*1000) 5G_ASEU_SA_RFSP,
			(NrdcAddSn_PrepFail_CpFail + NrdcAddSn_PrepFail_UpFail + NrdcAddSn_PrepFail_DuFail) S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Num,
			NrdcAddSn_Att S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Denom,
			((8 * ULUeThruVol_RFSP125)/1000) S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Num,
			(ULUeThruTime_RFSP125/8000) S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Denom,
			((8 * ULUeThruVol_RFSP125_95)/1000) S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Num,
			(ULUeThruTime_RFSP125_95/8000) S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Denom,
			((8 * ULUeThruVol_RFSP95_LCG4)/1000) S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Num,
			(ULUeThruTime_RFSP95_LCG4/8000) S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Denom,
			--Added on 1/29/2025 DENG-DENG-2689
			((DrbSetupAtt - DrbSetupSucc) - (DrbSetupAtt_5QI132 - DrbSetupSucc_5QI132)) 5GNC_DRBSetupFail_Mobility_PCT_Num,
			(DrbSetupAtt - DrbSetupAtt_5QI132) 5GNC_DRBSetupFail_Mobility_PCT_Denom,
			ConnNoTotPlmnRfsp_RFSP_115_95 S5NC_AvgRRC_Mobility_Num,
			ConnNoCntPlmnRfsp_RFSP_115_95 S5NC_AvgRRC_Mobility_Denom,
			ConnNoMaxPlmnRfsp_RFSP_115_95 S5NC_MaxRRC_Mobility,
			AirMacDLByte_RFSP_115_95/1000 S5ND_TotalMACDataVolumeDL_MB_Mobility,
			AirMacULByte_RFSP_115_95/1000 S5ND_TotalMACDataVolumeUL_MB_Mobility,
			(DLUeThruVol_SA_RFSP_115_95 * 8 * 1024) S5ND_DLUeThru_Mbps_Mobility_Num,
			DLUeThruTime_SA_RFSP_115_95 S5ND_DLUeThru_Mbps_Mobility_Denom,
			(DrbSetupPlmnSnssaiAtt_SNSSAI_16777222 - DrbSetupPlmnSnssaiSucc_SNSSAI_16777222) S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Num,
			DrbSetupPlmnSnssaiAtt_SNSSAI_16777222 S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Denom,
			((NVL(DrbRelTotal_5QI133,0) - NVL(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI133,0)) -
			((NVL(DrbRelbyAmf_PduSessionRelCmd_5QI133,0) - NVL(DrbRelbyAmf_PduSessionRelCmd_5QI133_active,0) + NVL(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI133_active,0)) +
			(NVL(DrbRelbyAmf_PduSessionModifyReq_5QI133,0) - NVL(DrbRelbyAmf_PduSessionModifyReq_5QI133_active,0) + NVL(DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI133_active,0)) +
			(NVL(DrbRelbyAmf_UeContextRelCmd_5QI133,0) - NVL(DrbRelbyAmf_UeContextRelCmd_5QI133_active,0) + NVL(DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI133_active,0)) -
			(NVL(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI133,0) - NVL(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI133_active,0) + NVL(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI133_active,0))+
			NVL(DrbRelbyGnb_UeContextRelReq_WithNormalCause_5QI133,0)+
			NVL(DrbRelbyIntraRatRedirection_5QI133,0) + 
			NVL(DrbRelbyInterRatRedirection_5QI133,0) + 
			NVL(DrbRelbyPreemption_5QI133,0))) S5NC_DRBDrop_PCT_5QI133_Slicing_Num,
			(DrbRelTotal_5QI133 - DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI133) S5NC_DRBDrop_PCT_5QI133_Slicing_Denom,
			(RlcDLByte_5QI133 * 1.024)/1000 S5ND_RLCDataVol_DL_SA_MB_5QI133,
			(RlcULByte_5QI133 * 1.024)/1000 S5ND_RLCDataVol_UL_SA_MB_5QI133,
			((DLUeThruVol_SA_RFSP_95_5QI_133_SNSSAI_16777222 * 8 * 1.024)/ 1000) S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Num,
			(DLUeThruTime_SA_RFSP_95_5QI_133_SNSSAI_16777222/power(10,6)) S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Denom,
			RlcSduDelayTot_SA_5QI133_SNSSAI_16777222 S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Num,
			RlcSduDelayCnt_SA_5QI133_SNSSAI_16777222 S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Denom,
			DiscardedPaging SAM_5G_SA_Celllvl_Paging_Discard_Rate_Num,	
			AttPaging SAM_5G_SA_Celllvl_Paging_Discard_Rate_Denom,
			AttPaging SAM_5G_SA_Celllvl_Paging_Attempts,
			_0xB006_CauseInternalCacCallCountOver Release_by_CAC
						
		from (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(NrdcMnConnNoTot) NrdcMnConnNoTot,
					sum(NrdcMnConnNoCnt) NrdcMnConnNoCnt,
					MAX(NrdcMnConnNoMax) NrdcMnConnNoMax
					
				from apachedataingestion.nr.nrdcsnodeconnectioninformationofmn_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[2],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
				
				 
			) M0
			full join  (				
                    SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
                            sum(ErabRelbyEnbQciTot) ErabRelbyEnbQciTot,
                            sum(ErabRelbyGnbQciTot) ErabRelbyGnbQciTot,
                            sum(ErabRelNormalbyGnbQci_IntraSNMobility) ErabRelNormalbyGnbQci_IntraSNMobility,
                            sum(ErabRelNormalbyGnbQci_InterSNMobility) ErabRelNormalbyGnbQci_InterSNMobility,
                            sum(CASE WHEN split(LOCATION,'/')[4]='QCI132' THEN ErabRelbyEnbQciTot END) ErabRelbyEnbQciTot_QCI132,
                            sum(CASE WHEN split(LOCATION,'/')[4]='QCI132' THEN ErabRelbyGnbQciTot END) ErabRelbyGnbQciTot_QCI132,
                            sum(CASE WHEN split(LOCATION,'/')[4]='QCI132' THEN ErabRelNormalbyGnbQci_IntraSNMobility END) ErabRelNormalbyGnbQci_IntraSNMobility_QCI132,
                            sum(CASE WHEN split(LOCATION,'/')[4]='QCI132' THEN ErabRelNormalbyGnbQci_InterSNMobility END) ErabRelNormalbyGnbQci_InterSNMobility_QCI132,
                            sum(CASE WHEN split(LOCATION,'/')[4] !='QCI132' THEN ErabRelbyEnbQciTot END) ErabRelbyEnbQciTot_NotQCI132,
                            sum(CASE WHEN split(LOCATION,'/')[4] !='QCI132' THEN ErabRelbyGnbQciTot END) ErabRelbyGnbQciTot_NotQCI132,
                            sum(CASE WHEN split(LOCATION,'/')[4] !='QCI132' THEN ErabRelNormalbyGnbQci_IntraSNMobility END) ErabRelNormalbyGnbQci_IntraSNMobility_NotQCI132,
                            sum(CASE WHEN split(LOCATION,'/')[4] !='QCI132' THEN ErabRelNormalbyGnbQci_InterSNMobility END) ErabRelNormalbyGnbQci_InterSNMobility_NotQCI132
                        from apachedataingestion.nr.completeerabreleasepergnbwithduidentifierperplmn_nr_hr_silver a
                       
                        inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
						
                        WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
                    GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T1 on M0.CalendarDate=T1.CalendarDate and M0.Hour24=T1.Hour24 and M0.du_id=T1.du_id and M0.GCELL_ID=T1.GCELL_ID
			
			full join (
				select Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
                        sum(ErabRel_DL_t310Expiry) ErabRel_DL_t310Expiry,
                        sum(ErabRel_DL_syncReconfFailure) ErabRel_DL_syncReconfFailure,
                        sum(ErabRel_DL_randomAccessProblem) ErabRel_DL_randomAccessProblem,
                        sum(ErabRel_DL_rlcMaxNumRetx) ErabRel_DL_rlcMaxNumRetx,
                        sum(ErabRel_DL_srb3IntegrityFailure) ErabRel_DL_srb3IntegrityFailure,
                        sum(ErabRel_DL_scgReconfFailure) ErabRel_DL_scgReconfFailure,
                        sum(ErabRel_UL_outOfSync) ErabRel_UL_outOfSync,
                        sum(ErabRel_UL_rlcMaxNumRetx) ErabRel_UL_rlcMaxNumRetx,
                        sum(ErabRel_UL_srb3IntegrityFailure) ErabRel_UL_srb3IntegrityFailure,
                        sum(ErabRel_MrBasedSuspendResume) ErabRel_MrBasedSuspendResume,
                        sum(ErabRel_T312Expiry) ErabRel_T312Expiry,
                        sum(ErabRel_BeamFailureRecoveryFailure) ErabRel_BeamFailureRecoveryFailure,
                        sum(ErabRel_OtherR16FailCauses) ErabRel_OtherR16FailCauses,
                        sum(ErabRel_DL_randomAccessProblem_AfterInitialAccess) ErabRel_DL_randomAccessProblem_AfterInitialAccess,
                        sum(ErabRel_SwitchOffOngoing) ErabRel_SwitchOffOngoing,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_DL_t310Expiry END)  ErabRel_DL_t310Expiry_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_DL_syncReconfFailure  END) ErabRel_DL_syncReconfFailure_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_DL_randomAccessProblem  END) ErabRel_DL_randomAccessProblem_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN  ErabRel_DL_rlcMaxNumRetx END) ErabRel_DL_rlcMaxNumRetx_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_DL_srb3IntegrityFailure END) ErabRel_DL_srb3IntegrityFailure_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_DL_scgReconfFailure END) ErabRel_DL_scgReconfFailure_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_UL_outOfSync END) ErabRel_UL_outOfSync_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_UL_rlcMaxNumRetx END) ErabRel_UL_rlcMaxNumRetx_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_UL_srb3IntegrityFailure END) ErabRel_UL_srb3IntegrityFailure_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_MrBasedSuspendResume END) ErabRel_MrBasedSuspendResume_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_T312Expiry 
                        END) ErabRel_T312Expiry_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_BeamFailureRecoveryFailure END) ErabRel_BeamFailureRecoveryFailure_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_OtherR16FailCauses END) ErabRel_OtherR16FailCauses_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_DL_randomAccessProblem_AfterInitialAccess END) ErabRel_DL_randomAccessProblem_AfterInitialAccess_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3]='QCI132' THEN ErabRel_SwitchOffOngoing END) ErabRel_SwitchOffOngoing_QCI132_,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_DL_t310Expiry END)  ErabRel_DL_t310Expiry_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_DL_syncReconfFailure  END) ErabRel_DL_syncReconfFailure_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_DL_randomAccessProblem  END) ErabRel_DL_randomAccessProblem_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN  ErabRel_DL_rlcMaxNumRetx END) ErabRel_DL_rlcMaxNumRetx_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_DL_srb3IntegrityFailure END) ErabRel_DL_srb3IntegrityFailure_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_DL_scgReconfFailure END) ErabRel_DL_scgReconfFailure_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_UL_outOfSync END) ErabRel_UL_outOfSync_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_UL_rlcMaxNumRetx END) ErabRel_UL_rlcMaxNumRetx_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_UL_srb3IntegrityFailure END) ErabRel_UL_srb3IntegrityFailure_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_MrBasedSuspendResume END) ErabRel_MrBasedSuspendResume_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_T312Expiry END) ErabRel_T312Expiry_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_BeamFailureRecoveryFailure END) ErabRel_BeamFailureRecoveryFailure_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_OtherR16FailCauses END) ErabRel_OtherR16FailCauses_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_DL_randomAccessProblem_AfterInitialAccess END) ErabRel_DL_randomAccessProblem_AfterInitialAccess_NotQCI132,
                        sum(CASE WHEN split(LOCATION,'/')[3] !='QCI132' THEN ErabRel_SwitchOffOngoing END) ErabRel_SwitchOffOngoing_NotQCI132
                    FROM apachedataingestion.nr.erabreleasepergnbwithduidentifier_nr_hr_silver a
                    				
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id 
					WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T2 on M0.CalendarDate=T2.CalendarDate and M0.Hour24=T2.Hour24 and M0.du_id=T2.du_id and M0.GCELL_ID=T2.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,  
						sum(NrdcSnConnNoTot) NrdcSnConnNoTot,
						sum(NrdcSnConnNoCnt) NrdcSnConnNoCnt,
						MAX(NrdcSnConnNoMax) NrdcSnConnNoMax
						
						-- select *
					from apachedataingestion.nr.nrdcsnodeconnectioninformationofsn_nr_hr_silver  a
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[2],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T3 on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID 
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,  
						sum(AirIfDelayUlTot) AirIfDelayUlTot,
						sum(AirIfDelayUlCnt) AirIfDelayUlCnt
						-- select *
					from apachedataingestion.nr.ulairinterfacedelay_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T4 on M0.CalendarDate=T4.CalendarDate and M0.Hour24=T4.Hour24 and M0.du_id=T4.du_id and M0.GCELL_ID=T4.GCELL_ID 
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,  
						sum(TotalDLActiveUETime) TotalDLActiveUETime_NSA
						-- select *
					from apachedataingestion.nr.activeuetimefornsa_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T5 on M0.CalendarDate=T5.CalendarDate and M0.Hour24=T5.Hour24 and M0.du_id=T5.du_id and M0.GCELL_ID=T5.GCELL_ID 
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,  
						sum(TotalDLActiveUETime) TotalDLActiveUETime_SA
						-- select *
					from apachedataingestion.nr.activeuetimeforsa_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T6 on M0.CalendarDate=T6.CalendarDate and M0.Hour24=T6.Hour24 and M0.du_id=T6.du_id and M0.GCELL_ID=T6.GCELL_ID 
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,  
						sum(CASE WHEN split(a.LOCATION,'/')[3] in ('QCI7','QCI8','QCI9','QCI132','QCI133') THEN TotalDLActiveDRBTime_NSA END) TotalDLActiveDRBTime_NSA_QCI,
						sum(CASE WHEN split(a.LOCATION,'/')[2] in ('SPIDIncludingInvalid115','SPIDIncludingInvalid125') THEN TotalDLActiveDRBTime_NSA END) TotalDLActiveDRBTime_NSA_SPID
						-- select *
					from apachedataingestion.nr.activedrbtimefornsa_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T7 on M0.CalendarDate=T7.CalendarDate and M0.Hour24=T7.Hour24 and M0.du_id=T7.du_id and M0.GCELL_ID=T7.GCELL_ID 
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[3] in ('5QI7','5QI8','5QI9','5QI132','5QI133') THEN TotalDLActiveDRBTime_SA END) TotalDLActiveDRBTime_SA_5QI,
						sum(CASE WHEN split(a.LOCATION,'/')[2] in ('RFSPIncludingInvalid115','RFSPIncludingInvalid125') THEN TotalDLActiveDRBTime_SA END) TotalDLActiveDRBTime_SA_RFSP
						-- select *
					from apachedataingestion.nr.activedrbtimeforsa_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T8 on M0.CalendarDate=T8.CalendarDate and M0.Hour24=T8.Hour24 and M0.du_id=T8.du_id and M0.GCELL_ID=T8.GCELL_ID 
			
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[1] = 'RFSPIncludingInvalid125' THEN ULUeThruVol END) ULUeThruVol_RFSP125,
						sum(CASE WHEN split(a.LOCATION,'/')[1] = 'RFSPIncludingInvalid125' THEN ULUeThruTime END) ULUeThruTime_RFSP125,
						sum(CASE WHEN split(a.LOCATION,'/')[1] in ('RFSPIncludingInvalid125','RFSPIncludingInvalid95') THEN ULUeThruVol END) ULUeThruVol_RFSP125_95,
						sum(CASE WHEN split(a.LOCATION,'/')[1] in ('RFSPIncludingInvalid125','RFSPIncludingInvalid95') THEN ULUeThruTime END) ULUeThruTime_RFSP125_95,
						sum(CASE WHEN split(a.LOCATION,'/')[1] ='RFSPIncludingInvalid95' and split(a.LOCATION,'/')[2] = 'LCG4' THEN ULUeThruVol END) ULUeThruVol_RFSP95_LCG4,
						sum(CASE WHEN split(a.LOCATION,'/')[1] ='RFSPIncludingInvalid95' and split(a.LOCATION,'/')[2] = 'LCG4' THEN ULUeThruTime END) ULUeThruTime_RFSP95_LCG4
						
						-- select *
					from apachedataingestion.nr.uplinkuethroughputperrfsp_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T9 on M0.CalendarDate=T9.CalendarDate and M0.Hour24=T9.Hour24 and M0.du_id=T9.du_id and M0.GCELL_ID=T9.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(NrdcAddSn_PrepFail_CpFail) NrdcAddSn_PrepFail_CpFail,
						sum(NrdcAddSn_PrepFail_UpFail) NrdcAddSn_PrepFail_UpFail,
						sum(NrdcAddSn_PrepFail_DuFail) NrdcAddSn_PrepFail_DuFail,
						sum(NrdcAddSn_Att) NrdcAddSn_Att
						
						-- select *
					from apachedataingestion.nr.nrdcsnodeadditonofsnwithduidentifier_nr_hr_silver  a
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[2],'CellIdentityWithInvalid','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T10 on M0.CalendarDate=T10.CalendarDate and M0.Hour24=T10.Hour24 and M0.du_id=T10.du_id and M0.GCELL_ID=T10.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						
							sum(DrbSetupAtt) DrbSetupAtt,
							sum(DrbSetupSucc) DrbSetupSucc,
							sum(CASE WHEN split(LOCATION,'/')[3]='5QI132' then DrbSetupAtt END) DrbSetupAtt_5QI132,
							sum(CASE WHEN split(LOCATION,'/')[3]='5QI132' then DrbSetupSucc END) DrbSetupSucc_5QI132
					
						-- select *
						FROM apachedataingestion.nr.drbsetupwithduidentifier_nr_hr_silver a
										
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T11 on M0.CalendarDate=T11.CalendarDate and M0.Hour24=T11.Hour24 and M0.du_id=T11.du_id and M0.GCELL_ID=T11.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[5] in ('RFSPIncludingInvalid115','RFSPIncludingInvalid95') THEN ConnNoTotPlmnRfsp END ) ConnNoTotPlmnRfsp_RFSP_115_95,
						sum(CASE WHEN split(a.LOCATION,'/')[5] in ('RFSPIncludingInvalid115','RFSPIncludingInvalid95') THEN ConnNoCntPlmnRfsp END ) ConnNoCntPlmnRfsp_RFSP_115_95,
						max(CASE WHEN split(a.LOCATION,'/')[5] in ('RFSPIncludingInvalid115','RFSPIncludingInvalid95') THEN ConnNoMaxPlmnRfsp END ) ConnNoMaxPlmnRfsp_RFSP_115_95
					
						-- select *
					from apachedataingestion.nr.rrcconnectioninformationwithduidentifierperplmnperrfsp_nr_hr_silver  a
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[2],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T12 on M0.CalendarDate=T12.CalendarDate and M0.Hour24=T12.Hour24 and M0.du_id=T12.du_id and M0.GCELL_ID=T12.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[1] in ('RFSPIncludingInvalid115','RFSPIncludingInvalid95') THEN AirMacDLByte END ) AirMacDLByte_RFSP_115_95,
						sum(CASE WHEN split(a.LOCATION,'/')[1] in ('RFSPIncludingInvalid115','RFSPIncludingInvalid95') THEN AirMacULByte END ) AirMacULByte_RFSP_115_95

						-- select *
					from  apachedataingestion.nr.airmacpacketperrfspnr_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T13 on M0.CalendarDate=T13.CalendarDate and M0.Hour24=T13.Hour24 and M0.du_id=T13.du_id and M0.GCELL_ID=T13.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[2] in ('RFSPIncludingInvalid115','RFSPIncludingInvalid95') THEN DLUeThruVol_SA END ) DLUeThruVol_SA_RFSP_115_95,
						sum(CASE WHEN split(a.LOCATION,'/')[2] in ('RFSPIncludingInvalid115','RFSPIncludingInvalid95') THEN DLUeThruTime_SA END ) DLUeThruTime_SA_RFSP_115_95,
						sum(CASE WHEN split(a.LOCATION,'/')[2] = 'RFSPIncludingInvalid95' and split(a.LOCATION,'/')[3] = '5QI133' and split(a.LOCATION,'/')[4] = 'SNSSAI16777222'  THEN DLUeThruVol_SA END ) DLUeThruVol_SA_RFSP_95_5QI_133_SNSSAI_16777222,
						sum(CASE WHEN split(a.LOCATION,'/')[2] = 'RFSPIncludingInvalid95' and split(a.LOCATION,'/')[3] = '5QI133' and split(a.LOCATION,'/')[4] = 'SNSSAI16777222' THEN DLUeThruTime_SA END ) DLUeThruTime_SA_RFSP_95_5QI_133_SNSSAI_16777222
					
						-- select *
					from  apachedataingestion.nr.uethroughputperplmnperrfsppersnssaiforsa_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T14 on M0.CalendarDate=T14.CalendarDate and M0.Hour24=T14.Hour24 and M0.du_id=T14.du_id and M0.GCELL_ID=T14.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = 'SNSSAI16777222' THEN DrbSetupPlmnSnssaiAtt END ) DrbSetupPlmnSnssaiAtt_SNSSAI_16777222,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = 'SNSSAI16777222' THEN DrbSetupPlmnSnssaiSucc END ) DrbSetupPlmnSnssaiSucc_SNSSAI_16777222
						-- select *
					from  apachedataingestion.nr.drbsetupwithduidentifierperplmnpersnssai_nr_hr_silver  a
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T15 on M0.CalendarDate=T15.CalendarDate and M0.Hour24=T15.Hour24 and M0.du_id=T15.du_id and M0.GCELL_ID=T15.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[3] = '5QI133' THEN DrbRelTotal END )  DrbRelTotal_5QI133,
						sum(CASE WHEN split(a.LOCATION,'/')[3] = '5QI133' THEN DrbRelbyAmf_UeContextRelCmd_IntraNrHo END )  DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI133,
						sum(CASE WHEN split(a.LOCATION,'/')[3] = '5QI133' THEN DrbRelbyAmf_PduSessionRelCmd END )  DrbRelbyAmf_PduSessionRelCmd_5QI133,
						sum(CASE WHEN split(a.LOCATION,'/')[3] = '5QI133' THEN DrbRelbyAmf_PduSessionModifyReq END )  DrbRelbyAmf_PduSessionModifyReq_5QI133,
						sum(CASE WHEN split(a.LOCATION,'/')[3] = '5QI133' THEN DrbRelbyAmf_UeContextRelCmd END )  DrbRelbyAmf_UeContextRelCmd_5QI133,
						sum(CASE WHEN split(a.LOCATION,'/')[3] = '5QI133' THEN DrbRelbyGnb_UeContextRelReq_WithNormalCause END )  DrbRelbyGnb_UeContextRelReq_WithNormalCause_5QI133,
						sum(CASE WHEN split(a.LOCATION,'/')[3] = '5QI133' THEN DrbRelbyIntraRatRedirection END )  DrbRelbyIntraRatRedirection_5QI133,
						sum(CASE WHEN split(a.LOCATION,'/')[3] = '5QI133' THEN DrbRelbyInterRatRedirection END )  DrbRelbyInterRatRedirection_5QI133,
						sum(CASE WHEN split(a.LOCATION,'/')[3] = '5QI133' THEN DrbRelbyPreemption END )  DrbRelbyPreemption_5QI133
												
						-- select *
					from  apachedataingestion.nr.releaseofsetupdrbwithduidentifier_nr_hr_silver  a
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T16 on M0.CalendarDate=T16.CalendarDate and M0.Hour24=T16.Hour24 and M0.du_id=T16.du_id and M0.GCELL_ID=T16.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = '5QI133' THEN DrbRelbyAmf_PduSessionRelCmd END )  DrbRelbyAmf_PduSessionRelCmd_5QI133_active,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = '5QI133' THEN DrbRelbyAmf_PduSessionRelCmd_WithNormalCause END )  DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI133_active,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = '5QI133' THEN DrbRelbyAmf_PduSessionModifyReq END )  DrbRelbyAmf_PduSessionModifyReq_5QI133_active,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = '5QI133' THEN DrbRelbyAmf_PduSessionModifyReq_WithNormalCause END )  DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI133_active,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = '5QI133' THEN DrbRelbyAmf_UeContextRelCmd END )  DrbRelbyAmf_UeContextRelCmd_5QI133_active,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = '5QI133' THEN DrbRelbyAmf_UeContextRelCmd_WithNormalCause END )  DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI133_active,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = '5QI133' THEN DrbRelbyAmf_UeContextRelCmd_IntraNrHo END )  DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI133_active,
						sum(CASE WHEN split(a.LOCATION,'/')[4] = '5QI133' THEN DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause END )  DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI133_active
					
						-- select *
					from  apachedataingestion.nr.releaseofsetupactivedrbwithduidentifier_nr_hr_silver  a
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_DU_ID','') as bigint)=b.kDU_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T17 on M0.CalendarDate=T17.CalendarDate and M0.Hour24=T17.Hour24 and M0.du_id=T17.du_id and M0.GCELL_ID=T17.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[2] = '5QI133' THEN RlcDLByte END )  RlcDLByte_5QI133,
						sum(CASE WHEN split(a.LOCATION,'/')[2] = '5QI133' THEN RlcULByte END )  RlcULByte_5QI133
												
						-- select *
					from  apachedataingestion.nr.rlcpacketperplmnforsa_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T18 on M0.CalendarDate=T18.CalendarDate and M0.Hour24=T18.Hour24 and M0.du_id=T18.du_id and M0.GCELL_ID=T18.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(CASE WHEN split(a.LOCATION,'/')[2] = '5QI133' and split(a.LOCATION,'/')[3] = 'SNSSAI16777222' THEN RlcSduDelayTot_SA END )  RlcSduDelayTot_SA_5QI133_SNSSAI_16777222,
						sum(CASE WHEN split(a.LOCATION,'/')[2] = '5QI133' and split(a.LOCATION,'/')[3] = 'SNSSAI16777222' THEN RlcSduDelayCnt_SA END )  RlcSduDelayCnt_SA_5QI133_SNSSAI_16777222
												
						-- select *
					from  apachedataingestion.nr.airinterfacedelayperplmnpersnssaiforsa_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T19 on M0.CalendarDate=T19.CalendarDate and M0.Hour24=T19.Hour24 and M0.du_id=T19.du_id and M0.GCELL_ID=T19.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(DiscardedPaging) DiscardedPaging,	
						sum(AttPaging) AttPaging
												
						-- select *
					from  apachedataingestion.nr.paging_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T20 on M0.CalendarDate=T20.CalendarDate and M0.Hour24=T20.Hour24 and M0.du_id=T20.du_id and M0.GCELL_ID=T20.GCELL_ID
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(_0xB006_CauseInternalCacCallCountOver) _0xB006_CauseInternalCacCallCountOver	
						
												
						-- select *
					from  apachedataingestion.nr.ducslhexa_nr_hr_silver  a
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T21 on M0.CalendarDate=T21.CalendarDate and M0.Hour24=T21.Hour24 and M0.du_id=T21.du_id and M0.GCELL_ID=T21.GCELL_ID
			
			
) X
GROUP BY CalendarDate,Hour24,GNODEB_ID,du_id,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME;  


          


delete from hive_metastore.default.widetable_5g_cell_hr_tmp2;

insert into hive_metastore.default.widetable_5g_cell_hr_tmp2
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	-- select count(distinct concat(GNODEB_ID,'_',DU_ID,'_',GCELL_ID)) --514527
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							-- select count(*)
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
)
select 
CalendarDate ,
Hour24 ,
GNODEB_ID,
du_id ,
GCELL_ID ,
MARKET_NAME ,
case when length(du_id)=14 then 
	case when substring(du_id, 7, 1)=0 then 'FR2' 	 when substring(du_id, 7, 1)=9 then 
				case when substring(du_id, 11, 1)=2 then 'FR1/LS3' when substring(du_id, 11, 1)=3 then 'FR1/LS6' 
				end
	end
else '' end NR_TYPE,
substring(du_id,4,3) SUB_MARKET_ID,
SUB_MARKET_NAME ,
max(S5NR_DLPRBUtilization_PCT_Num) S5NR_DLPRBUtilization_PCT_Num,
max(S5NR_DLPRBUtilization_PCT_Denom) S5NR_DLPRBUtilization_PCT_Denom,
max(S5NR_DLPRBUtilization_PCT_DSS_Num) S5NR_DLPRBUtilization_PCT_DSS_Num,
max(S5NR_DLPRBUtilization_PCT_DSS_Denom) S5NR_DLPRBUtilization_PCT_DSS_Denom,
max(S5NR_DLTTIUtilization_PCT_DSS_Num) S5NR_DLTTIUtilization_PCT_DSS_Num,
max(S5NR_DLTTIUtilization_PCT_DSS_Denom) S5NR_DLTTIUtilization_PCT_DSS_Denom,
max(S5NR_ULPRBUtilization_PCT_Num) S5NR_ULPRBUtilization_PCT_Num,
max(S5NR_ULPRBUtilization_PCT_Denom) S5NR_ULPRBUtilization_PCT_Denom,
max(S5NR_ULPRBUtilization_PCT_DSS_Num) S5NR_ULPRBUtilization_PCT_DSS_Num,
max(S5NR_ULPRBUtilization_PCT_DSS_Denom) S5NR_ULPRBUtilization_PCT_DSS_Denom,
max(S5NR_ULTTIUtilization_PCT_DSS_Num) S5NR_ULTTIUtilization_PCT_DSS_Num,
max(S5NR_ULTTIUtilization_PCT_DSS_Denom) S5NR_ULTTIUtilization_PCT_DSS_Denom,
max(S5NR_DLInitBLER_PCT_Num) S5NR_DLInitBLER_PCT_Num,
max(S5NR_DLInitBLER_PCT_Denom) S5NR_DLInitBLER_PCT_Denom,
max(S5NR_DLResidualBLER_PCT_Num) S5NR_DLResidualBLER_PCT_Num,
max(S5NR_DLResidualBLER_PCT_Denom) S5NR_DLResidualBLER_PCT_Denom,
max(S5NR_ULInitBLER_PCT_Num) S5NR_ULInitBLER_PCT_Num,
max(S5NR_ULInitBLER_PCT_Denom) S5NR_ULInitBLER_PCT_Denom,
max(S5NR_ULResidualBLER_PCT_Num) S5NR_ULResidualBLER_PCT_Num,
max(S5NR_ULResidualBLER_PCT_Denom) S5NR_ULResidualBLER_PCT_Denom,
max(DSS_INFO_DssNRDLPrbAvailable) DSS_INFO_DssNRDLPrbAvailable,
max(DSS_INFO_DssNRDLPrbUsed) DSS_INFO_DssNRDLPrbUsed,
max(DSS_INFO_DssNRDLTtiAvailable) DSS_INFO_DssNRDLTtiAvailable,
max(DSS_INFO_DssNRULPrbAvailable) DSS_INFO_DssNRULPrbAvailable,
max(DSS_INFO_DssNRULPrbUsed) DSS_INFO_DssNRULPrbUsed,
max(DSS_INFO_DssNRULTtiAvailable) DSS_INFO_DssNRULTtiAvailable,
max(PRB_TOTAL_TotDLAvailablePrb) PRB_TOTAL_TotDLAvailablePrb,
max(PRB_TOTAL_TotDLBroadcastPrb) PRB_TOTAL_TotDLBroadcastPrb,
max(PRB_TOTAL_TotDLUnicastPrb) PRB_TOTAL_TotDLUnicastPrb,
max(PRB_TOTAL_TotULAvailablePrb) PRB_TOTAL_TotULAvailablePrb,
max(PRB_TOTAL_TotULUsedPrb) PRB_TOTAL_TotULUsedPrb,
--add
max(S5NR_RLC_Delay_ms_Num) S5NR_RLC_Delay_ms_Num,
max(S5NR_RLC_Delay_ms_Denom) S5NR_RLC_Delay_ms_Denom,
max(S5NR_AirIF_Delay_ms_Num) S5NR_AirIF_Delay_ms_Num,
max(S5NR_AirIF_Delay_ms_Denom) S5NR_AirIF_Delay_ms_Denom,
max(S5NR_CADLMACLayerDataVolumePCell_MB) S5NR_CADLMACLayerDataVolumePCell_MB,
max(S5NR_CAULMACLayerDataVolumePCell_MB) S5NR_CAULMACLayerDataVolumePCell_MB,
max(S5NR_CADLMACLayerDataVolumeSCell_MB) S5NR_CADLMACLayerDataVolumeSCell_MB,
max(S5NR_CAULMACLayerDataVolumeSCell_MB) S5NR_CAULMACLayerDataVolumeSCell_MB,
max(S5NR_PDCCH_Block_DL_pct_NUM) S5NR_PDCCH_Block_DL_pct_NUM,
max(S5NR_PDCCH_Block_DL_pct_DENOM) S5NR_PDCCH_Block_DL_pct_DENOM,
max(S5NR_PDCCH_Block_UL_pct_NUM) S5NR_PDCCH_Block_UL_pct_NUM,
max(S5NR_PDCCH_Block_UL_pct_DENOM) S5NR_PDCCH_Block_UL_pct_DENOM,
max(S5NR_PDCCH_Blocking_Tot_pct_NUM) S5NR_PDCCH_Blocking_Tot_pct_NUM,
max(S5NR_PDCCH_Blocking_Tot_pct_DENOM) S5NR_PDCCH_Blocking_Tot_pct_DENOM,
max(S5NR_PDCCH_AggLvl1_DL_pct_NUM) S5NR_PDCCH_AggLvl1_DL_pct_NUM,
max(S5NR_PDCCH_AggLvl1_DL_pct_DENOM) S5NR_PDCCH_AggLvl1_DL_pct_DENOM,
max(S5NR_PDCCH_AggLvl2_DL_pct_NUM) S5NR_PDCCH_AggLvl2_DL_pct_NUM,
max(S5NR_PDCCH_AggLvl2_DL_pct_DENOM) S5NR_PDCCH_AggLvl2_DL_pct_DENOM,
max(S5NR_PDCCH_AggLvl4_DL_pct_NUM) S5NR_PDCCH_AggLvl4_DL_pct_NUM,
max(S5NR_PDCCH_AggLvl4_DL_pct_DENOM) S5NR_PDCCH_AggLvl4_DL_pct_DENOM,
max(S5NR_PDCCH_AggLvl8_DL_pct_NUM) S5NR_PDCCH_AggLvl8_DL_pct_NUM,
max(S5NR_PDCCH_AggLvl8_DL_pct_DENOM) S5NR_PDCCH_AggLvl8_DL_pct_DENOM,
max(S5NR_PDCCH_AggLvl1_UL_pct_NUM) S5NR_PDCCH_AggLvl1_UL_pct_NUM,
max(S5NR_PDCCH_AggLvl1_UL_pct_DENOM) S5NR_PDCCH_AggLvl1_UL_pct_DENOM,
max(S5NR_PDCCH_AggLvl2_UL_pct_NUM) S5NR_PDCCH_AggLvl2_UL_pct_NUM,
max(S5NR_PDCCH_AggLvl2_UL_pct_DENOM) S5NR_PDCCH_AggLvl2_UL_pct_DENOM,
max(S5NR_PDCCH_AggLvl4_UL_pct_NUM) S5NR_PDCCH_AggLvl4_UL_pct_NUM,
max(S5NR_PDCCH_AggLvl4_UL_pct_DENOM) S5NR_PDCCH_AggLvl4_UL_pct_DENOM,
max(S5NR_PDCCH_AggLvl8_UL_pct_NUM) S5NR_PDCCH_AggLvl8_UL_pct_NUM,
max(S5NR_PDCCH_AggLvl8_UL_pct_DENOM) S5NR_PDCCH_AggLvl8_UL_pct_DENOM,
max(S5NR_CA_Addition_Attempts) S5NR_CA_Addition_Attempts,
max(S5NR_CA_Addition_Failure_PCT_NUM) S5NR_CA_Addition_Failure_PCT_NUM,
max(S5NR_CA_Addition_Failure_PCT_DENOM) S5NR_CA_Addition_Failure_PCT_DENOM,
max(S5NR_CA_Activation_Attempts) S5NR_CA_Activation_Attempts,
max(S5NR_CA_Activation_Failure_PCT_Num) S5NR_CA_Activation_Failure_PCT_Num,
max(S5NR_CA_Activation_Failure_PCT_Denom) S5NR_CA_Activation_Failure_PCT_Denom,
max(S5NR_CA_Deactivation_Attempts) S5NR_CA_Deactivation_Attempts,
max(S5NR_CA_Deactivation_Failure_PCT_Num) S5NR_CA_Deactivation_Failure_PCT_Num,
max(S5NR_CA_Deactivation_Failure_PCT_Denom) S5NR_CA_Deactivation_Failure_PCT_Denom,
max(S5NR_CA_AvgAddDuration_s_NUM) S5NR_CA_AvgAddDuration_s_NUM,
max(S5NR_CA_AvgAddDuration_s_DENOM) S5NR_CA_AvgAddDuration_s_DENOM,
max(S5NR_CA_MaxAddDuration_s) S5NR_CA_MaxAddDuration_s,
max(S5NR_CA_TotAddDuration_s) S5NR_CA_TotAddDuration_s,
max(S5NR_CA_NumF1UECtxtSetupReq_NonCaCapUE) S5NR_CA_NumF1UECtxtSetupReq_NonCaCapUE,
max(S5NR_CA_NumF1UECtxtSetupReq_CaCapUE) S5NR_CA_NumF1UECtxtSetupReq_CaCapUE,
max(S5NR_CA_NumF1UECtxtSetupReq_NonULCaCapUE) S5NR_CA_NumF1UECtxtSetupReq_NonULCaCapUE,
max(S5NR_CA_NumF1UECtxtSetupReq_ULCaCapUE) S5NR_CA_NumF1UECtxtSetupReq_ULCaCapUE,
max(S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_NUM) S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_NUM,
max(S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_DENOM) S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_DENOM,
max(S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_NUM) S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_NUM,
max(S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_DENOM) S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_DENOM,
max(S5NR_ULAvgAssignedMCS_NUM) S5NR_ULAvgAssignedMCS_NUM,
max(S5NR_ULAvgAssignedMCS_DENOM) S5NR_ULAvgAssignedMCS_DENOM,
max(S5_AverageCQI_NUM) S5_AverageCQI_NUM,
max(S5_AverageCQI_DENOM) S5_AverageCQI_DENOM,
max(S5NR_RACH_SR_pct_NUM) S5NR_RACH_SR_pct_NUM,
max(S5NR_RACH_SR_pct_DENOM) S5NR_RACH_SR_pct_DENOM,
max(S5NR_RACH_CB_SR_pct_NUM) S5NR_RACH_CB_SR_pct_NUM,
max(S5NR_RACH_CB_SR_pct_DENOM) S5NR_RACH_CB_SR_pct_DENOM,
max(S5NR_RACH_CF_SR_pct_NUM) S5NR_RACH_CF_SR_pct_NUM,
max(S5NR_RACH_CF_SR_pct_DENOM) S5NR_RACH_CF_SR_pct_DENOM,
max(S5NR_RACH_Att_MSG1_CB) S5NR_RACH_Att_MSG1_CB,
max(S5NR_RACH_Att_MSG1_CF) S5NR_RACH_Att_MSG1_CF,
max(S5NR_RACH_Att_MSG2_CB) S5NR_RACH_Att_MSG2_CB,
max(S5NR_RACH_Att_MSG2_CF) S5NR_RACH_Att_MSG2_CF,
max(S5NR_RACH_Att_MSG3_CB) S5NR_RACH_Att_MSG3_CB,
max(S5NR_RACH_Att_MSG3_CF) S5NR_RACH_Att_MSG3_CF,
max(S5NR_RACH_Att_MSG5_CB) S5NR_RACH_Att_MSG5_CB,
max(S5NR_PUCCHAvgSINR_dB_NUM) S5NR_PUCCHAvgSINR_dB_NUM,
max(S5NR_PUCCHAvgSINR_dB_DENOM)  S5NR_PUCCHAvgSINR_dB_DENOM,
max(S5NR_PUSCHAvgSINR_dB_NUM) S5NR_PUSCHAvgSINR_dB_NUM,							
max(S5NR_PUSCHAvgSINR_dB_DENOM) S5NR_PUSCHAvgSINR_dB_DENOM,
max(Average_RSSI_Path0_3_Num) Average_RSSI_Path0_3_Num,
max(Average_RSSI_Path0_3_Denom) Average_RSSI_Path0_3_Denom,
max(S5NR_DLAvgAssignedMCS_NUM) S5NR_DLAvgAssignedMCS_NUM,
max(S5NR_DLAvgAssignedMCS_DENOM) S5NR_DLAvgAssignedMCS_DENOM,
-- add
max(RssiPathMax) RssiPathMax,
max(S5NR_PDCCH_SlotRationBlocking_DL_PCT_Num) S5NR_PDCCH_SlotRationBlocking_DL_PCT_Num,
max(S5NR_PDCCH_SlotRationBlocking_DL_PCT_Denom) S5NR_PDCCH_SlotRationBlocking_DL_PCT_Denom,
max(S5NR_PDCCH_SlotRationBlocking_UL_PCT_Num) S5NR_PDCCH_SlotRationBlocking_UL_PCT_Num,
max(S5NR_PDCCH_SlotRationBlocking_UL_PCT_Denom) S5NR_PDCCH_SlotRationBlocking_UL_PCT_Denom,
max(S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Num) S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Num,
max(S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Denom) S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Denom,
max(S5NR_PDCCH_AggLvl16_DL_PCT_Num) S5NR_PDCCH_AggLvl16_DL_PCT_Num,
max(S5NR_PDCCH_AggLvl16_DL_PCT_Denom) S5NR_PDCCH_AggLvl16_DL_PCT_Denom,
max(S5NR_PDCCH_AggLvl16_UL_PCT_Num) S5NR_PDCCH_AggLvl16_UL_PCT_Num,
max(S5NR_PDCCH_AggLvl16_UL_PCT_Denom) S5NR_PDCCH_AggLvl16_UL_PCT_Denom,
max(Cell_Availability_Num) Cell_Availability_Num,
max(Cell_Availability_Denom) Cell_Availability_Denom,
-- add
max(S5NR_AvgRRCConnectionHoldTime_s_Num) S5NR_AvgRRCConnectionHoldTime_s_Num,	
max(S5NR_AvgRRCConnectionHoldTime_s_Denom) S5NR_AvgRRCConnectionHoldTime_s_Denom,
max(S5NR_PUCCH_BLER_PCT_Num) S5NR_PUCCH_BLER_PCT_Num , 
max(S5NR_PUCCH_BLER_PCT_Denom) S5NR_PUCCH_BLER_PCT_Denom,
max(S5NR_PDCCH_Fail_DL_PCT_Num) S5NR_PDCCH_Fail_DL_PCT_Num,	
max(S5NR_PDCCH_Fail_DL_PCT_Denom) S5NR_PDCCH_Fail_DL_PCT_Denom,
max(S5NR_PDCCH_Fail_UL_PCT_Num) S5NR_PDCCH_Fail_UL_PCT_Num,
max(S5NR_PDCCH_Fail_UL_PCT_Denom) S5NR_PDCCH_Fail_UL_PCT_Denom,
max(S5NR_AvgNumMuMimoLayerPerMuTti_DL_Num) S5NR_AvgNumMuMimoLayerPerMuTti_DL_Num,	
max(S5NR_AvgNumMuMimoLayerPerMuTti_DL_Denom) S5NR_AvgNumMuMimoLayerPerMuTti_DL_Denom,
max(S5NR_AvgNumMuMimoUePerMuTti_DL_Num) S5NR_AvgNumMuMimoUePerMuTti_DL_Num,	
max(S5NR_AvgNumMuMimoUePerMuTti_DL_Denom) S5NR_AvgNumMuMimoUePerMuTti_DL_Denom,
max(S5NR_MuMimoUeRatio_DL_PCT_Num) S5NR_MuMimoUeRatio_DL_PCT_Num,	
max(S5NR_MuMimoUsedPrbRatio_DL_PCT_Num) S5NR_MuMimoUsedPrbRatio_DL_PCT_Num,	
max(S5NR_MuMimoUsedPrbRatio_DL_PCT_Denom) S5NR_MuMimoUsedPrbRatio_DL_PCT_Denom,
max(RlcDLByte_5qi)  RlcDLByte_5qi,
max(RlcULByte_5qi)	RlcULByte_5qi,
max(PUCCH_TotULPrb) PUCCH_TotULPrb,
--Added new KPIs on 1/23/2025 DENG-2659
max(S5NR_Cell_Availability_PCT_Num) S5NR_Cell_Availability_PCT_Num,
max(S5NR_Cell_Availability_PCT_Denom) S5NR_Cell_Availability_PCT_Denom,
max(S5NR_Cell_Availability_PCT_excl_Lock_ES_Num) S5NR_Cell_Availability_PCT_excl_Lock_ES_Num,
max(S5NR_Cell_Availability_PCT_excl_Lock_ES_Denom) S5NR_Cell_Availability_PCT_excl_Lock_ES_Denom,
max(CellUnavailableTimeLock_s_SUM) CellUnavailableTimeLock_s_SUM,
max(CellUnavailableTimeES_s_SUM) CellUnavailableTimeES_s_SUM	,
max(CellUnavailableTimeDown_s_SUM) CellUnavailableTimeDown_s_SUM,
max(CellAvailPmPeriodTime_s_SUM) CellAvailPmPeriodTime_s_SUM 
from (
			select 
			COALESCE(M0.CalendarDate,T1.CalendarDate,T2.CalendarDate,T3.CalendarDate,T4.CalendarDate,T5.CalendarDate,T6.CalendarDate,T7.CalendarDate,T8.CalendarDate,T9.CalendarDate,T10.CalendarDate,T11.CalendarDate,T12.CalendarDate,T13.CalendarDate,T14.CalendarDate,T15.CalendarDate,T16.CalendarDate,T17.CalendarDate,T18.CalendarDate,T19.CalendarDate,T20.CalendarDate,T21.CalendarDate,T22.CalendarDate,T23.CalendarDate,T24.CalendarDate,T25.CalendarDate) CalendarDate,
			COALESCE(M0.Hour24,T1.Hour24,T2.Hour24,T3.Hour24,T3.Hour24,T4.Hour24,T5.Hour24,T6.Hour24,T7.Hour24,T8.Hour24,T9.Hour24,T10.Hour24,T11.Hour24,T12.Hour24,T13.Hour24,T14.Hour24,T15.Hour24,T16.Hour24,T17.Hour24,T18.Hour24,T19.Hour24,T20.Hour24,T21.Hour24,T22.Hour24,T23.Hour24,T24.Hour24,T25.Hour24) Hour24,
			COALESCE(M0.GNODEB_ID,T1.GNODEB_ID,T2.GNODEB_ID,T3.GNODEB_ID,T3.GNODEB_ID,T4.GNODEB_ID,T5.GNODEB_ID,T6.GNODEB_ID,T7.GNODEB_ID,T8.GNODEB_ID,T9.GNODEB_ID,T10.GNODEB_ID,T11.GNODEB_ID,T12.GNODEB_ID,T13.GNODEB_ID,T14.GNODEB_ID,T15.GNODEB_ID,T16.GNODEB_ID,T17.GNODEB_ID,T18.GNODEB_ID,T19.GNODEB_ID,T20.GNODEB_ID,T21.GNODEB_ID,T22.GNODEB_ID,T23.GNODEB_ID,T24.GNODEB_ID,T25.GNODEB_ID) GNODEB_ID,
			COALESCE(M0.du_id,T1.du_id,T2.du_id,T3.du_id,T3.du_id,T4.du_id,T5.du_id,T6.du_id,T7.du_id,T8.du_id,T9.du_id,T10.du_id,T11.du_id,T12.du_id,T13.du_id,T14.du_id,T15.du_id,T16.du_id,T17.du_id,T18.du_id,T19.du_id,T20.du_id,T21.du_id,T22.du_id,T23.du_id,T24.du_id,T25.du_id) du_id,
			COALESCE(M0.GCELL_ID,T1.GCELL_ID,T2.GCELL_ID,T3.GCELL_ID,T3.GCELL_ID,T4.GCELL_ID,T5.GCELL_ID,T6.GCELL_ID,T7.GCELL_ID,T8.GCELL_ID,T9.GCELL_ID,T10.GCELL_ID,T11.GCELL_ID,T12.GCELL_ID,T13.GCELL_ID,T14.GCELL_ID,T15.GCELL_ID,T16.GCELL_ID,T17.GCELL_ID,T18.GCELL_ID,T19.GCELL_ID,T20.GCELL_ID,T21.GCELL_ID,T22.GCELL_ID,T23.GCELL_ID,T24.GCELL_ID,T25.GCELL_ID) GCELL_ID,
			COALESCE(M0.MARKET_NAME,T1.MARKET_NAME,T2.MARKET_NAME,T3.MARKET_NAME,T3.MARKET_NAME,T4.MARKET_NAME,T5.MARKET_NAME,T6.MARKET_NAME,T7.MARKET_NAME,T8.MARKET_NAME,T9.MARKET_NAME,T10.MARKET_NAME,T11.MARKET_NAME,T12.MARKET_NAME,T13.MARKET_NAME,T14.MARKET_NAME,T15.MARKET_NAME,T16.MARKET_NAME,T17.MARKET_NAME,T18.MARKET_NAME,T19.MARKET_NAME,T20.MARKET_NAME,T21.MARKET_NAME,T22.MARKET_NAME,T23.MARKET_NAME,T24.MARKET_NAME,T25.MARKET_NAME) MARKET_NAME,						
			COALESCE(M0.SUB_MARKET_NAME,T1.SUB_MARKET_NAME,T2.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T4.SUB_MARKET_NAME,T5.SUB_MARKET_NAME,T6.SUB_MARKET_NAME,T7.SUB_MARKET_NAME,T8.SUB_MARKET_NAME,T9.SUB_MARKET_NAME,T10.SUB_MARKET_NAME,T11.SUB_MARKET_NAME,T12.SUB_MARKET_NAME,T13.SUB_MARKET_NAME,T14.SUB_MARKET_NAME,T15.SUB_MARKET_NAME,T16.SUB_MARKET_NAME,T17.SUB_MARKET_NAME,T18.SUB_MARKET_NAME,T19.SUB_MARKET_NAME,T20.SUB_MARKET_NAME,T21.SUB_MARKET_NAME,T22.SUB_MARKET_NAME,T23.SUB_MARKET_NAME,T24.SUB_MARKET_NAME,T25.SUB_MARKET_NAME) SUB_MARKET_NAME,
			TotDLUnicastPrb	 						S5NR_DLPRBUtilization_PCT_Num,
			(TotDLAvailablePrb-TotDLBroadcastPrb) 	S5NR_DLPRBUtilization_PCT_Denom,
			DssNrDLPrbUsed 			S5NR_DLPRBUtilization_PCT_DSS_Num,
			DssNrDLPrbAvailable 	S5NR_DLPRBUtilization_PCT_DSS_Denom,
			DssNrDLTtiUsed 			S5NR_DLTTIUtilization_PCT_DSS_Num,
			DssNrDLTtiAvailable 	S5NR_DLTTIUtilization_PCT_DSS_Denom,
			TotULUsedPrb			S5NR_ULPRBUtilization_PCT_Num,
			TotULAvailablePrb 		S5NR_ULPRBUtilization_PCT_Denom,
			DssNrULPrbUsed 			S5NR_ULPRBUtilization_PCT_DSS_Num,	
			DssNrULPrbAvailable 	S5NR_ULPRBUtilization_PCT_DSS_Denom,
			DssNrULTtiUsed 			S5NR_ULTTIUtilization_PCT_DSS_Num,	
			DssNrULTtiAvailable 	S5NR_ULTTIUtilization_PCT_DSS_Denom,
			Nrof2ndTxTrial_DL		S5NR_DLInitBLER_PCT_Num,
			Nrof1stTxTrial_DL		S5NR_DLInitBLER_PCT_Denom,
			NrofResidualError_DL	S5NR_DLResidualBLER_PCT_Num,
			Nrof1stTxTrial_DL		S5NR_DLResidualBLER_PCT_Denom,
			Nrof2ndTxTrial_UL		S5NR_ULInitBLER_PCT_Num,
			Nrof1stTxTrial_UL		S5NR_ULInitBLER_PCT_Denom,
			NrofResidualError_UL	S5NR_ULResidualBLER_PCT_Num,
			Nrof1stTxTrial_UL 		S5NR_ULResidualBLER_PCT_Denom,
			DssNRDLPrbAvailable	  DSS_INFO_DssNRDLPrbAvailable,       
			DssNRDLPrbUsed		  DSS_INFO_DssNRDLPrbUsed,            
			DssNRDLTtiAvailable	  DSS_INFO_DssNRDLTtiAvailable,       
			DssNRULPrbAvailable	  DSS_INFO_DssNRULPrbAvailable,       
			DssNRULPrbUsed		  DSS_INFO_DssNRULPrbUsed,            
			DssNRULTtiAvailable	  DSS_INFO_DssNRULTtiAvailable, 			
			TotDLAvailablePrb	  PRB_TOTAL_TotDLAvailablePrb,        
			TotDLBroadcastPrb	  PRB_TOTAL_TotDLBroadcastPrb,        
			TotDLUnicastPrb		  PRB_TOTAL_TotDLUnicastPrb,          
			TotULAvailablePrb	  PRB_TOTAL_TotULAvailablePrb,        
			TotULUsedPrb		  PRB_TOTAL_TotULUsedPrb,
			--add
			RlcSduDelayTot/1000		S5NR_RLC_Delay_ms_Num,
			RlcSduDelayCnt			S5NR_RLC_Delay_ms_Denom,
			AirIfDelayTot/1000		S5NR_AirIF_Delay_ms_Num,
			AirIfDelayCnt			S5NR_AirIF_Delay_ms_Denom,
			AirMacDLByte_PCELL 	S5NR_CADLMACLayerDataVolumePCell_MB,
			AirMacULByte_PCELL 	S5NR_CAULMACLayerDataVolumePCell_MB,
			AirMacDLByte_SCELL	S5NR_CADLMACLayerDataVolumeSCell_MB,
			AirMacULByte_SCELL	S5NR_CAULMACLayerDataVolumeSCell_MB,
			(NumBlockedPDCCHDL) S5NR_PDCCH_Block_DL_pct_NUM,
			(NumAttemptPDCCHDL) S5NR_PDCCH_Block_DL_pct_DENOM,
			(NumBlockedPDCCHUL) S5NR_PDCCH_Block_UL_pct_NUM,
			(NumAttemptPDCCHUL) S5NR_PDCCH_Block_UL_pct_DENOM,
			NumBlockedPDCCHTot S5NR_PDCCH_Blocking_Tot_pct_NUM,
			(NumAttemptPDCCHUL + NumAttemptPDCCHDL) S5NR_PDCCH_Blocking_Tot_pct_DENOM,
			AttemptAggDL1  S5NR_PDCCH_AggLvl1_DL_pct_NUM,
			(AttemptAggDL1 + AttemptAggDL2 + AttemptAggDL4 + AttemptAggDL8 + AttemptAggDL16) S5NR_PDCCH_AggLvl1_DL_pct_DENOM,
			AttemptAggDL2 S5NR_PDCCH_AggLvl2_DL_pct_NUM,
			(AttemptAggDL1 + AttemptAggDL2 + AttemptAggDL4 + AttemptAggDL8 + AttemptAggDL16) S5NR_PDCCH_AggLvl2_DL_pct_DENOM,
			AttemptAggDL4 S5NR_PDCCH_AggLvl4_DL_pct_NUM,
			(AttemptAggDL1 + AttemptAggDL2 + AttemptAggDL4 + AttemptAggDL8 + AttemptAggDL16) S5NR_PDCCH_AggLvl4_DL_pct_DENOM,
			AttemptAggDL8 S5NR_PDCCH_AggLvl8_DL_pct_NUM,
			(AttemptAggDL1 + AttemptAggDL2 + AttemptAggDL4 + AttemptAggDL8 + AttemptAggDL16) S5NR_PDCCH_AggLvl8_DL_pct_DENOM,
			AttemptAggUL1 S5NR_PDCCH_AggLvl1_UL_pct_NUM,
			(AttemptAggUL1 + AttemptAggUL2 + AttemptAggUL4 + AttemptAggUL8 + AttemptAggUL16) S5NR_PDCCH_AggLvl1_UL_pct_DENOM,
			AttemptAggUL2 S5NR_PDCCH_AggLvl2_UL_pct_NUM,
			(AttemptAggUL1 + AttemptAggUL2 + AttemptAggUL4 + AttemptAggUL8 + AttemptAggUL16) S5NR_PDCCH_AggLvl2_UL_pct_DENOM,
			AttemptAggUL4 S5NR_PDCCH_AggLvl4_UL_pct_NUM,
			(AttemptAggUL1 + AttemptAggUL2 + AttemptAggUL4 + AttemptAggUL8 + AttemptAggUL16) S5NR_PDCCH_AggLvl4_UL_pct_DENOM,
			AttemptAggUL8 S5NR_PDCCH_AggLvl8_UL_pct_NUM,
			(AttemptAggUL1 + AttemptAggUL2 + AttemptAggUL4 + AttemptAggUL8 + AttemptAggUL16) S5NR_PDCCH_AggLvl8_UL_pct_DENOM,
			CaAddAtt S5NR_CA_Addition_Attempts,
			CaAddFail+CaAddNotSelected S5NR_CA_Addition_Failure_PCT_NUM,
			CaAddAtt  S5NR_CA_Addition_Failure_PCT_DENOM,
			(SCellActAtt_DLTraffic+SCellActAtt_ULTraffic+ SCellActAtt_Blind)	S5NR_CA_Activation_Attempts,
			(SCellActAtt_DLTraffic+SCellActAtt_ULTraffic+ SCellActAtt_Blind-SCellActSucc-SCellActSucc_ULTraffic- SCellActSucc_Blind) S5NR_CA_Activation_Failure_PCT_Num,	
			(SCellActAtt_DLTraffic+SCellActAtt_ULTraffic+ SCellActAtt_Blind) S5NR_CA_Activation_Failure_PCT_Denom,
			(SCellDeactAtt_NoUse+SCellDeactAtt_Preemption+SCellDeactAtt_UAI+SCellDeactAtt_SlotAggregation)	S5NR_CA_Deactivation_Attempts,
			(SCellDeactAtt_NoUse+SCellDeactAtt_Preemption+SCellDeactAtt_UAI+SCellDeactAtt_SlotAggregation-SCellDeactSucc_NoUse-SCellDeactSucc_Preemption-SCellDeactSucc_UAI-SCellDeactSucc_SlotAggregation)	S5NR_CA_Deactivation_Failure_PCT_Num,
			(SCellDeactAtt_NoUse+SCellDeactAtt_Preemption+SCellDeactAtt_UAI+SCellDeactAtt_SlotAggregation) S5NR_CA_Deactivation_Failure_PCT_Denom,
			CaAddDurationTot S5NR_CA_AvgAddDuration_s_NUM,
			CaAddDurationCnt*1000 S5NR_CA_AvgAddDuration_s_DENOM,
			CaAddDurationMax S5NR_CA_MaxAddDuration_s,
			CaAddDurationTot/1000 S5NR_CA_TotAddDuration_s,
			CaNonCapableUe S5NR_CA_NumF1UECtxtSetupReq_NonCaCapUE,
			CaCapableUe S5NR_CA_NumF1UECtxtSetupReq_CaCapUE,
			CaUlNonCapableUe S5NR_CA_NumF1UECtxtSetupReq_NonULCaCapUE,
			CaUlCapableUe S5NR_CA_NumF1UECtxtSetupReq_ULCaCapUE,
			UsedCCEperSlot S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_NUM,
			TotCCEperSlot  S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_DENOM,
			UsedCCEperSlotUL S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_NUM,
			TotCCEperSlotUL S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_DENOM,
			S5NR_ULAvgAssignedMCS_NUM,
			S5NR_ULAvgAssignedMCS_DENOM,
			S5_AverageCQI_NUM,
			S5_AverageCQI_DENOM,
			(NumMSG5PerBeam+NumMSG3CFRAPerBeam) 								S5NR_RACH_SR_pct_NUM,
			(RachPreambleAPerBeam+RachPreambleBPerBeam+RachPreambleACFRAPerBeam) S5NR_RACH_SR_pct_DENOM,
			NumMSG5PerBeam 														S5NR_RACH_CB_SR_pct_NUM,
			(RachPreambleAPerBeam+RachPreambleBPerBeam) 						S5NR_RACH_CB_SR_pct_DENOM,
			NumMSG3CFRAPerBeam 													S5NR_RACH_CF_SR_pct_NUM,
			RachPreambleACFRAPerBeam 											S5NR_RACH_CF_SR_pct_DENOM,
			RachPreambleAPerBeam+RachPreambleBPerBeam	 						S5NR_RACH_Att_MSG1_CB,
			RachPreambleACFRAPerBeam											S5NR_RACH_Att_MSG1_CF,
			NumRARPerBeam+NumRARGroupBPerBeam									S5NR_RACH_Att_MSG2_CB,
			NumRARCFRAPerBeam													S5NR_RACH_Att_MSG2_CF,
			NumMSG3PerBeam+NumMSG3GroupBPerBeam									S5NR_RACH_Att_MSG3_CB,
			NumMSG3CFRAPerBeam													S5NR_RACH_Att_MSG3_CF,
			NumMSG5PerBeam														S5NR_RACH_Att_MSG5_CB,
			S5NR_PUCCHAvgSINR_dB_NUM,
			S5NR_PUCCHAvgSINR_dB_DENOM,
			S5NR_PUSCHAvgSINR_dB_NUM,							
			S5NR_PUSCHAvgSINR_dB_DENOM,
			RssiPathTot Average_RSSI_Path0_3_Num,
      		RssiPathCnt Average_RSSI_Path0_3_Denom,
			S5NR_DLAvgAssignedMCS_NUM,
			S5NR_DLAvgAssignedMCS_DENOM,
			-- add
			RssiPathMax,
			NumSlotwBlockDL			S5NR_PDCCH_SlotRationBlocking_DL_PCT_Num,
			NumSlotwDLAttempt		S5NR_PDCCH_SlotRationBlocking_DL_PCT_Denom,
			NumSlotwBlockUL			S5NR_PDCCH_SlotRationBlocking_UL_PCT_Num,
			NumSlotwULAttempt		S5NR_PDCCH_SlotRationBlocking_UL_PCT_Denom,
			NumSlotwBlockTot		S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Num,
			NumSlotwTotAttempt  S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Denom,
			AttemptAggDL16			S5NR_PDCCH_AggLvl16_DL_PCT_Num,
			(AttemptAggDL1 + AttemptAggDL2 + AttemptAggDL4 + AttemptAggDL8 + AttemptAggDL16)  S5NR_PDCCH_AggLvl16_DL_PCT_Denom,
			AttemptAggUL16			S5NR_PDCCH_AggLvl16_UL_PCT_Num,
			(AttemptAggUL1 + AttemptAggUL2 + AttemptAggUL4 + AttemptAggUL8 + AttemptAggUL16)  S5NR_PDCCH_AggLvl16_UL_PCT_Denom,
			Cell_Availability_Num,
			Cell_Availability_Denom,
			-- add
			ReleaseCallHoldingTimeTot S5NR_AvgRRCConnectionHoldTime_s_Num,	
			ReleaseCallHoldingTimeCnt S5NR_AvgRRCConnectionHoldTime_s_Denom,
			PucchErrorCount	S5NR_PUCCH_BLER_PCT_Num , 
			NumOfTotPUCCH S5NR_PUCCH_BLER_PCT_Denom,
			(NumAttemptPDCCHDL - NumBlockedPDCCHDL) - (UsedAgg1+UsedAgg2+UsedAgg4+UsedAgg8+UsedAgg16) S5NR_PDCCH_Fail_DL_PCT_Num,	
			(NumAttemptPDCCHDL - NumBlockedPDCCHDL) S5NR_PDCCH_Fail_DL_PCT_Denom,
			(NumAttemptPDCCHUL - NumBlockedPDCCHUL) - (UsedAggUL1+UsedAggUL2+UsedAggUL4+UsedAggUL8+UsedAggUL16) S5NR_PDCCH_Fail_UL_PCT_Num,
			(NumAttemptPDCCHUL - NumBlockedPDCCHUL) S5NR_PDCCH_Fail_UL_PCT_Denom,
			TotDLMuMimoPairedLayer S5NR_AvgNumMuMimoLayerPerMuTti_DL_Num,	
			TotDLMuMimoUtilizedTti S5NR_AvgNumMuMimoLayerPerMuTti_DL_Denom,
			TotDLMuMimoPairedUe S5NR_AvgNumMuMimoUePerMuTti_DL_Num,	
			TotDLMuMimoUtilizedTti S5NR_AvgNumMuMimoUePerMuTti_DL_Denom,
			TotDLMuMimoPairedUe S5NR_MuMimoUeRatio_DL_PCT_Num,	
			TotDLMuPrb S5NR_MuMimoUsedPrbRatio_DL_PCT_Num,	
			TotDLMuMimoAvailablePrb S5NR_MuMimoUsedPrbRatio_DL_PCT_Denom,
			
			RlcDLByte_5qi,
			RlcULByte_5qi,
			--Added new KPI on 12/11/2024
			PUCCH_TotULPrb	,
			--Added new KPIs on 1/23/2025 DENG-2659
			S5NR_Cell_Availability_PCT_Num,
			Cell_Availability_Denom S5NR_Cell_Availability_PCT_Denom,
			S5NR_Cell_Availability_PCT_excl_Lock_ES_Num,
			Cell_Availability_Denom S5NR_Cell_Availability_PCT_excl_Lock_ES_Denom	,
      CellUnavailableTimeLock_s_SUM,
      CellUnavailableTimeES_s_SUM	,
			CellUnavailableTimeDown_s_SUM,
			CellAvailPmPeriodTime_s_SUM
			from (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(TotDLAvailablePrb_count_SUM) TotDLAvailablePrb,
					sum(TotDLBroadcastPrb_count_SUM) TotDLBroadcastPrb,
					sum(TotDLUnicastPrb_count_SUM) TotDLUnicastPrb,
					SUM(TotULUsedPrb_count_SUM) TotULUsedPrb,
					SUM(TotULAvailablePrb_count_SUM) TotULAvailablePrb 
				from apachedataingestion.nr.totalprbusage_nr_hr_silver a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(a.LOCATION,'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) M0 
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					SUM(DssNrDLPrbUsed_count_SUM)    DssNrDLPrbUsed	,
					SUM(DssNrDLPrbAvailable_count_SUM)      DssNrDLPrbAvailable,
					SUM(DssNrDLTtiUsed_count_SUM) DssNrDLTtiUsed	,
					SUM(DssNrDLTtiAvailable_count_SUM) DssNrDLTtiAvailable,
					SUM(DssNrULPrbUsed_count_SUM) DssNrULPrbUsed,	
					SUM(DssNrULPrbAvailable_count_SUM) DssNrULPrbAvailable,
					SUM(DssNrULTtiUsed_count_SUM) DssNrULTtiUsed,	
					SUM(DssNrULTtiAvailable_count_SUM) DssNrULTtiAvailable
				from apachedataingestion.nr.dssrelatedinformation_nr_hr_silver a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(a.LOCATION,'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME			
			) T1 on M0.CalendarDate=T1.CalendarDate and M0.Hour24=T1.Hour24 and M0.du_id=T1.du_id and M0.GCELL_ID=T1.GCELL_ID 
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(NrofResidualError_DL_count_SUM) NrofResidualError_DL,
					sum(Nrof2ndTxTrial_DL_count_SUM) Nrof2ndTxTrial_DL,
					sum(Nrof1stTxTrial_DL_count_SUM) Nrof1stTxTrial_DL
				from apachedataingestion.nr.dlharqtransmissioncountandbler_nr_hr_silver a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(a.LOCATION,'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T2 on M0.CalendarDate=T2.CalendarDate and M0.Hour24=T2.Hour24 and M0.du_id=T2.du_id and M0.GCELL_ID=T2.GCELL_ID 
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(Nrof2ndTxTrial_UL_count_SUM) Nrof2ndTxTrial_UL,
					sum(NrofResidualError_UL_count_SUM) NrofResidualError_UL,
					sum(Nrof1stTxTrial_UL_count_SUM) Nrof1stTxTrial_UL
                  from apachedataingestion.nr.ulharqtransmissioncountandbler_nr_hr_silver a
                  inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(a.LOCATION,'CellIdentity','')=b.gcell_id
                  WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T3 on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME, 
                    sum(RlcSduDelayTot_us_SUM) RlcSduDelayTot,
					sum(RlcSduDelayCnt_count_SUM) RlcSduDelayCnt,
					sum(AirIfDelayTot_us_SUM) AirIfDelayTot,
					sum(AirIfDelayCnt_count_SUM) AirIfDelayCnt
                from apachedataingestion.nr.airinterfacedelayfornsa_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                    WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T4 on M0.CalendarDate=T4.CalendarDate and M0.Hour24=T4.Hour24 and M0.du_id=T4.du_id and M0.GCELL_ID=T4.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,   
                    sum(AirMacDLByte_PCELL_Kbytes_SUM) AirMacDLByte_PCELL,
					sum(AirMacULByte_PCELL_Kbytes_SUM) AirMacULByte_PCELL
                from apachedataingestion.nr.AirMACPacketPCell_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                    WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T5 on M0.CalendarDate=T5.CalendarDate and M0.Hour24=T5.Hour24 and M0.du_id=T5.du_id and M0.GCELL_ID=T5.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,   
                    sum(AirMacDLByte_SCELL_Kbytes_SUM) AirMacDLByte_SCELL,
					sum(AirMacULByte_SCELL_Kbytes_SUM) AirMacULByte_SCELL
                from apachedataingestion.nr.AirMACPacketSCell_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                    WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T6 on M0.CalendarDate=T6.CalendarDate and M0.Hour24=T6.Hour24 and M0.du_id=T6.du_id and M0.GCELL_ID=T6.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
                    sum(NumBlockedPDCCHDL_count_SUM) NumBlockedPDCCHDL,
					sum(NumAttemptPDCCHDL_count_SUM) NumAttemptPDCCHDL,
					sum(NumBlockedPDCCHUL_count_SUM) NumBlockedPDCCHUL,
					sum(NumAttemptPDCCHUL_count_SUM) NumAttemptPDCCHUL,
					sum(NumBlockedPDCCHTot_count_SUM) NumBlockedPDCCHTot,
					-- add
					sum(NumSlotwBlockDL_count_SUM) 		NumSlotwBlockDL,
					sum(NumSlotwDLAttempt_count_SUM) 	NumSlotwDLAttempt,
					sum(NumSlotwBlockUL_count_SUM) 		NumSlotwBlockUL,
					sum(NumSlotwULAttempt_count_SUM) 	NumSlotwULAttempt,
					sum(NumSlotwBlockTot_count_SUM) 	NumSlotwBlockTot,
					sum(NumSlotwTotAttempt_count_SUM) NumSlotwTotAttempt,
					sum(AttemptAggDL1_count_SUM) AttemptAggDL1,
					sum(AttemptAggDL2_count_SUM) AttemptAggDL2,
					sum(AttemptAggDL4_count_SUM) AttemptAggDL4,
					sum(AttemptAggDL8_count_SUM) AttemptAggDL8,
					sum(AttemptAggDL16_count_SUM) AttemptAggDL16,
					sum(AttemptAggUL1_count_SUM) AttemptAggUL1,
					sum(AttemptAggUL2_count_SUM) AttemptAggUL2,
					sum(AttemptAggUL4_count_SUM) AttemptAggUL4,
					sum(AttemptAggUL8_count_SUM) AttemptAggUL8,
					sum(AttemptAggUL16_count_SUM) AttemptAggUL16
                from apachedataingestion.nr.blockedpdcchinformationdluldlandul_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T7 on M0.CalendarDate=T7.CalendarDate and M0.Hour24=T7.Hour24 and M0.du_id=T7.du_id and M0.GCELL_ID=T7.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
                    sum(CaAddAtt_count_SUM) CaAddAtt,
					sum(CaAddFail_count_SUM) CaAddFail,
					sum(CaAddNotSelected_count_SUM) CaAddNotSelected
                from apachedataingestion.nr.CAActionperNCI_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                 WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME							
			) T8 on M0.CalendarDate=T8.CalendarDate and M0.Hour24=T8.Hour24 and M0.du_id=T8.du_id and M0.GCELL_ID=T8.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(SCellDeactAtt_NoUse_count_SUM)  SCellDeactAtt_NoUse,
					sum(SCellActAtt_DLTraffic_count_SUM) SCellActAtt_DLTraffic,
					sum(SCellActAtt_ULTraffic_count_SUM) SCellActAtt_ULTraffic,
					sum(SCellActAtt_Blind_count_SUM) SCellActAtt_Blind,
					0 SCellActSucc_DLTraffic,
					sum(SCellActSucc_ULTraffic_count_SUM) SCellActSucc_ULTraffic,
					sum(SCellActSucc_Blind_count_SUM) SCellActSucc_Blind,
					sum(SCellDeactAtt_Preemption_count_SUM) SCellDeactAtt_Preemption,
					sum(SCellDeactAtt_UAI_count_SUM) SCellDeactAtt_UAI,
					0 SCellDeactAtt_SlotAggregation,
					sum(SCellDeactSucc_NoUse_count_SUM) SCellDeactSucc_NoUse,
					sum(SCellDeactSucc_Preemption_count_SUM) SCellDeactSucc_Preemption,
					sum(SCellDeactSucc_UAI_count_SUM) SCellDeactSucc_UAI,
					0 SCellDeactSucc_SlotAggregation,
					sum(SCellActSucc_count_SUM) SCellActSucc
				from apachedataingestion.nr.CarrierAggregationMessageCountforSCellActivationDeactivation_nr_hr_silver    a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T9 on M0.CalendarDate=T9.CalendarDate and M0.Hour24=T9.Hour24 and M0.du_id=T9.du_id and M0.GCELL_ID=T9.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,  
                    	sum(CaAddDurationTot_ms_SUM) CaAddDurationTot,
						sum(CaAddDurationCnt_count_SUM) CaAddDurationCnt,
						max(CaAddDurationMax_ms_MAX) CaAddDurationMax                      
                from apachedataingestion.nr.CATimeingNBDU_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                 WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T10 on M0.CalendarDate=T10.CalendarDate and M0.Hour24=T10.Hour24 and M0.du_id=T10.du_id and M0.GCELL_ID=T10.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,  
                        sum(CaNonCapableUe_count_SUM) CaNonCapableUe,
						sum(CaCapableUe_count_SUM) CaCapableUe,
						sum(CaUlNonCapableUe_count_SUM) CaUlNonCapableUe,
						sum(CaUlCapableUe_count_SUM) CaUlCapableUe
                from apachedataingestion.nr.CAUECapabilityingNBDU_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                   WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T11 on M0.CalendarDate=T11.CalendarDate and M0.Hour24=T11.Hour24 and M0.du_id=T11.du_id and M0.GCELL_ID=T11.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,   
                    sum(UsedCCEperSlot_count_SUM) UsedCCEperSlot,
					sum(TotCCEperSlot_count_SUM) TotCCEperSlot,
					sum(UsedCCEperSlotUL_count_SUM) UsedCCEperSlotUL,
					sum(TotCCEperSlotUL_count_SUM) TotCCEperSlotUL
                from apachedataingestion.nr.CCEUtilizationperSlot_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                   WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T12 on M0.CalendarDate=T12.CalendarDate and M0.Hour24=T12.Hour24 and M0.du_id=T12.du_id and M0.GCELL_ID=T12.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,     
                      sum(0*PuschScheduledCntMcs0_count_SUM+
						1*PuschScheduledCntMcs1_count_SUM+
						2*PuschScheduledCntMcs2_count_SUM+
						3*PuschScheduledCntMcs3_count_SUM+
						4*PuschScheduledCntMcs4_count_SUM+
						5*PuschScheduledCntMcs5_count_SUM+
						6*PuschScheduledCntMcs6_count_SUM+
						7*PuschScheduledCntMcs7_count_SUM+
						8*PuschScheduledCntMcs8_count_SUM+
						9*PuschScheduledCntMcs9_count_SUM+
						10*PuschScheduledCntMcs10_count_SUM+
						11*PuschScheduledCntMcs11_count_SUM+
						12*PuschScheduledCntMcs12_count_SUM+
						13*PuschScheduledCntMcs13_count_SUM+
						14*PuschScheduledCntMcs14_count_SUM+
						15*PuschScheduledCntMcs15_count_SUM+
						16*PuschScheduledCntMcs16_count_SUM+
						17*PuschScheduledCntMcs17_count_SUM+
						18*PuschScheduledCntMcs18_count_SUM+
						19*PuschScheduledCntMcs19_count_SUM+
						20*PuschScheduledCntMcs20_count_SUM+
						21*PuschScheduledCntMcs21_count_SUM+
						22*PuschScheduledCntMcs22_count_SUM+
						23*PuschScheduledCntMcs23_count_SUM+
						24*PuschScheduledCntMcs24_count_SUM+
						25*PuschScheduledCntMcs25_count_SUM+
						26*PuschScheduledCntMcs26_count_SUM+
						27*PuschScheduledCntMcs27_count_SUM+
						28*PuschScheduledCntMcs28_count_SUM) S5NR_ULAvgAssignedMCS_NUM,
						sum(PuschScheduledCntMcs0_count_SUM+
						PuschScheduledCntMcs1_count_SUM+
						PuschScheduledCntMcs2_count_SUM+
						PuschScheduledCntMcs3_count_SUM+
						PuschScheduledCntMcs4_count_SUM+
						PuschScheduledCntMcs5_count_SUM+
						PuschScheduledCntMcs6_count_SUM+
						PuschScheduledCntMcs7_count_SUM+
						PuschScheduledCntMcs8_count_SUM+
						PuschScheduledCntMcs9_count_SUM+
						PuschScheduledCntMcs10_count_SUM+
						PuschScheduledCntMcs11_count_SUM+
						PuschScheduledCntMcs12_count_SUM+
						PuschScheduledCntMcs13_count_SUM+
						PuschScheduledCntMcs14_count_SUM+
						PuschScheduledCntMcs15_count_SUM+
						PuschScheduledCntMcs16_count_SUM+
						PuschScheduledCntMcs17_count_SUM+
						PuschScheduledCntMcs18_count_SUM+
						PuschScheduledCntMcs19_count_SUM+
						PuschScheduledCntMcs20_count_SUM+
						PuschScheduledCntMcs21_count_SUM+
						PuschScheduledCntMcs22_count_SUM+
						PuschScheduledCntMcs23_count_SUM+
						PuschScheduledCntMcs24_count_SUM+
						PuschScheduledCntMcs25_count_SUM+
						PuschScheduledCntMcs26_count_SUM+
						PuschScheduledCntMcs27_count_SUM+
						PuschScheduledCntMcs28_count_SUM) S5NR_ULAvgAssignedMCS_DENOM
                from apachedataingestion.nr.UplinkMCSBLER_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T13 on M0.CalendarDate=T13.CalendarDate and M0.Hour24=T13.Hour24 and M0.du_id=T13.du_id and M0.GCELL_ID=T13.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,      
                      sum(1*DLReceivedCQI1_count_SUM+
						2*DLReceivedCQI2_count_SUM+
						3*DLReceivedCQI3_count_SUM+
						4*DLReceivedCQI4_count_SUM+
						5*DLReceivedCQI5_count_SUM+
						6*DLReceivedCQI6_count_SUM+
						7*DLReceivedCQI7_count_SUM+
						8*DLReceivedCQI8_count_SUM+
						9*DLReceivedCQI9_count_SUM+
						10*DLReceivedCQI10_count_SUM+
						11*DLReceivedCQI11_count_SUM+
						12*DLReceivedCQI12_count_SUM+
						13*DLReceivedCQI13_count_SUM+
						14*DLReceivedCQI14_count_SUM+
						15*DLReceivedCQI15_count_SUM) S5_AverageCQI_NUM,
						sum(DLReceivedCQI0_count_SUM+
						DLReceivedCQI1_count_SUM+
						DLReceivedCQI2_count_SUM+
						DLReceivedCQI3_count_SUM+
						DLReceivedCQI4_count_SUM+
						DLReceivedCQI5_count_SUM+
						DLReceivedCQI6_count_SUM+
						DLReceivedCQI7_count_SUM+
						DLReceivedCQI8_count_SUM+
						DLReceivedCQI9_count_SUM+
						DLReceivedCQI10_count_SUM+
						DLReceivedCQI11_count_SUM+
						DLReceivedCQI12_count_SUM+
						DLReceivedCQI13_count_SUM+
						DLReceivedCQI14_count_SUM+
						DLReceivedCQI15_count_SUM) S5_AverageCQI_DENOM
                from apachedataingestion.nr.DownlinkWidebandCQI_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                 WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME				
			) T14 on M0.CalendarDate=T14.CalendarDate and M0.Hour24=T14.Hour24 and M0.du_id=T14.du_id and M0.GCELL_ID=T14.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME, 
                    sum(NumMSG5PerBeam_count_SUM) NumMSG5PerBeam,
					sum(NumMSG3CFRAPerBeam_count_SUM) NumMSG3CFRAPerBeam,
					sum(RachPreambleAPerBeam_count_SUM)  RachPreambleAPerBeam,
					sum(RachPreambleBPerBeam_count_SUM) RachPreambleBPerBeam,
					sum(RachPreambleACFRAPerBeam_count_SUM) RachPreambleACFRAPerBeam,
					sum(NumRARPerBeam_count_SUM)  NumRARPerBeam,
					sum(NumRARGroupBPerBeam_count_SUM) NumRARGroupBPerBeam,
					sum(NumRARCFRAPerBeam_count_SUM) NumRARCFRAPerBeam,
					sum(NumMSG3PerBeam_count_SUM)  NumMSG3PerBeam,
					sum(NumMSG3GroupBPerBeam_count_SUM) NumMSG3GroupBPerBeam
                from apachedataingestion.nr.physicalrandomaccesschannelinnrforbeam_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T15 on M0.CalendarDate=T15.CalendarDate and M0.Hour24=T15.Hour24 and M0.du_id=T15.du_id and M0.GCELL_ID=T15.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,  
                      sum(PucchSinrDistBin0_count_SUM*power(10,-0.9)+
					PucchSinrDistBin1_count_SUM*power(10,-0.7)+
					PucchSinrDistBin2_count_SUM*power(10,-0.5)+
					PucchSinrDistBin3_count_SUM*power(10,-0.3)+
					PucchSinrDistBin4_count_SUM*power(10,-0.1)+
					PucchSinrDistBin5_count_SUM*power(10,0.1)+
					PucchSinrDistBin6_count_SUM*power(10,0.3)+
					PucchSinrDistBin7_count_SUM*power(10,0.5)+
					PucchSinrDistBin8_count_SUM*power(10,0.7)+
					PucchSinrDistBin9_count_SUM*power(10,0.9)+
					PucchSinrDistBin10_count_SUM*power(10,1.1)+
					PucchSinrDistBin11_count_SUM*power(10,1.3)+
					PucchSinrDistBin12_count_SUM*power(10,1.5)+
					PucchSinrDistBin13_count_SUM*power(10,1.7)+
					PucchSinrDistBin14_count_SUM*power(10,1.9)+
					PucchSinrDistBin15_count_SUM*power(10,2.1)+
					PucchSinrDistBin16_count_SUM*power(10,2.3)+
					PucchSinrDistBin17_count_SUM*power(10,2.5)+
					PucchSinrDistBin18_count_SUM*power(10,2.7)+
					PucchSinrDistBin19_count_SUM*power(10,2.9)) S5NR_PUCCHAvgSINR_dB_NUM,
					sum(PucchSinrDistBin0_count_SUM+
					PucchSinrDistBin1_count_SUM+
					PucchSinrDistBin2_count_SUM+
					PucchSinrDistBin3_count_SUM+
					PucchSinrDistBin4_count_SUM+
					PucchSinrDistBin5_count_SUM+
					PucchSinrDistBin6_count_SUM+
					PucchSinrDistBin7_count_SUM+
					PucchSinrDistBin8_count_SUM+
					PucchSinrDistBin9_count_SUM+
					PucchSinrDistBin10_count_SUM+
					PucchSinrDistBin11_count_SUM+
					PucchSinrDistBin12_count_SUM+
					PucchSinrDistBin13_count_SUM+
					PucchSinrDistBin14_count_SUM+
					PucchSinrDistBin15_count_SUM+
					PucchSinrDistBin16_count_SUM+
					PucchSinrDistBin17_count_SUM+
					PucchSinrDistBin18_count_SUM+
					PucchSinrDistBin19_count_SUM)  S5NR_PUCCHAvgSINR_dB_DENOM
                from apachedataingestion.nr.PUCCHSINRDistributionperBin_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                  WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T16 on M0.CalendarDate=T16.CalendarDate and M0.Hour24=T16.Hour24 and M0.du_id=T16.du_id and M0.GCELL_ID=T16.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME, 
                      sum(
						SinrDistULWbPreComp_Bin0_count_SUM*power(10,-0.9)+
						SinrDistULWbPreComp_Bin1_count_SUM*power(10,-0.7)+
						SinrDistULWbPreComp_Bin2_count_SUM*power(10,-0.5)+
						SinrDistULWbPreComp_Bin3_count_SUM*power(10,-0.3)+
						SinrDistULWbPreComp_Bin4_count_SUM*power(10,-0.1)+
						SinrDistULWbPreComp_Bin5_count_SUM*power(10,0.1)+ 
						SinrDistULWbPreComp_Bin6_count_SUM*power(10,0.3)+ 
						SinrDistULWbPreComp_Bin7_count_SUM*power(10,0.5)+ 
						SinrDistULWbPreComp_Bin8_count_SUM*power(10,0.7)+ 
						SinrDistULWbPreComp_Bin9_count_SUM*power(10,0.9)+ 
						SinrDistULWbPreComp_Bin10_count_SUM*power(10,1.1)+
						SinrDistULWbPreComp_Bin11_count_SUM*power(10,1.3)+
						SinrDistULWbPreComp_Bin12_count_SUM*power(10,1.5)+
						SinrDistULWbPreComp_Bin13_count_SUM*power(10,1.7)+
						SinrDistULWbPreComp_Bin14_count_SUM*power(10,1.9)+
						SinrDistULWbPreComp_Bin15_count_SUM*power(10,2.1)+
						SinrDistULWbPreComp_Bin16_count_SUM*power(10,2.3)+
						SinrDistULWbPreComp_Bin17_count_SUM*power(10,2.5)+
						SinrDistULWbPreComp_Bin18_count_SUM*power(10,2.7)+
						SinrDistULWbPreComp_Bin19_count_SUM*power(10,2.9) 
					) S5NR_PUSCHAvgSINR_dB_NUM,
					sum(
						SinrDistULWbPreComp_Bin0_count_SUM+
						SinrDistULWbPreComp_Bin1_count_SUM+
						SinrDistULWbPreComp_Bin2_count_SUM+
						SinrDistULWbPreComp_Bin3_count_SUM+
						SinrDistULWbPreComp_Bin4_count_SUM+
						SinrDistULWbPreComp_Bin5_count_SUM+
						SinrDistULWbPreComp_Bin6_count_SUM+
						SinrDistULWbPreComp_Bin7_count_SUM+
						SinrDistULWbPreComp_Bin8_count_SUM+
						SinrDistULWbPreComp_Bin9_count_SUM+
						SinrDistULWbPreComp_Bin10_count_SUM+
						SinrDistULWbPreComp_Bin11_count_SUM+
						SinrDistULWbPreComp_Bin12_count_SUM+
						SinrDistULWbPreComp_Bin13_count_SUM+
						SinrDistULWbPreComp_Bin14_count_SUM+
						SinrDistULWbPreComp_Bin15_count_SUM+
						SinrDistULWbPreComp_Bin16_count_SUM+
						SinrDistULWbPreComp_Bin17_count_SUM+
						SinrDistULWbPreComp_Bin18_count_SUM+
						SinrDistULWbPreComp_Bin19_count_SUM
					) S5NR_PUSCHAvgSINR_dB_DENOM 
                from apachedataingestion.nr.PUSCHSINRDistributionperBin_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                 WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				 GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T17 on M0.CalendarDate=T17.CalendarDate and M0.Hour24=T17.Hour24 and M0.du_id=T17.du_id and M0.GCELL_ID=T17.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
								sum(RssiPathTot_mW_10_13_SUM) RssiPathTot,
            		sum(RssiPathCnt_count_SUM) RssiPathCnt,
								max(RssiPathMax_dBm_MAX) RssiPathMax
                from apachedataingestion.nr.RSSIofEachPathMeasuredbyMAC_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T18 on M0.CalendarDate=T18.CalendarDate and M0.Hour24=T18.Hour24 and M0.du_id=T18.du_id and M0.GCELL_ID=T18.GCELL_ID	
			full join  (		
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
                    sum(0*DLTransmittedMcs0_count_SUM+
					1*DLTransmittedMcs1_count_SUM+
					2*DLTransmittedMcs2_count_SUM+
					3*DLTransmittedMcs3_count_SUM+
					4*DLTransmittedMcs4_count_SUM+
					5*DLTransmittedMcs5_count_SUM+
					6*DLTransmittedMcs6_count_SUM+
					7*DLTransmittedMcs7_count_SUM+
					8*DLTransmittedMcs8_count_SUM+
					9*DLTransmittedMcs9_count_SUM+
					10*DLTransmittedMcs10_count_SUM+
					11*DLTransmittedMcs11_count_SUM+
					12*DLTransmittedMcs12_count_SUM+
					13*DLTransmittedMcs13_count_SUM+
					14*DLTransmittedMcs14_count_SUM+
					15*DLTransmittedMcs15_count_SUM+
					16*DLTransmittedMcs16_count_SUM+
					17*DLTransmittedMcs17_count_SUM+
					18*DLTransmittedMcs18_count_SUM+
					19*DLTransmittedMcs19_count_SUM+
					20*DLTransmittedMcs20_count_SUM+
					21*DLTransmittedMcs21_count_SUM+
					22*DLTransmittedMcs22_count_SUM+
					23*DLTransmittedMcs23_count_SUM+
					24*DLTransmittedMcs24_count_SUM+
					25*DLTransmittedMcs25_count_SUM+
					26*DLTransmittedMcs26_count_SUM+
					27*DLTransmittedMcs27_count_SUM+
					28*DLTransmittedMcs28_count_SUM+
					29*DLTransmittedMcs29_count_SUM+
					30*DLTransmittedMcs30_count_SUM+
					31*DLTransmittedMcs31_count_SUM) S5NR_DLAvgAssignedMCS_NUM,
				sum(DLTransmittedMcs0_count_SUM+
					DLTransmittedMcs1_count_SUM+
					DLTransmittedMcs2_count_SUM+
					DLTransmittedMcs3_count_SUM+
					DLTransmittedMcs4_count_SUM+
					DLTransmittedMcs5_count_SUM+
					DLTransmittedMcs6_count_SUM+
					DLTransmittedMcs7_count_SUM+
					DLTransmittedMcs8_count_SUM+
					DLTransmittedMcs9_count_SUM+
					DLTransmittedMcs10_count_SUM+
					DLTransmittedMcs11_count_SUM+
					DLTransmittedMcs12_count_SUM+
					DLTransmittedMcs13_count_SUM+
					DLTransmittedMcs14_count_SUM+
					DLTransmittedMcs15_count_SUM+
					DLTransmittedMcs16_count_SUM+
					DLTransmittedMcs17_count_SUM+
					DLTransmittedMcs18_count_SUM+
					DLTransmittedMcs19_count_SUM+
					DLTransmittedMcs20_count_SUM+
					DLTransmittedMcs21_count_SUM+
					DLTransmittedMcs22_count_SUM+
					DLTransmittedMcs23_count_SUM+
					DLTransmittedMcs24_count_SUM+
					DLTransmittedMcs25_count_SUM+
					DLTransmittedMcs26_count_SUM+
					DLTransmittedMcs27_count_SUM+
					DLTransmittedMcs28_count_SUM+
					DLTransmittedMcs29_count_SUM+
					DLTransmittedMcs30_count_SUM+
					DLTransmittedMcs31_count_SUM) S5NR_DLAvgAssignedMCS_DENOM
                from apachedataingestion.nr.DownlinkMCSTransmission_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T19 on M0.CalendarDate=T19.CalendarDate and M0.Hour24=T19.Hour24 and M0.du_id=T19.du_id and M0.GCELL_ID=T19.GCELL_ID				
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
      				sum(CellAvailPmPeriodTime_s_SUM-CellUnavailableTimeDown_s_SUM+CellUnavailableTimeLock_s_SUM+CellUnavailableTimeES_s_SUM) Cell_Availability_Num,
      				sum(CellAvailPmPeriodTime_s_SUM) Cell_Availability_Denom,
					--Added new counters on 01/29/2025 DENG-2659
					sum(CellAvailPmPeriodTime_s_SUM-CellUnavailableTimeDown_s_SUM) S5NR_Cell_Availability_PCT_Num,
					--Modified formula on 4/2/2025 as per JIRA DENG-3328
					sum(CellAvailPmPeriodTime_s_SUM-(CellUnavailableTimeDown_s_SUM-CellUnavailableTimeLock_s_SUM-CellUnavailableTimeES_s_SUM)) S5NR_Cell_Availability_PCT_excl_Lock_ES_Num,
          sum(CellUnavailableTimeLock_s_SUM) CellUnavailableTimeLock_s_SUM,
          sum(CellUnavailableTimeES_s_SUM) CellUnavailableTimeES_s_SUM,
					sum(CellUnavailableTimeDown_s_SUM) CellUnavailableTimeDown_s_SUM,
					sum(CellAvailPmPeriodTime_s_SUM) CellAvailPmPeriodTime_s_SUM
					-- select *
				from apachedataingestion.nr.cellunavailabletime_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T20 on M0.CalendarDate=T20.CalendarDate and M0.Hour24=T20.Hour24 and M0.du_id=T20.du_id and M0.GCELL_ID=T20.GCELL_ID
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
      				sum(PucchErrorCount) PucchErrorCount,
      				sum(NumOfTotPUCCH) NumOfTotPUCCH,
					sum(TotUlPrb) PUCCH_TotULPrb

					-- select *
				from apachedataingestion.nr.pucch_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T21 on M0.CalendarDate=T21.CalendarDate and M0.Hour24=T21.Hour24 and M0.du_id=T21.du_id and M0.GCELL_ID=T21.GCELL_ID	
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
      				sum(UsedAgg1) UsedAgg1,
					sum(UsedAgg2) UsedAgg2,
					sum(UsedAgg4) UsedAgg4,
					sum(UsedAgg8) UsedAgg8,
					sum(UsedAgg16) UsedAgg16,
					sum(UsedAggUL1) UsedAggUL1,
					sum(UsedAggUL2) UsedAggUL2,
					sum(UsedAggUL4) UsedAggUL4,
					sum(UsedAggUL8) UsedAggUL8,
      				sum(UsedAggUL16) UsedAggUL16					 
					-- select *
				from apachedataingestion.nr.usageinformationonaggregationlevelforpdcch_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T22 on M0.CalendarDate=T22.CalendarDate and M0.Hour24=T22.Hour24 and M0.du_id=T22.du_id and M0.GCELL_ID=T22.GCELL_ID	
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,				
      				sum(TotDLMuMimoPairedLayer) TotDLMuMimoPairedLayer,
					sum(TotDLMuMimoUtilizedTti) TotDLMuMimoUtilizedTti,
					sum(TotDLMuMimoPairedUe) TotDLMuMimoPairedUe,
					sum(TotDLMuPrb) TotDLMuPrb,
					sum(TotDLMuMimoAvailablePrb) TotDLMuMimoAvailablePrb
					-- select * 
				from apachedataingestion.nr.downlinkmultiusermimoformassivemimo_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T23 on M0.CalendarDate=T23.CalendarDate and M0.Hour24=T23.Hour24 and M0.du_id=T23.du_id and M0.GCELL_ID=T23.GCELL_ID	
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,  
						sum(ReleaseCallHoldingTimeTot) ReleaseCallHoldingTimeTot,
						sum(ReleaseCallHoldingTimeCnt) ReleaseCallHoldingTimeCnt
						-- select *
					from apachedataingestion.nr.rrcrelatedtimepergnbwithduidentifierpercell_nr_hr_silver  a
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
					WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
					GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T24 on M0.CalendarDate=T24.CalendarDate and M0.Hour24=T24.Hour24 and M0.du_id=T24.du_id and M0.GCELL_ID=T24.GCELL_ID  
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						SUM(RlcDLByte) RlcDLByte_5qi,
						SUM(RlcULByte) RlcULByte_5qi					
						-- select *
				from apachedataingestion.nr.rlcpacketper5qi_hr_silver a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T25 on M0.CalendarDate=T25.CalendarDate and M0.Hour24=T25.Hour24 and M0.du_id=T25.du_id and M0.GCELL_ID=T25.GCELL_ID 	
) X
GROUP BY CalendarDate,Hour24,GNODEB_ID,du_id,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME;



delete from hive_metastore.default.widetable_5g_cell_hr_tmp10;

insert into hive_metastore.default.widetable_5g_cell_hr_tmp10
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	-- select count(distinct concat(GNODEB_ID,'_',DU_ID,'_',GCELL_ID)) --514527
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							-- select count(*)
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
)
select 
CalendarDate ,
Hour24 ,
GNODEB_ID,
du_id ,
GCELL_ID ,
MARKET_NAME ,
case when length(du_id)=14 then 
	case when substring(du_id, 7, 1)=0 then 'FR2' 	 when substring(du_id, 7, 1)=9 then 
				case when substring(du_id, 11, 1)=2 then 'FR1/LS3' when substring(du_id, 11, 1)=3 then 'FR1/LS6' 
				end
	end
else '' end NR_TYPE,
substring(du_id,4,3) SUB_MARKET_ID,
SUB_MARKET_NAME ,
max(S5NR_Avg_DL_SRS_SU_MCS_Num) S5NR_Avg_DL_SRS_SU_MCS_Num,
max(S5NR_Avg_DL_SRS_SU_MCS_Denom) S5NR_Avg_DL_SRS_SU_MCS_Denom,
max(S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Num) S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Num,
max(S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Denom) S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Denom,
max(S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Num) S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Num,
max(S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Denom) S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Denom,
max(S5NR_Avg_DL_SRS_SU_MCS_SPID125_Num) S5NR_Avg_DL_SRS_SU_MCS_SPID125_Num,
max(S5NR_Avg_DL_SRS_SU_MCS_SPID125_Denom) S5NR_Avg_DL_SRS_SU_MCS_SPID125_Denom,
max(S5NR_Avg_DL_SRS_SU_MCS_SPID115_Num) S5NR_Avg_DL_SRS_SU_MCS_SPID115_Num,
max(S5NR_Avg_DL_SRS_SU_MCS_SPID115_Denom) S5NR_Avg_DL_SRS_SU_MCS_SPID115_Denom,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Num) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Num,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Denom) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Denom,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Num) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Num,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Denom) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Denom,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Num) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Num,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Denom) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Denom,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Num) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Num,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Denom) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Denom,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Num) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Num,
max(S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Denom) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Denom,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Num) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Num,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Denom) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Denom,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Num) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Num,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Denom) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Denom,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Num) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Num,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Denom) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Denom,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Num) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Num,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Denom) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Denom,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Num) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Num,
max(S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Denom) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Denom,
max(S5GNR_Total_RrcEventForSrsAllo4Tas) S5GNR_Total_RrcEventForSrsAllo4Tas,
max(S5GNR_Total_RrcEventForSrsAllo4NonTas) S5GNR_Total_RrcEventForSrsAllo4NonTas,
max(S5GNR_Total_RrcEventForSrsRel) S5GNR_Total_RrcEventForSrsRel,
max(S5GNR_Total_RrcEventForSrsReconfig) S5GNR_Total_RrcEventForSrsReconfig,
max(S5GNR_Avg_NumUeSrsAllocation_Num) S5GNR_Avg_NumUeSrsAllocation_Num,
max(S5GNR_Avg_NumUeSrsAllocation_Denom) S5GNR_Avg_NumUeSrsAllocation_Denom,
max(S5GNR_Max_NumUeSrsAllocation) S5GNR_Max_NumUeSrsAllocation,
max(S5GNR_Avg_NumUeSrsAvailable_Num) S5GNR_Avg_NumUeSrsAvailable_Num,
max(S5GNR_Avg_NumUeSrsAvailable_Denom) S5GNR_Avg_NumUeSrsAvailable_Denom,
max(S5GNR_Avg_NumUeSrsUsed_Num) S5GNR_Avg_NumUeSrsUsed_Num,
max(S5GNR_Avg_NumUeSrsUsed_Denom) S5GNR_Avg_NumUeSrsUsed_Denom
from(
select 
  COALESCE(M0.CalendarDate,T1.CalendarDate,T2.CalendarDate,T3.CalendarDate,T4.CalendarDate,T5.CalendarDate,T6.CalendarDate,T7.CalendarDate,T8.CalendarDate,T9.CalendarDate,T10.CalendarDate) CalendarDate,
  COALESCE(M0.Hour24,T1.Hour24,T2.Hour24,T3.Hour24,T4.Hour24,T5.Hour24,T6.Hour24,T7.Hour24,T8.Hour24,T9.Hour24,T10.Hour24) Hour24,
  COALESCE(M0.GNODEB_ID,T1.GNODEB_ID,T2.GNODEB_ID,T3.GNODEB_ID,T4.GNODEB_ID,T5.GNODEB_ID,T6.GNODEB_ID,T7.GNODEB_ID,T8.GNODEB_ID,T9.GNODEB_ID,T10.GNODEB_ID) GNODEB_ID,
  COALESCE(M0.du_id,T1.du_id,T2.du_id,T3.du_id,T4.du_id,T5.du_id,T6.du_id,T7.du_id,T8.du_id,T9.du_id,T10.du_id) du_id,
  COALESCE(M0.GCELL_ID,T1.GCELL_ID,T2.GCELL_ID,T3.GCELL_ID,T4.GCELL_ID,T5.GCELL_ID,T6.GCELL_ID,T7.GCELL_ID,T8.GCELL_ID,T9.GCELL_ID,T10.GCELL_ID) GCELL_ID,
  COALESCE(M0.MARKET_NAME,T1.MARKET_NAME,T2.MARKET_NAME,T3.MARKET_NAME,T4.MARKET_NAME,T5.MARKET_NAME,T6.MARKET_NAME,T7.MARKET_NAME,T8.MARKET_NAME,T9.MARKET_NAME,T10.MARKET_NAME) MARKET_NAME,
  COALESCE(M0.SUB_MARKET_NAME,T1.SUB_MARKET_NAME,T2.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T4.SUB_MARKET_NAME,T5.SUB_MARKET_NAME,T6.SUB_MARKET_NAME,T7.SUB_MARKET_NAME,T8.SUB_MARKET_NAME,T9.SUB_MARKET_NAME,T10.SUB_MARKET_NAME) SUB_MARKET_NAME,
  S5NR_Avg_DL_SRS_SU_MCS_Num,
  S5NR_Avg_DL_SRS_SU_MCS_Denom,
  S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Num,
  S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Denom,
  S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Num,
  S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Denom,
  S5NR_Avg_DL_SRS_SU_MCS_SPID125_Num,
  S5NR_Avg_DL_SRS_SU_MCS_SPID125_Denom,
  S5NR_Avg_DL_SRS_SU_MCS_SPID115_Num,
  S5NR_Avg_DL_SRS_SU_MCS_SPID115_Denom,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Num,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Denom,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Num,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Denom,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Num,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Denom,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Num,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Denom,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Num,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Denom,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Num,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Denom,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Num,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Denom,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Num,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Denom,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Num,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Denom,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Num,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Denom,
  TotRrcEventForSrsAllo4Tas S5GNR_Total_RrcEventForSrsAllo4Tas,
  TotRrcEventForSrsAllo4Ntas S5GNR_Total_RrcEventForSrsAllo4NonTas,
  TotRrcEventForSrsRel S5GNR_Total_RrcEventForSrsRel,
  TotRrcEventForSrsReconfig S5GNR_Total_RrcEventForSrsReconfig,
  S5GNR_Avg_NumUeSrsAllocation_Num,
  S5GNR_Avg_NumUeSrsAllocation_Denom,
  S5GNR_Max_NumUeSrsAllocation,
  S5GNR_Avg_NumUeSrsAvailable_Num,
  S5GNR_Avg_NumUeSrsAvailable_Denom,
  S5GNR_Avg_NumUeSrsUsed_Num,
  S5GNR_Avg_NumUeSrsUsed_Denom
from

(SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,   
sum(
  0*DLSrsBasedSuMcs0 + 1*DLSrsBasedSuMcs1 + 2*DLSrsBasedSuMcs2 + 3*DLSrsBasedSuMcs3 + 4*DLSrsBasedSuMcs4 + 5*DLSrsBasedSuMcs5 + 
  6*DLSrsBasedSuMcs6 + 7*DLSrsBasedSuMcs7 + 8*DLSrsBasedSuMcs8 + 9*DLSrsBasedSuMcs9 + 10*DLSrsBasedSuMcs10 + 11*DLSrsBasedSuMcs11 + 
  12*DLSrsBasedSuMcs12 + 13*DLSrsBasedSuMcs13 + 14*DLSrsBasedSuMcs14 + 15*DLSrsBasedSuMcs15 + 16*DLSrsBasedSuMcs16 + 17*DLSrsBasedSuMcs17 + 
  18*DLSrsBasedSuMcs18 + 19*DLSrsBasedSuMcs19 + 20*DLSrsBasedSuMcs20 + 21*DLSrsBasedSuMcs21 + 22*DLSrsBasedSuMcs22 + 23*DLSrsBasedSuMcs23 + 
  24*DLSrsBasedSuMcs24 + 25*DLSrsBasedSuMcs25 + 26*DLSrsBasedSuMcs26 + 27*DLSrsBasedSuMcs27 + 28*DLSrsBasedSuMcs28 + 29*DLSrsBasedSuMcs29 + 
  30*DLSrsBasedSuMcs30 + 31*DLSrsBasedSuMcs31
) S5NR_Avg_DL_SRS_SU_MCS_Num,
sum(
  DLSrsBasedSuMcs0 + DLSrsBasedSuMcs1 + DLSrsBasedSuMcs2 + DLSrsBasedSuMcs3 + DLSrsBasedSuMcs4 + DLSrsBasedSuMcs5 + DLSrsBasedSuMcs6 + 
  DLSrsBasedSuMcs7 + DLSrsBasedSuMcs8 + DLSrsBasedSuMcs9 + DLSrsBasedSuMcs10 + DLSrsBasedSuMcs11 + DLSrsBasedSuMcs12 + DLSrsBasedSuMcs13 + 
  DLSrsBasedSuMcs14 + DLSrsBasedSuMcs15 + DLSrsBasedSuMcs16 + DLSrsBasedSuMcs17 + DLSrsBasedSuMcs18 + DLSrsBasedSuMcs19 + DLSrsBasedSuMcs20 + 
  DLSrsBasedSuMcs21 + DLSrsBasedSuMcs22 + DLSrsBasedSuMcs23 + DLSrsBasedSuMcs24 + DLSrsBasedSuMcs25 + DLSrsBasedSuMcs26 + DLSrsBasedSuMcs27 + 
  DLSrsBasedSuMcs28 + DLSrsBasedSuMcs29 + DLSrsBasedSuMcs30 + DLSrsBasedSuMcs31
) S5NR_Avg_DL_SRS_SU_MCS_Denom
from apachedataingestion.nr.mcsfordownlinksrsbasedsingleusermimo_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) M0

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
(
  0*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs0 end) + 1*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs1 end) + 
  2*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs2 end) + 3*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs3 end) + 
  4*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs4 end) + 5*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs5 end) + 
  6*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs6 end) + 7*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs7 end) + 
  8*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs8 end) + 9*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs9 end) + 
  10*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs10 end) + 11*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs11 end) + 
  12*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs12 end) + 13*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs13 end) + 
  14*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs14 end) + 15*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs15 end) + 
  16*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs16 end) + 17*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs17 end) + 
  18*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs18 end) + 19*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs19 end) + 
  20*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs20 end) + 21*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs21 end) + 
  22*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs22 end) + 23*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs23 end) + 
  24*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs24 end) + 25*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs25 end) + 
  26*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs26 end) + 27*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs27 end) + 
  28*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs28 end) + 29*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs29 end) + 
  30*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs30 end) + 31*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs31 end)
) S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Num,
(
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs0 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs1 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs2 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs3 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs4 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs5 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs6 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs7 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs8 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs9 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs10 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs11 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs12 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs13 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs14 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs15 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs16 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs17 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs18 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs19 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs20 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs21 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs22 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs23 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs24 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs25 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs26 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs27 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs28 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs29 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs30 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuMcs31 end)
) S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Denom,

(
  0*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs0 end) + 1*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs1 end) + 
  2*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs2 end) + 3*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs3 end) + 
  4*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs4 end) + 5*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs5 end) + 
  6*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs6 end) + 7*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs7 end) + 
  8*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs8 end) + 9*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs9 end) + 
  10*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs10 end) + 11*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs11 end) + 
  12*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs12 end) + 13*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs13 end) + 
  14*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs14 end) + 15*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs15 end) + 
  16*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs16 end) + 17*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs17 end) + 
  18*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs18 end) + 19*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs19 end) + 
  20*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs20 end) + 21*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs21 end) + 
  22*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs22 end) + 23*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs23 end) + 
  24*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs24 end) + 25*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs25 end) + 
  26*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs26 end) + 27*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs27 end) + 
  28*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs28 end) + 29*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs29 end) + 
  30*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs30 end) + 31*sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs31 end)
) S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Num,
(
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs0 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs1 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs2 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs3 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs4 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs5 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs6 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs7 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs8 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs9 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs10 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs11 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs12 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs13 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs14 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs15 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs16 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs17 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs18 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs19 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs20 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs21 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs22 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs23 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs24 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs25 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs26 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs27 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs28 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs29 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs30 end) + sum(case when replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuMcs31 end)
) S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Denom

from apachedataingestion.nr.mcsfordownlinksrsbasedsingleusermimoperrfsp_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") and replace(split(a.LOCATION,'/')[3],'RFSPIncludingInvalid','') in ('125','115')
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T1  on M0.CalendarDate=T1.CalendarDate and M0.Hour24=T1.Hour24 and M0.du_id=T1.du_id and M0.GCELL_ID=T1.GCELL_ID  

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
  sum(case when replace(split(a.LOCATION,'/')[2],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuTotPrb end) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Num,
  sum(case when replace(split(a.LOCATION,'/')[2],'RFSPIncludingInvalid','') = '125' then DLTotAvailablePrb end) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Denom,
  sum(case when replace(split(a.LOCATION,'/')[2],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuTotPrb end) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Num,
  sum(case when replace(split(a.LOCATION,'/')[2],'RFSPIncludingInvalid','') = '115' then DLTotAvailablePrb end) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Denom
from apachedataingestion.nr.prbusagefordownlinksrsbasedsingleusermimoperrfsp_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") and replace(split(a.LOCATION,'/')[2],'RFSPIncludingInvalid','') in ('125','115')
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T2  on M0.CalendarDate=T2.CalendarDate and M0.Hour24=T2.Hour24 and M0.du_id=T2.du_id and M0.GCELL_ID=T2.GCELL_ID  

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
  (
  0*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs0 end) + 1*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs1 end) + 
  2*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs2 end) + 3*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs3 end) + 
  4*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs4 end) + 5*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs5 end) + 
  6*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs6 end) + 7*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs7 end) + 
  8*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs8 end) + 9*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs9 end) + 
  10*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs10 end) + 11*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs11 end) + 
  12*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs12 end) + 13*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs13 end) + 
  14*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs14 end) + 15*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs15 end) + 
  16*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs16 end) + 17*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs17 end) + 
  18*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs18 end) + 19*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs19 end) + 
  20*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs20 end) + 21*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs21 end) + 
  22*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs22 end) + 23*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs23 end) + 
  24*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs24 end) + 25*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs25 end) + 
  26*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs26 end) + 27*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs27 end) + 
  28*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs28 end) + 29*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs29 end) + 
  30*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs30 end) + 31*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs31 end)
) S5NR_Avg_DL_SRS_SU_MCS_SPID125_Num,
(
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs0 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs1 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs2 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs3 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs4 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs5 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs6 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs7 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs8 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs9 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs10 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs11 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs12 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs13 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs14 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs15 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs16 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs17 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs18 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs19 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs20 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs21 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs22 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs23 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs24 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs25 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs26 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs27 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs28 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs29 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs30 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuMcs31 end)
) S5NR_Avg_DL_SRS_SU_MCS_SPID125_Denom,

(
  0*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs0 end) + 1*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs1 end) + 
  2*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs2 end) + 3*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs3 end) + 
  4*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs4 end) + 5*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs5 end) + 
  6*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs6 end) + 7*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs7 end) + 
  8*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs8 end) + 9*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs9 end) + 
  10*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs10 end) + 11*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs11 end) + 
  12*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs12 end) + 13*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs13 end) + 
  14*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs14 end) + 15*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs15 end) + 
  16*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs16 end) + 17*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs17 end) + 
  18*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs18 end) + 19*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs19 end) + 
  20*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs20 end) + 21*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs21 end) + 
  22*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs22 end) + 23*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs23 end) + 
  24*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs24 end) + 25*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs25 end) + 
  26*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs26 end) + 27*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs27 end) + 
  28*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs28 end) + 29*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs29 end) + 
  30*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs30 end) + 31*sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs31 end)
) S5NR_Avg_DL_SRS_SU_MCS_SPID115_Num,
(
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs0 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs1 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs2 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs3 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs4 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs5 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs6 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs7 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs8 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs9 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs10 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs11 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs12 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs13 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs14 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs15 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs16 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs17 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs18 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs19 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs20 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs21 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs22 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs23 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs24 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs25 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs26 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs27 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs28 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs29 end) + 
  sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs30 end) + sum(case when replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuMcs31 end)
) S5NR_Avg_DL_SRS_SU_MCS_SPID115_Denom

from apachedataingestion.nr.mcsfordownlinksrsbasedsingleusermimoperspid_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") and replace(split(a.LOCATION,'/')[3],'SPIDIncludingInvalid','') in ('125','115')
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T3  on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID  

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
  sum(case when replace(split(a.LOCATION,'/')[2],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuTotPrb end) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Num,
  sum(case when replace(split(a.LOCATION,'/')[2],'SPIDIncludingInvalid','') = '125' then DLTotAvailablePrb end) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Denom,
  sum(case when replace(split(a.LOCATION,'/')[2],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuTotPrb end) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Num,
  sum(case when replace(split(a.LOCATION,'/')[2],'SPIDIncludingInvalid','') = '115' then DLTotAvailablePrb end) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Denom
from apachedataingestion.nr.prbusagefordownlinksrsbasedsingleusermimoperspid_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") and replace(split(a.LOCATION,'/')[2],'SPIDIncludingInvalid','') in ('125','115')
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T4  on M0.CalendarDate=T4.CalendarDate and M0.Hour24=T4.Hour24 and M0.du_id=T4.du_id and M0.GCELL_ID=T4.GCELL_ID  

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
  sum(DLSrsBasedSuTotPrb) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Num,
  sum(DLTotAvailablePrb) S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Denom

from apachedataingestion.nr.prbusagefordownlinksrsbasedsingleusermimo_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T5  on M0.CalendarDate=T5.CalendarDate and M0.Hour24=T5.Hour24 and M0.du_id=T5.du_id and M0.GCELL_ID=T5.GCELL_ID  

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
  sum(DLSrsBasedSuTotLayer) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Num,
  sum(DLSrsBasedSuTotUe) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Denom

from apachedataingestion.nr.thenumberoflayersusedindownlinksrsbasedsingleusermimo_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T6  on M0.CalendarDate=T6.CalendarDate and M0.Hour24=T6.Hour24 and M0.du_id=T6.du_id and M0.GCELL_ID=T6.GCELL_ID  

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
  sum(case when replace(split(a.LOCATION,'/')[1],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuTotLayer end) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Num,
  sum(case when replace(split(a.LOCATION,'/')[1],'RFSPIncludingInvalid','') = '125' then DLSrsBasedSuTotUe end) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Denom,
  sum(case when replace(split(a.LOCATION,'/')[1],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuTotLayer end) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Num,
  sum(case when replace(split(a.LOCATION,'/')[1],'RFSPIncludingInvalid','') = '115' then DLSrsBasedSuTotUe end) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Denom
from apachedataingestion.nr.thenumberoflayersusedindownlinksrsbasedsingleusermimoperrfsp_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") and replace(split(a.LOCATION,'/')[1],'RFSPIncludingInvalid','') in ('125','115')
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T7  on M0.CalendarDate=T7.CalendarDate and M0.Hour24=T7.Hour24 and M0.du_id=T7.du_id and M0.GCELL_ID=T7.GCELL_ID  

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
  sum(case when replace(split(a.LOCATION,'/')[1],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuTotLayer end) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Num,
  sum(case when replace(split(a.LOCATION,'/')[1],'SPIDIncludingInvalid','') = '125' then DLSrsBasedSuTotUe end) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Denom,
  sum(case when replace(split(a.LOCATION,'/')[1],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuTotLayer end) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Num,
  sum(case when replace(split(a.LOCATION,'/')[1],'SPIDIncludingInvalid','') = '115' then DLSrsBasedSuTotUe end) S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Denom
from apachedataingestion.nr.thenumberoflayersusedindownlinksrsbasedsingleusermimoperspid_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") and replace(split(a.LOCATION,'/')[1],'SPIDIncludingInvalid','') in ('125','115')
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T8  on M0.CalendarDate=T8.CalendarDate and M0.Hour24=T8.Hour24 and M0.du_id=T8.du_id and M0.GCELL_ID=T8.GCELL_ID  

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
  sum(TotRrcEventForSrsAllo4Tas) TotRrcEventForSrsAllo4Tas,
  sum(TotRrcEventForSrsAllo4Ntas) TotRrcEventForSrsAllo4Ntas,
  sum(TotRrcEventForSrsRel) TotRrcEventForSrsRel,
  sum(TotRrcEventForSrsReconfig) TotRrcEventForSrsReconfig
from apachedataingestion.nr.rrcfrequencyforsrsconfiguration_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd")
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T9  on M0.CalendarDate=T9.CalendarDate and M0.Hour24=T9.Hour24 and M0.du_id=T9.du_id and M0.GCELL_ID=T9.GCELL_ID  

full join (

  SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
  sum(AvgNumUesSrsAlloTot) S5GNR_Avg_NumUeSrsAllocation_Num,
  sum(AvgNumUesSrsAlloCnt) S5GNR_Avg_NumUeSrsAllocation_Denom,
  max(PeakNumUesSrsAllo) S5GNR_Max_NumUeSrsAllocation,
  sum(AvgRatioSrsAvailTot) S5GNR_Avg_NumUeSrsAvailable_Num,
  sum(AvgRatioSrsAvailCnt) S5GNR_Avg_NumUeSrsAvailable_Denom,
  sum(AvgRatioSrsUsedTot) S5GNR_Avg_NumUeSrsUsed_Num,
  sum(AvgRatioSrsUsedCnt) S5GNR_Avg_NumUeSrsUsed_Denom
from apachedataingestion.nr.srsresourcemanagement_nr_hr_silver    a
inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
WHERE 5=5 and  Daily  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd")
GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME) T10  on M0.CalendarDate=T10.CalendarDate and M0.Hour24=T10.Hour24 and M0.du_id=T10.du_id and M0.GCELL_ID=T10.GCELL_ID  

) X
GROUP BY CalendarDate,Hour24,GNODEB_ID,du_id,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME;


						
/**
--Added as on 03/25/2025 DENG-3078
ALTER TABLE apachedataingestion.nr.widetable_5g_cell_hr_gold2 ADD COLUMN Release_by_CAC DOUBLE
*/

/**
--Added as on 04/08/2025 DENG-
ALTER TABLE apachedataingestion.nr.widetable_5g_cell_hr_gold2 ADD COLUMNS 
 ( S5NR_Avg_DL_SRS_SU_MCS_Num DOUBLE,
  S5NR_Avg_DL_SRS_SU_MCS_Denom DOUBLE,
  S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Num DOUBLE,
  S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Denom DOUBLE,
  S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Num DOUBLE,
  S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Denom DOUBLE,
  S5NR_Avg_DL_SRS_SU_MCS_SPID125_Num DOUBLE,
  S5NR_Avg_DL_SRS_SU_MCS_SPID125_Denom DOUBLE,
  S5NR_Avg_DL_SRS_SU_MCS_SPID115_Num DOUBLE,
  S5NR_Avg_DL_SRS_SU_MCS_SPID115_Denom DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Num DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Denom DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Num DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Denom DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Num DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Denom DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Num DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Denom DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Num DOUBLE,
  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Denom DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Num DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Denom DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Num DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Denom DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Num DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Denom DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Num DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Denom DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Num DOUBLE,
  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Denom DOUBLE,
  S5GNR_Total_RrcEventForSrsAllo4Tas DOUBLE,
  S5GNR_Total_RrcEventForSrsAllo4NonTas DOUBLE,
  S5GNR_Total_RrcEventForSrsRel DOUBLE,
  S5GNR_Total_RrcEventForSrsReconfig DOUBLE,
  S5GNR_Avg_NumUeSrsAllocation_Num DOUBLE,
  S5GNR_Avg_NumUeSrsAllocation_Denom DOUBLE,
  S5GNR_Max_NumUeSrsAllocation DOUBLE,
  S5GNR_Avg_NumUeSrsAvailable_Num DOUBLE,
  S5GNR_Avg_NumUeSrsAvailable_Denom DOUBLE,
  S5GNR_Avg_NumUeSrsUsed_Num DOUBLE,
  S5GNR_Avg_NumUeSrsUsed_Denom DOUBLE)
*/


delete from apachedataingestion.nr.widetable_5g_cell_hr_gold2
where CalendarDate =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
;

insert into apachedataingestion.nr.widetable_5g_cell_hr_gold2
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,frequency_band_indicator,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	-- select count(distinct concat(GNODEB_ID,'_',DU_ID,'_',GCELL_ID)) --514527
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,'' frequency_band_indicator,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							-- select count(*)
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
),
conf_market (select cast(SUB_MARKET_ID AS INT) SUB_MARKET_ID,SUB_MARKET_NAME,REGION,Time_Offset from hive_metastore.default.vz_conf_market)
SELECT  frequency_band_indicator,
		y.CalendarDate,
		y.Hour24,
		Y.GNODEB_ID,
		y.du_id,
		y.GCELL_ID,
		y.MARKET_NAME,
		y.NR_TYPE,			
		y.SUB_MARKET_ID,
		y.SUB_MARKET_NAME,
		ENDC_Drop_Rate_NUM,
		ENDC_Drop_Rate_DENOM,
		S5NR_ReConfigurationFailureRate_PCT_22A_Num,
		S5NR_ReConfigurationFailureRate_PCT_22A_Denom,
		S5NR_AdditionFailureRate_NoResources_PCT_22A_Num,
		S5NR_AdditionFailureRate_NoResources_PCT_22A_Denom,
		S5NR_IntragNBHOFailRate_PCT_Num ,
		S5NR_IntragNBHOFailRate_PCT_Denom ,
		S5NR_IntergNBHOFailRate_PCT_Num ,
		S5NR_IntergNBHOFailRate_PCT_Denom ,
		S5NR_AvgRRCconnectedUsersPerCell_Num,
		S5NR_AvgRRCconnectedUsersPerCell_Denom,
		S5NR_DLMACLayerDataVolume_MB,
		S5NR_ULMACLayerDataVolume_MB,
		S5NR_DLUserPerceivedTput_Mbps_Num ,
		S5NR_DLUserPerceivedTput_Mbps_DENOM ,
		S5NR_ULUserPerceivedTput_Mbps_NUM,
		S5NR_ULUserPerceivedTput_Mbps_DENOM,
		S5NR_CA_AvgNumCC_NUM,
		S5NR_CA_AvgNumCC_DENOM,
		S5NR_TotalERABSetupFailureRate_PCT_Num,
		S5NR_TotalERABSetupFailureRate_PCT_Denom,
		S5NR_MaxRRCconnectedUsersPerCell,
		S5NR_TotalDLRLCLayerDataVolume_MB,
		S5NR_TotalULRLCLayerDataVolume_MB,
		S5NR_DLMACcellAggregateTput_Mbps_Num,
		S5NR_DLMACcellAggregateTput_Mbps_Denom,
		S5NR_ULMACcellAggregateTput_Mbps_Num,
		S5NR_ULMACcellAggregateTput_Mbps_Denom,
		S5NR_DLTTIUtilization_Pct_Num,
		S5NR_DLTTIUtilization_Pct_Denom,
		S5NR_ULTTIUtilization_PCT_Num,
		S5NR_ULTTIUtilization_PCT_Denom,
		S5NR_DLRLCReTx_PCT_Num,
		S5NR_DLRLCReTx_PCT_Denom,
		S5NR_DLPRBUtilization_PCT_Num,
		S5NR_DLPRBUtilization_PCT_Denom,
		S5NR_DLPRBUtilization_PCT_DSS_Num,
		S5NR_DLPRBUtilization_PCT_DSS_Denom,
		S5NR_DLTTIUtilization_PCT_DSS_Num,
		S5NR_DLTTIUtilization_PCT_DSS_Denom,
		S5NR_ULPRBUtilization_PCT_Num,
		S5NR_ULPRBUtilization_PCT_Denom,
		S5NR_ULPRBUtilization_PCT_DSS_Num,
		S5NR_ULPRBUtilization_PCT_DSS_Denom,
		S5NR_ULTTIUtilization_PCT_DSS_Num,
		S5NR_ULTTIUtilization_PCT_DSS_Denom,
		S5NR_DLInitBLER_PCT_Num,
		S5NR_DLInitBLER_PCT_Denom,
		S5NR_DLResidualBLER_PCT_Num,
		S5NR_DLResidualBLER_PCT_Denom,
		S5NR_ULInitBLER_PCT_Num,
		S5NR_ULInitBLER_PCT_Denom,
		S5NR_ULResidualBLER_PCT_Num,
		S5NR_ULResidualBLER_PCT_Denom,
		AIR_MAC_BYTES_AirMacDLByte,         
		AIR_MAC_BYTES_AirMacULByte,                    
		UL_MIMO_ULNumPuschAvailableSlots,   
		DL_MIMO_DLNumPdschAvailableSlots,
		DSS_INFO_DssNRDLPrbAvailable,       
		DSS_INFO_DssNRDLPrbUsed,            
		DSS_INFO_DssNRDLTtiAvailable,       
		DSS_INFO_DssNRULPrbAvailable,       
		DSS_INFO_DssNRULPrbUsed,            
		DSS_INFO_DssNRULTtiAvailable, 			
		PRB_TOTAL_TotDLAvailablePrb,        
		PRB_TOTAL_TotDLBroadcastPrb,        
		PRB_TOTAL_TotDLUnicastPrb,          
		PRB_TOTAL_TotULAvailablePrb,        
		PRB_TOTAL_TotULUsedPrb,
		--add tmp1
		S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Num,
		S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Denom,
		S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Num,
		S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Denom,
		S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Num,
		S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Denom,
		S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Num,
		S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Denom,
		S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Num,
		S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Denom,
		S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Num,
		S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Denom,
		S5NR_CA_AvgNumUE_1CC_Num,
		S5NR_CA_AvgNumUE_1CC_Denom,
		S5NR_CA_AvgNumUE_2CC_Num,
		S5NR_CA_AvgNumUE_2CC_Denom,
		S5NR_CA_AvgNumUE_3CC_Num,
		S5NR_CA_AvgNumUE_3CC_Denom,
		S5NR_CA_AvgNumUE_4CC_Num,
		S5NR_CA_AvgNumUE_4CC_Denom,
		S5NR_CA_AvgNumUE_5CC_Num,
		S5NR_CA_AvgNumUE_5CC_Denom,
		S5NR_CA_AvgNumUE_6CC_Num,
		S5NR_CA_AvgNumUE_6CC_Denom,
		S5NR_CA_AvgNumUE_7CC_Num,
		S5NR_CA_AvgNumUE_7CC_Denom,
		S5NR_CA_AvgNumUE_8CC_Num,
		S5NR_CA_AvgNumUE_8CC_Denom,
		S5NR_MuMimoUeRatio_UL_PCT_Num,
		S5NR_MuMimoUeRatio_UL_PCT_Denom,
		--add tmp2
		S5NR_RLC_Delay_ms_Num ,
		S5NR_RLC_Delay_ms_Denom ,
		S5NR_AirIF_Delay_ms_Num ,
		S5NR_AirIF_Delay_ms_Denom ,
		S5NR_CADLMACLayerDataVolumePCell_MB ,
		S5NR_CAULMACLayerDataVolumePCell_MB ,
		S5NR_CADLMACLayerDataVolumeSCell_MB ,
		S5NR_CAULMACLayerDataVolumeSCell_MB ,
		S5NR_PDCCH_Block_DL_pct_NUM ,
		S5NR_PDCCH_Block_DL_pct_DENOM ,
		S5NR_PDCCH_Block_UL_pct_NUM ,
		S5NR_PDCCH_Block_UL_pct_DENOM ,
		S5NR_PDCCH_Blocking_Tot_pct_NUM ,
		S5NR_PDCCH_Blocking_Tot_pct_DENOM ,
		S5NR_PDCCH_AggLvl1_DL_pct_NUM ,
		S5NR_PDCCH_AggLvl1_DL_pct_DENOM ,
		S5NR_PDCCH_AggLvl2_DL_pct_NUM ,
		S5NR_PDCCH_AggLvl2_DL_pct_DENOM ,
		S5NR_PDCCH_AggLvl4_DL_pct_NUM ,
		S5NR_PDCCH_AggLvl4_DL_pct_DENOM ,
		S5NR_PDCCH_AggLvl8_DL_pct_NUM ,
		S5NR_PDCCH_AggLvl8_DL_pct_DENOM ,
		S5NR_PDCCH_AggLvl1_UL_pct_NUM ,
		S5NR_PDCCH_AggLvl1_UL_pct_DENOM ,
		S5NR_PDCCH_AggLvl2_UL_pct_NUM ,
		S5NR_PDCCH_AggLvl2_UL_pct_DENOM ,
		S5NR_PDCCH_AggLvl4_UL_pct_NUM ,
		S5NR_PDCCH_AggLvl4_UL_pct_DENOM ,
		S5NR_PDCCH_AggLvl8_UL_pct_NUM ,
		S5NR_PDCCH_AggLvl8_UL_pct_DENOM ,
		S5NR_CA_Addition_Attempts ,
		S5NR_CA_Addition_Failure_PCT_NUM ,
		S5NR_CA_Addition_Failure_PCT_DENOM ,
		S5NR_CA_Activation_Attempts ,
		S5NR_CA_Activation_Failure_PCT_Num ,
		S5NR_CA_Activation_Failure_PCT_Denom ,
		S5NR_CA_Deactivation_Attempts ,
		S5NR_CA_Deactivation_Failure_PCT_Num ,
		S5NR_CA_Deactivation_Failure_PCT_Denom ,
		S5NR_CA_AvgAddDuration_s_NUM ,
		S5NR_CA_AvgAddDuration_s_DENOM ,
		S5NR_CA_MaxAddDuration_s ,
		S5NR_CA_TotAddDuration_s ,
		S5NR_CA_NumF1UECtxtSetupReq_NonCaCapUE ,
		S5NR_CA_NumF1UECtxtSetupReq_CaCapUE ,
		S5NR_CA_NumF1UECtxtSetupReq_NonULCaCapUE ,
		S5NR_CA_NumF1UECtxtSetupReq_ULCaCapUE ,
		S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_NUM ,
		S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_DENOM ,
		S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_NUM ,
		S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_DENOM ,
		S5NR_ULAvgAssignedMCS_NUM ,
		S5NR_ULAvgAssignedMCS_DENOM ,
		S5_AverageCQI_NUM ,
		S5_AverageCQI_DENOM ,
		S5NR_RACH_SR_pct_NUM ,
		S5NR_RACH_SR_pct_DENOM ,
		S5NR_RACH_CB_SR_pct_NUM ,
		S5NR_RACH_CB_SR_pct_DENOM ,
		S5NR_RACH_CF_SR_pct_NUM ,
		S5NR_RACH_CF_SR_pct_DENOM ,
		S5NR_RACH_Att_MSG1_CB ,
		S5NR_RACH_Att_MSG1_CF ,
		S5NR_RACH_Att_MSG2_CB ,
		S5NR_RACH_Att_MSG2_CF ,
		S5NR_RACH_Att_MSG3_CB ,
		S5NR_RACH_Att_MSG3_CF ,
		S5NR_RACH_Att_MSG5_CB ,
		S5NR_PUCCHAvgSINR_dB_NUM ,
		S5NR_PUCCHAvgSINR_dB_DENOM ,
		S5NR_PUSCHAvgSINR_dB_NUM ,
		S5NR_PUSCHAvgSINR_dB_DENOM ,
		Average_RSSI_Path0_3_Num ,
		Average_RSSI_Path0_3_Denom,
		S5NR_DLAvgAssignedMCS_NUM,
		S5NR_DLAvgAssignedMCS_DENOM,
		--add
		S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Num,
		S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Denom,
		S5NR_AvgNumMuMimoUePerSlot_UL_Num,
		S5NR_AvgNumMuMimoUePerSlot_UL_Denom,
		S5NR_MuMimoUsedPrbRatio_UL_PCT_Num,
		S5NR_MuMimoUsedPrbRatio_UL_PCT_Denom,
		S5NR_AvgNumLayerPerSlot_UL_Num,
		S5NR_AvgNumLayerPerSlot_UL_Denom,
		RssiPathMax,
		S5NR_PDCCH_SlotRationBlocking_DL_PCT_Num,
		S5NR_PDCCH_SlotRationBlocking_DL_PCT_Denom,
		S5NR_PDCCH_SlotRationBlocking_UL_PCT_Num,
		S5NR_PDCCH_SlotRationBlocking_UL_PCT_Denom,
		S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Num,
		S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Denom,
		S5NR_PDCCH_AggLvl16_DL_PCT_Num,
		S5NR_PDCCH_AggLvl16_DL_PCT_Denom,
		S5NR_PDCCH_AggLvl16_UL_PCT_Num,
		S5NR_PDCCH_AggLvl16_UL_PCT_Denom,
		-- add qci
		S5NR_TotalDLRLCLayerDataVolume_MB_QCI8,
		S5NR_TotalDLRLCLayerDataVolume_MB_QCI132,
		S5NR_TotalULRLCLayerDataVolume_MB_QCI8,
		S5NR_TotalULRLCLayerDataVolume_MB_QCI132,
		S5NR_DLUserPerceivedTput_Mbps_QCI8_Num,
		S5NR_DLUserPerceivedTput_Mbps_QCI8_Denom,
		S5NR_DLUserPerceivedTput_Mbps_QCI132_Num,
		S5NR_DLUserPerceivedTput_Mbps_QCI132_Denom,		
		Cell_Availability_Num,
		Cell_Availability_Denom,
		-- add 
		S5NR_AvgRRCConnectionHoldTime_s_Num,	
		S5NR_AvgRRCConnectionHoldTime_s_Denom,
		S5NR_PUCCH_BLER_PCT_Num , 
		S5NR_PUCCH_BLER_PCT_Denom,
		S5NR_PDCCH_Fail_DL_PCT_Num,	
		S5NR_PDCCH_Fail_DL_PCT_Denom,
		S5NR_PDCCH_Fail_UL_PCT_Num,
		S5NR_PDCCH_Fail_UL_PCT_Denom,
		S5NR_AvgNumMuMimoLayerPerMuTti_DL_Num,	
		S5NR_AvgNumMuMimoLayerPerMuTti_DL_Denom,
		S5NR_AvgNumMuMimoUePerMuTti_DL_Num,	
		S5NR_AvgNumMuMimoUePerMuTti_DL_Denom,
		S5NR_MuMimoUeRatio_DL_PCT_Num,	
		S5NR_MuMimoUeRatio_DL_PCT_Denom,
		S5NR_MuMimoUsedPrbRatio_DL_PCT_Num,	
		S5NR_MuMimoUsedPrbRatio_DL_PCT_Denom,
		ULRatioSuRank2UEs_Num,
		ULRatioSuRank2UEs_Denom,		
		S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Num,
		S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Denom,
		S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Num,
		S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Denom,
		S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Num,
		S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Denom, 
		S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Num,
		S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Denom,
		S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Num,
		S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Denom,
		S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Num,
		S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Denom,
		S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Num,
		S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Denom,
		S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Num,
		S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Denom,
		case 	when B.Time_Offset=-5 then  convert_timezone('America/New_York','UTC',cast(concat(Y.CalendarDate,' ',lpad(Y.hour24,2,0),':00:00') as TIMESTAMP)) 
	 			when B.Time_Offset=-6 then  convert_timezone('America/Chicago','UTC',cast(concat(Y.CalendarDate,' ',lpad(Y.hour24,2,0),':00:00') as TIMESTAMP)) 
	 			when B.Time_Offset=-8 then  convert_timezone('America/Los_Angeles','UTC',cast(concat(Y.CalendarDate,' ',lpad(Y.hour24,2,0),':00:00') as TIMESTAMP)) 
 		end D_DTM_UTC,
  		replace(Y.du_ID,'VZ_','') ne_id2,
		--Added new KPI on 12/11/2024 JIRA DENG-2445
		PUCCH_TotULPrb,
		--Added new columns on 12/26/2024 JIRA:DENG-2463
			NSA_ERAB_Drop_Rate_FWA_PCT_Num,
			NSA_ERAB_Drop_Rate_FWA_PCT_Denom,
			NSA_ERAB_Drop_Rate_Mobility_PCT_Num,
			NSA_ERAB_Drop_Rate_Mobility_PCT_Denom,
			NSA_ERAB_Drop_Rate_Overall_PCT_Num,
			NSA_ERAB_Drop_Rate_Overall_PCT_Denom,
		--Added new columns as on 1/23/2025 DENG-2659
		S5NR_Cell_Availability_PCT_Num,
		S5NR_Cell_Availability_PCT_Denom,
		S5NR_Cell_Availability_PCT_excl_Lock_ES_Num,
		S5NR_Cell_Availability_PCT_excl_Lock_ES_Denom,
		S5NC_ERABSetupFailureRate_PCT_Mobility_Num,
		S5NC_ERABSetupFailureRate_PCT_Mobility_Denom,
		Avg_NRDC_Users_MN_Num,
		Avg_NRDC_Users_MN_Denom,
		Max_NRDC_Users_MN,
		Avg_NRDC_Users_SN_Num,
		Avg_NRDC_Users_SN_Denom,
		Max_NRDC_Users_SN,
		S5NR_AirIF_Delay_UL_ms_Num,
		S5NR_AirIF_Delay_UL_ms_Denom,
		5G_ASEU_NSA_CELL,
		5G_ASEU_SA_CELL,
		5G_ASEU_NSA_QCI,
		5G_ASEU_SA_5QI,
		5G_ASEU_NSA_SPID,
		5G_ASEU_SA_RFSP,
		S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Num,
		S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Denom,
		S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Num,
		S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Denom,
		S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Num,
		S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Denom,
		S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Num,
		S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Denom,

		--Added on 1/29/2025 DENG-2689
		5GNC_DRBSetupFail_Mobility_PCT_Num,
		5GNC_DRBSetupFail_Mobility_PCT_Denom,
		S5NC_AvgRRC_Mobility_Num,
		S5NC_AvgRRC_Mobility_Denom,
		S5NC_MaxRRC_Mobility,
		S5ND_TotalMACDataVolumeDL_MB_Mobility,
		S5ND_TotalMACDataVolumeUL_MB_Mobility,
		S5ND_DLUeThru_Mbps_Mobility_Num,
		S5ND_DLUeThru_Mbps_Mobility_Denom,
		S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Num,
		S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Denom,
		S5NC_DRBDrop_PCT_5QI133_Slicing_Num,
		S5NC_DRBDrop_PCT_5QI133_Slicing_Denom,
		S5ND_RLCDataVol_DL_SA_MB_5QI133,
		S5ND_RLCDataVol_UL_SA_MB_5QI133,
		S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Num,
		S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Denom,
		S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Num,
		S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Denom,
		SAM_5G_SA_Celllvl_Paging_Discard_Rate_Num,	
		SAM_5G_SA_Celllvl_Paging_Discard_Rate_Denom,
		SAM_5G_SA_Celllvl_Paging_Attempts,		
		CellUnavailableTimeLock_s_SUM,
		CellUnavailableTimeES_s_SUM,
		CellUnavailableTimeDown_s_SUM,
		CellAvailPmPeriodTime_s_SUM,
		--Added as on 03/25/2025 DENG-3078
		Release_by_CAC,
	  S5NR_Avg_DL_SRS_SU_MCS_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_Denom,
	  S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Denom,
	  S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Denom,
	  S5NR_Avg_DL_SRS_SU_MCS_SPID125_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_SPID125_Denom,
	  S5NR_Avg_DL_SRS_SU_MCS_SPID115_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_SPID115_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Denom,
    S5GNR_Total_RrcEventForSrsAllo4Tas,
    S5GNR_Total_RrcEventForSrsAllo4NonTas,
    S5GNR_Total_RrcEventForSrsRel,
    S5GNR_Total_RrcEventForSrsReconfig,
	  S5GNR_Avg_NumUeSrsAllocation_Num,
	  S5GNR_Avg_NumUeSrsAllocation_Denom,
	  S5GNR_Max_NumUeSrsAllocation,
	  S5GNR_Avg_NumUeSrsAvailable_Num,
	  S5GNR_Avg_NumUeSrsAvailable_Denom,
	  S5GNR_Avg_NumUeSrsUsed_Num,
	  S5GNR_Avg_NumUeSrsUsed_Denom
 from (
		select 
		COALESCE(M0.CalendarDate,T1.CalendarDate,T2.CalendarDate) CalendarDate,
		COALESCE(M0.Hour24,T1.Hour24,T2.Hour24) Hour24,
		COALESCE(M0.GNODEB_ID,T1.GNODEB_ID,T2.GNODEB_ID) GNODEB_ID,
		COALESCE(M0.du_id,T1.du_id,T2.du_id) du_id,
		COALESCE(M0.GCELL_ID,T1.GCELL_ID,T2.GCELL_ID) GCELL_ID,
		COALESCE(M0.MARKET_NAME,T1.MARKET_NAME,T2.MARKET_NAME) MARKET_NAME,
		COALESCE(M0.NR_TYPE,T1.NR_TYPE,T2.NR_TYPE) NR_TYPE,			
		COALESCE(M0.SUB_MARKET_ID,T1.SUB_MARKET_ID,T2.SUB_MARKET_ID) SUB_MARKET_ID,
		COALESCE(M0.SUB_MARKET_NAME,T1.SUB_MARKET_NAME,T2.SUB_MARKET_NAME) SUB_MARKET_NAME,
		ENDC_Drop_Rate_NUM,
		ENDC_Drop_Rate_DENOM,
		S5NR_ReConfigurationFailureRate_PCT_22A_Num,
		S5NR_ReConfigurationFailureRate_PCT_22A_Denom,
		S5NR_AdditionFailureRate_NoResources_PCT_22A_Num,
		S5NR_AdditionFailureRate_NoResources_PCT_22A_Denom,
		S5NR_IntragNBHOFailRate_PCT_Num ,
		S5NR_IntragNBHOFailRate_PCT_Denom ,
		S5NR_IntergNBHOFailRate_PCT_Num ,
		S5NR_IntergNBHOFailRate_PCT_Denom ,
		S5NR_AvgRRCconnectedUsersPerCell_Num,
		S5NR_AvgRRCconnectedUsersPerCell_Denom,
		S5NR_DLMACLayerDataVolume_MB,
		S5NR_ULMACLayerDataVolume_MB,
		S5NR_DLUserPerceivedTput_Mbps_Num ,
		S5NR_DLUserPerceivedTput_Mbps_DENOM ,
		S5NR_ULUserPerceivedTput_Mbps_NUM,
		S5NR_ULUserPerceivedTput_Mbps_DENOM,
		S5NR_CA_AvgNumCC_NUM,
		S5NR_CA_AvgNumCC_DENOM,
		S5NR_TotalERABSetupFailureRate_PCT_Num,
		S5NR_TotalERABSetupFailureRate_PCT_Denom,
		S5NR_MaxRRCconnectedUsersPerCell,
		S5NR_TotalDLRLCLayerDataVolume_MB,
		S5NR_TotalULRLCLayerDataVolume_MB,
		S5NR_DLMACcellAggregateTput_Mbps_Num,
		S5NR_DLMACcellAggregateTput_Mbps_Denom,
		S5NR_ULMACcellAggregateTput_Mbps_Num,
		S5NR_ULMACcellAggregateTput_Mbps_Denom,
		S5NR_DLTTIUtilization_Pct_Num,
		S5NR_DLTTIUtilization_Pct_Denom,
		S5NR_ULTTIUtilization_PCT_Num,
		S5NR_ULTTIUtilization_PCT_Denom,
		S5NR_DLRLCReTx_PCT_Num,
		S5NR_DLRLCReTx_PCT_Denom,
		S5NR_DLPRBUtilization_PCT_Num,
		S5NR_DLPRBUtilization_PCT_Denom,
		S5NR_DLPRBUtilization_PCT_DSS_Num,
		S5NR_DLPRBUtilization_PCT_DSS_Denom,
		S5NR_DLTTIUtilization_PCT_DSS_Num,
		S5NR_DLTTIUtilization_PCT_DSS_Denom,
		S5NR_ULPRBUtilization_PCT_Num,
		S5NR_ULPRBUtilization_PCT_Denom,
		S5NR_ULPRBUtilization_PCT_DSS_Num,
		S5NR_ULPRBUtilization_PCT_DSS_Denom,
		S5NR_ULTTIUtilization_PCT_DSS_Num,
		S5NR_ULTTIUtilization_PCT_DSS_Denom,
		S5NR_DLInitBLER_PCT_Num,
		S5NR_DLInitBLER_PCT_Denom,
		S5NR_DLResidualBLER_PCT_Num,
		S5NR_DLResidualBLER_PCT_Denom,
		S5NR_ULInitBLER_PCT_Num,
		S5NR_ULInitBLER_PCT_Denom,
		S5NR_ULResidualBLER_PCT_Num,
		S5NR_ULResidualBLER_PCT_Denom,
		AIR_MAC_BYTES_AirMacDLByte,         
		AIR_MAC_BYTES_AirMacULByte,                    
		UL_MIMO_ULNumPuschAvailableSlots,   
		DL_MIMO_DLNumPdschAvailableSlots,
		DSS_INFO_DssNRDLPrbAvailable,       
		DSS_INFO_DssNRDLPrbUsed,            
		DSS_INFO_DssNRDLTtiAvailable,       
		DSS_INFO_DssNRULPrbAvailable,       
		DSS_INFO_DssNRULPrbUsed,            
		DSS_INFO_DssNRULTtiAvailable, 			
		PRB_TOTAL_TotDLAvailablePrb,        
		PRB_TOTAL_TotDLBroadcastPrb,        
		PRB_TOTAL_TotDLUnicastPrb,          
		PRB_TOTAL_TotULAvailablePrb,        
		PRB_TOTAL_TotULUsedPrb,
		--add tmp1
		(8 * AIR_MAC_BYTES_AirMacDLByte / 1000) 		S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Num,
		(S5NR_DLTTIUtilization_Pct_Num / 1000)  		S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Denom,
		(8 * AIR_MAC_BYTES_AirMacULByte / 1000)	 		S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Num,
		(S5NR_ULTTIUtilization_PCT_Num / 1000) 			S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Denom,
		(8 * AIR_MAC_BYTES_AirMacDLByte/1000)	 		S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Num,
		(S5NR_DLTTIUtilization_PCT_DSS_Num / 1000) 		S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Denom,
		(8 * AIR_MAC_BYTES_AirMacULByte/1000)			S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Num,
		(S5NR_ULTTIUtilization_PCT_DSS_Num/ 1000) 		S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Denom,
		(8  * 0.8 * AIR_MAC_BYTES_AirMacDLByte/1000)	S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Num,
		(S5NR_DLTTIUtilization_Pct_Num / 2000) 			S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Denom,
		(8  * 0.2 * AIR_MAC_BYTES_AirMacULByte/1000)	S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Num,
		(S5NR_ULTTIUtilization_PCT_Num / 2000)       	S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Denom,
		CaUeNum_perCC1Tot S5NR_CA_AvgNumUE_1CC_Num,
		CaUeNum_perCC1Cnt S5NR_CA_AvgNumUE_1CC_Denom,
		CaUeNum_perCC2Tot S5NR_CA_AvgNumUE_2CC_Num,
		CaUeNum_perCC2Cnt S5NR_CA_AvgNumUE_2CC_Denom,
		CaUeNum_perCC3Tot S5NR_CA_AvgNumUE_3CC_Num,
		CaUeNum_perCC3Cnt S5NR_CA_AvgNumUE_3CC_Denom,
		CaUeNum_perCC4Tot S5NR_CA_AvgNumUE_4CC_Num,
		CaUeNum_perCC4Cnt S5NR_CA_AvgNumUE_4CC_Denom,
		CaUeNum_perCC5Tot S5NR_CA_AvgNumUE_5CC_Num,
		CaUeNum_perCC5Cnt S5NR_CA_AvgNumUE_5CC_Denom,
		CaUeNum_perCC6Tot S5NR_CA_AvgNumUE_6CC_Num,
		CaUeNum_perCC6Cnt S5NR_CA_AvgNumUE_6CC_Denom,
		CaUeNum_perCC7Tot S5NR_CA_AvgNumUE_7CC_Num,
		CaUeNum_perCC7Cnt S5NR_CA_AvgNumUE_7CC_Denom,
		CaUeNum_perCC8Tot S5NR_CA_AvgNumUE_8CC_Num,
		CaUeNum_perCC8Cnt S5NR_CA_AvgNumUE_8CC_Denom,
		ULNumMuMimoUEs	  S5NR_MuMimoUeRatio_UL_PCT_Num,
		ULNumScheduledUEs S5NR_MuMimoUeRatio_UL_PCT_Denom,
		--add tmp2
		S5NR_RLC_Delay_ms_Num ,
		S5NR_RLC_Delay_ms_Denom ,
		S5NR_AirIF_Delay_ms_Num ,
		S5NR_AirIF_Delay_ms_Denom ,
		S5NR_CADLMACLayerDataVolumePCell_MB/1000 S5NR_CADLMACLayerDataVolumePCell_MB,
		S5NR_CAULMACLayerDataVolumePCell_MB/1000 S5NR_CAULMACLayerDataVolumePCell_MB,
		S5NR_CADLMACLayerDataVolumeSCell_MB/1000 S5NR_CADLMACLayerDataVolumeSCell_MB,
		S5NR_CAULMACLayerDataVolumeSCell_MB/1000 S5NR_CAULMACLayerDataVolumeSCell_MB,
		S5NR_PDCCH_Block_DL_pct_NUM ,
		S5NR_PDCCH_Block_DL_pct_DENOM ,
		S5NR_PDCCH_Block_UL_pct_NUM ,
		S5NR_PDCCH_Block_UL_pct_DENOM ,
		S5NR_PDCCH_Blocking_Tot_pct_NUM ,
		S5NR_PDCCH_Blocking_Tot_pct_DENOM ,
		S5NR_PDCCH_AggLvl1_DL_pct_NUM ,
		S5NR_PDCCH_AggLvl1_DL_pct_DENOM ,
		S5NR_PDCCH_AggLvl2_DL_pct_NUM ,
		S5NR_PDCCH_AggLvl2_DL_pct_DENOM ,
		S5NR_PDCCH_AggLvl4_DL_pct_NUM ,
		S5NR_PDCCH_AggLvl4_DL_pct_DENOM ,
		S5NR_PDCCH_AggLvl8_DL_pct_NUM ,
		S5NR_PDCCH_AggLvl8_DL_pct_DENOM ,
		S5NR_PDCCH_AggLvl1_UL_pct_NUM ,
		S5NR_PDCCH_AggLvl1_UL_pct_DENOM ,
		S5NR_PDCCH_AggLvl2_UL_pct_NUM ,
		S5NR_PDCCH_AggLvl2_UL_pct_DENOM ,
		S5NR_PDCCH_AggLvl4_UL_pct_NUM ,
		S5NR_PDCCH_AggLvl4_UL_pct_DENOM ,
		S5NR_PDCCH_AggLvl8_UL_pct_NUM ,
		S5NR_PDCCH_AggLvl8_UL_pct_DENOM ,
		S5NR_CA_Addition_Attempts ,
		S5NR_CA_Addition_Failure_PCT_NUM ,
		S5NR_CA_Addition_Failure_PCT_DENOM ,
		S5NR_CA_Activation_Attempts ,
		S5NR_CA_Activation_Failure_PCT_Num ,
		S5NR_CA_Activation_Failure_PCT_Denom ,
		S5NR_CA_Deactivation_Attempts ,
		S5NR_CA_Deactivation_Failure_PCT_Num ,
		S5NR_CA_Deactivation_Failure_PCT_Denom ,
		S5NR_CA_AvgAddDuration_s_NUM ,
		S5NR_CA_AvgAddDuration_s_DENOM ,
		S5NR_CA_MaxAddDuration_s ,
		S5NR_CA_TotAddDuration_s ,
		S5NR_CA_NumF1UECtxtSetupReq_NonCaCapUE ,
		S5NR_CA_NumF1UECtxtSetupReq_CaCapUE ,
		S5NR_CA_NumF1UECtxtSetupReq_NonULCaCapUE ,
		S5NR_CA_NumF1UECtxtSetupReq_ULCaCapUE ,
		S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_NUM ,
		S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_DENOM ,
		S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_NUM ,
		S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_DENOM ,
		S5NR_ULAvgAssignedMCS_NUM ,
		S5NR_ULAvgAssignedMCS_DENOM ,
		S5_AverageCQI_NUM ,
		S5_AverageCQI_DENOM ,
		S5NR_RACH_SR_pct_NUM ,
		S5NR_RACH_SR_pct_DENOM ,
		S5NR_RACH_CB_SR_pct_NUM ,
		S5NR_RACH_CB_SR_pct_DENOM ,
		S5NR_RACH_CF_SR_pct_NUM ,
		S5NR_RACH_CF_SR_pct_DENOM ,
		S5NR_RACH_Att_MSG1_CB ,
		S5NR_RACH_Att_MSG1_CF ,
		S5NR_RACH_Att_MSG2_CB ,
		S5NR_RACH_Att_MSG2_CF ,
		S5NR_RACH_Att_MSG3_CB ,
		S5NR_RACH_Att_MSG3_CF ,
		S5NR_RACH_Att_MSG5_CB ,
		S5NR_PUCCHAvgSINR_dB_NUM ,
		S5NR_PUCCHAvgSINR_dB_DENOM ,
		S5NR_PUSCHAvgSINR_dB_NUM ,
		S5NR_PUSCHAvgSINR_dB_DENOM ,
		Average_RSSI_Path0_3_Num ,
		Average_RSSI_Path0_3_Denom,
		S5NR_DLAvgAssignedMCS_NUM,
		S5NR_DLAvgAssignedMCS_DENOM,
		--add
		S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Num,
		S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Denom,
		S5NR_AvgNumMuMimoUePerSlot_UL_Num,
		S5NR_AvgNumMuMimoUePerSlot_UL_Denom,
		S5NR_MuMimoUsedPrbRatio_UL_PCT_Num,
		S5NR_MuMimoUsedPrbRatio_UL_PCT_Denom,
		S5NR_AvgNumLayerPerSlot_UL_Num,
		S5NR_AvgNumLayerPerSlot_UL_Denom,
		RssiPathMax,
		S5NR_PDCCH_SlotRationBlocking_DL_PCT_Num,
		S5NR_PDCCH_SlotRationBlocking_DL_PCT_Denom,
		S5NR_PDCCH_SlotRationBlocking_UL_PCT_Num,
		S5NR_PDCCH_SlotRationBlocking_UL_PCT_Denom,
		S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Num,
		S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Denom,
		S5NR_PDCCH_AggLvl16_DL_PCT_Num,
		S5NR_PDCCH_AggLvl16_DL_PCT_Denom,
		S5NR_PDCCH_AggLvl16_UL_PCT_Num,
		S5NR_PDCCH_AggLvl16_UL_PCT_Denom,
		-- add qci
		S5NR_TotalDLRLCLayerDataVolume_MB_QCI8,
		S5NR_TotalDLRLCLayerDataVolume_MB_QCI132,
		S5NR_TotalULRLCLayerDataVolume_MB_QCI8,
		S5NR_TotalULRLCLayerDataVolume_MB_QCI132,
		S5NR_DLUserPerceivedTput_Mbps_QCI8_Num,
		S5NR_DLUserPerceivedTput_Mbps_QCI8_Denom,
		S5NR_DLUserPerceivedTput_Mbps_QCI132_Num,
		S5NR_DLUserPerceivedTput_Mbps_QCI132_Denom,		
		Cell_Availability_Num,
		Cell_Availability_Denom,
		-- add 
		S5NR_AvgRRCConnectionHoldTime_s_Num,	
		S5NR_AvgRRCConnectionHoldTime_s_Denom,
		S5NR_PUCCH_BLER_PCT_Num , 
		S5NR_PUCCH_BLER_PCT_Denom,
		S5NR_PDCCH_Fail_DL_PCT_Num,	
		S5NR_PDCCH_Fail_DL_PCT_Denom,
		S5NR_PDCCH_Fail_UL_PCT_Num,
		S5NR_PDCCH_Fail_UL_PCT_Denom,
		S5NR_AvgNumMuMimoLayerPerMuTti_DL_Num,	
		S5NR_AvgNumMuMimoLayerPerMuTti_DL_Denom,
		S5NR_AvgNumMuMimoUePerMuTti_DL_Num,	
		S5NR_AvgNumMuMimoUePerMuTti_DL_Denom,
		S5NR_MuMimoUeRatio_DL_PCT_Num,	
		DLNumScheduledUEs S5NR_MuMimoUeRatio_DL_PCT_Denom,
		S5NR_MuMimoUsedPrbRatio_DL_PCT_Num,	
		S5NR_MuMimoUsedPrbRatio_DL_PCT_Denom,
		ULNumSuRank2UEs ULRatioSuRank2UEs_Num,
		ULNumScheduledUEs ULRatioSuRank2UEs_Denom,		
		
		
		0.8 * 8 * 1.024 * (S5NR_TotalDLRLCLayerDataVolume_MB + (case when isnull(RlcDLByte_5qi)=1 then 0 else RlcDLByte_5qi end/1000))	S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Num,
		(S5NR_DLTTIUtilization_Pct_Num / 8000) 	S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Denom,
		0.2 * 8 * 1.024 * (S5NR_TotalULRLCLayerDataVolume_MB + (case when isnull(RlcULByte_5qi)=1 then 0 else RlcULByte_5qi end/1000))	 S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Num,
		(S5NR_ULTTIUtilization_PCT_Num / 8000) 	S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Denom,
		8 * 1.024 * (S5NR_TotalDLRLCLayerDataVolume_MB + (case when isnull(RlcDLByte_5qi)=1 then 0 else RlcDLByte_5qi end/1000))		S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Num,
		(S5NR_DLTTIUtilization_Pct_Num / 1000) 				 	S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Denom, 
		8 * 1.024 * (S5NR_TotalULRLCLayerDataVolume_MB + (case when isnull(RlcULByte_5qi)=1 then 0 else RlcULByte_5qi end/1000))	 S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Num,
		(S5NR_ULTTIUtilization_PCT_Num / 1000)					S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Denom,
		8 * 1.024 * (S5NR_TotalDLRLCLayerDataVolume_MB + (case when isnull(RlcDLByte_5qi)=1 then 0 else RlcDLByte_5qi end/1000))	 S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Num,
		(S5NR_DLTTIUtilization_PCT_DSS_Num / 1000)													S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Denom,
		8 * 1.024 * (S5NR_TotalULRLCLayerDataVolume_MB + (case when isnull(RlcULByte_5qi)=1 then 0 else RlcULByte_5qi end/1000))	 S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Num,
		(S5NR_ULTTIUtilization_PCT_DSS_Num / 1000)													S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Denom,
		0.8 * 8 * 1.024 * (S5NR_TotalDLRLCLayerDataVolume_MB + (case when isnull(RlcDLByte_5qi)=1 then 0 else RlcDLByte_5qi end/1000)) 	S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Num,
		(S5NR_DLTTIUtilization_Pct_Num / 2000)	S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Denom,
		0.2 * 8 * 1.024 * (S5NR_TotalULRLCLayerDataVolume_MB + (case when isnull(RlcULByte_5qi)=1 then 0 else RlcULByte_5qi end/1000))	 S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Num,
		(S5NR_ULTTIUtilization_PCT_Num / 2000)	S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Denom,
		--Added new KPI on 12/11/2024 JIRA DENG-2445
		PUCCH_TotULPrb,
		--Added new columns on 12/26/2024 JIRA:DENG-2463
			NSA_ERAB_Drop_Rate_FWA_PCT_Num,
			NSA_ERAB_Drop_Rate_FWA_PCT_Denom,
			NSA_ERAB_Drop_Rate_Mobility_PCT_Num,
			NSA_ERAB_Drop_Rate_Mobility_PCT_Denom,
			NSA_ERAB_Drop_Rate_Overall_PCT_Num,
			NSA_ERAB_Drop_Rate_Overall_PCT_Denom,
		--Added new columns as on 1/23/2025 DENG-2659
		S5NR_Cell_Availability_PCT_Num,
		S5NR_Cell_Availability_PCT_Denom,
		S5NR_Cell_Availability_PCT_excl_Lock_ES_Num,
		S5NR_Cell_Availability_PCT_excl_Lock_ES_Denom,
		S5NC_ERABSetupFailureRate_PCT_Mobility_Num,
		S5NC_ERABSetupFailureRate_PCT_Mobility_Denom,
		Avg_NRDC_Users_MN_Num,
		Avg_NRDC_Users_MN_Denom,
		Max_NRDC_Users_MN,
		Avg_NRDC_Users_SN_Num,
		Avg_NRDC_Users_SN_Denom,
		Max_NRDC_Users_SN,
		S5NR_AirIF_Delay_UL_ms_Num,
		S5NR_AirIF_Delay_UL_ms_Denom,
		5G_ASEU_NSA_CELL,
		5G_ASEU_SA_CELL,
		5G_ASEU_NSA_QCI,
		5G_ASEU_SA_5QI,
		5G_ASEU_NSA_SPID,
		5G_ASEU_SA_RFSP,
		S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Num,
		S5NC_AdditionFailureRate_NoResources_PCT_NRDC_Denom,
		S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Num,
		S5ND_AvgUEThpt_UL_SA_Mbps_RFSP125_Denom,
		S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Num,
		S5ND_AvgUEThpt_UL_SA_Mbps_Mobility_Denom,
		S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Num,
		S5ND_AvgUEThpt_UL_SA_Mbps_RFSP95_LCG4_Denom,

		--Added on 1/29/2025 DENG-DENG-2689
		5GNC_DRBSetupFail_Mobility_PCT_Num,
		5GNC_DRBSetupFail_Mobility_PCT_Denom,
		S5NC_AvgRRC_Mobility_Num,
		S5NC_AvgRRC_Mobility_Denom,
		S5NC_MaxRRC_Mobility,
		S5ND_TotalMACDataVolumeDL_MB_Mobility,
		S5ND_TotalMACDataVolumeUL_MB_Mobility,
		S5ND_DLUeThru_Mbps_Mobility_Num,
		S5ND_DLUeThru_Mbps_Mobility_Denom,
		S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Num,
		S5NC_DRBSetupFail_PCT_SA_SNSSAI6_Denom,
		S5NC_DRBDrop_PCT_5QI133_Slicing_Num,
		S5NC_DRBDrop_PCT_5QI133_Slicing_Denom,
		S5ND_RLCDataVol_DL_SA_MB_5QI133,
		S5ND_RLCDataVol_UL_SA_MB_5QI133,
		S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Num,
		S5ND_AvgUEThpt_SA_Mbps_5QI133_RFSP95_SNSSAI6_Denom,
		S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Num,
		S5ND_AvgRLCDelay_DL_SA_us_5QI133_SNSSAI6_Denom,
		SAM_5G_SA_Celllvl_Paging_Discard_Rate_Num,	
		SAM_5G_SA_Celllvl_Paging_Discard_Rate_Denom,
		SAM_5G_SA_Celllvl_Paging_Attempts,		
		CellUnavailableTimeLock_s_SUM,
		CellUnavailableTimeES_s_SUM,
		CellUnavailableTimeDown_s_SUM,
		CellAvailPmPeriodTime_s_SUM,
		--Added as on 03/25/2025 DENG-3078
		Release_by_CAC,
		
		--Added as on 4/8/2025 DENG - 
	  S5NR_Avg_DL_SRS_SU_MCS_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_Denom,
	  S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_RFSP125_Denom,
	  S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_RFSP115_Denom,
	  S5NR_Avg_DL_SRS_SU_MCS_SPID125_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_SPID125_Denom,
	  S5NR_Avg_DL_SRS_SU_MCS_SPID115_Num,
	  S5NR_Avg_DL_SRS_SU_MCS_SPID115_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_PCT_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP125_PCT_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_RFSP115_PCT_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID125_PCT_Denom,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Num,
	  S5GNR_Avg_DLR_SRS_SU_MIMO_PRB_Utilization_SPID115_PCT_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP125_PCT_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_RFSP115_PCT_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID125_PCT_Denom,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Num,
	  S5GNR_Avg_DL_SRS_SU_MIMO_LAYER_SPID115_PCT_Denom,
	  S5GNR_Total_RrcEventForSrsAllo4Tas,
	  S5GNR_Total_RrcEventForSrsAllo4NonTas,
	  S5GNR_Total_RrcEventForSrsRel,
	  S5GNR_Total_RrcEventForSrsReconfig,
	  S5GNR_Avg_NumUeSrsAllocation_Num,
	  S5GNR_Avg_NumUeSrsAllocation_Denom,
	  S5GNR_Max_NumUeSrsAllocation,
	  S5GNR_Avg_NumUeSrsAvailable_Num,
	  S5GNR_Avg_NumUeSrsAvailable_Denom,
	  S5GNR_Avg_NumUeSrsUsed_Num,
	  S5GNR_Avg_NumUeSrsUsed_Denom		
		from hive_metastore.default.widetable_5g_cell_hr_tmp1 M0
			full join hive_metastore.default.widetable_5g_cell_hr_tmp2 	T1 on M0.CalendarDate=T1.CalendarDate and M0.Hour24=T1.Hour24 and M0.du_id=T1.du_id and M0.GCELL_ID=T1.GCELL_ID 
			full join hive_metastore.default.widetable_5g_cell_hr_tmp0 	T2 on M0.CalendarDate=T2.CalendarDate and M0.Hour24=T2.Hour24 and M0.du_id=T2.du_id and M0.GCELL_ID=T2.GCELL_ID 
			full join hive_metastore.default.widetable_5g_cell_hr_tmp10 	T3 on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID 
		WHERE 5=5 and  M0.CalendarDate  =  date_format(date_add(now(), int(:days)),"yyyy-MM-dd") 
) Y
left join ( select GNODEB_ID,DU_ID,GCELL_ID,frequency_band_indicator from conf_du group by GNODEB_ID,DU_ID,GCELL_ID,frequency_band_indicator) K on  Y.GNODEB_ID=K.GNODEB_ID and  Y.DU_ID=K.DU_ID and Y.GCELL_ID=K.GCELL_ID
inner join conf_market B on cast(Y.SUB_MARKET_ID AS INT)=B.SUB_MARKET_ID;
