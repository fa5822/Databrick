-- %%
 


-- ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp3 ADD COLUMN 	  DrbRelbyGnb_UeContextRelReq_WithNormalCause_5QI8  DOUBLE;


delete from hive_metastore.default.widetable_5g_cell_hr_tmp3;

insert into hive_metastore.default.widetable_5g_cell_hr_tmp3
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	-- select count(distinct concat(GNODEB_ID,'_',DU_ID,'_',GCELL_ID)) --514527
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							-- select count(*)
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
)
select 
CalendarDate ,
Hour24 ,
GNODEB_ID,
du_id ,
GCELL_ID ,
MARKET_NAME ,
case when length(du_id)=14 then 
	case when substring(du_id, 7, 1)=0 then 'FR2' 	 when substring(du_id, 7, 1)=9 then 
				case when substring(du_id, 11, 1)=2 then 'FR1/LS3' when substring(du_id, 11, 1)=3 then 'FR1/LS6' 
				end
	end
else '' end NR_TYPE,
substring(du_id,4,3) SUB_MARKET_ID,
SUB_MARKET_NAME ,
max(PdcpSduVolumeDL_CELL_PLMN_QCI) PdcpSduVolumeDL_CELL_PLMN_QCI,
max(PdcpSduVolumeUL_CELL_PLMN_QCI) PdcpSduVolumeUL_CELL_PLMN_QCI,
max(PdcpSduVolumeSplitNrDL_CELL_PLMN_QCI) PdcpSduVolumeSplitNrDL_CELL_PLMN_QCI,
max(PdcpSduVolumeSplitNrUL_CELL_PLMN_QCI) PdcpSduVolumeSplitNrUL_CELL_PLMN_QCI,
max(PdcpSduVolumeSplitLteDL_CELL_PLMN_QCI) PdcpSduVolumeSplitLteDL_CELL_PLMN_QCI,
max(PdcpSduVolumeSplitLteUL_CELL_PLMN_QCI) PdcpSduVolumeSplitLteUL_CELL_PLMN_QCI,
max(PdcpSduByteDL_CELL_PLMN_QCI) PdcpSduByteDL_CELL_PLMN_QCI,
max(PdcpSduByteUL_CELL_PLMN_QCI) PdcpSduByteUL_CELL_PLMN_QCI,
max(PdcpSduLossCntDL_CELL_PLMN_QCI) PdcpSduLossCntDL_CELL_PLMN_QCI,
max(PdcpSduLossCntUL_CELL_PLMN_QCI) PdcpSduLossCntUL_CELL_PLMN_QCI,
max(PdcpSduLossCntSplitLteDL_CELL_PLMN_QCI) PdcpSduLossCntSplitLteDL_CELL_PLMN_QCI,
max(PdcpSduLossCntSplitNrDL_CELL_PLMN_QCI) PdcpSduLossCntSplitNrDL_CELL_PLMN_QCI,
max(PdcpSduDiscardCntDL_CELL_PLMN_QCI) PdcpSduDiscardCntDL_CELL_PLMN_QCI,
max(PdcpSduDropCntDL_CELL_PLMN_QCI) PdcpSduDropCntDL_CELL_PLMN_QCI,
max(PdcpSduRetxCntDL_CELL_PLMN_QCI) PdcpSduRetxCntDL_CELL_PLMN_QCI,
max(PdcpSduDelayDLTot_CELL_PLMN_QCI) PdcpSduDelayDLTot_CELL_PLMN_QCI,
max(PdcpSduDelayULTot_CELL_PLMN_QCI) PdcpSduDelayULTot_CELL_PLMN_QCI,
max(PdcpSduDelaySplitLteDLTot_CELL_PLMN_QCI) PdcpSduDelaySplitLteDLTot_CELL_PLMN_QCI,
max(PdcpSduDelaySplitLteULTot_CELL_PLMN_QCI) PdcpSduDelaySplitLteULTot_CELL_PLMN_QCI,
max(PdcpSduDelaySplitNrDLTot_CELL_PLMN_QCI) PdcpSduDelaySplitNrDLTot_CELL_PLMN_QCI,
max(PdcpSduDelaySplitNrULTot_CELL_PLMN_QCI) PdcpSduDelaySplitNrULTot_CELL_PLMN_QCI,
max(PdcpSduByteDLCnt_CELL_PLMN_QCI) PdcpSduByteDLCnt_CELL_PLMN_QCI,
max(PdcpSduByteULCnt_CELL_PLMN_QCI) PdcpSduByteULCnt_CELL_PLMN_QCI,
max(PdcpSduCntDL_CELL_PLMN_QCI) PdcpSduCntDL_CELL_PLMN_QCI,
max(PdcpSduCntUL_CELL_PLMN_QCI) PdcpSduCntUL_CELL_PLMN_QCI,
max(PdcpSduCntSplitLteDL_CELL_PLMN_QCI) PdcpSduCntSplitLteDL_CELL_PLMN_QCI,
max(PdcpSduCntSplitNrDL_CELL_PLMN_QCI) PdcpSduCntSplitNrDL_CELL_PLMN_QCI,
max(PdcpSduDelayDLCnt_CELL_PLMN_QCI) PdcpSduDelayDLCnt_CELL_PLMN_QCI,
max(PdcpSduDelayULCnt_CELL_PLMN_QCI) PdcpSduDelayULCnt_CELL_PLMN_QCI,
max(PdcpSduDelaySplitLteDLCnt_CELL_PLMN_QCI) PdcpSduDelaySplitLteDLCnt_CELL_PLMN_QCI,
max(PdcpSduDelaySplitLteULCnt_CELL_PLMN_QCI) PdcpSduDelaySplitLteULCnt_CELL_PLMN_QCI,
max(PdcpSduDelaySplitNrDLCnt_CELL_PLMN_QCI) PdcpSduDelaySplitNrDLCnt_CELL_PLMN_QCI,
max(PdcpSduDelaySplitNrULCnt_CELL_PLMN_QCI) PdcpSduDelaySplitNrULCnt_CELL_PLMN_QCI,
max(EndcAddMnHoInterEnbAtt) EndcAddMnHoInterEnbAtt,
max(EndcAddMnHoInterEnbHoSucc) EndcAddMnHoInterEnbHoSucc,
max(EndcAddSgnbChgAtt) EndcAddSgnbChgAtt,
max(EndcAddSgnbChgSucc) EndcAddSgnbChgSucc,
max(AddProcTimeTot) AddProcTimeTot,
max(AddProcTimeCnt) AddProcTimeCnt,
max(DrbNoTot) DrbNoTot,
max(ConnEstabAtt) ConnEstabAtt,
max(ConnEstabSucc) ConnEstabSucc,
max(NgConnEstabAtt) NgConnEstabAtt,
max(NgConnEstabSucc) NgConnEstabSucc,
max(PduSetupPlmnSnssaiAtt) PduSetupPlmnSnssaiAtt,
max(PduSetupPlmnSnssaiSucc) PduSetupPlmnSnssaiSucc,
max(DrbSetupAtt) DrbSetupAtt,
max(DrbSetupSucc) DrbSetupSucc,
max(DrbSetupAtt_5QI8) DrbSetupAtt_5QI8,
max(DrbSetupSucc_5QI8) DrbSetupSucc_5QI8,
max(DrbRelTotal) DrbRelTotal,
max(DrbRelbyAmf_UeContextRelCmd_IntraNrHo) DrbRelbyAmf_UeContextRelCmd_IntraNrHo,
max(DrbRelTotal_5QI8) DrbRelTotal_5QI8,
max(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8) DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8,
max(DrbRelbyGnb_UeContextRelReq) DrbRelbyGnb_UeContextRelReq,
max(DrbRelbyGnb_UeContextRelReq_WithNormalCause) DrbRelbyGnb_UeContextRelReq_WithNormalCause,
max(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause) DrbRelbyAmf_PduSessionRelCmd_WithNormalCause,
max(DrbRelbyAmf_PduSessionModifyReq_WithNormalCause) DrbRelbyAmf_PduSessionModifyReq_WithNormalCause,
max(DrbRelbyAmf_UeContextRelCmd_WithNormalCause) DrbRelbyAmf_UeContextRelCmd_WithNormalCause,
max(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause) DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause,
max(DrbRelbyIntraRatRedirection) DrbRelbyIntraRatRedirection,
max(DrbRelbyInterRatRedirection) DrbRelbyInterRatRedirection,
max(DrbRelbyPreemption) DrbRelbyPreemption,
max(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8) DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8,
max(DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8) DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8,
max(DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8) DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8,
max(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8) DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8,
max(DrbRelbyIntraRatRedirection_5QI8) DrbRelbyIntraRatRedirection_5QI8,
max(DrbRelbyInterRatRedirection_5QI8) DrbRelbyInterRatRedirection_5QI8,
max(DrbRelbyPreemption_5QI8) DrbRelbyPreemption_5QI8,
-- add
max(DrbRelbyAmf_PduSessionModifyReq) DrbRelbyAmf_PduSessionModifyReq,
max(DrbRelbyAmf_PduSessionRelCmd) DrbRelbyAmf_PduSessionRelCmd,
max(DrbRelbyAmf_UeContextRelCmd) DrbRelbyAmf_UeContextRelCmd,
max(DrbRelbyAmf_PduSessionModifyReq_5QI8) DrbRelbyAmf_PduSessionModifyReq_5QI8,
max(DrbRelbyAmf_PduSessionRelCmd_5QI8) DrbRelbyAmf_PduSessionRelCmd_5QI8,
max(DrbRelbyAmf_UeContextRelCmd_5QI8) DrbRelbyAmf_UeContextRelCmd_5QI8,
max(DrbRelTotal_T11) DrbRelTotal_T11,
max(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_T11) DrbRelbyAmf_UeContextRelCmd_IntraNrHo_T11,
max(DrbRelTotal_5QI8_T11) DrbRelTotal_5QI8_T11,
max(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8_T11) DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8_T11,
max(DrbRelbyGnb_UeContextRelReq_T11) DrbRelbyGnb_UeContextRelReq_T11,
max(DrbRelbyGnb_UeContextRelReq_WithNormalCause_T11) DrbRelbyGnb_UeContextRelReq_WithNormalCause_T11,
max(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_T11) DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_T11,
max(DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_T11) DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_T11,
max(DrbRelbyAmf_UeContextRelCmd_WithNormalCause_T11) DrbRelbyAmf_UeContextRelCmd_WithNormalCause_T11,
max(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_T11) DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_T11,
max(DrbRelbyIntraRatRedirection_T11) DrbRelbyIntraRatRedirection_T11,
max(DrbRelbyInterRatRedirection_T11) DrbRelbyInterRatRedirection_T11,
max(DrbRelbyPreemption_T11) DrbRelbyPreemption_T11,
max(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8_T11) DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8_T11,
max(DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8_T11) DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8_T11,
max(DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8_T11) DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8_T11,
max(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8_T11) DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8_T11,
max(DrbRelbyIntraRatRedirection_5QI8_T11) DrbRelbyIntraRatRedirection_5QI8_T11,
max(DrbRelbyInterRatRedirection_5QI8_T11) DrbRelbyInterRatRedirection_5QI8_T11,
max(DrbRelbyPreemption_5QI8_T11) DrbRelbyPreemption_5QI8_T11,
max(DrbRelbyAmf_PduSessionModifyReq_T11) DrbRelbyAmf_PduSessionModifyReq_T11,
max(DrbRelbyAmf_PduSessionRelCmd_T11) DrbRelbyAmf_PduSessionRelCmd_T11,
max(DrbRelbyAmf_UeContextRelCmd_T11) DrbRelbyAmf_UeContextRelCmd_T11,
max(DrbRelbyAmf_PduSessionModifyReq_5QI8_T11) DrbRelbyAmf_PduSessionModifyReq_5QI8_T11,
max(DrbRelbyAmf_PduSessionRelCmd_5QI8_T11) DrbRelbyAmf_PduSessionRelCmd_5QI8_T11,
max(DrbRelbyAmf_UeContextRelCmd_5QI8_T11) DrbRelbyAmf_UeContextRelCmd_5QI8_T11,
max(DrbRelbyGnb_UeContextRelReq_WithNormalCause_5QI8) DrbRelbyGnb_UeContextRelReq_WithNormalCause_5QI8
from (
			select 
			COALESCE(M0.CalendarDate,T1.CalendarDate,T2.CalendarDate,T3.CalendarDate,T4.CalendarDate,T5.CalendarDate,T6.CalendarDate,T7.CalendarDate,T8.CalendarDate,T9.CalendarDate,T10.CalendarDate,T11.CalendarDate) CalendarDate,
			COALESCE(M0.Hour24,T1.Hour24,T2.Hour24,T3.Hour24,T3.Hour24,T4.Hour24,T5.Hour24,T6.Hour24,T7.Hour24,T8.Hour24,T9.Hour24,T10.Hour24,T11.Hour24) Hour24,
			COALESCE(M0.GNODEB_ID,T1.GNODEB_ID,T2.GNODEB_ID,T3.GNODEB_ID,T3.GNODEB_ID,T4.GNODEB_ID,T5.GNODEB_ID,T6.GNODEB_ID,T7.GNODEB_ID,T8.GNODEB_ID,T9.GNODEB_ID,T10.GNODEB_ID,T11.GNODEB_ID) GNODEB_ID,
			COALESCE(M0.du_id,T1.du_id,T2.du_id,T3.du_id,T3.du_id,T4.du_id,T5.du_id,T6.du_id,T7.du_id,T8.du_id,T9.du_id,T10.du_id,T11.du_id) du_id,
			COALESCE(M0.GCELL_ID,T1.GCELL_ID,T2.GCELL_ID,T3.GCELL_ID,T3.GCELL_ID,T4.GCELL_ID,T5.GCELL_ID,T6.GCELL_ID,T7.GCELL_ID,T8.GCELL_ID,T9.GCELL_ID,T10.GCELL_ID,T11.GCELL_ID) GCELL_ID,
			COALESCE(M0.MARKET_NAME,T1.MARKET_NAME,T2.MARKET_NAME,T3.MARKET_NAME,T3.MARKET_NAME,T4.MARKET_NAME,T5.MARKET_NAME,T6.MARKET_NAME,T7.MARKET_NAME,T8.MARKET_NAME,T9.MARKET_NAME,T10.MARKET_NAME,T11.MARKET_NAME) MARKET_NAME,						
			COALESCE(M0.SUB_MARKET_NAME,T1.SUB_MARKET_NAME,T2.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T4.SUB_MARKET_NAME,T5.SUB_MARKET_NAME,T6.SUB_MARKET_NAME,T7.SUB_MARKET_NAME,T8.SUB_MARKET_NAME,T9.SUB_MARKET_NAME,T10.SUB_MARKET_NAME,T11.SUB_MARKET_NAME) SUB_MARKET_NAME,
			PdcpSduVolumeDL_CELL_PLMN_QCI,
			PdcpSduVolumeUL_CELL_PLMN_QCI,
			PdcpSduVolumeSplitNrDL_CELL_PLMN_QCI,
			PdcpSduVolumeSplitNrUL_CELL_PLMN_QCI,
			PdcpSduVolumeSplitLteDL_CELL_PLMN_QCI,
			PdcpSduVolumeSplitLteUL_CELL_PLMN_QCI,
			PdcpSduByteDL_CELL_PLMN_QCI,
			PdcpSduByteUL_CELL_PLMN_QCI,
			PdcpSduLossCntDL_CELL_PLMN_QCI,
			PdcpSduLossCntUL_CELL_PLMN_QCI,
			PdcpSduLossCntSplitLteDL_CELL_PLMN_QCI,
			PdcpSduLossCntSplitNrDL_CELL_PLMN_QCI,
			PdcpSduDiscardCntDL_CELL_PLMN_QCI,
			PdcpSduDropCntDL_CELL_PLMN_QCI,
			PdcpSduRetxCntDL_CELL_PLMN_QCI,
			PdcpSduDelayDLTot_CELL_PLMN_QCI,
			PdcpSduDelayULTot_CELL_PLMN_QCI,
			PdcpSduDelaySplitLteDLTot_CELL_PLMN_QCI,
			PdcpSduDelaySplitLteULTot_CELL_PLMN_QCI,
			PdcpSduDelaySplitNrDLTot_CELL_PLMN_QCI,
			PdcpSduDelaySplitNrULTot_CELL_PLMN_QCI,
			PdcpSduByteDLCnt_CELL_PLMN_QCI,
			PdcpSduByteULCnt_CELL_PLMN_QCI,
			PdcpSduCntDL_CELL_PLMN_QCI,
			PdcpSduCntUL_CELL_PLMN_QCI,
			PdcpSduCntSplitLteDL_CELL_PLMN_QCI,
			PdcpSduCntSplitNrDL_CELL_PLMN_QCI,
			PdcpSduDelayDLCnt_CELL_PLMN_QCI,
			PdcpSduDelayULCnt_CELL_PLMN_QCI,
			PdcpSduDelaySplitLteDLCnt_CELL_PLMN_QCI,
			PdcpSduDelaySplitLteULCnt_CELL_PLMN_QCI,
			PdcpSduDelaySplitNrDLCnt_CELL_PLMN_QCI,
			PdcpSduDelaySplitNrULCnt_CELL_PLMN_QCI,
			EndcAddMnHoInterEnbAtt,
			EndcAddMnHoInterEnbHoSucc,
			EndcAddSgnbChgAtt,
			EndcAddSgnbChgSucc,
			AddProcTimeTot,
			AddProcTimeCnt,
			DrbNoTot,
			ConnEstabAtt,
			ConnEstabSucc,
			NgConnEstabAtt,
			NgConnEstabSucc,
			PduSetupPlmnSnssaiAtt,
			PduSetupPlmnSnssaiSucc,
			DrbSetupAtt,
			DrbSetupSucc,
			DrbSetupAtt_5QI8,
			DrbSetupSucc_5QI8,

			T10.DrbRelTotal,
			T10.DrbRelbyAmf_UeContextRelCmd_IntraNrHo,
			T10.DrbRelTotal_5QI8,
			T10.DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8,
			T10.DrbRelbyGnb_UeContextRelReq,
			T10.DrbRelbyGnb_UeContextRelReq_WithNormalCause,
			T10.DrbRelbyAmf_PduSessionRelCmd_WithNormalCause,
			T10.DrbRelbyAmf_PduSessionModifyReq_WithNormalCause,
			T10.DrbRelbyAmf_UeContextRelCmd_WithNormalCause,
			T10.DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause,
			T10.DrbRelbyIntraRatRedirection,
			T10.DrbRelbyInterRatRedirection,
			T10.DrbRelbyPreemption,
			T10.DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8,
			T10.DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8,
			T10.DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8,
			T10.DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8,
			T10.DrbRelbyIntraRatRedirection_5QI8,
			T10.DrbRelbyInterRatRedirection_5QI8,
			T10.DrbRelbyPreemption_5QI8,
				-- add
			T10.DrbRelbyAmf_PduSessionModifyReq,
			T10.DrbRelbyAmf_PduSessionRelCmd,
			T10.DrbRelbyAmf_UeContextRelCmd,
			T10.DrbRelbyAmf_PduSessionModifyReq_5QI8,
			T10.DrbRelbyAmf_PduSessionRelCmd_5QI8,
			T10.DrbRelbyAmf_UeContextRelCmd_5QI8,			

			T11.DrbRelTotal DrbRelTotal_T11,
			T11.DrbRelbyAmf_UeContextRelCmd_IntraNrHo DrbRelbyAmf_UeContextRelCmd_IntraNrHo_T11,
			T11.DrbRelTotal_5QI8 DrbRelTotal_5QI8_T11,
			T11.DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8 DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8_T11,
			T11.DrbRelbyGnb_UeContextRelReq DrbRelbyGnb_UeContextRelReq_T11,
			T11.DrbRelbyGnb_UeContextRelReq_WithNormalCause DrbRelbyGnb_UeContextRelReq_WithNormalCause_T11,
			T11.DrbRelbyAmf_PduSessionRelCmd_WithNormalCause DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_T11,
			T11.DrbRelbyAmf_PduSessionModifyReq_WithNormalCause DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_T11,
			T11.DrbRelbyAmf_UeContextRelCmd_WithNormalCause DrbRelbyAmf_UeContextRelCmd_WithNormalCause_T11,
			T11.DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_T11,
			T11.DrbRelbyIntraRatRedirection DrbRelbyIntraRatRedirection_T11,
			T11.DrbRelbyInterRatRedirection DrbRelbyInterRatRedirection_T11,
			T11.DrbRelbyPreemption DrbRelbyPreemption_T11,
			T11.DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8 DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8_T11,
			T11.DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8 DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8_T11,
			T11.DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8 DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8_T11,
			T11.DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8 DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8_T11,
			T11.DrbRelbyIntraRatRedirection_5QI8 DrbRelbyIntraRatRedirection_5QI8_T11,
			T11.DrbRelbyInterRatRedirection_5QI8 DrbRelbyInterRatRedirection_5QI8_T11,
			T11.DrbRelbyPreemption_5QI8 DrbRelbyPreemption_5QI8_T11,
			-- new counter
			T11.DrbRelbyAmf_PduSessionModifyReq DrbRelbyAmf_PduSessionModifyReq_T11,
			T11.DrbRelbyAmf_PduSessionRelCmd DrbRelbyAmf_PduSessionRelCmd_T11,
			T11.DrbRelbyAmf_UeContextRelCmd DrbRelbyAmf_UeContextRelCmd_T11,
			T11.DrbRelbyAmf_PduSessionModifyReq_5QI8 DrbRelbyAmf_PduSessionModifyReq_5QI8_T11,
			T11.DrbRelbyAmf_PduSessionRelCmd_5QI8 DrbRelbyAmf_PduSessionRelCmd_5QI8_T11,
			T11.DrbRelbyAmf_UeContextRelCmd_5QI8 DrbRelbyAmf_UeContextRelCmd_5QI8_T11,
			T10.DrbRelbyGnb_UeContextRelReq_WithNormalCause_5QI8
from (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(PdcpSduVolumeDL_CELL_PLMN_QCI) PdcpSduVolumeDL_CELL_PLMN_QCI,
                    sum(PdcpSduVolumeUL_CELL_PLMN_QCI) PdcpSduVolumeUL_CELL_PLMN_QCI,
                    sum(PdcpSduVolumeSplitNrDL_CELL_PLMN_QCI) PdcpSduVolumeSplitNrDL_CELL_PLMN_QCI,
                    sum(PdcpSduVolumeSplitNrUL_CELL_PLMN_QCI) PdcpSduVolumeSplitNrUL_CELL_PLMN_QCI,
                    sum(PdcpSduVolumeSplitLteDL_CELL_PLMN_QCI) PdcpSduVolumeSplitLteDL_CELL_PLMN_QCI,
                    sum(PdcpSduVolumeSplitLteUL_CELL_PLMN_QCI) PdcpSduVolumeSplitLteUL_CELL_PLMN_QCI
				from apachedataingestion.nr.pdcpvolumepercellidentityperplmnperqci_nr_hr_silver a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")    
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) M0 
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(PdcpSduByteDL_CELL_PLMN_QCI) PdcpSduByteDL_CELL_PLMN_QCI,
                    sum(PdcpSduByteUL_CELL_PLMN_QCI) PdcpSduByteUL_CELL_PLMN_QCI,
                    sum(PdcpSduLossCntDL_CELL_PLMN_QCI) PdcpSduLossCntDL_CELL_PLMN_QCI,
                    sum(PdcpSduLossCntUL_CELL_PLMN_QCI) PdcpSduLossCntUL_CELL_PLMN_QCI,
                    sum(PdcpSduLossCntSplitLteDL_CELL_PLMN_QCI) PdcpSduLossCntSplitLteDL_CELL_PLMN_QCI,
                    sum(PdcpSduLossCntSplitNrDL_CELL_PLMN_QCI) PdcpSduLossCntSplitNrDL_CELL_PLMN_QCI,
                    sum(PdcpSduDiscardCntDL_CELL_PLMN_QCI) PdcpSduDiscardCntDL_CELL_PLMN_QCI,
                    sum(PdcpSduDropCntDL_CELL_PLMN_QCI) PdcpSduDropCntDL_CELL_PLMN_QCI,
                    sum(PdcpSduRetxCntDL_CELL_PLMN_QCI) PdcpSduRetxCntDL_CELL_PLMN_QCI,
                    sum(PdcpSduDelayDLTot_CELL_PLMN_QCI) PdcpSduDelayDLTot_CELL_PLMN_QCI,
                    sum(PdcpSduDelayULTot_CELL_PLMN_QCI) PdcpSduDelayULTot_CELL_PLMN_QCI,
                    sum(PdcpSduDelaySplitLteDLTot_CELL_PLMN_QCI) PdcpSduDelaySplitLteDLTot_CELL_PLMN_QCI,
                    sum(PdcpSduDelaySplitLteULTot_CELL_PLMN_QCI) PdcpSduDelaySplitLteULTot_CELL_PLMN_QCI,
                    sum(PdcpSduDelaySplitNrDLTot_CELL_PLMN_QCI) PdcpSduDelaySplitNrDLTot_CELL_PLMN_QCI,
                    sum(PdcpSduDelaySplitNrULTot_CELL_PLMN_QCI) PdcpSduDelaySplitNrULTot_CELL_PLMN_QCI,
                    sum(PdcpSduByteDLCnt_CELL_PLMN_QCI) PdcpSduByteDLCnt_CELL_PLMN_QCI,
                    sum(PdcpSduByteULCnt_CELL_PLMN_QCI) PdcpSduByteULCnt_CELL_PLMN_QCI,
                    sum(PdcpSduCntDL_CELL_PLMN_QCI) PdcpSduCntDL_CELL_PLMN_QCI,
                    sum(PdcpSduCntUL_CELL_PLMN_QCI) PdcpSduCntUL_CELL_PLMN_QCI,
                    sum(PdcpSduCntSplitLteDL_CELL_PLMN_QCI) PdcpSduCntSplitLteDL_CELL_PLMN_QCI,
                    sum(PdcpSduCntSplitNrDL_CELL_PLMN_QCI) PdcpSduCntSplitNrDL_CELL_PLMN_QCI,
                    sum(PdcpSduDelayDLCnt_CELL_PLMN_QCI) PdcpSduDelayDLCnt_CELL_PLMN_QCI,
                    sum(PdcpSduDelayULCnt_CELL_PLMN_QCI) PdcpSduDelayULCnt_CELL_PLMN_QCI,
                    sum(PdcpSduDelaySplitLteDLCnt_CELL_PLMN_QCI) PdcpSduDelaySplitLteDLCnt_CELL_PLMN_QCI,
                    sum(PdcpSduDelaySplitLteULCnt_CELL_PLMN_QCI) PdcpSduDelaySplitLteULCnt_CELL_PLMN_QCI,
                    sum(PdcpSduDelaySplitNrDLCnt_CELL_PLMN_QCI) PdcpSduDelaySplitNrDLCnt_CELL_PLMN_QCI,
                    sum(PdcpSduDelaySplitNrULCnt_CELL_PLMN_QCI) PdcpSduDelaySplitNrULCnt_CELL_PLMN_QCI
				from apachedataingestion.nr.pdcppacketpercellidentityperplmnperqci_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME			
			) T1 on M0.CalendarDate=T1.CalendarDate and M0.Hour24=T1.Hour24 and M0.du_id=T1.du_id and M0.GCELL_ID=T1.GCELL_ID 
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(EndcAddMnHoInterEnbAtt) EndcAddMnHoInterEnbAtt,
					sum(EndcAddMnHoInterEnbHoSucc) EndcAddMnHoInterEnbHoSucc
				from apachedataingestion.nr.sgnbadditionbyinterenbhowithduidentifier_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T2 on M0.CalendarDate=T2.CalendarDate and M0.Hour24=T2.Hour24 and M0.du_id=T2.du_id and M0.GCELL_ID=T2.GCELL_ID 
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(EndcAddSgnbChgAtt) EndcAddSgnbChgAtt,					
					sum(EndcAddSgnbChgSucc) EndcAddSgnbChgSucc
                  from apachedataingestion.nr.sgnbadditionduetosgnbchangewithduidentifier_nr_hr_silver a
                  inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                  WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T3 on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME, 
                    sum(AddProcTimeTot) AddProcTimeTot,
					sum(AddProcTimeCnt) AddProcTimeCnt
                    --select *
                from apachedataingestion.nr.sgnbproceduretimepergnbwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id				
                    WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T4 on M0.CalendarDate=T4.CalendarDate and M0.Hour24=T4.Hour24 and M0.du_id=T4.du_id and M0.GCELL_ID=T4.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,   
                    sum(DrbNoTot) DrbNoTot
                from apachedataingestion.nr.drbconnectionnumberpergnbwithduidentifier_nr_hr_silver  a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id				
                    WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T5 on M0.CalendarDate=T5.CalendarDate and M0.Hour24=T5.Hour24 and M0.du_id=T5.du_id and M0.GCELL_ID=T5.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,   
                    sum(ConnEstabAtt) ConnEstabAtt,
					sum(ConnEstabSucc) ConnEstabSucc
                from apachedataingestion.nr.rrcconnectionestablishmentwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                    WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T6 on M0.CalendarDate=T6.CalendarDate and M0.Hour24=T6.Hour24 and M0.du_id=T6.du_id and M0.GCELL_ID=T6.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
                    sum(NgConnEstabAtt) NgConnEstabAtt,
                    sum(NgConnEstabSucc) NgConnEstabSucc
                    -- select *
                from apachedataingestion.nr.ueassociatedlogicalngconnectionestablishmentwithduidentifier_nr_hr_silver   a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T7 on M0.CalendarDate=T7.CalendarDate and M0.Hour24=T7.Hour24 and M0.du_id=T7.du_id and M0.GCELL_ID=T7.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
                    sum(PduSetupPlmnSnssaiAtt) PduSetupPlmnSnssaiAtt,					
					sum(PduSetupPlmnSnssaiSucc) PduSetupPlmnSnssaiSucc
                from apachedataingestion.nr.pdusessionresourcesetupwithduidentifierperplmnpersnssai_nr_hr_silver   a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                 WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")        
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME							
			) T8 on M0.CalendarDate=T8.CalendarDate and M0.Hour24=T8.Hour24 and M0.du_id=T8.du_id and M0.GCELL_ID=T8.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
					sum(DrbSetupAtt)  DrbSetupAtt,
					sum(DrbSetupSucc) DrbSetupSucc,
                    sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbSetupAtt end )  DrbSetupAtt_5QI8,
                    sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbSetupSucc end )  DrbSetupSucc_5QI8
                from apachedataingestion.nr.drbsetupwithduidentifier_nr_hr_silver    a                
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T9 on M0.CalendarDate=T9.CalendarDate and M0.Hour24=T9.Hour24 and M0.du_id=T9.du_id and M0.GCELL_ID=T9.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,  
					sum(DrbRelTotal) DrbRelTotal,
					sum(DrbRelbyAmf_UeContextRelCmd_IntraNrHo) DrbRelbyAmf_UeContextRelCmd_IntraNrHo,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelTotal end )  DrbRelTotal_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_UeContextRelCmd_IntraNrHo end )  DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8,
					sum(DrbRelbyGnb_UeContextRelReq) DrbRelbyGnb_UeContextRelReq,
					sum(DrbRelbyGnb_UeContextRelReq_WithNormalCause) DrbRelbyGnb_UeContextRelReq_WithNormalCause,
					sum(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause) DrbRelbyAmf_PduSessionRelCmd_WithNormalCause,
					sum(DrbRelbyAmf_PduSessionModifyReq_WithNormalCause) DrbRelbyAmf_PduSessionModifyReq_WithNormalCause,
					sum(DrbRelbyAmf_UeContextRelCmd_WithNormalCause) DrbRelbyAmf_UeContextRelCmd_WithNormalCause,
					sum(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause) DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause,
					sum(DrbRelbyIntraRatRedirection) DrbRelbyIntraRatRedirection,
					sum(DrbRelbyInterRatRedirection) DrbRelbyInterRatRedirection,
					sum(DrbRelbyPreemption) DrbRelbyPreemption,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_PduSessionRelCmd_WithNormalCause end )  DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_PduSessionModifyReq_WithNormalCause end )  DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_UeContextRelCmd_WithNormalCause end )  DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause end )  DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyIntraRatRedirection end )  DrbRelbyIntraRatRedirection_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyInterRatRedirection end )  DrbRelbyInterRatRedirection_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyPreemption end )  DrbRelbyPreemption_5QI8,
					--add
					sum(DrbRelbyAmf_PduSessionModifyReq) DrbRelbyAmf_PduSessionModifyReq,
					sum(DrbRelbyAmf_PduSessionRelCmd) DrbRelbyAmf_PduSessionRelCmd,
					sum(DrbRelbyAmf_UeContextRelCmd) DrbRelbyAmf_UeContextRelCmd,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_PduSessionModifyReq end )  DrbRelbyAmf_PduSessionModifyReq_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_PduSessionRelCmd end )  DrbRelbyAmf_PduSessionRelCmd_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_UeContextRelCmd end )  DrbRelbyAmf_UeContextRelCmd_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyGnb_UeContextRelReq_WithNormalCause end )  DrbRelbyGnb_UeContextRelReq_WithNormalCause_5QI8
				-- select *
                from apachedataingestion.nr.releaseofsetupdrbwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                 WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T10 on M0.CalendarDate=T10.CalendarDate and M0.Hour24=T10.Hour24 and M0.du_id=T10.du_id and M0.GCELL_ID=T10.GCELL_ID
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,  
					sum(DrbRelTotal) DrbRelTotal,
					sum(DrbRelbyAmf_UeContextRelCmd_IntraNrHo) DrbRelbyAmf_UeContextRelCmd_IntraNrHo,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelTotal end )  DrbRelTotal_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_UeContextRelCmd_IntraNrHo end )  DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8,
					sum(DrbRelbyGnb_UeContextRelReq) DrbRelbyGnb_UeContextRelReq,
					sum(DrbRelbyGnb_UeContextRelReq_WithNormalCause) DrbRelbyGnb_UeContextRelReq_WithNormalCause,
					sum(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause) DrbRelbyAmf_PduSessionRelCmd_WithNormalCause,
					sum(DrbRelbyAmf_PduSessionModifyReq_WithNormalCause) DrbRelbyAmf_PduSessionModifyReq_WithNormalCause,
					sum(DrbRelbyAmf_UeContextRelCmd_WithNormalCause) DrbRelbyAmf_UeContextRelCmd_WithNormalCause,
					sum(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause) DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause,
					sum(DrbRelbyIntraRatRedirection) DrbRelbyIntraRatRedirection,
					sum(DrbRelbyInterRatRedirection) DrbRelbyInterRatRedirection,
					sum(DrbRelbyPreemption) DrbRelbyPreemption,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_PduSessionRelCmd_WithNormalCause end )  DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_PduSessionModifyReq_WithNormalCause end )  DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_UeContextRelCmd_WithNormalCause end )  DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause end )  DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyIntraRatRedirection end )  DrbRelbyIntraRatRedirection_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyInterRatRedirection end )  DrbRelbyInterRatRedirection_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyPreemption end )  DrbRelbyPreemption_5QI8,
					--add  
					sum(DrbRelbyAmf_PduSessionModifyReq) DrbRelbyAmf_PduSessionModifyReq,
					sum(DrbRelbyAmf_PduSessionRelCmd) DrbRelbyAmf_PduSessionRelCmd,
					sum(DrbRelbyAmf_UeContextRelCmd) DrbRelbyAmf_UeContextRelCmd,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_PduSessionModifyReq end )  DrbRelbyAmf_PduSessionModifyReq_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_PduSessionRelCmd end )  DrbRelbyAmf_PduSessionRelCmd_5QI8,
					sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbRelbyAmf_UeContextRelCmd end )  DrbRelbyAmf_UeContextRelCmd_5QI8
				-- select *
                from apachedataingestion.nr.releaseofsetupactivedrbwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                 WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T11 on M0.CalendarDate=T11.CalendarDate and M0.Hour24=T11.Hour24 and M0.du_id=T11.du_id and M0.GCELL_ID=T11.GCELL_ID
) X
GROUP BY CalendarDate,Hour24,GNODEB_ID,du_id,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME;


--select *  from apachedataingestion.nr.ReleaseofSetupActiveDRBwithDUIdentifier_nr_hr_silver

/*
Add new columns to tmp4 table DENG-2505
alter table hive_metastore.default.widetable_5g_cell_hr_tmp4 add column InterSysLTE_Out_PrepSucc DOUBLE; 
alter table hive_metastore.default.widetable_5g_cell_hr_tmp4 add column InterSysLTE_Out_VoNR_PrepSucc DOUBLE;  
alter table hive_metastore.default.widetable_5g_cell_hr_tmp4 add column NrdcAddMn_Att DOUBLE;
alter table hive_metastore.default.widetable_5g_cell_hr_tmp4 add column NrdcAddSn_Att DOUBLE;
*/


delete from hive_metastore.default.widetable_5g_cell_hr_tmp4; 

insert into hive_metastore.default.widetable_5g_cell_hr_tmp4
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	-- select count(distinct concat(GNODEB_ID,'_',DU_ID,'_',GCELL_ID)) --514527
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							-- select count(*)
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
)
select 
CalendarDate ,
Hour24 ,
GNODEB_ID,
du_id ,
GCELL_ID ,
MARKET_NAME ,
case when length(du_id)=14 then 
	case when substring(du_id, 7, 1)=0 then 'FR2' 	 when substring(du_id, 7, 1)=9 then 
				case when substring(du_id, 11, 1)=2 then 'FR1/LS3' when substring(du_id, 11, 1)=3 then 'FR1/LS6' 
				end
	end
else '' end NR_TYPE,
substring(du_id,4,3) SUB_MARKET_ID,
SUB_MARKET_NAME ,
max(DLUeThruVol_SA) DLUeThruVol_SA,
max(DLUeThruTime_SA) DLUeThruTime_SA,
max(UeContextRelTotal) UeContextRelTotal,
max(UeRelbyAmf_UeContextRelCmd_IntraNrHo) UeRelbyAmf_UeContextRelCmd_IntraNrHo,
max(UeRelbyAmf_UeContextRelCmd_WithNormalCause) UeRelbyAmf_UeContextRelCmd_WithNormalCause,
max(UeRelbyGnb_UeContextRelReq_WithNormalCause) UeRelbyGnb_UeContextRelReq_WithNormalCause,
max(UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause) UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause,
max(UeRelbyIntraRatRedirection) UeRelbyIntraRatRedirection,
max(UeRelbyInterRatRedirection) UeRelbyInterRatRedirection,
max(UeRelbyPreemption) UeRelbyPreemption,
max(UeRelbyGnb_UeContextRelReq) UeRelbyGnb_UeContextRelReq,
max(IntraGnbReEstabAtt) IntraGnbReEstabAtt,
max(InterGnbReEstabAtt) InterGnbReEstabAtt,
max(InterGnbReEstabRreSucc) InterGnbReEstabRreSucc,
max(InterGnbReEstabRrcSetupSucc) InterGnbReEstabRrcSetupSucc,
max(IntraGnbReEstabRreSucc) IntraGnbReEstabRreSucc,
max(IntraGnbReEstabRrcSetupSucc) IntraGnbReEstabRrcSetupSucc,
max(InterXn_HoTimeTot) InterXn_HoTimeTot,
max(InterXn_HoTimeCnt) InterXn_HoTimeCnt,
max(InterNg_HoTimeTot) InterNg_HoTimeTot,
max(InterNg_HoTimeCnt) InterNg_HoTimeCnt,
max(IntragNB_HoTimeTot) IntragNB_HoTimeTot,
max(IntragNB_HoTimeCnt) IntragNB_HoTimeCnt,
max(InterNgOut_Att) InterNgOut_Att,
max(InterNgOut_HandoverCancel) InterNgOut_HandoverCancel,
max(InterNgOut_RRE) InterNgOut_RRE,
max(InterNgOut_Succ) InterNgOut_Succ,
max(InterXnOut_Att) InterXnOut_Att,
max(InterXnOut_HandoverCancel) InterXnOut_HandoverCancel,
max(InterXnOut_RRE) InterXnOut_RRE,
max(InterXnOut_Succ) InterXnOut_Succ,
max(IntraGnbOut_Att) IntraGnbOut_Att,
max(IntraGnbOut_HandoverCancel) IntraGnbOut_HandoverCancel,
max(IntraGnbOut_RRE) IntraGnbOut_RRE,
max(IntraGnbOut_Succ) IntraGnbOut_Succ,
max(IntraFreqOut_Succ) IntraFreqOut_Succ,
max(IntraFreqOut_RRE) IntraFreqOut_RRE,
max(IntraFreqOut_HandoverCancel) IntraFreqOut_HandoverCancel,
max(IntraFreqOut_Att) IntraFreqOut_Att,
max(InterFreqOutWithGap_RRE) InterFreqOutWithGap_RRE,
max(InterFreqOutWithGap_Succ) InterFreqOutWithGap_Succ,
max(InterFreqOutWithGap_HandoverCancel) InterFreqOutWithGap_HandoverCancel,
max(InterFreqOutWithGap_Att) InterFreqOutWithGap_Att,
max(InterSysLTE_Out_RRE) InterSysLTE_Out_RRE,
max(InterSysLTE_Out_Succ) InterSysLTE_Out_Succ,
max(InterSysLTE_Out_HandoverCancel) InterSysLTE_Out_HandoverCancel,
max(InterSysLTE_Out_Att) InterSysLTE_Out_Att,
max(ConnNoTot) ConnNoTot,
max(ConnNoCnt) ConnNoCnt,
max(ConnNoMax) ConnNoMax,
max(CallHoldingTimeTot) CallHoldingTimeTot,
max(CallHoldingTimeCnt) CallHoldingTimeCnt,
max(InactCallHoldingTimeTot) InactCallHoldingTimeTot,
max(InactCallHoldingTimeCnt) InactCallHoldingTimeCnt,
max(ConnInactCallHoldingTimeTot) ConnInactCallHoldingTimeTot,
max(ConnInactCallHoldingTimeCnt) ConnInactCallHoldingTimeCnt,
max(NrdcAddMn_Succ) NrdcAddMn_Succ,
max(NrdcAddMn_Total) NrdcAddMn_Total,
max(NrdcAddSn_Succ) NrdcAddSn_Succ,
max(NrdcAddSn_Total) NrdcAddSn_Total,
max(InterSysLTE_Out_VoNR_Succ) InterSysLTE_Out_VoNR_Succ,
-- add
max(UeRelbyAmf_UeContextRelCmd) UeRelbyAmf_UeContextRelCmd,
max(UeRelbyAmf_UeContextRelCmd_T11) UeRelbyAmf_UeContextRelCmd_T11,
max(UeRelbyAmf_UeContextRelCmd_WithNormalCause_T11) UeRelbyAmf_UeContextRelCmd_WithNormalCause_T11,
max(UeRelbyAmf_UeContextRelCmd_IntraNrHo_T11) UeRelbyAmf_UeContextRelCmd_IntraNrHo_T11,
max(UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_T11) UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_T11,
--Added new columns DENG-2505
max(InterSysLTE_Out_PrepSucc)InterSysLTE_Out_PrepSucc,
max(InterSysLTE_Out_VoNR_PrepSucc) InterSysLTE_Out_VoNR_PrepSucc,
max(NrdcAddMn_Att) NrdcAddMn_Att,
max(NrdcAddSn_Att) NrdcAddSn_Att
from (
			select 
			COALESCE(M0.CalendarDate,T1.CalendarDate,T2.CalendarDate,T3.CalendarDate,T4.CalendarDate,T5.CalendarDate,T6.CalendarDate,T7.CalendarDate,T8.CalendarDate,T9.CalendarDate,T10.CalendarDate,T11.CalendarDate) CalendarDate,
			COALESCE(M0.Hour24,T1.Hour24,T2.Hour24,T3.Hour24,T3.Hour24,T4.Hour24,T5.Hour24,T6.Hour24,T7.Hour24,T8.Hour24,T9.Hour24,T10.Hour24,T11.Hour24) Hour24,
			COALESCE(M0.GNODEB_ID,T1.GNODEB_ID,T2.GNODEB_ID,T3.GNODEB_ID,T3.GNODEB_ID,T4.GNODEB_ID,T5.GNODEB_ID,T6.GNODEB_ID,T7.GNODEB_ID,T8.GNODEB_ID,T9.GNODEB_ID,T10.GNODEB_ID,T11.GNODEB_ID) GNODEB_ID,
			COALESCE(M0.du_id,T1.du_id,T2.du_id,T3.du_id,T3.du_id,T4.du_id,T5.du_id,T6.du_id,T7.du_id,T8.du_id,T9.du_id,T10.du_id,T11.du_id) du_id,
			COALESCE(M0.GCELL_ID,T1.GCELL_ID,T2.GCELL_ID,T3.GCELL_ID,T3.GCELL_ID,T4.GCELL_ID,T5.GCELL_ID,T6.GCELL_ID,T7.GCELL_ID,T8.GCELL_ID,T9.GCELL_ID,T10.GCELL_ID,T11.GCELL_ID) GCELL_ID,
			COALESCE(M0.MARKET_NAME,T1.MARKET_NAME,T2.MARKET_NAME,T3.MARKET_NAME,T3.MARKET_NAME,T4.MARKET_NAME,T5.MARKET_NAME,T6.MARKET_NAME,T7.MARKET_NAME,T8.MARKET_NAME,T9.MARKET_NAME,T10.MARKET_NAME,T11.MARKET_NAME) MARKET_NAME,						
			COALESCE(M0.SUB_MARKET_NAME,T1.SUB_MARKET_NAME,T2.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T4.SUB_MARKET_NAME,T5.SUB_MARKET_NAME,T6.SUB_MARKET_NAME,T7.SUB_MARKET_NAME,T8.SUB_MARKET_NAME,T9.SUB_MARKET_NAME,T10.SUB_MARKET_NAME,T11.SUB_MARKET_NAME) SUB_MARKET_NAME,
			DLUeThruVol_SA,
			DLUeThruTime_SA,
			
			T1.UeContextRelTotal,
			T1.UeRelbyAmf_UeContextRelCmd_IntraNrHo,
			T1.UeRelbyAmf_UeContextRelCmd_WithNormalCause,
			T1.UeRelbyGnb_UeContextRelReq_WithNormalCause,
			T1.UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause,
			T1.UeRelbyIntraRatRedirection,
			T1.UeRelbyInterRatRedirection,
			T1.UeRelbyPreemption,
			T1.UeRelbyGnb_UeContextRelReq, -- add

			IntraGnbReEstabAtt,
			InterGnbReEstabAtt,
			InterGnbReEstabRreSucc,
			InterGnbReEstabRrcSetupSucc,
			IntraGnbReEstabRreSucc,
			IntraGnbReEstabRrcSetupSucc,
			InterXn_HoTimeTot,
			InterXn_HoTimeCnt,
			InterNg_HoTimeTot,
			InterNg_HoTimeCnt,
			IntragNB_HoTimeTot,
			IntragNB_HoTimeCnt,
			InterNgOut_Att,
			InterNgOut_HandoverCancel,
			InterNgOut_RRE,
			InterNgOut_Succ,
			InterXnOut_Att,
			InterXnOut_HandoverCancel,
			InterXnOut_RRE,
			InterXnOut_Succ,
			IntraGnbOut_Att,
			IntraGnbOut_HandoverCancel,
			IntraGnbOut_RRE,
			IntraGnbOut_Succ,
			IntraFreqOut_Succ,
			IntraFreqOut_RRE,
			IntraFreqOut_HandoverCancel,
			IntraFreqOut_Att,
			InterFreqOutWithGap_RRE,
			InterFreqOutWithGap_Succ,
			InterFreqOutWithGap_HandoverCancel,
			InterFreqOutWithGap_Att,
			InterSysLTE_Out_RRE,
			InterSysLTE_Out_Succ,
			InterSysLTE_Out_HandoverCancel,
			InterSysLTE_Out_Att,
			ConnNoTot,
			ConnNoCnt,
			ConnNoMax,
			CallHoldingTimeTot,
			CallHoldingTimeCnt,
			InactCallHoldingTimeTot,
			InactCallHoldingTimeCnt,
			ConnInactCallHoldingTimeTot,
			ConnInactCallHoldingTimeCnt,
			NrdcAddMn_Succ,
			NrdcAddMn_Total,
			NrdcAddSn_Succ,
			NrdcAddSn_Total,
			InterSysLTE_Out_VoNR_Succ,
			-- add
			T1.UeRelbyAmf_UeContextRelCmd,			
			T11.UeRelbyAmf_UeContextRelCmd UeRelbyAmf_UeContextRelCmd_T11,
			T11.UeRelbyAmf_UeContextRelCmd_WithNormalCause UeRelbyAmf_UeContextRelCmd_WithNormalCause_T11,
			T11.UeRelbyAmf_UeContextRelCmd_IntraNrHo UeRelbyAmf_UeContextRelCmd_IntraNrHo_T11,
			T11.UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_T11,
			--added new columns DENG-2505
			InterSysLTE_Out_PrepSucc,
			InterSysLTE_Out_VoNR_PrepSucc,
			NrdcAddMn_Att,
			NrdcAddSn_Att
from (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,     
                      sum(DLUeThruVol_SA) DLUeThruVol_SA,
                      sum(DLUeThruTime_SA) DLUeThruTime_SA
                from apachedataingestion.nr.uethroughput_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) M0
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,  
                    sum(UeContextRelTotal) UeContextRelTotal,
                    sum(UeRelbyAmf_UeContextRelCmd_IntraNrHo) UeRelbyAmf_UeContextRelCmd_IntraNrHo,
                    sum(UeRelbyAmf_UeContextRelCmd_WithNormalCause) UeRelbyAmf_UeContextRelCmd_WithNormalCause,
                    sum(UeRelbyGnb_UeContextRelReq_WithNormalCause) UeRelbyGnb_UeContextRelReq_WithNormalCause,
                    sum(UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause) UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause,
                    sum(UeRelbyIntraRatRedirection) UeRelbyIntraRatRedirection,
                    sum(UeRelbyInterRatRedirection) UeRelbyInterRatRedirection,
                    sum(UeRelbyPreemption) UeRelbyPreemption,
					sum(UeRelbyGnb_UeContextRelReq) UeRelbyGnb_UeContextRelReq,  -- add
					sum(UeRelbyAmf_UeContextRelCmd) UeRelbyAmf_UeContextRelCmd  -- add
                from apachedataingestion.nr.releaseofsetupuecontextwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                   WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T1 on M0.CalendarDate=T1.CalendarDate and M0.Hour24=T1.Hour24 and M0.du_id=T1.du_id and M0.GCELL_ID=T1.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,   
                    sum(IntraGnbReEstabAtt) IntraGnbReEstabAtt,
                    sum(InterGnbReEstabAtt) InterGnbReEstabAtt,
                    sum(InterGnbReEstabRreSucc) InterGnbReEstabRreSucc,
                    sum(InterGnbReEstabRrcSetupSucc) InterGnbReEstabRrcSetupSucc,
                    sum(IntraGnbReEstabRreSucc) IntraGnbReEstabRreSucc,
                    sum(IntraGnbReEstabRrcSetupSucc) IntraGnbReEstabRrcSetupSucc
                    -- select *
                from apachedataingestion.nr.rrcreestablishmentwithduidentifier_nr_hr_silver   a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                   WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T2 on M0.CalendarDate=T2.CalendarDate and M0.Hour24=T2.Hour24 and M0.du_id=T2.du_id and M0.GCELL_ID=T2.GCELL_ID 
      full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,      
                      sum(InterXn_HoTimeTot) InterXn_HoTimeTot,
                      sum(InterXn_HoTimeCnt) InterXn_HoTimeCnt,
                      sum(InterNg_HoTimeTot) InterNg_HoTimeTot,
                      sum(InterNg_HoTimeCnt) InterNg_HoTimeCnt,
                      sum(IntragNB_HoTimeTot) IntragNB_HoTimeTot,
                      sum(IntragNB_HoTimeCnt) IntragNB_HoTimeCnt
                from apachedataingestion.nr.handovertimewithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id				
                 WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME				
			) T3 on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME, 
                    sum(InterNgOut_Att) InterNgOut_Att,
                    sum(InterNgOut_HandoverCancel) InterNgOut_HandoverCancel,
                    sum(InterNgOut_RRE) InterNgOut_RRE,
                    sum(InterNgOut_Succ) InterNgOut_Succ,
                    sum(InterXnOut_Att) InterXnOut_Att,
                    sum(InterXnOut_HandoverCancel) InterXnOut_HandoverCancel,
                    sum(InterXnOut_RRE) InterXnOut_RRE,
                    sum(InterXnOut_Succ) InterXnOut_Succ,
                    sum(IntraGnbOut_Att) IntraGnbOut_Att,
                    sum(IntraGnbOut_HandoverCancel) IntraGnbOut_HandoverCancel,
                    sum(IntraGnbOut_RRE) IntraGnbOut_RRE,
                    sum(IntraGnbOut_Succ) IntraGnbOut_Succ
                from apachedataingestion.nr.nrhandoveroutgoingwithduidentifier_nr_hr_silver   a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T4 on M0.CalendarDate=T4.CalendarDate and M0.Hour24=T4.Hour24 and M0.du_id=T4.du_id and M0.GCELL_ID=T4.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,  
                    sum(IntraFreqOut_Succ) IntraFreqOut_Succ,
										sum(IntraFreqOut_RRE) IntraFreqOut_RRE,
										sum(IntraFreqOut_HandoverCancel) IntraFreqOut_HandoverCancel,
										sum(IntraFreqOut_Att) IntraFreqOut_Att
					-- select *
                from apachedataingestion.nr.intranrintrafrequencyoutgoinghandoverwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                  WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T5 on M0.CalendarDate=T5.CalendarDate and M0.Hour24=T5.Hour24 and M0.du_id=T5.du_id and M0.GCELL_ID=T5.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME, 
               	sum(InterFreqOutWithGap_RRE) InterFreqOutWithGap_RRE,
								sum(InterFreqOutWithGap_Succ) InterFreqOutWithGap_Succ,
								sum(InterFreqOutWithGap_HandoverCancel) InterFreqOutWithGap_HandoverCancel,
								sum(InterFreqOutWithGap_Att) InterFreqOutWithGap_Att
                from apachedataingestion.nr.intranrinterfrequencyoutgoinghandoverwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                 WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				 GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T6 on M0.CalendarDate=T6.CalendarDate and M0.Hour24=T6.Hour24 and M0.du_id=T6.du_id and M0.GCELL_ID=T6.GCELL_ID 
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
						sum(InterSysLTE_Out_RRE) InterSysLTE_Out_RRE,
						sum(InterSysLTE_Out_Succ) InterSysLTE_Out_Succ,
						sum(InterSysLTE_Out_HandoverCancel) InterSysLTE_Out_HandoverCancel,
						sum(InterSysLTE_Out_Att) InterSysLTE_Out_Att,
						sum(InterSysLTE_Out_VoNR_Succ)  InterSysLTE_Out_VoNR_Succ,
						--Bringing more columns DENG-2505
						sum(InterSysLTE_Out_PrepSucc) InterSysLTE_Out_PrepSucc,
						sum(InterSysLTE_Out_VoNR_PrepSucc) InterSysLTE_Out_VoNR_PrepSucc
                from apachedataingestion.nr.nrhandoveroutgoingtoeutranwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T7 on M0.CalendarDate=T7.CalendarDate and M0.Hour24=T7.Hour24 and M0.du_id=T7.du_id and M0.GCELL_ID=T7.GCELL_ID 
			full join  (		
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
                    sum(ConnNoTot) ConnNoTot,
					sum(ConnNoCnt) ConnNoCnt,
					max(ConnNoMax) ConnNoMax,
					sum(CallHoldingTimeTot) CallHoldingTimeTot,
					sum(CallHoldingTimeCnt) CallHoldingTimeCnt,
					sum(InactCallHoldingTimeTot) InactCallHoldingTimeTot,
					sum(InactCallHoldingTimeCnt) InactCallHoldingTimeCnt,
					sum(ConnInactCallHoldingTimeTot) ConnInactCallHoldingTimeTot,
					sum(ConnInactCallHoldingTimeCnt) ConnInactCallHoldingTimeCnt
					-- select *
                from apachedataingestion.nr.rrcconnectioninformationwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id				
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T8 on M0.CalendarDate=T8.CalendarDate and M0.Hour24=T8.Hour24 and M0.du_id=T8.du_id and M0.GCELL_ID=T8.GCELL_ID 
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
      				sum(NrdcAddMn_Succ) NrdcAddMn_Succ,
					sum(NrdcAddMn_Total) NrdcAddMn_Total,
					--Getting another column on 12/20/2024 DENG-2505
					sum(NrdcAddMn_Att) NrdcAddMn_Att
					-- select *
				from apachedataingestion.nr.nrdcsnodeadditionofmnwithduidentifier_nr_hr_silver    a
               inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T9 on M0.CalendarDate=T9.CalendarDate and M0.Hour24=T9.Hour24 and M0.du_id=T9.du_id and M0.GCELL_ID=T9.GCELL_ID 
			full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
      				sum(NrdcAddSn_Succ) NrdcAddSn_Succ,
      				sum(NrdcAddSn_Total) NrdcAddSn_Total,
					--Getting new column on 12/20/2024 DENG-2505
					sum(NrdcAddSn_Att) NrdcAddSn_Att
					-- select *
				from apachedataingestion.nr.nrdcsnodeadditonofsnwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentityWithInvalid','')=b.gcell_id				
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")      
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T10 on M0.CalendarDate=T10.CalendarDate and M0.Hour24=T10.Hour24 and M0.du_id=T10.du_id and M0.GCELL_ID=T10.GCELL_ID
			full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,  
                    sum(UeRelbyAmf_UeContextRelCmd) UeRelbyAmf_UeContextRelCmd,
					sum(UeRelbyAmf_UeContextRelCmd_WithNormalCause) UeRelbyAmf_UeContextRelCmd_WithNormalCause,
					sum(UeRelbyAmf_UeContextRelCmd_IntraNrHo) UeRelbyAmf_UeContextRelCmd_IntraNrHo,
					sum(UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause) UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause
					-- select *
                from apachedataingestion.nr.releaseofsetupactiveuecontextwithduidentifier_nr_hr_silver    a
                inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id				
                   WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME	
			) T11 on M0.CalendarDate=T11.CalendarDate and M0.Hour24=T11.Hour24 and M0.du_id=T11.du_id and M0.GCELL_ID=T11.GCELL_ID 
			
) X
GROUP BY CalendarDate,Hour24,GNODEB_ID,du_id,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME;			
			
		
			


delete from hive_metastore.default.widetable_5g_cell_hr_tmp5;

insert into hive_metastore.default.widetable_5g_cell_hr_tmp5
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	-- select count(distinct concat(GNODEB_ID,'_',DU_ID,'_',GCELL_ID)) --514527
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							-- select count(*)
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
)
select 
CalendarDate ,
Hour24 ,
GNODEB_ID,
du_id ,
GCELL_ID ,
MARKET_NAME ,
case when length(du_id)=14 then 
	case when substring(du_id, 7, 1)=0 then 'FR2' 	 when substring(du_id, 7, 1)=9 then 
				case when substring(du_id, 11, 1)=2 then 'FR1/LS3' when substring(du_id, 11, 1)=3 then 'FR1/LS6' 
				end
	end
else '' end NR_TYPE,
substring(du_id,4,3) SUB_MARKET_ID,
SUB_MARKET_NAME ,
max(NrdcRelSn_MnInit_RadioConnectionWithUeLost) NrdcRelSn_MnInit_RadioConnectionWithUeLost,
max(NrdcRelSn_SnInit_RLFailureRLC) NrdcRelSn_SnInit_RLFailureRLC,
max(NrdcRelSn_SnInit_RLFailureOthers) NrdcRelSn_SnInit_RLFailureOthers,
max(NrdcRelSn_Total) NrdcRelSn_Total,
max(NrdcRelMn_SnInit_RadioConnectionWithUeLost) NrdcRelMn_SnInit_RadioConnectionWithUeLost,
max(NrdcRelMn_MnInit_t310Expiry) NrdcRelMn_MnInit_t310Expiry,
max(NrdcRelMn_MnInit_randomAccessProblem) NrdcRelMn_MnInit_randomAccessProblem,
max(NrdcRelMn_MnInit_rlcMaxNumRetx) NrdcRelMn_MnInit_rlcMaxNumRetx,
max(NrdcRelMn_MnInit_synchReconfigFailureSCG) NrdcRelMn_MnInit_synchReconfigFailureSCG,
max(NrdcRelMn_MnInit_scgReconfigFailure) NrdcRelMn_MnInit_scgReconfigFailure,
max(NrdcRelMn_MnInit_t312Expiry) NrdcRelMn_MnInit_t312Expiry,
max(NrdcRelMn_MnInit_srb3IntegrityFailure) NrdcRelMn_MnInit_srb3IntegrityFailure,
max(NrdcRelMn_MnInit_beamFailureRecoveryFailure) NrdcRelMn_MnInit_beamFailureRecoveryFailure,
max(NrdcRelMn_MnInit_others) NrdcRelMn_MnInit_others,
max(NrdcRelMn_Total) NrdcRelMn_Total,
max(InterSysLTE_Out_EPSFallback_Succ) InterSysLTE_Out_EPSFallback_Succ,
max(InterSysLTE_Out_EPSFallback_HandoverCancel) InterSysLTE_Out_EPSFallback_HandoverCancel,
max(InterSysLTE_Out_EPSFallback_RRE) InterSysLTE_Out_EPSFallback_RRE,
max(InterSysLTE_Out_EPSFallback_Att) InterSysLTE_Out_EPSFallback_Att,
max(InterSysLTE_Out_EmergencyFallback_Succ) InterSysLTE_Out_EmergencyFallback_Succ,
max(InterSysLTE_Out_EmergencyFallback_HandoverCancel) InterSysLTE_Out_EmergencyFallback_HandoverCancel,
max(InterSysLTE_Out_EmergencyFallback_RRE) InterSysLTE_Out_EmergencyFallback_RRE,
max(InterSysLTE_Out_EmergencyFallback_Att) InterSysLTE_Out_EmergencyFallback_Att,
max(ConnEstabTimeTot) ConnEstabTimeTot,
max(ConnEstabTimeCnt) ConnEstabTimeCnt,
max(NgConnEstabTimeTot) NgConnEstabTimeTot,
max(NgConnEstabTimeCnt) NgConnEstabTimeCnt,
max(DrbHoldingTimeTot) DrbHoldingTimeTot,
max(DrbHoldingTimeCnt) DrbHoldingTimeCnt,
max(InactDrbHoldingTimeTot) InactDrbHoldingTimeTot,
max(InactDrbHoldingTimeCnt) InactDrbHoldingTimeCnt,
max(ConnInactDrbHoldingTimeTot) ConnInactDrbHoldingTimeTot,
max(ConnInactDrbHoldingTimeCnt) ConnInactDrbHoldingTimeCnt,
max(IntraSn_HoTimeTot) IntraSn_HoTimeTot,
max(IntraSn_HoTimeCnt) IntraSn_HoTimeCnt,
max(IntraSnViaSrb3_HoTimeTot) IntraSnViaSrb3_HoTimeTot,
max(IntraSnViaSrb3_HoTimeCnt) IntraSnViaSrb3_HoTimeCnt,
max(InterSn_HoTimeTot) InterSn_HoTimeTot,
max(InterSn_HoTimeCnt) InterSn_HoTimeCnt,
max(ErabSpecInfo_HoldingTimeTot) ErabSpecInfo_HoldingTimeTot,
max(ErabSpecInfo_HoldingTimeCnt) ErabSpecInfo_HoldingTimeCnt,
max(IntraSNSPcellChgMCGSRBTot) IntraSNSPcellChgMCGSRBTot,
max(IntraSNSPcellChgMCGSRBCnt) IntraSNSPcellChgMCGSRBCnt,
max(InterSNSPcellChgTot) InterSNSPcellChgTot,
max(InterSNSPcellChgCnt) InterSNSPcellChgCnt,
max(InterSysLTE_Out_EPSFallback_PrepSucc) InterSysLTE_Out_EPSFallback_PrepSucc,
max(InterSysLTE_Out_EmergencyFallback_PrepSuc) InterSysLTE_Out_EmergencyFallback_PrepSuc
from (
			select 
			COALESCE(M0.CalendarDate,T3.CalendarDate,T4.CalendarDate,T5.CalendarDate,T6.CalendarDate,T7.CalendarDate,T8.CalendarDate,T9.CalendarDate,T10.CalendarDate) CalendarDate,
			COALESCE(M0.Hour24,T3.Hour24,T3.Hour24,T4.Hour24,T5.Hour24,T6.Hour24,T7.Hour24,T8.Hour24,T9.Hour24,T10.Hour24) Hour24,
			COALESCE(M0.GNODEB_ID,T3.GNODEB_ID,T3.GNODEB_ID,T4.GNODEB_ID,T5.GNODEB_ID,T6.GNODEB_ID,T7.GNODEB_ID,T8.GNODEB_ID,T9.GNODEB_ID,T10.GNODEB_ID) GNODEB_ID,
			COALESCE(M0.du_id,T3.du_id,T3.du_id,T4.du_id,T5.du_id,T6.du_id,T7.du_id,T8.du_id,T9.du_id,T10.du_id) du_id,
			COALESCE(M0.GCELL_ID,T3.GCELL_ID,T3.GCELL_ID,T4.GCELL_ID,T5.GCELL_ID,T6.GCELL_ID,T7.GCELL_ID,T8.GCELL_ID,T9.GCELL_ID,T10.GCELL_ID) GCELL_ID,
			COALESCE(M0.MARKET_NAME,T3.MARKET_NAME,T3.MARKET_NAME,T4.MARKET_NAME,T5.MARKET_NAME,T6.MARKET_NAME,T7.MARKET_NAME,T8.MARKET_NAME,T9.MARKET_NAME,T10.MARKET_NAME) MARKET_NAME,						
			COALESCE(M0.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T4.SUB_MARKET_NAME,T5.SUB_MARKET_NAME,T6.SUB_MARKET_NAME,T7.SUB_MARKET_NAME,T8.SUB_MARKET_NAME,T9.SUB_MARKET_NAME,T10.SUB_MARKET_NAME) SUB_MARKET_NAME,
			NrdcRelSn_MnInit_RadioConnectionWithUeLost,
			NrdcRelSn_SnInit_RLFailureRLC,
			NrdcRelSn_SnInit_RLFailureOthers,
			NrdcRelSn_Total,
			NrdcRelMn_SnInit_RadioConnectionWithUeLost,
			NrdcRelMn_MnInit_t310Expiry,
			NrdcRelMn_MnInit_randomAccessProblem,
			NrdcRelMn_MnInit_rlcMaxNumRetx,
			NrdcRelMn_MnInit_synchReconfigFailureSCG,
			NrdcRelMn_MnInit_scgReconfigFailure,
			NrdcRelMn_MnInit_t312Expiry,
			NrdcRelMn_MnInit_srb3IntegrityFailure,
			NrdcRelMn_MnInit_beamFailureRecoveryFailure,
			NrdcRelMn_MnInit_others,
			NrdcRelMn_Total,
			InterSysLTE_Out_EPSFallback_Succ,
			InterSysLTE_Out_EPSFallback_HandoverCancel,
			InterSysLTE_Out_EPSFallback_RRE,
			InterSysLTE_Out_EPSFallback_Att,
			InterSysLTE_Out_EmergencyFallback_Succ,
			InterSysLTE_Out_EmergencyFallback_HandoverCancel,
			InterSysLTE_Out_EmergencyFallback_RRE,
			InterSysLTE_Out_EmergencyFallback_Att,
			ConnEstabTimeTot,
			ConnEstabTimeCnt,
			NgConnEstabTimeTot,
			NgConnEstabTimeCnt,
			DrbHoldingTimeTot,
			DrbHoldingTimeCnt,
			InactDrbHoldingTimeTot,
			InactDrbHoldingTimeCnt,
			ConnInactDrbHoldingTimeTot,
			ConnInactDrbHoldingTimeCnt,
			IntraSn_HoTimeTot,
			IntraSn_HoTimeCnt,
			IntraSnViaSrb3_HoTimeTot,
			IntraSnViaSrb3_HoTimeCnt,
			InterSn_HoTimeTot,
			InterSn_HoTimeCnt,
			ErabSpecInfo_HoldingTimeTot,
			ErabSpecInfo_HoldingTimeCnt,
			IntraSNSPcellChgMCGSRBTot,
			IntraSNSPcellChgMCGSRBCnt,
			InterSNSPcellChgTot,
			InterSNSPcellChgCnt,
			InterSysLTE_Out_EPSFallback_PrepSucc,
			InterSysLTE_Out_EmergencyFallback_PrepSuc
from (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(NrdcRelSn_MnInit_RadioConnectionWithUeLost) NrdcRelSn_MnInit_RadioConnectionWithUeLost,
						sum(NrdcRelSn_SnInit_RLFailureRLC) NrdcRelSn_SnInit_RLFailureRLC, 
						sum(NrdcRelSn_SnInit_RLFailureOthers) NrdcRelSn_SnInit_RLFailureOthers,
						sum(NrdcRelSn_Total) NrdcRelSn_Total				
						-- select *
				from apachedataingestion.nr.nrdcsnodereleaseofsnwithduidentifier_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) M0	
			full join  (
					SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,  
						sum(NrdcRelMn_SnInit_RadioConnectionWithUeLost) NrdcRelMn_SnInit_RadioConnectionWithUeLost,
						sum(NrdcRelMn_MnInit_t310Expiry) NrdcRelMn_MnInit_t310Expiry,
						sum(NrdcRelMn_MnInit_randomAccessProblem) NrdcRelMn_MnInit_randomAccessProblem,
						sum(NrdcRelMn_MnInit_rlcMaxNumRetx) NrdcRelMn_MnInit_rlcMaxNumRetx,
						sum(NrdcRelMn_MnInit_synchReconfigFailureSCG) NrdcRelMn_MnInit_synchReconfigFailureSCG,
						sum(NrdcRelMn_MnInit_scgReconfigFailure) NrdcRelMn_MnInit_scgReconfigFailure,
						sum(NrdcRelMn_MnInit_t312Expiry) NrdcRelMn_MnInit_t312Expiry,
						sum(NrdcRelMn_MnInit_srb3IntegrityFailure) NrdcRelMn_MnInit_srb3IntegrityFailure,
						sum(NrdcRelMn_MnInit_beamFailureRecoveryFailure) NrdcRelMn_MnInit_beamFailureRecoveryFailure,
						sum(NrdcRelMn_MnInit_others) NrdcRelMn_MnInit_others,
						sum(NrdcRelMn_Total) NrdcRelMn_Total
						-- select *
					from apachedataingestion.nr.nrdcsnodereleaseofmnwithduidentifier_nr_hr_silver  a
					inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
					WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
					GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T3 on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID 
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(InterSysLTE_Out_EPSFallback_Succ) InterSysLTE_Out_EPSFallback_Succ,
						sum(InterSysLTE_Out_EPSFallback_HandoverCancel) InterSysLTE_Out_EPSFallback_HandoverCancel,
						sum(InterSysLTE_Out_EPSFallback_RRE) InterSysLTE_Out_EPSFallback_RRE,
						sum(InterSysLTE_Out_EPSFallback_Att) InterSysLTE_Out_EPSFallback_Att,
						sum(InterSysLTE_Out_EmergencyFallback_Succ) InterSysLTE_Out_EmergencyFallback_Succ,
						sum(InterSysLTE_Out_EmergencyFallback_HandoverCancel) InterSysLTE_Out_EmergencyFallback_HandoverCancel,
						sum(InterSysLTE_Out_EmergencyFallback_RRE) InterSysLTE_Out_EmergencyFallback_RRE,
						sum(InterSysLTE_Out_EmergencyFallback_Att) InterSysLTE_Out_EmergencyFallback_Att,
						sum(InterSysLTE_Out_EPSFallback_PrepSucc) InterSysLTE_Out_EPSFallback_PrepSucc,
						sum(InterSysLTE_Out_EmergencyFallback_PrepSucc) InterSysLTE_Out_EmergencyFallback_PrepSuc
						-- select *
				from apachedataingestion.nr.nrhandoveroutgoingtoeutranforfallbackwithduidentifier_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T4 on M0.CalendarDate=T4.CalendarDate and M0.Hour24=T4.Hour24 and M0.du_id=T4.du_id and M0.GCELL_ID=T4.GCELL_ID 
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(ConnEstabTimeTot) ConnEstabTimeTot,
						sum(ConnEstabTimeCnt) ConnEstabTimeCnt				
						-- select *
				from apachedataingestion.nr.rrcconnectionsetuptimewithduidentifier_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T5 on M0.CalendarDate=T5.CalendarDate and M0.Hour24=T5.Hour24 and M0.du_id=T5.du_id and M0.GCELL_ID=T5.GCELL_ID 
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(NgConnEstabTimeTot) NgConnEstabTimeTot,
						sum(NgConnEstabTimeCnt) NgConnEstabTimeCnt				
						-- select *
				from apachedataingestion.nr.ngconnectionsetuptimewithduidentifier_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T6 on M0.CalendarDate=T6.CalendarDate and M0.Hour24=T6.Hour24 and M0.du_id=T6.du_id and M0.GCELL_ID=T6.GCELL_ID 
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(DrbHoldingTimeTot) DrbHoldingTimeTot,
						sum(DrbHoldingTimeCnt) DrbHoldingTimeCnt,
						sum(InactDrbHoldingTimeTot) InactDrbHoldingTimeTot,
						sum(InactDrbHoldingTimeCnt) InactDrbHoldingTimeCnt,
						sum(ConnInactDrbHoldingTimeTot) ConnInactDrbHoldingTimeTot,
						sum(ConnInactDrbHoldingTimeCnt) ConnInactDrbHoldingTimeCnt			
						-- select *
				from apachedataingestion.nr.drbconnectioninformationwithduidentifier_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T7 on M0.CalendarDate=T7.CalendarDate and M0.Hour24=T7.Hour24 and M0.du_id=T7.du_id and M0.GCELL_ID=T7.GCELL_ID 
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(IntraSn_HoTimeTot) IntraSn_HoTimeTot,
						sum(IntraSn_HoTimeCnt) IntraSn_HoTimeCnt,
						sum(IntraSnViaSrb3_HoTimeTot) IntraSnViaSrb3_HoTimeTot,
						sum(IntraSnViaSrb3_HoTimeCnt) IntraSnViaSrb3_HoTimeCnt,
						sum(InterSn_HoTimeTot) InterSn_HoTimeTot,
						sum(InterSn_HoTimeCnt) InterSn_HoTimeCnt			
						-- select *
				from apachedataingestion.nr.pscellchangetimewithduidentifier_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T8 on M0.CalendarDate=T8.CalendarDate and M0.Hour24=T8.Hour24 and M0.du_id=T8.du_id and M0.GCELL_ID=T8.GCELL_ID 
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(ErabSpecInfo_HoldingTimeTot) ErabSpecInfo_HoldingTimeTot,
						sum(ErabSpecInfo_HoldingTimeCnt) ErabSpecInfo_HoldingTimeCnt
						-- select *
				from apachedataingestion.nr.erabspecificinformationpergnbwithduidentifierpercell_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[1],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[3],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T9 on M0.CalendarDate=T9.CalendarDate and M0.Hour24=T9.Hour24 and M0.du_id=T9.du_id and M0.GCELL_ID=T9.GCELL_ID  
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(IntraSNSPcellChgMCGSRBTot) IntraSNSPcellChgMCGSRBTot,
						sum(IntraSNSPcellChgMCGSRBCnt) IntraSNSPcellChgMCGSRBCnt,
						sum(InterSNSPcellChgTot) InterSNSPcellChgTot,
						sum(InterSNSPcellChgCnt) InterSNSPcellChgCnt
						-- select *
				from apachedataingestion.nr.spcellchangetimewithduidentifier_nr_hr_silver a
				inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T10 on M0.CalendarDate=T10.CalendarDate and M0.Hour24=T10.Hour24 and M0.du_id=T10.du_id and M0.GCELL_ID=T10.GCELL_ID			
) X
GROUP BY CalendarDate,Hour24,GNODEB_ID,du_id,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME;			
			

/*
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_BeamChangeSuccRate_PCT_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_BeamChangeSuccRate_PCT_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_UEPwrHeadroom_dB_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_UEPwrHeadroom_dB_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_AverageBRSRP_dBm_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_AverageBRSRP_dBm_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NC_InitDRBSetupFail_PCT_SA_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NC_InitDRBSetupFail_PCT_SA_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_ULUserPerceivedTput_NSA_Mbps_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_ULUserPerceivedTput_NSA_Mbps_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_ULUserPerceivedTput_SA_Mbps_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5NR_ULUserPerceivedTput_SA_Mbps_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5ND_AvgRRCUsers_SANSA_perCell_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5ND_AvgRRCUsers_SANSA_perCell_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5ND_MaxRRCUsers_SANSA_perCell	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5ND_RLC_UL_Delay_ms_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5ND_RLC_UL_Delay_ms_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5ND_AvgRLCDelay_UL_SA_us_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	S5ND_AvgRLCDelay_UL_SA_us_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	InterSysLTE_Out_Succ	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	RedirectionToLTE_CoverageOut	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	Average_TA_C_Band_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	Average_TA_C_Band_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	Average_TA_LS3_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	Average_TA_LS3_Denom	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	Average_TA_mmWave_Num	 DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp6 ADD COLUMN 	Average_TA_mmWave_Denom	 DOUBLE;


*/




/*

ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp8 ADD COLUMN 	  S5NC_InitDRBSetupFail_5QI8_PCT_Num  DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp8 ADD COLUMN 	  S5NC_InitDRBSetupFail_5QI8_PCT_Denom  DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp8 ADD COLUMN 	  REDIRECTIONTOLTE_BLINDA2  DOUBLE;

select * from hive_metastore.default.widetable_5g_cell_hr_tmp8;

ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp8 ADD COLUMN 	  RedirectionToLTE_EPSFallback  DOUBLE; 

*/




delete from hive_metastore.default.widetable_5g_cell_hr_tmp6;


insert into hive_metastore.default.widetable_5g_cell_hr_tmp6
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
)
select 
CalendarDate ,
Hour24 ,
GNODEB_ID,
du_id ,
GCELL_ID ,
MARKET_NAME ,
case when length(du_id)=14 then 
	case when substring(du_id, 7, 1)=0 then 'FR2' 	 when substring(du_id, 7, 1)=9 then 
				case when substring(du_id, 11, 1)=2 then 'FR1/LS3' when substring(du_id, 11, 1)=3 then 'FR1/LS6' 
				end
	end
else '' end NR_TYPE,
substring(du_id,4,3) SUB_MARKET_ID,
SUB_MARKET_NAME ,
max(IpLatTot) IpLatTot,
max(IpLatSampleCnt) IpLatSampleCnt,
max(RlcSduDelayTot_SA) RlcSduDelayTot_SA,
max(RlcSduDelayCnt_SA) RlcSduDelayCnt_SA,
max(AirIfDelayTot_SA) AirIfDelayTot_SA,
max(AirIfDelayCnt_SA) AirIfDelayCnt_SA,
max(DLReceivedRi1) DLReceivedRi1,
max(DLReceivedRi2) DLReceivedRi2,
max(DLReceivedRi3) DLReceivedRi3,
max(DLReceivedRi4) DLReceivedRi4,
max(DLNumPdschAvailableSlots) DLNumPdschAvailableSlots,
max(DLNumScheduledSlots) DLNumScheduledSlots,
max(DLNumMuMimoUEs_A6) DLNumMuMimoUEs_A6,
max(DLMuMimoLayers_A6) DLMuMimoLayers_A6,
max(DLNumScheduledUEs) DLNumScheduledUEs,
max(PucchErrorCount) PucchErrorCount,
max(NumOfTotPUCCH) NumOfTotPUCCH,
max(TotULPrb) TotULPrb,
max(RlcDLByte) RlcDLByte,
max(RlcULByte) RlcULByte,
max(RlcDLRePktCnt) RlcDLRePktCnt,
max(RlcDLPktCnt) RlcDLPktCnt,
max(UsedAgg1) UsedAgg1,
max(UsedAgg2) UsedAgg2,
max(UsedAgg4) UsedAgg4,
max(UsedAgg8) UsedAgg8,
max(UsedAgg16) UsedAgg16,
max(UsedAggUL1) UsedAggUL1,
max(UsedAggUL2) UsedAggUL2,
max(UsedAggUL4) UsedAggUL4,
max(UsedAggUL8) UsedAggUL8,
max(UsedAggUL16) UsedAggUL16,
max(UsedAggTot1) UsedAggTot1,
max(UsedAggTot2) UsedAggTot2,
max(UsedAggTot4) UsedAggTot4,
max(UsedAggTot8) UsedAggTot8,
max(UsedAggTot16) UsedAggTot16,
max(NumBlockedPDCCHDL) NumBlockedPDCCHDL,
max(NumAttemptPDCCHDL) NumAttemptPDCCHDL,
max(NumBlockedPDCCHUL) NumBlockedPDCCHUL,
max(NumAttemptPDCCHUL) NumAttemptPDCCHUL,
max(NumBlockedPDCCHTot) NumBlockedPDCCHTot,
max(NumSlotwBlockDL) NumSlotwBlockDL,
max(NumSlotwDLAttempt) NumSlotwDLAttempt,
max(NumSlotwBlockUL) NumSlotwBlockUL,
max(NumSlotwULAttempt) NumSlotwULAttempt,
max(NumSlotwBlockTot) NumSlotwBlockTot,
max(NumSlotwTotAttempt) NumSlotwTotAttempt,
max(AttemptAggDL1) AttemptAggDL1,
max(AttemptAggDL2) AttemptAggDL2,
max(AttemptAggDL4) AttemptAggDL4,
max(AttemptAggDL8) AttemptAggDL8,
max(AttemptAggDL16) AttemptAggDL16,
max(AttemptAggUL1) AttemptAggUL1,
max(AttemptAggUL2) AttemptAggUL2,
max(AttemptAggUL4) AttemptAggUL4,
max(AttemptAggUL8) AttemptAggUL8,
max(AttemptAggUL16) AttemptAggUL16,
max(EndcAddAtt) EndcAddAtt,
max(EndcAddSucc) EndcAddSucc,
max(EndcAddPrepFail_CpFail) EndcAddPrepFail_CpFail,
max(EndcAddPrepFail_UpFail) EndcAddPrepFail_UpFail,
max(EndcAddPrepFail_DuFail) EndcAddPrepFail_DuFail,
max(NrdcPsCellChange_Out_SnInit_IntraSn_Att) NrdcPsCellChange_Out_SnInit_IntraSn_Att,
max(NrdcPsCellChange_Out_SnInit_IntraSn_Succ) NrdcPsCellChange_Out_SnInit_IntraSn_Succ
from (
			select 
			COALESCE(M0.CalendarDate,T1.CalendarDate,T2.CalendarDate,T3.CalendarDate,T4.CalendarDate,T5.CalendarDate,T6.CalendarDate,T7.CalendarDate,T8.CalendarDate,T9.CalendarDate) CalendarDate,
			COALESCE(M0.Hour24,T1.Hour24,T2.Hour24,T3.Hour24,T3.Hour24,T4.Hour24,T5.Hour24,T6.Hour24,T7.Hour24,T8.Hour24,T9.Hour24) Hour24,
			COALESCE(M0.GNODEB_ID,T1.GNODEB_ID,T2.GNODEB_ID,T3.GNODEB_ID,T3.GNODEB_ID,T4.GNODEB_ID,T5.GNODEB_ID,T6.GNODEB_ID,T7.GNODEB_ID,T8.GNODEB_ID,T9.GNODEB_ID) GNODEB_ID,
			COALESCE(M0.du_id,T1.du_id,T2.du_id,T3.du_id,T3.du_id,T4.du_id,T5.du_id,T6.du_id,T7.du_id,T8.du_id,T9.du_id) du_id,
			COALESCE(M0.GCELL_ID,T1.GCELL_ID,T2.GCELL_ID,T3.GCELL_ID,T3.GCELL_ID,T4.GCELL_ID,T5.GCELL_ID,T6.GCELL_ID,T7.GCELL_ID,T8.GCELL_ID,T9.GCELL_ID) GCELL_ID,
			COALESCE(M0.MARKET_NAME,T1.MARKET_NAME,T2.MARKET_NAME,T3.MARKET_NAME,T3.MARKET_NAME,T4.MARKET_NAME,T5.MARKET_NAME,T6.MARKET_NAME,T7.MARKET_NAME,T8.MARKET_NAME,T9.MARKET_NAME) MARKET_NAME,						
			COALESCE(M0.SUB_MARKET_NAME,T1.SUB_MARKET_NAME,T2.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T3.SUB_MARKET_NAME,T4.SUB_MARKET_NAME,T5.SUB_MARKET_NAME,T6.SUB_MARKET_NAME,T7.SUB_MARKET_NAME,T8.SUB_MARKET_NAME,T9.SUB_MARKET_NAME) SUB_MARKET_NAME,
			IpLatTot,
			IpLatSampleCnt,
			RlcSduDelayTot_SA,
			RlcSduDelayCnt_SA,
			AirIfDelayTot_SA,
			AirIfDelayCnt_SA,
			DLReceivedRi1,
			DLReceivedRi2,
			DLReceivedRi3,
			DLReceivedRi4,
			DLNumPdschAvailableSlots,
			DLNumScheduledSlots,
			DLNumMuMimoUEs_A6,
			DLMuMimoLayers_A6,
			DLNumScheduledUEs,
			PucchErrorCount,
			NumOfTotPUCCH,
			TotULPrb,
			RlcDLByte,
			RlcULByte,
			RlcDLRePktCnt,
			RlcDLPktCnt,
			UsedAgg1,
			UsedAgg2,
			UsedAgg4,
			UsedAgg8,
			UsedAgg16,
			UsedAggUL1,
			UsedAggUL2,
			UsedAggUL4,
			UsedAggUL8,
			UsedAggUL16,			
			UsedAggTot1,
			UsedAggTot2,
			UsedAggTot4,
			UsedAggTot8,
			UsedAggTot16,
			NumBlockedPDCCHDL,
			NumAttemptPDCCHDL,
			NumBlockedPDCCHUL,
			NumAttemptPDCCHUL,
			NumBlockedPDCCHTot,
			NumSlotwBlockDL,
			NumSlotwDLAttempt,
			NumSlotwBlockUL,
			NumSlotwULAttempt,
			NumSlotwBlockTot,
			NumSlotwTotAttempt,
			AttemptAggDL1,
			AttemptAggDL2,
			AttemptAggDL4,
			AttemptAggDL8,
			AttemptAggDL16,
			AttemptAggUL1,
			AttemptAggUL2,
			AttemptAggUL4,
			AttemptAggUL8,
			AttemptAggUL16,
			EndcAddAtt,
			EndcAddSucc,
			EndcAddPrepFail_CpFail,
			EndcAddPrepFail_UpFail,
			EndcAddPrepFail_DuFail,
			NrdcPsCellChange_Out_SnInit_IntraSn_Att,
			NrdcPsCellChange_Out_SnInit_IntraSn_Succ
from (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(IpLatTot) IpLatTot,
						sum(IpLatSampleCnt) IpLatSampleCnt			
						
				from apachedataingestion.nr.rlcintegrityper5qi_nr_hr_silver a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) M0 
			full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						sum(RlcSduDelayTot_SA) RlcSduDelayTot_SA,
						sum(RlcSduDelayCnt_SA) RlcSduDelayCnt_SA,
						sum(AirIfDelayTot_SA) AirIfDelayTot_SA,
						sum(AirIfDelayCnt_SA) AirIfDelayCnt_SA			
						
				from apachedataingestion.nr.airinterfacedelayforsa_nr_hr_silver a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T1 on M0.CalendarDate=T1.CalendarDate and M0.Hour24=T1.Hour24 and M0.du_id=T1.du_id and M0.GCELL_ID=T1.GCELL_ID 		
		full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,						
						sum(DLReceivedRi1_count_SUM) DLReceivedRi1,
						sum(DLReceivedRi2_count_SUM) DLReceivedRi2,
						sum(DLReceivedRi3_count_SUM) DLReceivedRi3,
						sum(DLReceivedRi4_count_SUM) DLReceivedRi4
						
				from apachedataingestion.nr.downlinkri_nr_hr_silver a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")       
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
			) T2 on M0.CalendarDate=T2.CalendarDate and M0.Hour24=T2.Hour24 and M0.du_id=T2.du_id and M0.GCELL_ID=T2.GCELL_ID 
full join  (	
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
					sum(DLNumPdschAvailableSlots_count_SUM) DLNumPdschAvailableSlots,
					SUM(DLNumScheduledSlots_count_SUM) DLNumScheduledSlots,
					sum(DLNumMuMimoUEs_A6_count_SUM) DLNumMuMimoUEs_A6,
					Sum(DLMuMimoLayers_A6_count_SUM) DLMuMimoLayers_A6,
					Sum(DLNumScheduledUEs_count_SUM) DLNumScheduledUEs  

					from apachedataingestion.nr.downlinkmimo_nr_hr_silver a 
					inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(a.LOCATION,'CellIdentity','')=b.gcell_id
					WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")     
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME		
) T3 on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID 
full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
      				sum(PucchErrorCount) PucchErrorCount,
      				sum(NumOfTotPUCCH) NumOfTotPUCCH,
							sum(TotULPrb) TotULPrb
					
				from apachedataingestion.nr.pucch_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")     
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T4 on M0.CalendarDate=T4.CalendarDate and M0.Hour24=T4.Hour24 and M0.du_id=T4.du_id and M0.GCELL_ID=T4.GCELL_ID 
full join  (
				SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
						SUM(RlcDLByte) RlcDLByte,
						SUM(RlcULByte) RlcULByte,				
						sum(RlcDLRePktCnt)	 RlcDLRePktCnt,
						sum(RlcDLPktCnt) RlcDLPktCnt
						
				from apachedataingestion.nr.rlcpacketper5qi_hr_silver a
				inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
				WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")     
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T5 on M0.CalendarDate=T5.CalendarDate and M0.Hour24=T5.Hour24 and M0.du_id=T5.du_id and M0.GCELL_ID=T5.GCELL_ID 	
full join  (	
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
							sum(UsedAgg1) UsedAgg1,
							sum(UsedAgg2) UsedAgg2,
							sum(UsedAgg4) UsedAgg4,
							sum(UsedAgg8) UsedAgg8,
							sum(UsedAgg16) UsedAgg16,
							sum(UsedAggUL1) UsedAggUL1,
							sum(UsedAggUL2) UsedAggUL2,
							sum(UsedAggUL4) UsedAggUL4,
							sum(UsedAggUL8) UsedAggUL8,
							sum(UsedAggUL16) UsedAggUL16,
							sum(UsedAggTot1) UsedAggTot1,
							sum(UsedAggTot2) UsedAggTot2,
							sum(UsedAggTot4) UsedAggTot4,
							sum(UsedAggTot8) UsedAggTot8,
							sum(UsedAggTot16) UsedAggTot16
					
				from apachedataingestion.nr.usageinformationonaggregationlevelforpdcch_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")     
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T6 on M0.CalendarDate=T6.CalendarDate and M0.Hour24=T6.Hour24 and M0.du_id=T6.du_id and M0.GCELL_ID=T6.GCELL_ID 
full join  (
				SELECT  Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME, SUB_MARKET_NAME,
						sum(NumBlockedPDCCHDL_count_SUM) NumBlockedPDCCHDL,
						sum(NumAttemptPDCCHDL_count_SUM) NumAttemptPDCCHDL,
						sum(NumBlockedPDCCHUL_count_SUM) NumBlockedPDCCHUL,
						sum(NumAttemptPDCCHUL_count_SUM) NumAttemptPDCCHUL,
						sum(NumBlockedPDCCHTot_count_SUM) NumBlockedPDCCHTot,
						
						sum(NumSlotwBlockDL_count_SUM) 		NumSlotwBlockDL,
						sum(NumSlotwDLAttempt_count_SUM) 	NumSlotwDLAttempt,
						sum(NumSlotwBlockUL_count_SUM) 		NumSlotwBlockUL,
						sum(NumSlotwULAttempt_count_SUM) 	NumSlotwULAttempt,
						sum(NumSlotwBlockTot_count_SUM) 	NumSlotwBlockTot,
						sum(NumSlotwTotAttempt_count_SUM) NumSlotwTotAttempt,
						sum(AttemptAggDL1_count_SUM) AttemptAggDL1,
						sum(AttemptAggDL2_count_SUM) AttemptAggDL2,
						sum(AttemptAggDL4_count_SUM) AttemptAggDL4,
						sum(AttemptAggDL8_count_SUM) AttemptAggDL8,
						sum(AttemptAggDL16_count_SUM) AttemptAggDL16,
						sum(AttemptAggUL1_count_SUM) AttemptAggUL1,
						sum(AttemptAggUL2_count_SUM) AttemptAggUL2,
						sum(AttemptAggUL4_count_SUM) AttemptAggUL4,
						sum(AttemptAggUL8_count_SUM) AttemptAggUL8,
						sum(AttemptAggUL16_count_SUM) AttemptAggUL16
						
        from apachedataingestion.nr.blockedpdcchinformationdluldlandul_nr_hr_silver    a
                inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id
                WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")     
				GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T7 on M0.CalendarDate=T7.CalendarDate and M0.Hour24=T7.Hour24 and M0.du_id=T7.du_id and M0.GCELL_ID=T7.GCELL_ID 
full join  (
			SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
				SUM(EndcAddAtt_count_SUM) EndcAddAtt,
				SUM(EndcAddSucc_count_SUM) EndcAddSucc,
				SUM(EndcAddPrepFail_CpFail_count_SUM) EndcAddPrepFail_CpFail,
				SUM(EndcAddPrepFail_UpFail_count_SUM) EndcAddPrepFail_UpFail,
				SUM(EndcAddPrepFail_DuFail_count_SUM) EndcAddPrepFail_DuFail
				
			from apachedataingestion.nr.sgnbadditionpergnbwithduidentifier_hr_silver a
			inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentityWithInvalid','')=b.gcell_id		
			WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")     
			GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T8 on M0.CalendarDate=T8.CalendarDate and M0.Hour24=T8.Hour24 and M0.du_id=T8.du_id and M0.GCELL_ID=T8.GCELL_ID 
full join  (
			SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
			SUM(NrdcPsCellChange_Out_SnInit_IntraSn_Att) NrdcPsCellChange_Out_SnInit_IntraSn_Att,
			SUM(NrdcPsCellChange_Out_SnInit_IntraSn_Succ) NrdcPsCellChange_Out_SnInit_IntraSn_Succ
			-- select *
			from apachedataingestion.nr.nrdcpscellchangeoutgoingwithduidentifier_nr_hr_silver a
			inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id		
			WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")     
			GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T9 on M0.CalendarDate=T9.CalendarDate and M0.Hour24=T9.Hour24 and M0.du_id=T9.du_id and M0.GCELL_ID=T9.GCELL_ID 

) X
GROUP BY CalendarDate,Hour24,GNODEB_ID,du_id,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME;		



delete from hive_metastore.default.widetable_5g_cell_hr_tmp8;


insert into hive_metastore.default.widetable_5g_cell_hr_tmp8
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID
			          	-- select count(distinct concat(GNODEB_ID,'_',DU_ID,'_',GCELL_ID)) --514527
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID
							-- select count(*)
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
)
select 
CalendarDate ,
Hour24 ,
GNODEB_ID,
du_id ,
GCELL_ID ,
MARKET_NAME ,
case when length(du_id)=14 then 
	case when substring(du_id, 7, 1)=0 then 'FR2' 	 when substring(du_id, 7, 1)=9 then 
				case when substring(du_id, 11, 1)=2 then 'FR1/LS3' when substring(du_id, 11, 1)=3 then 'FR1/LS6' 
				end
	end
else '' end NR_TYPE,
substring(du_id,4,3) SUB_MARKET_ID,
SUB_MARKET_NAME ,
max(S5NR_BeamChangeSuccRate_PCT_Num) S5NR_BeamChangeSuccRate_PCT_Num ,
max(S5NR_BeamChangeSuccRate_PCT_Denom) S5NR_BeamChangeSuccRate_PCT_Denom ,
max(S5NR_UEPwrHeadroom_dB_Num) S5NR_UEPwrHeadroom_dB_Num ,
max(S5NR_UEPwrHeadroom_dB_Denom) S5NR_UEPwrHeadroom_dB_Denom ,
max(S5NR_AverageBRSRP_dBm_Num) S5NR_AverageBRSRP_dBm_Num ,
max(S5NR_AverageBRSRP_dBm_Denom) S5NR_AverageBRSRP_dBm_Denom ,
max(S5NC_InitDRBSetupFail_PCT_SA_Num) S5NC_InitDRBSetupFail_PCT_SA_Num ,
max(S5NC_InitDRBSetupFail_PCT_SA_Denom) S5NC_InitDRBSetupFail_PCT_SA_Denom ,
max(S5NR_ULUserPerceivedTput_NSA_Mbps_Num) S5NR_ULUserPerceivedTput_NSA_Mbps_Num ,
max(S5NR_ULUserPerceivedTput_NSA_Mbps_Denom) S5NR_ULUserPerceivedTput_NSA_Mbps_Denom ,
max(S5NR_ULUserPerceivedTput_SA_Mbps_Num) S5NR_ULUserPerceivedTput_SA_Mbps_Num ,
max(S5NR_ULUserPerceivedTput_SA_Mbps_Denom) S5NR_ULUserPerceivedTput_SA_Mbps_Denom ,
max(S5ND_AvgRRCUsers_SANSA_perCell_Num) S5ND_AvgRRCUsers_SANSA_perCell_Num ,
max(S5ND_AvgRRCUsers_SANSA_perCell_Denom) S5ND_AvgRRCUsers_SANSA_perCell_Denom ,
max(S5ND_MaxRRCUsers_SANSA_perCell) S5ND_MaxRRCUsers_SANSA_perCell ,
max(S5ND_RLC_UL_Delay_ms_Num) S5ND_RLC_UL_Delay_ms_Num ,
max(S5ND_RLC_UL_Delay_ms_Denom) S5ND_RLC_UL_Delay_ms_Denom ,
max(S5ND_AvgRLCDelay_UL_SA_us_Num) S5ND_AvgRLCDelay_UL_SA_us_Num ,
max(S5ND_AvgRLCDelay_UL_SA_us_Denom) S5ND_AvgRLCDelay_UL_SA_us_Denom ,
max(InterSysLTE_Out_Succ) InterSysLTE_Out_Succ ,
max(RedirectionToLTE_CoverageOut) RedirectionToLTE_CoverageOut ,
max(Average_TA_C_Band_Num) Average_TA_C_Band_Num ,
max(Average_TA_C_Band_Denom) Average_TA_C_Band_Denom ,
max(Average_TA_LS3_Num) Average_TA_LS3_Num ,
max(Average_TA_LS3_Denom) Average_TA_LS3_Denom ,
max(Average_TA_mmWave_Num) Average_TA_mmWave_Num ,
max(Average_TA_mmWave_Denom) Average_TA_mmWave_Denom,
max(S5NC_InitDRBSetupFail_5QI8_PCT_Num) S5NC_InitDRBSetupFail_5QI8_PCT_Num,
max(S5NC_InitDRBSetupFail_5QI8_PCT_Denom) S5NC_InitDRBSetupFail_5QI8_PCT_Denom,
max(REDIRECTIONTOLTE_BLINDA2) REDIRECTIONTOLTE_BLINDA2,
max(RedirectionToLTE_EPSFallback) RedirectionToLTE_EPSFallback,
max(RedirectionToLTE_EmergencyFallback)  RedirectionToLTE_EmergencyFallback
from (
			select 
			COALESCE(M0.CalendarDate,T10.CalendarDate,T11.CalendarDate,T12.CalendarDate,T13.CalendarDate,T14.CalendarDate,T15.CalendarDate,T16.CalendarDate,T17.CalendarDate,T18.CalendarDate,T19.CalendarDate,T20.CalendarDate) CalendarDate,
COALESCE(M0.Hour24,T10.Hour24,T11.Hour24,T12.Hour24,T13.Hour24,T14.Hour24,T15.Hour24,T16.Hour24,T17.Hour24,T18.Hour24,T19.Hour24,T20.Hour24) Hour24,
COALESCE(M0.GNODEB_ID,T10.GNODEB_ID,T11.GNODEB_ID,T12.GNODEB_ID,T13.GNODEB_ID,T14.GNODEB_ID,T15.GNODEB_ID,T16.GNODEB_ID,T17.GNODEB_ID,T18.GNODEB_ID,T19.GNODEB_ID,T20.GNODEB_ID) GNODEB_ID,
COALESCE(M0.du_id,T10.du_id,T11.du_id,T12.du_id,T13.du_id,T14.du_id,T15.du_id,T16.du_id,T17.du_id,T18.du_id,T19.du_id,T20.du_id) du_id,
COALESCE(M0.GCELL_ID,T10.GCELL_ID,T11.GCELL_ID,T12.GCELL_ID,T13.GCELL_ID,T14.GCELL_ID,T15.GCELL_ID,T16.GCELL_ID,T17.GCELL_ID,T18.GCELL_ID,T19.GCELL_ID,T20.GCELL_ID) GCELL_ID,
COALESCE(M0.MARKET_NAME,T10.MARKET_NAME,T11.MARKET_NAME,T12.MARKET_NAME,T13.MARKET_NAME,T14.MARKET_NAME,T15.MARKET_NAME,T16.MARKET_NAME,T17.MARKET_NAME,T18.MARKET_NAME,T19.MARKET_NAME,T20.MARKET_NAME) MARKET_NAME,						
COALESCE(M0.SUB_MARKET_NAME,T10.SUB_MARKET_NAME,T11.SUB_MARKET_NAME,T12.SUB_MARKET_NAME,T13.SUB_MARKET_NAME,T14.SUB_MARKET_NAME,T15.SUB_MARKET_NAME,T16.SUB_MARKET_NAME,T17.SUB_MARKET_NAME,T18.SUB_MARKET_NAME,T19.SUB_MARKET_NAME,T20.SUB_MARKET_NAME) SUB_MARKET_NAME,
			
			S5NR_BeamChangeSuccRate_PCT_Num,
			S5NR_BeamChangeSuccRate_PCT_Denom ,
			S5NR_UEPwrHeadroom_dB_Num ,
			S5NR_UEPwrHeadroom_dB_Denom ,
			S5NR_AverageBRSRP_dBm_Num ,
			S5NR_AverageBRSRP_dBm_Denom ,
			S5NC_InitDRBSetupFail_PCT_SA_Num ,
			S5NC_InitDRBSetupFail_PCT_SA_Denom ,
			S5NR_ULUserPerceivedTput_NSA_Mbps_Num ,
			S5NR_ULUserPerceivedTput_NSA_Mbps_Denom ,
			S5NR_ULUserPerceivedTput_SA_Mbps_Num ,
			S5NR_ULUserPerceivedTput_SA_Mbps_Denom ,
			S5ND_AvgRRCUsers_SANSA_perCell_Num ,
			S5ND_AvgRRCUsers_SANSA_perCell_Denom ,
			S5ND_MaxRRCUsers_SANSA_perCell ,
			S5ND_RLC_UL_Delay_ms_Num ,
			S5ND_RLC_UL_Delay_ms_Denom ,
			S5ND_AvgRLCDelay_UL_SA_us_Num ,
			S5ND_AvgRLCDelay_UL_SA_us_Denom ,
			InterSysLTE_Out_Succ ,
			RedirectionToLTE_CoverageOut ,
			Average_TA_C_Band_Num ,
			Average_TA_C_Band_Denom ,
			Average_TA_LS3_Num ,
			Average_TA_LS3_Denom ,
			Average_TA_mmWave_Num ,
			Average_TA_mmWave_Denom,
			S5NC_InitDRBSetupFail_5QI8_PCT_Num,
			S5NC_InitDRBSetupFail_5QI8_PCT_Denom,
			REDIRECTIONTOLTE_BLINDA2,
			RedirectionToLTE_EPSFallback,
			RedirectionToLTE_EmergencyFallback
from (
				
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									SUM(BeamIdNormalPdsch_Succ) S5NR_BeamChangeSuccRate_PCT_Num,
									SUM(BeamIdNormalPdsch_Att) S5NR_BeamChangeSuccRate_PCT_Denom
									-- select *
								from apachedataingestion.nr.beamtracking_nr_hr_silver a
								inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id	
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								and cast (replace(split(a.LOCATION,'/')[1],'BeamID','') as int) between  0 and 56
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) M0
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									sum(PhrIndex0_count_SUM * -33 + PhrIndex1_count_SUM * -32 + PhrIndex2_count_SUM * -31 + PhrIndex3_count_SUM * -30 + PhrIndex4_count_SUM * -29 + PhrIndex5_count_SUM * -28 + PhrIndex6_count_SUM * -27 + PhrIndex7_count_SUM * -26 + PhrIndex8_count_SUM * -25 + PhrIndex9_count_SUM * -24 + PhrIndex10_count_SUM * -23 + PhrIndex11_count_SUM * -22 + PhrIndex12_count_SUM * -21 + PhrIndex13_count_SUM * -20 + PhrIndex14_count_SUM * -19 + PhrIndex15_count_SUM * -18 + PhrIndex16_count_SUM * -17 + PhrIndex17_count_SUM * -16 + PhrIndex18_count_SUM * -15 + PhrIndex19_count_SUM * -14 + PhrIndex20_count_SUM * -13 + PhrIndex21_count_SUM * -12 + PhrIndex22_count_SUM * -11 + PhrIndex23_count_SUM * -10 + PhrIndex24_count_SUM * -9 + PhrIndex25_count_SUM * -8 + PhrIndex26_count_SUM * -7 + PhrIndex27_count_SUM * -6 + PhrIndex28_count_SUM * -5 + PhrIndex29_count_SUM * -4 + PhrIndex30_count_SUM * -3 + PhrIndex31_count_SUM * -2 + PhrIndex32_count_SUM * -1 + PhrIndex33_count_SUM * 0 + PhrIndex34_count_SUM * 1 + PhrIndex35_count_SUM * 2 + PhrIndex36_count_SUM * 3 + PhrIndex37_count_SUM * 4 + PhrIndex38_count_SUM * 5 + PhrIndex39_count_SUM * 6 + PhrIndex40_count_SUM * 7 + PhrIndex41_count_SUM * 8 + PhrIndex42_count_SUM * 9 + PhrIndex43_count_SUM * 10 + PhrIndex44_count_SUM * 11 + PhrIndex45_count_SUM * 12 + PhrIndex46_count_SUM * 13 + PhrIndex47_count_SUM * 14 + PhrIndex48_count_SUM * 15 + PhrIndex49_count_SUM * 16 + PhrIndex50_count_SUM * 17 + PhrIndex51_count_SUM * 18 + PhrIndex52_count_SUM * 19 + PhrIndex53_count_SUM * 20 + PhrIndex54_count_SUM * 21 + PhrIndex55_count_SUM * 22 + PhrIndex56_count_SUM * 24 + PhrIndex57_count_SUM * 26 + PhrIndex58_count_SUM * 28 + PhrIndex59_count_SUM * 30 + PhrIndex60_count_SUM * 32 + PhrIndex61_count_SUM * 34 + PhrIndex62_count_SUM * 36 + PhrIndex63_count_SUM * 38) S5NR_UEPwrHeadroom_dB_Num,
									sum(PhrIndex0_count_SUM + PhrIndex1_count_SUM + PhrIndex2_count_SUM + PhrIndex3_count_SUM + PhrIndex4_count_SUM + PhrIndex5_count_SUM + PhrIndex6_count_SUM + PhrIndex7_count_SUM + PhrIndex8_count_SUM + PhrIndex9_count_SUM + PhrIndex10_count_SUM + PhrIndex11_count_SUM + PhrIndex12_count_SUM + PhrIndex13_count_SUM + PhrIndex14_count_SUM + PhrIndex15_count_SUM + PhrIndex16_count_SUM + PhrIndex17_count_SUM + PhrIndex18_count_SUM + PhrIndex19_count_SUM + PhrIndex20_count_SUM + PhrIndex21_count_SUM + PhrIndex22_count_SUM + PhrIndex23_count_SUM + PhrIndex24_count_SUM + PhrIndex25_count_SUM + PhrIndex26_count_SUM + PhrIndex27_count_SUM + PhrIndex28_count_SUM + PhrIndex29_count_SUM + PhrIndex30_count_SUM + PhrIndex31_count_SUM + PhrIndex32_count_SUM + PhrIndex33_count_SUM + PhrIndex34_count_SUM + PhrIndex35_count_SUM + PhrIndex36_count_SUM + PhrIndex37_count_SUM + PhrIndex38_count_SUM + PhrIndex39_count_SUM + PhrIndex40_count_SUM + PhrIndex41_count_SUM + PhrIndex42_count_SUM + PhrIndex43_count_SUM + PhrIndex44_count_SUM + PhrIndex45_count_SUM + PhrIndex46_count_SUM + PhrIndex47_count_SUM + PhrIndex48_count_SUM + PhrIndex49_count_SUM + PhrIndex50_count_SUM + PhrIndex51_count_SUM + PhrIndex52_count_SUM + PhrIndex53_count_SUM + PhrIndex54_count_SUM + PhrIndex55_count_SUM + PhrIndex56_count_SUM + PhrIndex57_count_SUM + PhrIndex58_count_SUM + PhrIndex59_count_SUM + PhrIndex60_count_SUM + PhrIndex61_count_SUM + PhrIndex62_count_SUM + PhrIndex63_count_SUM) S5NR_UEPwrHeadroom_dB_Denom
									-- select *
								from apachedataingestion.nr.powerheadroomreport_nr_hr_silver a
								inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id	
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T10 on M0.CalendarDate=T10.CalendarDate and M0.Hour24=T10.Hour24 and M0.du_id=T10.du_id and M0.GCELL_ID=T10.GCELL_ID 
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									sum(RsrpBestForSsbri_Bin0_count_SUM * power(10,-13.9)+RsrpBestForSsbri_Bin1_count_SUM * power(10,-13.6)+RsrpBestForSsbri_Bin2_count_SUM * power(10,-13.3)+RsrpBestForSsbri_Bin3_count_SUM * power(10,-13)+RsrpBestForSsbri_Bin4_count_SUM * power(10,-12.7)+RsrpBestForSsbri_Bin5_count_SUM * power(10,-12.4)+RsrpBestForSsbri_Bin6_count_SUM * power(10,-12.1)+RsrpBestForSsbri_Bin7_count_SUM * power(10,-11.8)+RsrpBestForSsbri_Bin8_count_SUM * power(10,-11.5)+RsrpBestForSsbri_Bin9_count_SUM * power(10,-11.2)+RsrpBestForSsbri_Bin10_count_SUM * power(10,-10.9)+RsrpBestForSsbri_Bin11_count_SUM * power(10,-10.6)+RsrpBestForSsbri_Bin12_count_SUM * power(10,-10.3)+RsrpBestForSsbri_Bin13_count_SUM * power(10,-10)+RsrpBestForSsbri_Bin14_count_SUM * power(10,-9.7)+RsrpBestForSsbri_Bin15_count_SUM * power(10,-9.4)+RsrpBestForSsbri_Bin16_count_SUM * power(10,-9.1)+RsrpBestForSsbri_Bin17_count_SUM * power(10,-8.8)+RsrpBestForSsbri_Bin18_count_SUM * power(10,-8.5)+RsrpBestForSsbri_Bin19_count_SUM * power(10,-8.2)+RsrpBestForSsbri_Bin20_count_SUM * power(10,-7.9)+RsrpBestForSsbri_Bin21_count_SUM * power(10,-7.6)+RsrpBestForSsbri_Bin22_count_SUM * power(10,-7.3)+RsrpBestForSsbri_Bin23_count_SUM * power(10,-7)+RsrpBestForSsbri_Bin24_count_SUM * power(10,-6.7)+RsrpBestForSsbri_Bin25_count_SUM * power(10,-6.4)+RsrpBestForSsbri_Bin26_count_SUM * power(10,-6.1)+RsrpBestForSsbri_Bin27_count_SUM * power(10,-5.8)+RsrpBestForSsbri_Bin28_count_SUM * power(10,-5.5)+RsrpBestForSsbri_Bin29_count_SUM * power(10,-5.2)+RsrpBestForSsbri_Bin30_count_SUM * power(10,-4.9)+RsrpBestForSsbri_Bin31_count_SUM * power(10,-4.6)+RsrpBestForSsbri_Bin32_count_SUM * power(10,-4.3)) S5NR_AverageBRSRP_dBm_Num,
									sum(RsrpBestForSsbri_Bin0_count_SUM+RsrpBestForSsbri_Bin1_count_SUM+RsrpBestForSsbri_Bin2_count_SUM+RsrpBestForSsbri_Bin3_count_SUM+RsrpBestForSsbri_Bin4_count_SUM+RsrpBestForSsbri_Bin5_count_SUM+RsrpBestForSsbri_Bin6_count_SUM+RsrpBestForSsbri_Bin7_count_SUM+RsrpBestForSsbri_Bin8_count_SUM+RsrpBestForSsbri_Bin9_count_SUM+RsrpBestForSsbri_Bin10_count_SUM+RsrpBestForSsbri_Bin11_count_SUM+RsrpBestForSsbri_Bin12_count_SUM+RsrpBestForSsbri_Bin13_count_SUM+RsrpBestForSsbri_Bin14_count_SUM+RsrpBestForSsbri_Bin15_count_SUM+RsrpBestForSsbri_Bin16_count_SUM+RsrpBestForSsbri_Bin17_count_SUM+RsrpBestForSsbri_Bin18_count_SUM+RsrpBestForSsbri_Bin19_count_SUM+RsrpBestForSsbri_Bin20_count_SUM+RsrpBestForSsbri_Bin21_count_SUM+RsrpBestForSsbri_Bin22_count_SUM+RsrpBestForSsbri_Bin23_count_SUM+RsrpBestForSsbri_Bin24_count_SUM+RsrpBestForSsbri_Bin25_count_SUM+RsrpBestForSsbri_Bin26_count_SUM+RsrpBestForSsbri_Bin27_count_SUM+RsrpBestForSsbri_Bin28_count_SUM+RsrpBestForSsbri_Bin29_count_SUM+RsrpBestForSsbri_Bin30_count_SUM+RsrpBestForSsbri_Bin31_count_SUM+RsrpBestForSsbri_Bin32_count_SUM) S5NR_AverageBRSRP_dBm_Denom
									-- select *
								from apachedataingestion.nr.ssbrifeedbackrsrp_nr_hr_silver a
								inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id	
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T11 on M0.CalendarDate=T11.CalendarDate and M0.Hour24=T11.Hour24 and M0.du_id=T11.du_id and M0.GCELL_ID=T11.GCELL_ID 
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									sum(DrbSetupAtt-DrbSetupSucc)	S5NC_InitDRBSetupFail_PCT_SA_Num,
									sum(DrbSetupAtt)   S5NC_InitDRBSetupFail_PCT_SA_Denom,									
									sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbSetupAtt-DrbSetupSucc end )  S5NC_InitDRBSetupFail_5QI8_PCT_Num,
									sum(case when split(LOCATION,'/')[3] in ('5QI8') then DrbSetupAtt end )  S5NC_InitDRBSetupFail_5QI8_PCT_Denom									
									-- select *
								from apachedataingestion.nr.InitialDRBSetupwithDUIdentifier_nr_hr_silver a 
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id	
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T12 on M0.CalendarDate=T12.CalendarDate and M0.Hour24=T12.Hour24 and M0.du_id=T12.du_id and M0.GCELL_ID=T12.GCELL_ID 
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									sum(8 * ULUeThruVolNsa / 1000)	S5NR_ULUserPerceivedTput_NSA_Mbps_Num,
									sum(ULUeThruTimeNsa / 8000) S5NR_ULUserPerceivedTput_NSA_Mbps_Denom
									-- select *
								from apachedataingestion.nr.UplinkUEThroughputforNSA_nr_hr_silver a 
								inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T13 on M0.CalendarDate=T13.CalendarDate and M0.Hour24=T13.Hour24 and M0.du_id=T13.du_id and M0.GCELL_ID=T13.GCELL_ID
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									sum(8 * ULUeThruVolSa / 1000) S5NR_ULUserPerceivedTput_SA_Mbps_Num,
									sum(ULUeThruTimeSa / 8000) S5NR_ULUserPerceivedTput_SA_Mbps_Denom
									-- select *
								from apachedataingestion.nr.UplinkUEThroughputforSA_nr_hr_silver a 
								inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T14 on M0.CalendarDate=T14.CalendarDate and M0.Hour24=T14.Hour24 and M0.du_id=T14.du_id and M0.GCELL_ID=T14.GCELL_ID
--Modified silver table for the below KPIs from apachedataingestion.nr.CallNumberinCellNR_nr_hr_silver to apachedataingestion.nr.uenumberperbpu_nr_hr_silver on 2025-02-18 JIRA:DENG-2983
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
									sum(SpCellUeNumPerCellTot) S5ND_AvgRRCUsers_SANSA_perCell_Num,
									sum(SpCellUeNumPerCellCnt) S5ND_AvgRRCUsers_SANSA_perCell_Denom,
									max(SpCellUeNumPerCellMax) S5ND_MaxRRCUsers_SANSA_perCell
									-- select *
								from apachedataingestion.nr.uenumberpercell_nr_hr_silver a 
								inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T15 on M0.CalendarDate=T15.CalendarDate and M0.Hour24=T15.Hour24 and M0.du_id=T15.du_id and M0.GCELL_ID=T15.GCELL_ID
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,									
										sum(RlcULSduDelayTot / 1000)  S5ND_RLC_UL_Delay_ms_Num,
										sum(RlcULSduCnt)  S5ND_RLC_UL_Delay_ms_Denom
									-- select *
								from apachedataingestion.nr.RLCULPacketDelayperPLMNforNSA_nr_hr_silver a 
								inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T16 on M0.CalendarDate=T16.CalendarDate and M0.Hour24=T16.Hour24 and M0.du_id=T16.du_id and M0.GCELL_ID=T16.GCELL_ID
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,									
										sum(RlcULSduDelayTot_SA)  S5ND_AvgRLCDelay_UL_SA_us_Num,
										sum(RlcULSduCnt_SA)  S5ND_AvgRLCDelay_UL_SA_us_Denom
									-- select *
								from apachedataingestion.nr.RLCULPacketDelayperPLMNperSNSSAIforSA_nr_hr_silver a 
								inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T17 on M0.CalendarDate=T17.CalendarDate and M0.Hour24=T17.Hour24 and M0.du_id=T17.du_id and M0.GCELL_ID=T17.GCELL_ID
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,									
										sum(InterSysLTE_Out_Succ)  InterSysLTE_Out_Succ
									-- select *
								from apachedataingestion.nr.nrhandoveroutgoingtoeutranwithduidentifier_nr_hr_silver a 
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T18 on M0.CalendarDate=T18.CalendarDate and M0.Hour24=T18.Hour24 and M0.du_id=T18.du_id and M0.GCELL_ID=T18.GCELL_ID
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,									
										sum(RedirectionToLTE_CoverageOut)  RedirectionToLTE_CoverageOut,
										sum(REDIRECTIONTOLTE_BLINDA2)  REDIRECTIONTOLTE_BLINDA2,
										sum(RedirectionToLTE_EPSFallback) RedirectionToLTE_EPSFallback,
										sum(RedirectionToLTE_EmergencyFallback)  RedirectionToLTE_EmergencyFallback
									-- select *
								from apachedataingestion.nr.eutranredirectionoutwithduidentifier_nr_hr_silver a 
								inner join conf_du b on cast(replace(split(a.LOCATION,'/')[0],'gNB_ID','') as bigint)=b.kGNODEB_ID and replace(split(a.LOCATION,'/')[2],'CellIdentity','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T19 on M0.CalendarDate=T19.CalendarDate and M0.Hour24=T19.Hour24 and M0.du_id=T19.du_id and M0.GCELL_ID=T19.GCELL_ID
full join  (
								SELECT Daily CalendarDate,Hourly Hour24,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME,
										sum(19.5*timeadvancesection0+59*timeadvancesection1+98*timeadvancesection2+137*timeadvancesection3+176*timeadvancesection4+215*timeadvancesection5+273.5*timeadvancesection6+351.5*timeadvancesection7+585.5*timeadvancesection8+976*timeadvancesection9+1366.5*timeadvancesection10+1756.5*timeadvancesection11+2147*timeadvancesection12+2537.5*timeadvancesection13+2927.5*timeadvancesection14+3318*timeadvancesection15+3708.5*timeadvancesection16+4098.5*timeadvancesection17+4489*timeadvancesection18+4879.5*timeadvancesection19+5269.5*timeadvancesection20+5660*timeadvancesection21+6831.5*timeadvancesection22+9759*timeadvancesection23+13662.5*timeadvancesection24+19518*timeadvancesection25+27325*timeadvancesection26+35132*timeadvancesection27+42939*timeadvancesection28+50746*timeadvancesection29+58553*timeadvancesection30+66360*timeadvancesection31)  Average_TA_C_Band_Num,
										sum(...) Average_TA_C_Band_Denom,
										sum(39*timeadvancesection0+117*timeadvancesection1+195*timeadvancesection2+273*timeadvancesection3+351*timeadvancesection4+429*timeadvancesection5+546*timeadvancesection6+702*timeadvancesection7+1170.5*timeadvancesection8+1951.5*timeadvancesection9+2732*timeadvancesection10+3512.5*timeadvancesection11+4293.5*timeadvancesection12+5074*timeadvancesection13+5854.5*timeadvancesection14+6635.5*timeadvancesection15+7416.5*timeadvancesection16+8197*timeadvancesection17+8977.5*timeadvancesection18+9758.5*timeadvancesection19+10539*timeadvancesection20+11319.5*timeadvancesection21+13662*timeadvancesection22+19517.5*timeadvancesection23+27324.5*timeadvancesection24+39035*timeadvancesection25+54649*timeadvancesection26+70263*timeadvancesection27+85877.5*timeadvancesection28+101492*timeadvancesection29+117106*timeadvancesection30+132720*timeadvancesection31) Average_TA_LS3_Num,
										sum(...) Average_TA_LS3_Denom,
										sum(4.5*timeadvancesection0+14*timeadvancesection1+24*timeadvancesection2+34*timeadvancesection3+43.5*timeadvancesection4+53*timeadvancesection5+68*timeadvancesection6+87.5*timeadvancesection7+146*timeadvancesection8+243.5*timeadvancesection9+341*timeadvancesection10+438.5*timeadvancesection11+536*timeadvancesection12+634*timeadvancesection13+731.5*timeadvancesection14+829*timeadvancesection15+926.5*timeadvancesection16+1024*timeadvancesection17+1122*timeadvancesection18+1219.5*timeadvancesection19+1317*timeadvancesection20+1414.5*timeadvancesection21+1707*timeadvancesection22+2439*timeadvancesection23+3415*timeadvancesection24+4879*timeadvancesection25+6831*timeadvancesection26+8782.5*timeadvancesection27+10734*timeadvancesection28+12686*timeadvancesection29+14638*timeadvancesection30+16589.5*timeadvancesection31) Average_TA_mmWave_Num,
										sum(...) Average_TA_mmWave_Denom
									-- select *
								from apachedataingestion.nr.TimingAdvance_nr_hr_silver a 
								inner join conf_du b on concat('VZ_',left(REGEXP_REPLACE(NE_NAME, '[^0-9]', ''),11))=b.DU_ID and replace(split(a.LOCATION,'/')[0],'CellIdentity','')=b.gcell_id		
								WHERE 5=5 and  Daily  =  date_format(date_add(now(), :days),"yyyy-MM-dd")   
								GROUP BY Daily,Hourly,b.du_id,GNODEB_ID,b.GCELL_ID,MARKET_NAME,SUB_MARKET_NAME
) T20 on M0.CalendarDate=T20.CalendarDate and M0.Hour24=T20.Hour24 and M0.du_id=T20.du_id and M0.GCELL_ID=T20.GCELL_ID

) X
GROUP BY CalendarDate,Hour24,GNODEB_ID,du_id,GCELL_ID,MARKET_NAME,SUB_MARKET_NAME;		
		




/*
select  * from hive_metastore.default.widetable_5g_cell_hr_tmp3;
select * from hive_metastore.default.widetable_5g_cell_hr_tmp4;
select * from hive_metastore.default.widetable_5g_cell_hr_tmp5;
select * from hive_metastore.default.widetable_5g_cell_hr_tmp6;

show create table hive_metastore.default.widetable_5g_cell_hr_tmp6;

delete from apachedataingestion.nr.widetable_5g_SA_hr_gold2
where CalendarDate >= date_format(date_add(now(), :days),"yyyy-MM-dd") and CalendarDate < date_format(date_add(now(), (:days)+1),"yyyy-MM-dd") 
;

select * from apachedataingestion.nr.widetable_5g_SA_hr_gold2



S5NU_PDCP_Datavol_DL_Mb_SA
S5NU_PDCP_Datavol_UL_Mb_SA
S5NU_PDCPLoss_UL_SA_ppmPCT
S5NU_PDCPLoss_DL_SA_ppmPCT
S5NU_DLPDCPDrop_gNB_ppmPCT_SA
S5NU_PDCPDelay_DL_SA_us

ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_PDCP_Datavol_DL_Mb_SA	;			
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_PDCP_Datavol_UL_Mb_SA	;			
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_PDCPLoss_UL_SA_ppmPCT_Num	;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_PDCPLoss_UL_SA_ppmPCT_Denom	;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_PDCPLoss_DL_SA_ppmPCT_Num	;	
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_PDCPLoss_DL_SA_ppmPCT_Denom	;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_DLPDCPDrop_gNB_ppmPCT_SA_Num	;	
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_DLPDCPDrop_gNB_ppmPCT_SA_Denom	;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_PDCPDelay_DL_SA_us_Num	;	
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop  COLUMN S5NU_PDCPDelay_DL_SA_us_Denom	;


show create table apachedataingestion.nr.widetable_5g_SA_hr_gold2;

*/

/*

ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_BeamChangeSuccRate_PCT_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_BeamChangeSuccRate_PCT_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_UEPwrHeadroom_dB_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_UEPwrHeadroom_dB_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_AverageBRSRP_dBm_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_AverageBRSRP_dBm_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_InitDRBSetupFail_PCT_SA_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_InitDRBSetupFail_PCT_SA_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_ULUserPerceivedTput_NSA_Mbps_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_ULUserPerceivedTput_NSA_Mbps_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_ULUserPerceivedTput_SA_Mbps_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NR_ULUserPerceivedTput_SA_Mbps_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5ND_AvgRRCUsers_SANSA_perCell_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5ND_AvgRRCUsers_SANSA_perCell_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5ND_MaxRRCUsers_SANSA_perCell  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5ND_RLC_UL_Delay_ms_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5ND_RLC_UL_Delay_ms_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5ND_AvgRLCDelay_UL_SA_us_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5ND_AvgRLCDelay_UL_SA_us_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  SAMSUNG_NRSAtoLTE_Transition_PCT_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  SAMSUNG_NRSAtoLTE_Transition_PCT_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Average_TA_C_Band_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Average_TA_C_Band_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Average_TA_LS3_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Average_TA_LS3_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Average_TA_mmWave_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Average_TA_mmWave_Denom   DOUBLE;   


ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_InitDRBSetupFail_5QI8_PCT_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_InitDRBSetupFail_5QI8_PCT_Denom  DOUBLE;

ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  SAMSUNG_NRSAtoLTE_Transition_PCT_Num2  DOUBLE;

select * from apachedataingestion.nr.widetable_5g_SA_hr_gold2 where SAMSUNG_NRSAtoLTE_Transition_PCT_Num2 > 0
 * */

/*

show create table apachedataingestion.nr.widetable_5g_SA_hr_gold2;

ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp4 ADD COLUMN 	  InterSysLTE_Out_VoNR_Succ  DOUBLE; 
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp8 ADD COLUMN 	  RedirectionToLTE_EPSFallback  DOUBLE; 
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp8 ADD COLUMN 	  RedirectionToLTE_EmergencyFallback  DOUBLE;
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp5 ADD COLUMN 	  InterSysLTE_Out_EPSFallback_PrepSucc  DOUBLE; 
ALTER TABLE hive_metastore.default.widetable_5g_cell_hr_tmp5 ADD COLUMN 	  InterSysLTE_Out_EmergencyFallback_PrepSuc  DOUBLE; 


ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 drop COLUMN   SAMSUNG_NRSAtoLTE_Transition_PCT_Num2;

ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EPSFB_IRAT_HO_Failure_pct_SA_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EPSFB_IRAT_HO_Failure_pct_SA_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EmergFB_IRAT_HO_Failure_pct_SA_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EmergFB_IRAT_HO_Failure_pct_SA_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Data_Redirection_pct_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Data_Redirection_pct_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Voice_Redirection_pct_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  Voice_Redirection_pct_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EPSFB_IRAT_HO_PrepFailure_pct_SA_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EPSFB_IRAT_HO_PrepFailure_pct_SA_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EPSFB_LTE_Redir_Att_SA  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EmergFB_IRAT_HO_PrepFailure_pct_SA_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EmergFB_IRAT_HO_PrepFailure_pct_SA_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_EmergFB_LTE_Redir_Att_SA  DOUBLE;



ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_DRBDrop_pct_SA_23B_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_DRBDrop_pct_SA_23B_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_DRBDrop_5QI8_pct_23B_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_DRBDrop_5QI8_pct_23B_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_UECtxtDrop_pct_SA_23B_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_UECtxtDrop_pct_SA_23B_Denom  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_NRDC_PScell_HO_Fail_pct_SA_Num  DOUBLE;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  S5NC_NRDC_PScell_HO_Fail_pct_SA_Denom  DOUBLE;

ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  NE_ID2 STRING first;
ALTER TABLE apachedataingestion.nr.widetable_5g_SA_hr_gold2 ADD COLUMN 	  D_DTM_UTC TIMESTAMP first;
  
show create table apachedataingestion.nr.widetable_5g_SA_hr_gold2

*/



delete from apachedataingestion.nr.widetable_5g_SA_hr_gold2
where CalendarDate >= date_format(date_add(now(), :days),"yyyy-MM-dd") and CalendarDate < date_format(date_add(now(), (:days)+1),"yyyy-MM-dd") 
;




insert into apachedataingestion.nr.widetable_5g_SA_hr_gold2
with conf_du (          
			          	select substring(DU_ID,1,10) GNODEB_ID,DU_ID,GCELL_ID,MARKET_NAME,SUB_MARKET_ID,SUB_MARKET_NAME,frequency_band_indicator,cast (replace(substring(DU_ID,1,10),'VZ_','') as bigint) kGNODEB_ID ,cast (replace(DU_ID,'VZ_','') as bigint) kDU_ID			          	
                  		from hive_metastore.`default`.vz_conf_gnode_du_gcell_silver  where not(length(GNODEB_ID) < 10 or length(du_id) < 14) 
				  	union all
						select a.* from (
							select concat('VZ_',gNB_ID) GNODEB_ID,concat('VZ_',DU_ID) DU_ID,CellIdentity GCELL_ID,'' MARKET_NAME,'' SUB_MARKET_ID,'' SUB_MARKET_NAME,'' frequency_band_indicator,cast (gNB_ID as bigint) kGNODEB_ID ,cast (DU_ID as bigint) kDU_ID						
							from hive_metastore.`default`.jwk_mapping_live 
						) a
						full join hive_metastore.`default`.vz_conf_gnode_du_gcell_silver b on a.kDU_ID=cast (replace(b.DU_ID,'VZ_','') as bigint) and a.GCELL_ID=b.GCELL_ID
						where b.DU_ID is null 
),
conf_market (select cast(SUB_MARKET_ID AS INT) SUB_MARKET_ID,SUB_MARKET_NAME,REGION,Time_Offset from hive_metastore.default.vz_conf_market)
select 
		case 	when B.Time_Offset=-5 then  convert_timezone('America/New_York','UTC',cast(concat(Y.CalendarDate,' ',lpad(Y.hour24,2,0),':00:00') as TIMESTAMP)) 
	 				when B.Time_Offset=-6 then  convert_timezone('America/Chicago','UTC',cast(concat(Y.CalendarDate,' ',lpad(Y.hour24,2,0),':00:00') as TIMESTAMP)) 
	 				when B.Time_Offset=-8 then  convert_timezone('America/Los_Angeles','UTC',cast(concat(Y.CalendarDate,' ',lpad(Y.hour24,2,0),':00:00') as TIMESTAMP)) 
 		end D_DTM_UTC,
  	replace(Y.du_ID,'VZ_','') ne_id2,
		frequency_band_indicator,Y.* 
from (
		select 
		COALESCE(M0.CalendarDate,T1.CalendarDate,T2.CalendarDate,T3.CalendarDate) CalendarDate,
		COALESCE(M0.Hour24,T1.Hour24,T2.Hour24,T3.Hour24) Hour24,
		COALESCE(M0.GNODEB_ID,T1.GNODEB_ID,T2.GNODEB_ID,T3.GNODEB_ID) GNODEB_ID,
		COALESCE(M0.du_id,T1.du_id,T2.du_id,T3.du_id) du_id,
		COALESCE(M0.GCELL_ID,T1.GCELL_ID,T2.GCELL_ID,T3.GCELL_ID) GCELL_ID,
		COALESCE(M0.MARKET_NAME,T1.MARKET_NAME,T2.MARKET_NAME,T3.MARKET_NAME) MARKET_NAME,
		COALESCE(M0.NR_TYPE,T1.NR_TYPE,T2.NR_TYPE,T3.NR_TYPE) NR_TYPE,			
		COALESCE(M0.SUB_MARKET_ID,T1.SUB_MARKET_ID,T2.SUB_MARKET_ID,T3.SUB_MARKET_ID) SUB_MARKET_ID,
		COALESCE(M0.SUB_MARKET_NAME,T1.SUB_MARKET_NAME,T2.SUB_MARKET_NAME,T3.SUB_MARKET_NAME) SUB_MARKET_NAME,
PdcpSduVolumeSplitNrDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Volume_NR_RatioPCT_Num	,
	PdcpSduVolumeDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Volume_NR_RatioPCT_Denom	,
PdcpSduVolumeSplitNrUL_CELL_PLMN_QCI	S5NUC_UL_PDCP_Volume_NR_RatioPCT_Num	,
	PdcpSduVolumeUL_CELL_PLMN_QCI	S5NUC_UL_PDCP_Volume_NR_RatioPCT_Denom	,
PdcpSduVolumeDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_DataVolume_MB	,			
PdcpSduVolumeUL_CELL_PLMN_QCI	S5NUC_UL_PDCP_DataVolume_MB	,			
PdcpSduVolumeSplitLteDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Split_LTE_DataVolume_MB	,			
PdcpSduVolumeSplitLteUL_CELL_PLMN_QCI	S5NUC_UL_PDCP_Split_LTE_DataVolume_MB	,			
PdcpSduVolumeSplitNrDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Split_NR_DataVolume_MB	,			
PdcpSduVolumeSplitNrUL_CELL_PLMN_QCI	S5NUC_UL_PDCP_Split_NR_DataVolume_MB	,			
8 * PdcpSduByteDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_AvgTput_Mbps_Num	,
	PdcpSduByteDLCnt_CELL_PLMN_QCI / 10	S5NUC_DL_PDCP_AvgTput_Mbps_Denom	,
8 * PdcpSduByteUL_CELL_PLMN_QCI	S5NUC_UL_PDCP_AvgTput_Mbps_Num	,
	PdcpSduByteULCnt_CELL_PLMN_QCI / 10	S5NUC_UL_PDCP_AvgTput_Mbps_Denom	,
PdcpSduLossCntDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Loss_PCT_Num	,
	PdcpSduCntDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Loss_PCT_Denom	,
PdcpSduLossCntUL_CELL_PLMN_QCI	S5NUC_UL_PDCP_Loss_PCT_Num	,
	PdcpSduCntUL_CELL_PLMN_QCI	S5NUC_UL_PDCP_Loss_PCT_Denom	,
PdcpSduLossCntSplitLteDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Loss_Split_LTE_PCT_Num	,
	PdcpSduCntSplitLteDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Loss_Split_LTE_PCT_Denom	,
PdcpSduLossCntSplitNrDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Loss_Split_NR_PCT_Num	,
	PdcpSduCntSplitNrDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Loss_Split_NR_PCT_Denom	,
PdcpSduDiscardCntDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Discard_PCT_Num	,
	PdcpSduCntDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Discard_PCT_Denom	,
PdcpSduDropCntDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Drop_PCT_Num	,
	PdcpSduCntDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_Drop_PCT_Denom	,
PdcpSduRetxCntDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_ReTx_PCT_Num	,
	PdcpSduCntDL_CELL_PLMN_QCI	S5NUC_DL_PDCP_ReTx_PCT_Denom	,
PdcpSduDelayDLTot_CELL_PLMN_QCI	S5NUC_DL_PDCP_Latency_ms_Num	,
	PdcpSduDelayDLCnt_CELL_PLMN_QCI	S5NUC_DL_PDCP_Latency_ms_Denom	,
PdcpSduDelayULTot_CELL_PLMN_QCI	S5NUC_UL_PDCP_Latency_ms_Num	,
	PdcpSduDelayULCnt_CELL_PLMN_QCI	S5NUC_UL_PDCP_Latency_ms_Denom	,
PdcpSduDelaySplitLteDLTot_CELL_PLMN_QCI	S5NUC_DL_PDCP_Split_LTE_Latency_ms_Num	,
	PdcpSduDelaySplitLteDLCnt_CELL_PLMN_QCI	S5NUC_DL_PDCP_Split_LTE_Latency_ms_Denom	,
PdcpSduDelaySplitLteULTot_CELL_PLMN_QCI	S5NUC_UL_PDCP_Split_LTE_Latency_ms_Num	,
	PdcpSduDelaySplitLteULCnt_CELL_PLMN_QCI	S5NUC_UL_PDCP_Split_LTE_Latency_ms_Denom	,
PdcpSduDelaySplitNrDLTot_CELL_PLMN_QCI	S5NUC_DL_PDCP_Split_NR_Latency_ms_Num	,
	PdcpSduDelaySplitNrDLCnt_CELL_PLMN_QCI	S5NUC_DL_PDCP_Split_NR_Latency_ms_Denom	,
PdcpSduDelaySplitNrULTot_CELL_PLMN_QCI	S5NUC_UL_PDCP_Split_NR_Latency_ms_Num	,
	PdcpSduDelaySplitNrULCnt_CELL_PLMN_QCI	S5NUC_UL_PDCP_Split_NR_Latency_ms_Denom	,
(EndcAddAtt+EndcAddMnHoInterEnbAtt+EndcAddSgnbChgAtt)-(EndcAddSucc+EndcAddMnHoInterEnbHoSucc+EndcAddSgnbChgSucc)	Re_configuration_Failure_Rate_PCT_incl_Mobility_Num	,
	(EndcAddAtt+EndcAddMnHoInterEnbAtt+EndcAddSgnbChgAtt)	Re_configuration_Failure_Rate_PCT_incl_Mobility_Denom	,
AddProcTimeTot	Average_Addition_Procedure_Time_ms_Num	,
	AddProcTimeCnt	Average_Addition_Procedure_Time_ms_Denom	,
3600 * DrbNoTot	Avg_xRAB_Hold_Time_QCI_s	,			
(NumAttemptPDCCHUL + NumAttemptPDCCHDL - NumBlockedPDCCHTot)-(UsedAggTot1+UsedAggTot16+UsedAggTot2+UsedAggTot4+UsedAggTot8)	S5NR_PDCCH_Fail_Tot_PCT_Num,
(NumAttemptPDCCHUL + NumAttemptPDCCHDL - NumBlockedPDCCHTot)	S5NR_PDCCH_Fail_Tot_PCT_Denom	,
(ConnEstabAtt - ConnEstabSucc)	S5NC_RRCSetupFailure_PCT_SA_Num	,	ConnEstabAtt	S5NC_RRCSetupFailure_PCT_SA_Denom	,
(NgConnEstabAtt - NgConnEstabSucc)	S5NC_NGSetupFailure_PCT_SA_Num	,
	NgConnEstabAtt	S5NC_NGSetupFailure_PCT_SA_Denom	,
(PduSetupPlmnSnssaiAtt - PduSetupPlmnSnssaiSucc)	S5NC_PDUSetupFail_PCT_SA_Num	,
	PduSetupPlmnSnssaiAtt	S5NC_PDUSetupFail_PCT_SA_Denom	,
(DrbSetupAtt - DrbSetupSucc)	S5NC_DRBSetupFail_PCT_SA_Num	,
	DrbSetupAtt	S5NC_DRBSetupFail_PCT_SA_Denom	,
(DrbSetupAtt - DrbSetupSucc)	S5NC_DRBSetupFail_5QI8_PCT_Num	,
	DrbSetupAtt	S5NC_DRBSetupFail_5QI8_PCT_Denom	,
(DrbRelTotal - DrbRelbyAmf_UeContextRelCmd_IntraNrHo)-(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause+DrbRelbyAmf_PduSessionModifyReq_WithNormalCause+DrbRelbyGnb_UeContextRelReq_WithNormalCause+DrbRelbyAmf_UeContextRelCmd_WithNormalCause-DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause+DrbRelbyIntraRatRedirection+DrbRelbyInterRatRedirection+DrbRelbyPreemption)	S5NC_DRBDrop_PCT_SA_Num	,	(DrbRelTotal - DrbRelbyAmf_UeContextRelCmd_IntraNrHo) S5NC_DRBDrop_PCT_SA_Denom,
(DrbRelTotal - DrbRelbyAmf_UeContextRelCmd_IntraNrHo)-(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause+DrbRelbyAmf_PduSessionModifyReq_WithNormalCause+DrbRelbyGnb_UeContextRelReq_WithNormalCause+DrbRelbyAmf_UeContextRelCmd_WithNormalCause-DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause+DrbRelbyIntraRatRedirection+DrbRelbyInterRatRedirection+DrbRelbyPreemption)	S5NC_DRBDrop_5QI8_PCT_Num,
(DrbRelTotal - DrbRelbyAmf_UeContextRelCmd_IntraNrHo)	S5NC_DRBDrop_5QI8_PCT_Denom,
(UeContextRelTotal - UeRelbyAmf_UeContextRelCmd_IntraNrHo) -  (UeRelbyAmf_UeContextRelCmd_WithNormalCause + UeRelbyGnb_UeContextRelReq_WithNormalCause - UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause + UeRelbyIntraRatRedirection + UeRelbyInterRatRedirection + UeRelbyPreemption)	S5NC_UECtxtDrop_PCT_SA_Num	,
(UeContextRelTotal - UeRelbyAmf_UeContextRelCmd_IntraNrHo)	S5NC_UECtxtDrop_PCT_SA_Denom	,
(IntraGnbReEstabAtt + InterGnbReEstabAtt - InterGnbReEstabRreSucc - InterGnbReEstabRrcSetupSucc - IntraGnbReEstabRreSucc - IntraGnbReEstabRrcSetupSucc)	S5NC_GnbReEstabFail_PCT_SA_Num	,	
(InterGnbReEstabAtt + IntraGnbReEstabAtt)	S5NC_GnbReEstabFail_PCT_SA_Denom	,
DLUeThruVol_SA * 8 * 1.024 / 1000 * power(10, 6)	S5ND_AvgUEThpt_SA_Mbps_Num	,	
DLUeThruTime_SA	S5ND_AvgUEThpt_SA_Mbps_Denom	,
InterXn_HoTimeTot	S5NC_InterGNBXn_HO_AvgLatency_ms_SA_Num	,	
InterXn_HoTimeCnt	S5NC_InterGNBXn_HO_AvgLatency_ms_SA_Denom	,
InterNg_HoTimeTot	S5NC_InterGNBNG_HO_AvgLatency_ms_SA_Num	,	
InterNg_HoTimeCnt	S5NC_InterGNBNG_HO_AvgLatency_ms_SA_Denom	,
IntragNB_HoTimeTot	S5NC_IntraGNB_HO_AvgLatency_ms_SA_Num	,	
IntragNB_HoTimeCnt	S5NC_IntraGNB_HO_AvgLatency_ms_SA_Denom	,
(InterNgOut_HandoverCancel + InterNgOut_RRE + InterNgOut_Succ + InterXnOut_HandoverCancel + InterXnOut_RRE + InterXnOut_Succ + IntraGnbOut_RRE + IntraGnbOut_Succ + IntraGnbOut_HandoverCancel)	S5NC_IntraNR_HO_Succ_PCT_SA_Num	,	(InterNgOut_Att + InterXnOut_Att + IntraGnbOut_Att)	S5NC_IntraNR_HO_Succ_PCT_SA_Denom	,
(IntraGnbOut_RRE + IntraGnbOut_Succ + IntraGnbOut_HandoverCancel)	S5NC_IntraGNB_OutHO_Succ_PCT_SA_Num	,	IntraGnbOut_Att	S5NC_IntraGNB_OutHO_Succ_PCT_SA_Denom	,
(InterXnOut_HandoverCancel + InterXnOut_RRE + InterXnOut_Succ)	S5NC_InterGNBXN_OutHO_Succ_PCT_SA_Num	,	InterXnOut_Att	S5NC_InterGNBXN_OutHO_Succ_PCT_SA_Denom	,
(InterXnOut_HandoverCancel + InterXnOut_RRE + InterXnOut_Succ)	S5NC_InterGNBNG_OutHO_Succ_PCT_SA_Num	,	InterNgOut_Att	S5NC_InterGNBNG_OutHO_Succ_PCT_SA_Denom	,
(IntraFreqOut_Succ + IntraFreqOut_RRE + IntraFreqOut_HandoverCancel)	S5NC_IntraFreq_HO_Succ_PCT_SA_Num	,	IntraFreqOut_Att	S5NC_IntraFreq_HO_Succ_PCT_SA_Denom	,
(InterFreqOutWithGap_RRE + InterFreqOutWithGap_Succ + InterFreqOutWithGap_HandoverCancel)	S5NC_InterFreq_HO_Succ_PCT_SA__Num	,	InterFreqOutWithGap_Att	S5NC_InterFreq_HO_Succ_PCT_SA__Denom	,
(InterSysLTE_Out_RRE + T1.InterSysLTE_Out_Succ + InterSysLTE_Out_HandoverCancel) 	S5NC_IRAT_HO_2EUTRAN_Succ_PCT_SA_Num	,	InterSysLTE_Out_Att	S5NC_IRAT_HO_2EUTRAN_Succ_PCT_SA_Denom	,
ConnNoTot	S5NC_AvgRRC_SA_Num	,	ConnNoCnt	S5NC_AvgRRC_SA_Denom	,
ConnNoMax	S5NC_MaxRRC_SA	,	
--Modified KPI S5NC_NRDCAdd_MN_Succ_PCT_SA_Denom on 12/20/2024 DENG-2505	
NrdcAddMn_Succ	S5NC_NRDCAdd_MN_Succ_PCT_SA_Num	,	NrdcAddMn_Att	S5NC_NRDCAdd_MN_Succ_PCT_SA_Denom	,
--Modified KPI S5NC_NRDCAdd_SN_Succ_PCT_SA_Denom on 12/20/2024 DENG-2505
NrdcAddSn_Succ	S5NC_NRDCAdd_SN_Succ_PCT_SA_Num	,	NrdcAddSn_Att	S5NC_NRDCAdd_SN_Succ_PCT_SA_Denom	,
--(NrdcAddMn_Succ + NrdcAddSn_Succ)	S5NC_NRDCAdd_Succ_PCT_SA_Num	,	(NrdcAddMn_Total + NrdcAddSn_Total)	S5NC_NRDCAdd_Succ_PCT_SA_Denom	,
(nvl(NrdcAddMn_Succ,0) + nvl(NrdcAddSn_Succ,0)) S5NC_NRDCAdd_Succ_PCT_SA_Num  , (nvl(NrdcAddMn_Total,0) + nvl(NrdcAddSn_Total,0)) S5NC_NRDCAdd_Succ_PCT_SA_Denom  ,
(DrbRelbyGnb_UeContextRelReq - DrbRelbyGnb_UeContextRelReq_WithNormalCause)	DRB_Retainability_gNB_Num	,	DrbRelTotal	DRB_Retainability_gNB_Denom	,
(UeRelbyGnb_UeContextRelReq - UeRelbyGnb_UeContextRelReq_WithNormalCause)	UE_Context_Retainability_gNB_Num	,	UeContextRelTotal	UE_Context_Retainability_gNB_Denom	,
(NrdcRelMn_SnInit_RadioConnectionWithUeLost+NrdcRelMn_MnInit_t310Expiry+NrdcRelMn_MnInit_randomAccessProblem+NrdcRelMn_MnInit_rlcMaxNumRetx+NrdcRelMn_MnInit_synchReconfigFailureSCG+NrdcRelMn_MnInit_scgReconfigFailure+NrdcRelMn_MnInit_t312Expiry+NrdcRelMn_MnInit_srb3IntegrityFailure+NrdcRelMn_MnInit_beamFailureRecoveryFailure+NrdcRelMn_MnInit_others)	NRDC_SN_Drop_Rate_MN_Num	,	NrdcRelMn_Total	NRDC_SN_Drop_Rate_MN_Denom	,
(NrdcRelSn_MnInit_RadioConnectionWithUeLost + NrdcRelSn_SnInit_RLFailureRLC + NrdcRelSn_SnInit_RLFailureOthers)	NRDC_SN_Drop_Rate_SN_Num	,	NrdcRelSn_Total	NRDC_SN_Drop_Rate_SN_Denom	,
--(NrdcRelMn_SnInit_RadioConnectionWithUeLost+NrdcRelMn_MnInit_t310Expiry+NrdcRelMn_MnInit_randomAccessProblem+NrdcRelMn_MnInit_rlcMaxNumRetx+NrdcRelMn_MnInit_synchReconfigFailureSCG+NrdcRelMn_MnInit_scgReconfigFailure+NrdcRelMn_MnInit_t312Expiry+NrdcRelMn_MnInit_srb3IntegrityFailure+NrdcRelMn_MnInit_beamFailureRecoveryFailure+NrdcRelMn_MnInit_others + NrdcRelSn_MnInit_RadioConnectionWithUeLost+NrdcRelSn_SnInit_RLFailureRLC+NrdcRelSn_SnInit_RLFailureOthers)	NRDC_SN_Drop_Rate_Num	,	(NrdcRelMn_Total + NrdcRelSn_Total)	NRDC_SN_Drop_Rate_Denom	,
(nvl((NrdcRelMn_SnInit_RadioConnectionWithUeLost+NrdcRelMn_MnInit_t310Expiry+NrdcRelMn_MnInit_randomAccessProblem+NrdcRelMn_MnInit_rlcMaxNumRetx+NrdcRelMn_MnInit_synchReconfigFailureSCG+NrdcRelMn_MnInit_scgReconfigFailure+NrdcRelMn_MnInit_t312Expiry+NrdcRelMn_MnInit_srb3IntegrityFailure+NrdcRelMn_MnInit_beamFailureRecoveryFailure+NrdcRelMn_MnInit_others),0) + nvl((NrdcRelSn_MnInit_RadioConnectionWithUeLost+NrdcRelSn_SnInit_RLFailureRLC+NrdcRelSn_SnInit_RLFailureOthers),0)) NRDC_SN_Drop_Rate_Num , (nvl(NrdcRelMn_Total,0) + nvl(NrdcRelSn_Total,0)) NRDC_SN_Drop_Rate_Denom ,
(InterSysLTE_Out_EPSFallback_Succ + InterSysLTE_Out_EPSFallback_HandoverCancel + InterSysLTE_Out_EPSFallback_RRE)	EPSFB_to_EUTRAN_SR_Num	,	InterSysLTE_Out_EPSFallback_Att	EPSFB_to_EUTRAN_SR_Denom	,
(InterSysLTE_Out_EmergencyFallback_Succ + InterSysLTE_Out_EmergencyFallback_HandoverCancel + InterSysLTE_Out_EmergencyFallback_RRE)	EMFB_to_EUTRAN_SR_Num	,	(InterSysLTE_Out_EmergencyFallback_Att)	EMFB_to_EUTRAN_SR_Denom	,
CallHoldingTimeTot	S5NC_RRC_HoldingTime_SA_sec_Num	,	CallHoldingTimeCnt	S5NC_RRC_HoldingTime_SA_sec_Denom	,
ConnEstabTimeTot	S5NC_RRC_SetupTime_SA_ms_Num	,	ConnEstabTimeCnt	S5NC_RRC_SetupTime_SA_ms_Denom	,
NgConnEstabTimeTot	S5NC_NG_SetupTime_SA_ms_Num	,	NgConnEstabTimeCnt	S5NC_NG_SetupTime_SA_ms_Denom	,
InactCallHoldingTimeTot	S5NC_RRC_Inact_HoldingTime_SA_sec_Num	,	InactCallHoldingTimeCnt	S5NC_RRC_Inact_HoldingTime_SA_sec_Denom	,
ConnInactCallHoldingTimeTot	S5NC_RRC_Total_HoldingTime_SA_sec_Num	,	ConnInactCallHoldingTimeCnt	S5NC_RRC_Total_HoldingTime_SA_sec_Denom	,
DrbHoldingTimeTot	S5NC_DRB_Act_HoldingTime_SA_sec_Num	,	DrbHoldingTimeCnt	S5NC_DRB_Act_HoldingTime_SA_sec_Denom	,
InactDrbHoldingTimeTot	S5NC_DRB_Inact_HoldingTime_SA_sec_Num	,	InactDrbHoldingTimeCnt	S5NC_DRB_Inact_HoldingTime_SA_sec_Denom	,
ConnInactDrbHoldingTimeTot	S5NC_DRB_Total_HoldingTime_SA_sec_Num	,	ConnInactDrbHoldingTimeCnt	S5NC_DRB_Total_HoldingTime_SA_sec_Denom	,
IntraSn_HoTimeTot	S5NC_IntraSN_HO_Time_SA_ms_Num	,	IntraSn_HoTimeCnt	S5NC_IntraSN_HO_Time_SA_ms_Denom	,
IntraSnViaSrb3_HoTimeTot	S5NC_SRB3_IntraSN_HO_Time_SA_ms_Num	,	IntraSnViaSrb3_HoTimeCnt	S5NC_SRB3_IntraSN_HO_Time_SA_ms_Denom	,
InterSn_HoTimeTot	S5NC_InterSN_HO_Time_SA_ms_Num	,	InterSn_HoTimeCnt	S5NC_InterSN_HO_Time_SA_ms_Denom	,
IpLatTot	S5ND_AvgIPLatency_DL_SA_us_Num	,	IpLatSampleCnt	S5ND_AvgIPLatency_DL_SA_us_Denom	,
RlcSduDelayTot_SA	S5ND_AvgRLCDelay_DL_SA_us_Num	,	RlcSduDelayCnt_SA	S5ND_AvgRLCDelay_DL_SA_us_Denom	,
AirIfDelayTot_SA	S5ND_AvgAirIfDelay_DL_SA_us_Num	,	AirIfDelayCnt_SA	S5ND_AvgAirIfDelay_DL_SA_us_Denom	,
RlcDLRePktCnt	S5ND_RLC_Retran_DL_PCT_SA_Num	,	RlcDLPktCnt	S5ND_RLC_Retran_DL_PCT_SA_Denom	,
RlcDLByte * 1.024 / 1000	S5ND_RLCDataVol_DL_SA_Mb	,			
RlcULByte * 1.024 / 1000	S5ND_RLCDataVol_UL_SA_Mb	,			
ErabSpecInfo_HoldingTimeTot	S5NR_AvgERABHoldTime_sec_Num	,	ErabSpecInfo_HoldingTimeCnt	S5NR_AvgERABHoldTime_sec_Denom	,
IntraSNSPcellChgMCGSRBTot	S5NC_IntraSN_PSCell_Change_Time_sec_Num	,	IntraSNSPcellChgMCGSRBCnt	S5NC_IntraSN_PSCell_Change_Time_sec_Denom	,
InterSNSPcellChgTot	S5NC_InterSN_PSCell_Change_Time_sec_Num	,	InterSNSPcellChgCnt	S5NC_InterSN_PSCell_Change_Time_sec_Denom	,
(InterNgOut_Att + InterXnOut_Att + IntraGnbOut_Att - InterNgOut_HandoverCancel - InterNgOut_RRE - InterNgOut_Succ - InterXnOut_HandoverCancel - InterXnOut_RRE - InterXnOut_Succ - IntraGnbOut_RRE - IntraGnbOut_Succ - IntraGnbOut_HandoverCancel)	S5NC_IntraNR_HO_Failure_PCT_SA_Num	,	(InterNgOut_Att + InterXnOut_Att + IntraGnbOut_Att)	S5NC_IntraNR_HO_Failure_PCT_SA_Denom	,
(IntraGnbOut_Att - IntraGnbOut_RRE - IntraGnbOut_Succ - IntraGnbOut_HandoverCancel)	S5NC_IntraGNB_HO_Failure_PCT_SA_Num	,	IntraGnbOut_Att	S5NC_IntraGNB_HO_Failure_PCT_SA_Denom	,
(InterXnOut_Att - InterXnOut_HandoverCancel - InterXnOut_RRE - InterXnOut_Succ)	S5NC_InterGNBXN_HO_Failure_PCT_SA_Num	,	InterXnOut_Att	S5NC_InterGNBXN_HO_Failure_PCT_SA_Denom	,
(InterNgOut_Att - InterNgOut_HandoverCancel - InterNgOut_RRE - InterNgOut_Succ)	S5NC_InterGNBNG_HO_Failure_PCT_SA_Num	,	InterNgOut_Att	S5NC_InterGNBNG_HO_Failure_PCT_SA_Denom	,
(IntraFreqOut_Att - IntraFreqOut_Succ - IntraFreqOut_RRE - IntraFreqOut_HandoverCancel)	S5NC_IntraFreq_HO_Failure_PCT_SA_Num	,	IntraFreqOut_Att	S5NC_IntraFreq_HO_Failure_PCT_SA_Denom	,
(InterFreqOutWithGap_Att - InterFreqOutWithGap_RRE - InterFreqOutWithGap_Succ - InterFreqOutWithGap_HandoverCancel)	S5NC_InterFreq_HO_Failure_PCT_SA_Num	,	InterFreqOutWithGap_Att	S5NC_InterFreq_HO_Failure_PCT_SA_Denom	,
--Modified formula for S5NC_IRAT_HO_Failure_PCT_SA_Num KPI on 12/20/2024 DENG-2505
(InterSysLTE_Out_Att -  T1.InterSysLTE_Out_Succ )	S5NC_IRAT_HO_Failure_PCT_SA_Num	,	InterSysLTE_Out_Att	S5NC_IRAT_HO_Failure_PCT_SA_Denom	,
TotULPrb	PUCCH_TotULPrb	,			
(DLReceivedRi1 + 2*DLReceivedRi2 + 3*DLReceivedRi3 + 4*DLReceivedRi4)	AvgReceivedRI_DL_Num	,	(DLReceivedRi1 + DLReceivedRi2 + DLReceivedRi3 + DLReceivedRi4)	AvgReceivedRI_DL_Denom	,
DLMuMimoLayers_A6	Avg_TX_Layers_DL_Num	,	DLNumScheduledSlots	Avg_TX_Layers_DL_Denom,
  S5NR_BeamChangeSuccRate_PCT_Num ,
  S5NR_BeamChangeSuccRate_PCT_Denom ,
  S5NR_UEPwrHeadroom_dB_Num ,
  S5NR_UEPwrHeadroom_dB_Denom ,
  S5NR_AverageBRSRP_dBm_Num ,
  S5NR_AverageBRSRP_dBm_Denom ,
  S5NC_InitDRBSetupFail_PCT_SA_Num ,
  S5NC_InitDRBSetupFail_PCT_SA_Denom ,
  S5NR_ULUserPerceivedTput_NSA_Mbps_Num ,
  S5NR_ULUserPerceivedTput_NSA_Mbps_Denom ,
  S5NR_ULUserPerceivedTput_SA_Mbps_Num ,
  S5NR_ULUserPerceivedTput_SA_Mbps_Denom ,
  S5ND_AvgRRCUsers_SANSA_perCell_Num ,
  S5ND_AvgRRCUsers_SANSA_perCell_Denom ,
  S5ND_MaxRRCUsers_SANSA_perCell ,
  S5ND_RLC_UL_Delay_ms_Num ,
  S5ND_RLC_UL_Delay_ms_Denom ,
  S5ND_AvgRLCDelay_UL_SA_us_Num ,
  S5ND_AvgRLCDelay_UL_SA_us_Denom ,
  /*nvl(T4.InterSysLTE_Out_Succ,0) + nvl(T4.RedirectionToLTE_CoverageOut,0)  as SAMSUNG_NRSAtoLTE_Transition_PCT_Num,*/
  nvl(T4.InterSysLTE_Out_Succ,0) + nvl(T4.RedirectionToLTE_CoverageOut,0)+ nvl(T4.REDIRECTIONTOLTE_BLINDA2,0) as SAMSUNG_NRSAtoLTE_Transition_PCT_Num,
  nvl(T1.UeContextRelTotal,0) SAMSUNG_NRSAtoLTE_Transition_PCT_Denom, 
  Average_TA_C_Band_Num ,
  Average_TA_C_Band_Denom ,
  Average_TA_LS3_Num ,
  Average_TA_LS3_Denom ,
  Average_TA_mmWave_Num ,
  Average_TA_mmWave_Denom ,
  S5NC_InitDRBSetupFail_5QI8_PCT_Num,
  S5NC_InitDRBSetupFail_5QI8_PCT_Denom,
  /*nvl(T4.InterSysLTE_Out_Succ,0) + nvl(T4.RedirectionToLTE_CoverageOut,0)+ nvl(T4.REDIRECTIONTOLTE_BLINDA2,0)  as SAMSUNG_NRSAtoLTE_Transition_PCT_Num2,*/
-- add
  (InterSysLTE_Out_EPSFallback_Att - InterSysLTE_Out_EPSFallback_Succ) S5NC_EPSFB_IRAT_HO_Failure_pct_SA_Num,
   InterSysLTE_Out_EPSFallback_Att S5NC_EPSFB_IRAT_HO_Failure_pct_SA_Denom,
  (InterSysLTE_Out_EmergencyFallback_Att - InterSysLTE_Out_EmergencyFallback_Succ) S5NC_EmergFB_IRAT_HO_Failure_pct_SA_Num,
   InterSysLTE_Out_EmergencyFallback_Att S5NC_EmergFB_IRAT_HO_Failure_pct_SA_Denom,
   RedirectionToLTE_BlindA2 Data_Redirection_pct_Num,
   --Modified formula for KPI Data_Redirection_pct_Denom on 12/20/2024 DENG-2505
  (nvl(RedirectionToLTE_BlindA2,0) + nvl(InterSysLTE_Out_PrepSucc,0) - nvl(InterSysLTE_Out_VoNR_PrepSucc,0)) Data_Redirection_pct_Denom,
   RedirectionToLTE_EPSFallback Voice_Redirection_pct_Num,
   --Modified formula for KPI Voice_Redirection_pct_Denom on 12/20/2024 DENG-2505
  (nvl(RedirectionToLTE_EPSFallback,0) + nvl(InterSysLTE_Out_EPSFallback_PrepSucc,0)) Voice_Redirection_pct_Denom,
  (InterSysLTE_Out_EPSFallback_Att - InterSysLTE_Out_EPSFallback_PrepSucc) S5NC_EPSFB_IRAT_HO_PrepFailure_pct_SA_Num,
   InterSysLTE_Out_EPSFallback_Att S5NC_EPSFB_IRAT_HO_PrepFailure_pct_SA_Denom,
   RedirectionToLTE_EPSFallback	S5NC_EPSFB_LTE_Redir_Att_SA,
  (InterSysLTE_Out_EmergencyFallback_Att - InterSysLTE_Out_EmergencyFallback_PrepSuc)	S5NC_EmergFB_IRAT_HO_PrepFailure_pct_SA_Num,
   InterSysLTE_Out_EmergencyFallback_Att S5NC_EmergFB_IRAT_HO_PrepFailure_pct_SA_Denom,
   RedirectionToLTE_EmergencyFallback S5NC_EmergFB_LTE_Redir_Att_SA,
	 -- add
	 (
			nvl(DrbRelTotal,0) 
		- nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo,0) 
		- nvl(DrbRelbyAmf_PduSessionRelCmd,0) 
		- nvl(DrbRelbyAmf_PduSessionModifyReq,0) 
		- nvl(DrbRelbyAmf_UeContextRelCmd ,0)
		+ nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo ,0)
		- nvl(DrbRelbyGnb_UeContextRelReq_WithNormalCause,0)
		- nvl(DrbRelbyIntraRatRedirection ,0)
		- nvl(DrbRelbyInterRatRedirection ,0)
		- nvl(DrbRelbyPreemption  ,0)
		+ nvl(DrbRelbyAmf_PduSessionRelCmd_T11 ,0)
		- nvl(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_T11,0)
		+ nvl(DrbRelbyAmf_PduSessionModifyReq_T11 ,0)
		- nvl(DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_T11 ,0)
		+ nvl(DrbRelbyAmf_UeContextRelCmd_T11 ,0)
		- nvl(DrbRelbyAmf_UeContextRelCmd_WithNormalCause_T11 ,0)
		- nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_T11 ,0)
		+ nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_T11 ,0)
		)	 S5NC_DRBDrop_pct_SA_23B_Num,
		(nvl(DrbRelTotal,0) - nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo,0)) S5NC_DRBDrop_pct_SA_23B_Denom,
		(
			nvl(DrbRelTotal_5QI8 ,0)
		- nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8 ,0)
		- nvl(DrbRelbyAmf_PduSessionRelCmd_5QI8 ,0)
		- nvl(DrbRelbyAmf_PduSessionModifyReq_5QI8 ,0)
		- nvl(DrbRelbyAmf_UeContextRelCmd_5QI8 ,0)
		+ nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8 ,0)
		- nvl(DrbRelbyGnb_UeContextRelReq_WithNormalCause_5QI8,0)
		- nvl(DrbRelbyIntraRatRedirection_5QI8 ,0)
		- nvl(DrbRelbyInterRatRedirection_5QI8 ,0)
		- nvl(DrbRelbyPreemption_5QI8  ,0)
		+ nvl(DrbRelbyAmf_PduSessionRelCmd_5QI8_T11 ,0)
		- nvl(DrbRelbyAmf_PduSessionRelCmd_WithNormalCause_5QI8_T11 ,0)
		+ nvl(DrbRelbyAmf_PduSessionModifyReq_5QI8_T11 ,0)
		- nvl(DrbRelbyAmf_PduSessionModifyReq_WithNormalCause_5QI8_T11 ,0)
		+ nvl(DrbRelbyAmf_UeContextRelCmd_5QI8_T11 ,0)
		- nvl(DrbRelbyAmf_UeContextRelCmd_WithNormalCause_5QI8_T11 ,0)
		- nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8_T11 ,0)
		+ nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_5QI8_T11 ,0)
		) S5NC_DRBDrop_5QI8_pct_23B_Num,
		(nvl(DrbRelTotal_5QI8,0) - nvl(DrbRelbyAmf_UeContextRelCmd_IntraNrHo_5QI8,0)) S5NC_DRBDrop_5QI8_pct_23B_Denom,
		(
			nvl(UeContextRelTotal ,0)
		- nvl(UeRelbyAmf_UeContextRelCmd_IntraNrHo ,0)
		- nvl(UeRelbyAmf_UeContextRelCmd ,0)
		+ nvl(UeRelbyAmf_UeContextRelCmd_IntraNrHo ,0)
		- nvl(UeRelbyGnb_UeContextRelReq_WithNormalCause ,0)
		- nvl(UeRelbyIntraRatRedirection ,0)
		- nvl(UeRelbyInterRatRedirection ,0)
		- nvl(UeRelbyPreemption,0)
		+ nvl(UeRelbyAmf_UeContextRelCmd_T11 ,0)
		- nvl(UeRelbyAmf_UeContextRelCmd_WithNormalCause_T11 ,0)
		- nvl(UeRelbyAmf_UeContextRelCmd_IntraNrHo_T11 ,0)
		+ nvl(UeRelbyAmf_UeContextRelCmd_IntraNrHo_WithNormalCause_T11 ,0)
		) S5NC_UECtxtDrop_pct_SA_23B_Num,
		(UeContextRelTotal - UeRelbyAmf_UeContextRelCmd_IntraNrHo) S5NC_UECtxtDrop_pct_SA_23B_Denom,
		(NrdcPsCellChange_Out_SnInit_IntraSn_Att - NrdcPsCellChange_Out_SnInit_IntraSn_Succ)	S5NC_NRDC_PScell_HO_Fail_pct_SA_Num,
		(NrdcPsCellChange_Out_SnInit_IntraSn_Att) S5NC_NRDC_PScell_HO_Fail_pct_SA_Denom
		from hive_metastore.default.widetable_5g_cell_hr_tmp3 M0
		full join hive_metastore.default.widetable_5g_cell_hr_tmp4 T1 on M0.CalendarDate=T1.CalendarDate and M0.Hour24=T1.Hour24 and M0.du_id=T1.du_id and M0.GCELL_ID=T1.GCELL_ID 
		full join hive_metastore.default.widetable_5g_cell_hr_tmp5 T2 on M0.CalendarDate=T2.CalendarDate and M0.Hour24=T2.Hour24 and M0.du_id=T2.du_id and M0.GCELL_ID=T2.GCELL_ID 
		full join hive_metastore.default.widetable_5g_cell_hr_tmp6 T3 on M0.CalendarDate=T3.CalendarDate and M0.Hour24=T3.Hour24 and M0.du_id=T3.du_id and M0.GCELL_ID=T3.GCELL_ID 
		full join hive_metastore.default.widetable_5g_cell_hr_tmp8 T4 on M0.CalendarDate=T4.CalendarDate and M0.Hour24=T4.Hour24 and M0.du_id=T4.du_id and M0.GCELL_ID=T4.GCELL_ID
		WHERE 5=5 and  M0.CalendarDate  =  date_format(date_add(now(), :days),"yyyy-MM-dd") 
) Y
left join ( select GNODEB_ID,DU_ID,GCELL_ID,frequency_band_indicator from conf_du group by GNODEB_ID,DU_ID,GCELL_ID,frequency_band_indicator) K on  Y.GNODEB_ID=K.GNODEB_ID and  Y.DU_ID=K.DU_ID and Y.GCELL_ID=K.GCELL_ID
inner join conf_market B on cast(Y.SUB_MARKET_ID AS INT)=B.SUB_MARKET_ID
;
