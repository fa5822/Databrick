-- %%
/*
show create table apachedataingestion.nr.widetable_5g_cell_hr_gold2;

CREATE TABLE apachedataingestion.nr.widetable_5g_cell_dy_gold2 ( 
  CalendarDate DATE,  
  GNODEB_ID STRING,
  du_id STRING,
  GCELL_ID BIGINT,
  MARKET_NAME STRING,
  NR_TYPE STRING,
  SUB_MARKET_ID STRING,
  SUB_MARKET_NAME STRING,
  frequency_band_indicator STRING,
  ENDC_Drop_Rate_NUM DOUBLE,
  ENDC_Drop_Rate_DENOM DOUBLE,
  S5NR_ReConfigurationFailureRate_PCT_22A_Num DOUBLE,
  S5NR_ReConfigurationFailureRate_PCT_22A_Denom DOUBLE,
  S5NR_AdditionFailureRate_NoResources_PCT_22A_Num DOUBLE,
  S5NR_AdditionFailureRate_NoResources_PCT_22A_Denom DOUBLE,
  S5NR_IntragNBHOFailRate_PCT_Num DOUBLE,
  S5NR_IntragNBHOFailRate_PCT_Denom DOUBLE,
  S5NR_IntergNBHOFailRate_PCT_Num DOUBLE,
  S5NR_IntergNBHOFailRate_PCT_Denom DOUBLE,
  S5NR_AvgRRCconnectedUsersPerCell_Num DOUBLE,
  S5NR_AvgRRCconnectedUsersPerCell_Denom DOUBLE,
  S5NR_DLMACLayerDataVolume_MB DOUBLE,
  S5NR_ULMACLayerDataVolume_MB DOUBLE,
  S5NR_DLUserPerceivedTput_Mbps_Num DOUBLE,
  S5NR_DLUserPerceivedTput_Mbps_DENOM DOUBLE,
  S5NR_ULUserPerceivedTput_Mbps_NUM DOUBLE,
  S5NR_ULUserPerceivedTput_Mbps_DENOM DOUBLE,
  S5NR_CA_AvgNumCC_NUM DOUBLE,
  S5NR_CA_AvgNumCC_DENOM DOUBLE,
  S5NR_TotalERABSetupFailureRate_PCT_Num DOUBLE,
  S5NR_TotalERABSetupFailureRate_PCT_Denom DOUBLE,
  S5NR_MaxRRCconnectedUsersPerCell DOUBLE,
  S5NR_TotalDLRLCLayerDataVolume_MB DOUBLE,
  S5NR_TotalULRLCLayerDataVolume_MB DOUBLE,
  S5NR_DLMACcellAggregateTput_Mbps_Num DOUBLE,
  S5NR_DLMACcellAggregateTput_Mbps_Denom DOUBLE,
  S5NR_ULMACcellAggregateTput_Mbps_Num DOUBLE,
  S5NR_ULMACcellAggregateTput_Mbps_Denom DOUBLE,
  S5NR_DLTTIUtilization_Pct_Num DOUBLE,
  S5NR_DLTTIUtilization_Pct_Denom DOUBLE,
  S5NR_ULTTIUtilization_PCT_Num DOUBLE,
  S5NR_ULTTIUtilization_PCT_Denom DOUBLE,
  S5NR_DLRLCReTx_PCT_Num DOUBLE,
  S5NR_DLRLCReTx_PCT_Denom DOUBLE,
  S5NR_DLPRBUtilization_PCT_Num DOUBLE,
  S5NR_DLPRBUtilization_PCT_Denom DOUBLE,
  S5NR_DLPRBUtilization_PCT_DSS_Num DOUBLE,
  S5NR_DLPRBUtilization_PCT_DSS_Denom DOUBLE,
  S5NR_DLTTIUtilization_PCT_DSS_Num DOUBLE,
  S5NR_DLTTIUtilization_PCT_DSS_Denom DOUBLE,
  S5NR_ULPRBUtilization_PCT_Num DOUBLE,
  S5NR_ULPRBUtilization_PCT_Denom DOUBLE,
  S5NR_ULPRBUtilization_PCT_DSS_Num DOUBLE,
  S5NR_ULPRBUtilization_PCT_DSS_Denom DOUBLE,
  S5NR_ULTTIUtilization_PCT_DSS_Num DOUBLE,
  S5NR_ULTTIUtilization_PCT_DSS_Denom DOUBLE,
  S5NR_DLInitBLER_PCT_Num DOUBLE,
  S5NR_DLInitBLER_PCT_Denom DOUBLE,
  S5NR_DLResidualBLER_PCT_Num DOUBLE,
  S5NR_DLResidualBLER_PCT_Denom DOUBLE,
  S5NR_ULInitBLER_PCT_Num DOUBLE,
  S5NR_ULInitBLER_PCT_Denom DOUBLE,
  S5NR_ULResidualBLER_PCT_Num DOUBLE,
  S5NR_ULResidualBLER_PCT_Denom DOUBLE,
  AIR_MAC_BYTES_AirMacDLByte DOUBLE,
  AIR_MAC_BYTES_AirMacULByte DOUBLE,
  UL_MIMO_ULNumPuschAvailableSlots DOUBLE,
  DL_MIMO_DLNumPdschAvailableSlots DOUBLE,
  DSS_INFO_DssNRDLPrbAvailable DOUBLE,
  DSS_INFO_DssNRDLPrbUsed DOUBLE,
  DSS_INFO_DssNRDLTtiAvailable DOUBLE,
  DSS_INFO_DssNRULPrbAvailable DOUBLE,
  DSS_INFO_DssNRULPrbUsed DOUBLE,
  DSS_INFO_DssNRULTtiAvailable DOUBLE,
  PRB_TOTAL_TotDLAvailablePrb DOUBLE,
  PRB_TOTAL_TotDLBroadcastPrb DOUBLE,
  PRB_TOTAL_TotDLUnicastPrb DOUBLE,
  PRB_TOTAL_TotULAvailablePrb DOUBLE,
  PRB_TOTAL_TotULUsedPrb DOUBLE,
  S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Num DOUBLE,
  S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Denom DOUBLE,
  S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Num DOUBLE,
  S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Denom DOUBLE,
  S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Num DOUBLE,
  S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Denom DOUBLE,
  S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Num DOUBLE,
  S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Denom DOUBLE,
  S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Num DOUBLE,
  S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Denom DOUBLE,
  S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Num DOUBLE,
  S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Denom DOUBLE,
  S5NR_CA_AvgNumUE_1CC_Num DOUBLE,
  S5NR_CA_AvgNumUE_1CC_Denom DOUBLE,
  S5NR_CA_AvgNumUE_2CC_Num DOUBLE,
  S5NR_CA_AvgNumUE_2CC_Denom DOUBLE,
  S5NR_CA_AvgNumUE_3CC_Num DOUBLE,
  S5NR_CA_AvgNumUE_3CC_Denom DOUBLE,
  S5NR_CA_AvgNumUE_4CC_Num DOUBLE,
  S5NR_CA_AvgNumUE_4CC_Denom DOUBLE,
  S5NR_CA_AvgNumUE_5CC_Num DOUBLE,
  S5NR_CA_AvgNumUE_5CC_Denom DOUBLE,
  S5NR_CA_AvgNumUE_6CC_Num DOUBLE,
  S5NR_CA_AvgNumUE_6CC_Denom DOUBLE,
  S5NR_CA_AvgNumUE_7CC_Num DOUBLE,
  S5NR_CA_AvgNumUE_7CC_Denom DOUBLE,
  S5NR_CA_AvgNumUE_8CC_Num DOUBLE,
  S5NR_CA_AvgNumUE_8CC_Denom DOUBLE,
  S5NR_MuMimoUeRatio_UL_PCT_Num DOUBLE,
  S5NR_MuMimoUeRatio_UL_PCT_Denom DOUBLE,
  S5NR_RLC_Delay_ms_Num DOUBLE,
  S5NR_RLC_Delay_ms_Denom DOUBLE,
  S5NR_AirIF_Delay_ms_Num DOUBLE,
  S5NR_AirIF_Delay_ms_Denom DOUBLE,
  S5NR_CADLMACLayerDataVolumePCell_MB DOUBLE,
  S5NR_CAULMACLayerDataVolumePCell_MB DOUBLE,
  S5NR_CADLMACLayerDataVolumeSCell_MB DOUBLE,
  S5NR_CAULMACLayerDataVolumeSCell_MB DOUBLE,
  S5NR_PDCCH_Block_DL_pct_NUM DOUBLE,
  S5NR_PDCCH_Block_DL_pct_DENOM DOUBLE,
  S5NR_PDCCH_Block_UL_pct_NUM DOUBLE,
  S5NR_PDCCH_Block_UL_pct_DENOM DOUBLE,
  S5NR_PDCCH_Blocking_Tot_pct_NUM DOUBLE,
  S5NR_PDCCH_Blocking_Tot_pct_DENOM DOUBLE,
  S5NR_PDCCH_AggLvl1_DL_pct_NUM DOUBLE,
  S5NR_PDCCH_AggLvl1_DL_pct_DENOM DOUBLE,
  S5NR_PDCCH_AggLvl2_DL_pct_NUM DOUBLE,
  S5NR_PDCCH_AggLvl2_DL_pct_DENOM DOUBLE,
  S5NR_PDCCH_AggLvl4_DL_pct_NUM DOUBLE,
  S5NR_PDCCH_AggLvl4_DL_pct_DENOM DOUBLE,
  S5NR_PDCCH_AggLvl8_DL_pct_NUM DOUBLE,
  S5NR_PDCCH_AggLvl8_DL_pct_DENOM DOUBLE,
  S5NR_PDCCH_AggLvl1_UL_pct_NUM DOUBLE,
  S5NR_PDCCH_AggLvl1_UL_pct_DENOM DOUBLE,
  S5NR_PDCCH_AggLvl2_UL_pct_NUM DOUBLE,
  S5NR_PDCCH_AggLvl2_UL_pct_DENOM DOUBLE,
  S5NR_PDCCH_AggLvl4_UL_pct_NUM DOUBLE,
  S5NR_PDCCH_AggLvl4_UL_pct_DENOM DOUBLE,
  S5NR_PDCCH_AggLvl8_UL_pct_NUM DOUBLE,
  S5NR_PDCCH_AggLvl8_UL_pct_DENOM DOUBLE,
  S5NR_CA_Addition_Attempts DOUBLE,
  S5NR_CA_Addition_Failure_PCT_NUM DOUBLE,
  S5NR_CA_Addition_Failure_PCT_DENOM DOUBLE,
  S5NR_CA_Activation_Attempts DOUBLE,
  S5NR_CA_Activation_Failure_PCT_Num DOUBLE,
  S5NR_CA_Activation_Failure_PCT_Denom DOUBLE,
  S5NR_CA_Deactivation_Attempts DOUBLE,
  S5NR_CA_Deactivation_Failure_PCT_Num DOUBLE,
  S5NR_CA_Deactivation_Failure_PCT_Denom DOUBLE,
  S5NR_CA_AvgAddDuration_s_NUM DOUBLE,
  S5NR_CA_AvgAddDuration_s_DENOM DOUBLE,
  S5NR_CA_MaxAddDuration_s DOUBLE,
  S5NR_CA_TotAddDuration_s DOUBLE,
  S5NR_CA_NumF1UECtxtSetupReq_NonCaCapUE DOUBLE,
  S5NR_CA_NumF1UECtxtSetupReq_CaCapUE DOUBLE,
  S5NR_CA_NumF1UECtxtSetupReq_NonULCaCapUE DOUBLE,
  S5NR_CA_NumF1UECtxtSetupReq_ULCaCapUE DOUBLE,
  S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_NUM DOUBLE,
  S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_DENOM DOUBLE,
  S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_NUM DOUBLE,
  S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_DENOM DOUBLE,
  S5NR_ULAvgAssignedMCS_NUM DOUBLE,
  S5NR_ULAvgAssignedMCS_DENOM DOUBLE,
  S5_AverageCQI_NUM DOUBLE,
  S5_AverageCQI_DENOM DOUBLE,
  S5NR_RACH_SR_pct_NUM DOUBLE,
  S5NR_RACH_SR_pct_DENOM DOUBLE,
  S5NR_RACH_CB_SR_pct_NUM DOUBLE,
  S5NR_RACH_CB_SR_pct_DENOM DOUBLE,
  S5NR_RACH_CF_SR_pct_NUM DOUBLE,
  S5NR_RACH_CF_SR_pct_DENOM DOUBLE,
  S5NR_RACH_Att_MSG1_CB DOUBLE,
  S5NR_RACH_Att_MSG1_CF DOUBLE,
  S5NR_RACH_Att_MSG2_CB DOUBLE,
  S5NR_RACH_Att_MSG2_CF DOUBLE,
  S5NR_RACH_Att_MSG3_CB DOUBLE,
  S5NR_RACH_Att_MSG3_CF DOUBLE,
  S5NR_RACH_Att_MSG5_CB DOUBLE,
  S5NR_PUCCHAvgSINR_dB_NUM DOUBLE,
  S5NR_PUCCHAvgSINR_dB_DENOM DOUBLE,
  S5NR_PUSCHAvgSINR_dB_NUM DOUBLE,
  S5NR_PUSCHAvgSINR_dB_DENOM DOUBLE,
  Average_RSSI_Path0_3_Num DOUBLE,
  Average_RSSI_Path0_3_Denom DOUBLE,
  S5NR_DLAvgAssignedMCS_NUM DOUBLE,
  S5NR_DLAvgAssignedMCS_DENOM DOUBLE,
  S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Num DOUBLE,
  S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Denom DOUBLE,
  S5NR_AvgNumMuMimoUePerSlot_UL_Num DOUBLE,
  S5NR_AvgNumMuMimoUePerSlot_UL_Denom DOUBLE,
  S5NR_MuMimoUsedPrbRatio_UL_PCT_Num DOUBLE,
  S5NR_MuMimoUsedPrbRatio_UL_PCT_Denom DOUBLE,
  S5NR_AvgNumLayerPerSlot_UL_Num DOUBLE,
  S5NR_AvgNumLayerPerSlot_UL_Denom DOUBLE,
  RssiPathMax DOUBLE,
  S5NR_PDCCH_SlotRationBlocking_DL_PCT_Num DOUBLE,
  S5NR_PDCCH_SlotRationBlocking_DL_PCT_Denom DOUBLE,
  S5NR_PDCCH_SlotRationBlocking_UL_PCT_Num DOUBLE,
  S5NR_PDCCH_SlotRationBlocking_UL_PCT_Denom DOUBLE,
  S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Num DOUBLE,
  S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Denom DOUBLE,
  S5NR_PDCCH_AggLvl16_DL_PCT_Num DOUBLE,
  S5NR_PDCCH_AggLvl16_DL_PCT_Denom DOUBLE,
  S5NR_PDCCH_AggLvl16_UL_PCT_Num DOUBLE,
  S5NR_PDCCH_AggLvl16_UL_PCT_Denom DOUBLE,
  S5NR_TotalDLRLCLayerDataVolume_MB_QCI8 DOUBLE,
  S5NR_TotalDLRLCLayerDataVolume_MB_QCI132 DOUBLE,
  S5NR_TotalULRLCLayerDataVolume_MB_QCI8 DOUBLE,
  S5NR_TotalULRLCLayerDataVolume_MB_QCI132 DOUBLE,
  S5NR_DLUserPerceivedTput_Mbps_QCI8_Num DOUBLE,
  S5NR_DLUserPerceivedTput_Mbps_QCI8_Denom DOUBLE,
  S5NR_DLUserPerceivedTput_Mbps_QCI132_Num DOUBLE,
  S5NR_DLUserPerceivedTput_Mbps_QCI132_Denom DOUBLE,
  Cell_Availability_Num DOUBLE,
  Cell_Availability_Denom DOUBLE,
  S5NR_AvgRRCConnectionHoldTime_s_Num DOUBLE,
  S5NR_AvgRRCConnectionHoldTime_s_Denom DOUBLE,
  S5NR_PUCCH_BLER_PCT_Num DOUBLE,
  S5NR_PUCCH_BLER_PCT_Denom DOUBLE,
  S5NR_PDCCH_Fail_DL_PCT_Num DOUBLE,
  S5NR_PDCCH_Fail_DL_PCT_Denom DOUBLE,
  S5NR_PDCCH_Fail_UL_PCT_Num DOUBLE,
  S5NR_PDCCH_Fail_UL_PCT_Denom DOUBLE,
  S5NR_AvgNumMuMimoLayerPerMuTti_DL_Num DOUBLE,
  S5NR_AvgNumMuMimoLayerPerMuTti_DL_Denom DOUBLE,
  S5NR_AvgNumMuMimoUePerMuTti_DL_Num DOUBLE,
  S5NR_AvgNumMuMimoUePerMuTti_DL_Denom DOUBLE,
  S5NR_MuMimoUeRatio_DL_PCT_Num DOUBLE,
  S5NR_MuMimoUeRatio_DL_PCT_Denom DOUBLE,
  S5NR_MuMimoUsedPrbRatio_DL_PCT_Num DOUBLE,
  S5NR_MuMimoUsedPrbRatio_DL_PCT_Denom DOUBLE,
  ULRatioSuRank2UEs_Num DOUBLE,
  ULRatioSuRank2UEs_Denom DOUBLE,
  S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Num DOUBLE,
  S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Denom DOUBLE,
  S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Num DOUBLE,
  S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Denom DOUBLE,
  S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Num DOUBLE,
  S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Denom DOUBLE,
  S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Num DOUBLE,
  S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Denom DOUBLE,
  S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Num DOUBLE,
  S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Denom DOUBLE,
  S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Num DOUBLE,
  S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Denom DOUBLE,
  S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Num DOUBLE,
  S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Denom DOUBLE,
  S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Num DOUBLE,
  S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Denom DOUBLE)
USING delta
PARTITIONED BY (CalendarDate)
TBLPROPERTIES (
  'delta.checkpoint.writeStatsAsJson' = 'false',
  'delta.checkpoint.writeStatsAsStruct' = 'true',
  'delta.columnMapping.mode' = 'name',
  'delta.enableDeletionVectors' = 'true',
  'delta.feature.columnMapping' = 'supported',
  'delta.feature.deletionVectors' = 'supported',
  'delta.minReaderVersion' = '3',
  'delta.minWriterVersion' = '7')


select * from apachedataingestion.nr.widetable_5g_cell_dy_gold2

*/

delete from apachedataingestion.nr.widetable_5g_cell_dy_gold2 where CalendarDate = date_format(date_add(now(), {{ days }}),"yyyy-MM-dd");


insert into  apachedataingestion.nr.widetable_5g_cell_dy_gold2
select
  CalendarDate,
  GNODEB_ID,
  du_id,
  GCELL_ID,
  MARKET_NAME,
  NR_TYPE,
  SUB_MARKET_ID,
  SUB_MARKET_NAME,
  frequency_band_indicator,
  sum(ENDC_Drop_Rate_NUM) ENDC_Drop_Rate_NUM,
  sum(ENDC_Drop_Rate_DENOM) ENDC_Drop_Rate_DENOM,
  sum(S5NR_ReConfigurationFailureRate_PCT_22A_Num) S5NR_ReConfigurationFailureRate_PCT_22A_Num,
  sum(S5NR_ReConfigurationFailureRate_PCT_22A_Denom) S5NR_ReConfigurationFailureRate_PCT_22A_Denom,
  sum(S5NR_AdditionFailureRate_NoResources_PCT_22A_Num) S5NR_AdditionFailureRate_NoResources_PCT_22A_Num,
  sum(S5NR_AdditionFailureRate_NoResources_PCT_22A_Denom) S5NR_AdditionFailureRate_NoResources_PCT_22A_Denom,
  sum(S5NR_IntragNBHOFailRate_PCT_Num) S5NR_IntragNBHOFailRate_PCT_Num,
  sum(S5NR_IntragNBHOFailRate_PCT_Denom) S5NR_IntragNBHOFailRate_PCT_Denom,
  sum(S5NR_IntergNBHOFailRate_PCT_Num) S5NR_IntergNBHOFailRate_PCT_Num,
  sum(S5NR_IntergNBHOFailRate_PCT_Denom) S5NR_IntergNBHOFailRate_PCT_Denom,
  sum(S5NR_AvgRRCconnectedUsersPerCell_Num) S5NR_AvgRRCconnectedUsersPerCell_Num,
  sum(S5NR_AvgRRCconnectedUsersPerCell_Denom) S5NR_AvgRRCconnectedUsersPerCell_Denom,
  sum(S5NR_DLMACLayerDataVolume_MB) S5NR_DLMACLayerDataVolume_MB,
  sum(S5NR_ULMACLayerDataVolume_MB) S5NR_ULMACLayerDataVolume_MB,
  sum(S5NR_DLUserPerceivedTput_Mbps_Num) S5NR_DLUserPerceivedTput_Mbps_Num,
  sum(S5NR_DLUserPerceivedTput_Mbps_DENOM) S5NR_DLUserPerceivedTput_Mbps_DENOM,
  sum(S5NR_ULUserPerceivedTput_Mbps_NUM) S5NR_ULUserPerceivedTput_Mbps_NUM,
  sum(S5NR_ULUserPerceivedTput_Mbps_DENOM) S5NR_ULUserPerceivedTput_Mbps_DENOM,
  sum(S5NR_CA_AvgNumCC_NUM) S5NR_CA_AvgNumCC_NUM,
  sum(S5NR_CA_AvgNumCC_DENOM) S5NR_CA_AvgNumCC_DENOM,
  sum(S5NR_TotalERABSetupFailureRate_PCT_Num) S5NR_TotalERABSetupFailureRate_PCT_Num,
  sum(S5NR_TotalERABSetupFailureRate_PCT_Denom) S5NR_TotalERABSetupFailureRate_PCT_Denom,
  max(S5NR_MaxRRCconnectedUsersPerCell) S5NR_MaxRRCconnectedUsersPerCell,
  sum(S5NR_TotalDLRLCLayerDataVolume_MB) S5NR_TotalDLRLCLayerDataVolume_MB,
  sum(S5NR_TotalULRLCLayerDataVolume_MB) S5NR_TotalULRLCLayerDataVolume_MB,
  sum(S5NR_DLMACcellAggregateTput_Mbps_Num) S5NR_DLMACcellAggregateTput_Mbps_Num,
  sum(S5NR_DLMACcellAggregateTput_Mbps_Denom) S5NR_DLMACcellAggregateTput_Mbps_Denom,
  sum(S5NR_ULMACcellAggregateTput_Mbps_Num) S5NR_ULMACcellAggregateTput_Mbps_Num,
  sum(S5NR_ULMACcellAggregateTput_Mbps_Denom) S5NR_ULMACcellAggregateTput_Mbps_Denom,
  sum(S5NR_DLTTIUtilization_Pct_Num) S5NR_DLTTIUtilization_Pct_Num,
  sum(S5NR_DLTTIUtilization_Pct_Denom) S5NR_DLTTIUtilization_Pct_Denom,
  sum(S5NR_ULTTIUtilization_PCT_Num) S5NR_ULTTIUtilization_PCT_Num,
  sum(S5NR_ULTTIUtilization_PCT_Denom) S5NR_ULTTIUtilization_PCT_Denom,
  sum(S5NR_DLRLCReTx_PCT_Num) S5NR_DLRLCReTx_PCT_Num,
  sum(S5NR_DLRLCReTx_PCT_Denom) S5NR_DLRLCReTx_PCT_Denom,
  sum(S5NR_DLPRBUtilization_PCT_Num) S5NR_DLPRBUtilization_PCT_Num,
  sum(S5NR_DLPRBUtilization_PCT_Denom) S5NR_DLPRBUtilization_PCT_Denom,
  sum(S5NR_DLPRBUtilization_PCT_DSS_Num) S5NR_DLPRBUtilization_PCT_DSS_Num,
  sum(S5NR_DLPRBUtilization_PCT_DSS_Denom) S5NR_DLPRBUtilization_PCT_DSS_Denom,
  sum(S5NR_DLTTIUtilization_PCT_DSS_Num) S5NR_DLTTIUtilization_PCT_DSS_Num,
  sum(S5NR_DLTTIUtilization_PCT_DSS_Denom) S5NR_DLTTIUtilization_PCT_DSS_Denom,
  sum(S5NR_ULPRBUtilization_PCT_Num) S5NR_ULPRBUtilization_PCT_Num,
  sum(S5NR_ULPRBUtilization_PCT_Denom) S5NR_ULPRBUtilization_PCT_Denom,
  sum(S5NR_ULPRBUtilization_PCT_DSS_Num) S5NR_ULPRBUtilization_PCT_DSS_Num,
  sum(S5NR_ULPRBUtilization_PCT_DSS_Denom) S5NR_ULPRBUtilization_PCT_DSS_Denom,
  sum(S5NR_ULTTIUtilization_PCT_DSS_Num) S5NR_ULTTIUtilization_PCT_DSS_Num,
  sum(S5NR_ULTTIUtilization_PCT_DSS_Denom) S5NR_ULTTIUtilization_PCT_DSS_Denom,
  sum(S5NR_DLInitBLER_PCT_Num) S5NR_DLInitBLER_PCT_Num,
  sum(S5NR_DLInitBLER_PCT_Denom) S5NR_DLInitBLER_PCT_Denom,
  sum(S5NR_DLResidualBLER_PCT_Num) S5NR_DLResidualBLER_PCT_Num,
  sum(S5NR_DLResidualBLER_PCT_Denom) S5NR_DLResidualBLER_PCT_Denom,
  sum(S5NR_ULInitBLER_PCT_Num) S5NR_ULInitBLER_PCT_Num,
  sum(S5NR_ULInitBLER_PCT_Denom) S5NR_ULInitBLER_PCT_Denom,
  sum(S5NR_ULResidualBLER_PCT_Num) S5NR_ULResidualBLER_PCT_Num,
  sum(S5NR_ULResidualBLER_PCT_Denom) S5NR_ULResidualBLER_PCT_Denom,
  sum(AIR_MAC_BYTES_AirMacDLByte) AIR_MAC_BYTES_AirMacDLByte,
  sum(AIR_MAC_BYTES_AirMacULByte) AIR_MAC_BYTES_AirMacULByte,
  sum(UL_MIMO_ULNumPuschAvailableSlots) UL_MIMO_ULNumPuschAvailableSlots,
  sum(DL_MIMO_DLNumPdschAvailableSlots) DL_MIMO_DLNumPdschAvailableSlots,
  sum(DSS_INFO_DssNRDLPrbAvailable) DSS_INFO_DssNRDLPrbAvailable,
  sum(DSS_INFO_DssNRDLPrbUsed) DSS_INFO_DssNRDLPrbUsed,
  sum(DSS_INFO_DssNRDLTtiAvailable) DSS_INFO_DssNRDLTtiAvailable,
  sum(DSS_INFO_DssNRULPrbAvailable) DSS_INFO_DssNRULPrbAvailable,
  sum(DSS_INFO_DssNRULPrbUsed) DSS_INFO_DssNRULPrbUsed,
  sum(DSS_INFO_DssNRULTtiAvailable) DSS_INFO_DssNRULTtiAvailable,
  sum(PRB_TOTAL_TotDLAvailablePrb) PRB_TOTAL_TotDLAvailablePrb,
  sum(PRB_TOTAL_TotDLBroadcastPrb) PRB_TOTAL_TotDLBroadcastPrb,
  sum(PRB_TOTAL_TotDLUnicastPrb) PRB_TOTAL_TotDLUnicastPrb,
  sum(PRB_TOTAL_TotULAvailablePrb) PRB_TOTAL_TotULAvailablePrb,
  sum(PRB_TOTAL_TotULUsedPrb) PRB_TOTAL_TotULUsedPrb,
  sum(S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Num) S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Num,
  sum(S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Denom) S5NR_DLMACcellAggregateTput_Mbps_FR1FDD_Denom,
  sum(S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Num) S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Num,
  sum(S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Denom) S5NR_ULMACcellAggregateTput_Mbps_FR1FDD_Denom,
  sum(S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Num) S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Num,
  sum(S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Denom) S5NR_DLMACcellAggregateTput_Mbps_FR1DSS_Denom,
  sum(S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Num) S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Num,
  sum(S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Denom) S5NR_ULMACcellAggregateTput_Mbps_FR1DSS_Denom,
  sum(S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Num) S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Num,
  sum(S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Denom) S5NR_DLMACcellAggregateTput_Mbps_FR1TDD_Denom,
  sum(S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Num) S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Num,
  sum(S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Denom) S5NR_ULMACcellAggregateTput_Mbps_FR1TDD_Denom,
  sum(S5NR_CA_AvgNumUE_1CC_Num) S5NR_CA_AvgNumUE_1CC_Num,
  sum(S5NR_CA_AvgNumUE_1CC_Denom) S5NR_CA_AvgNumUE_1CC_Denom,
  sum(S5NR_CA_AvgNumUE_2CC_Num) S5NR_CA_AvgNumUE_2CC_Num,
  sum(S5NR_CA_AvgNumUE_2CC_Denom) S5NR_CA_AvgNumUE_2CC_Denom,
  sum(S5NR_CA_AvgNumUE_3CC_Num) S5NR_CA_AvgNumUE_3CC_Num,
  sum(S5NR_CA_AvgNumUE_3CC_Denom) S5NR_CA_AvgNumUE_3CC_Denom,
  sum(S5NR_CA_AvgNumUE_4CC_Num) S5NR_CA_AvgNumUE_4CC_Num,
  sum(S5NR_CA_AvgNumUE_4CC_Denom) S5NR_CA_AvgNumUE_4CC_Denom,
  sum(S5NR_CA_AvgNumUE_5CC_Num) S5NR_CA_AvgNumUE_5CC_Num,
  sum(S5NR_CA_AvgNumUE_5CC_Denom) S5NR_CA_AvgNumUE_5CC_Denom,
  sum(S5NR_CA_AvgNumUE_6CC_Num) S5NR_CA_AvgNumUE_6CC_Num,
  sum(S5NR_CA_AvgNumUE_6CC_Denom) S5NR_CA_AvgNumUE_6CC_Denom,
  sum(S5NR_CA_AvgNumUE_7CC_Num) S5NR_CA_AvgNumUE_7CC_Num,
  sum(S5NR_CA_AvgNumUE_7CC_Denom) S5NR_CA_AvgNumUE_7CC_Denom,
  sum(S5NR_CA_AvgNumUE_8CC_Num) S5NR_CA_AvgNumUE_8CC_Num,
  sum(S5NR_CA_AvgNumUE_8CC_Denom) S5NR_CA_AvgNumUE_8CC_Denom,
  sum(S5NR_MuMimoUeRatio_UL_PCT_Num) S5NR_MuMimoUeRatio_UL_PCT_Num,
  sum(S5NR_MuMimoUeRatio_UL_PCT_Denom) S5NR_MuMimoUeRatio_UL_PCT_Denom,
  sum(S5NR_RLC_Delay_ms_Num) S5NR_RLC_Delay_ms_Num,
  sum(S5NR_RLC_Delay_ms_Denom) S5NR_RLC_Delay_ms_Denom,
  sum(S5NR_AirIF_Delay_ms_Num) S5NR_AirIF_Delay_ms_Num,
  sum(S5NR_AirIF_Delay_ms_Denom) S5NR_AirIF_Delay_ms_Denom,
  sum(S5NR_CADLMACLayerDataVolumePCell_MB) S5NR_CADLMACLayerDataVolumePCell_MB,
  sum(S5NR_CAULMACLayerDataVolumePCell_MB) S5NR_CAULMACLayerDataVolumePCell_MB,
  sum(S5NR_CADLMACLayerDataVolumeSCell_MB) S5NR_CADLMACLayerDataVolumeSCell_MB,
  sum(S5NR_CAULMACLayerDataVolumeSCell_MB) S5NR_CAULMACLayerDataVolumeSCell_MB,
  sum(S5NR_PDCCH_Block_DL_pct_NUM) S5NR_PDCCH_Block_DL_pct_NUM,
  sum(S5NR_PDCCH_Block_DL_pct_DENOM) S5NR_PDCCH_Block_DL_pct_DENOM,
  sum(S5NR_PDCCH_Block_UL_pct_NUM) S5NR_PDCCH_Block_UL_pct_NUM,
  sum(S5NR_PDCCH_Block_UL_pct_DENOM) S5NR_PDCCH_Block_UL_pct_DENOM,
  sum(S5NR_PDCCH_Blocking_Tot_pct_NUM) S5NR_PDCCH_Blocking_Tot_pct_NUM,
  sum(S5NR_PDCCH_Blocking_Tot_pct_DENOM) S5NR_PDCCH_Blocking_Tot_pct_DENOM,
  sum(S5NR_PDCCH_AggLvl1_DL_pct_NUM) S5NR_PDCCH_AggLvl1_DL_pct_NUM,
  sum(S5NR_PDCCH_AggLvl1_DL_pct_DENOM) S5NR_PDCCH_AggLvl1_DL_pct_DENOM,
  sum(S5NR_PDCCH_AggLvl2_DL_pct_NUM) S5NR_PDCCH_AggLvl2_DL_pct_NUM,
  sum(S5NR_PDCCH_AggLvl2_DL_pct_DENOM) S5NR_PDCCH_AggLvl2_DL_pct_DENOM,
  sum(S5NR_PDCCH_AggLvl4_DL_pct_NUM) S5NR_PDCCH_AggLvl4_DL_pct_NUM,
  sum(S5NR_PDCCH_AggLvl4_DL_pct_DENOM) S5NR_PDCCH_AggLvl4_DL_pct_DENOM,
  sum(S5NR_PDCCH_AggLvl8_DL_pct_NUM) S5NR_PDCCH_AggLvl8_DL_pct_NUM,
  sum(S5NR_PDCCH_AggLvl8_DL_pct_DENOM) S5NR_PDCCH_AggLvl8_DL_pct_DENOM,
  sum(S5NR_PDCCH_AggLvl1_UL_pct_NUM) S5NR_PDCCH_AggLvl1_UL_pct_NUM,
  sum(S5NR_PDCCH_AggLvl1_UL_pct_DENOM) S5NR_PDCCH_AggLvl1_UL_pct_DENOM,
  sum(S5NR_PDCCH_AggLvl2_UL_pct_NUM) S5NR_PDCCH_AggLvl2_UL_pct_NUM,
  sum(S5NR_PDCCH_AggLvl2_UL_pct_DENOM) S5NR_PDCCH_AggLvl2_UL_pct_DENOM,
  sum(S5NR_PDCCH_AggLvl4_UL_pct_NUM) S5NR_PDCCH_AggLvl4_UL_pct_NUM,
  sum(S5NR_PDCCH_AggLvl4_UL_pct_DENOM) S5NR_PDCCH_AggLvl4_UL_pct_DENOM,
  sum(S5NR_PDCCH_AggLvl8_UL_pct_NUM) S5NR_PDCCH_AggLvl8_UL_pct_NUM,
  sum(S5NR_PDCCH_AggLvl8_UL_pct_DENOM) S5NR_PDCCH_AggLvl8_UL_pct_DENOM,
  sum(S5NR_CA_Addition_Attempts) S5NR_CA_Addition_Attempts,
  sum(S5NR_CA_Addition_Failure_PCT_NUM) S5NR_CA_Addition_Failure_PCT_NUM,
  sum(S5NR_CA_Addition_Failure_PCT_DENOM) S5NR_CA_Addition_Failure_PCT_DENOM,
  sum(S5NR_CA_Activation_Attempts) S5NR_CA_Activation_Attempts,
  sum(S5NR_CA_Activation_Failure_PCT_Num) S5NR_CA_Activation_Failure_PCT_Num,
  sum(S5NR_CA_Activation_Failure_PCT_Denom) S5NR_CA_Activation_Failure_PCT_Denom,
  sum(S5NR_CA_Deactivation_Attempts) S5NR_CA_Deactivation_Attempts,
  sum(S5NR_CA_Deactivation_Failure_PCT_Num) S5NR_CA_Deactivation_Failure_PCT_Num,
  sum(S5NR_CA_Deactivation_Failure_PCT_Denom) S5NR_CA_Deactivation_Failure_PCT_Denom,
  sum(S5NR_CA_AvgAddDuration_s_NUM) S5NR_CA_AvgAddDuration_s_NUM,
  sum(S5NR_CA_AvgAddDuration_s_DENOM) S5NR_CA_AvgAddDuration_s_DENOM,
  max(S5NR_CA_MaxAddDuration_s) S5NR_CA_MaxAddDuration_s,
  sum(S5NR_CA_TotAddDuration_s) S5NR_CA_TotAddDuration_s,
  sum(S5NR_CA_NumF1UECtxtSetupReq_NonCaCapUE) S5NR_CA_NumF1UECtxtSetupReq_NonCaCapUE,
  sum(S5NR_CA_NumF1UECtxtSetupReq_CaCapUE) S5NR_CA_NumF1UECtxtSetupReq_CaCapUE,
  sum(S5NR_CA_NumF1UECtxtSetupReq_NonULCaCapUE) S5NR_CA_NumF1UECtxtSetupReq_NonULCaCapUE,
  sum(S5NR_CA_NumF1UECtxtSetupReq_ULCaCapUE) S5NR_CA_NumF1UECtxtSetupReq_ULCaCapUE,
  sum(S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_NUM) S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_NUM,
  sum(S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_DENOM) S5NR_PDCCH_CCE_UsedPerSlot_DL_pct_DENOM,
  sum(S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_NUM) S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_NUM,
  sum(S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_DENOM) S5NR_PDCCH_CCE_UsedPerSlot_UL_pct_DENOM,
  sum(S5NR_ULAvgAssignedMCS_NUM) S5NR_ULAvgAssignedMCS_NUM,
  sum(S5NR_ULAvgAssignedMCS_DENOM) S5NR_ULAvgAssignedMCS_DENOM,
  sum(S5_AverageCQI_NUM) S5_AverageCQI_NUM,
  sum(S5_AverageCQI_DENOM) S5_AverageCQI_DENOM,
  sum(S5NR_RACH_SR_pct_NUM) S5NR_RACH_SR_pct_NUM,
  sum(S5NR_RACH_SR_pct_DENOM) S5NR_RACH_SR_pct_DENOM,
  sum(S5NR_RACH_CB_SR_pct_NUM) S5NR_RACH_CB_SR_pct_NUM,
  sum(S5NR_RACH_CB_SR_pct_DENOM) S5NR_RACH_CB_SR_pct_DENOM,
  sum(S5NR_RACH_CF_SR_pct_NUM) S5NR_RACH_CF_SR_pct_NUM,
  sum(S5NR_RACH_CF_SR_pct_DENOM) S5NR_RACH_CF_SR_pct_DENOM,
  sum(S5NR_RACH_Att_MSG1_CB) S5NR_RACH_Att_MSG1_CB,
  sum(S5NR_RACH_Att_MSG1_CF) S5NR_RACH_Att_MSG1_CF,
  sum(S5NR_RACH_Att_MSG2_CB) S5NR_RACH_Att_MSG2_CB,
  sum(S5NR_RACH_Att_MSG2_CF) S5NR_RACH_Att_MSG2_CF,
  sum(S5NR_RACH_Att_MSG3_CB) S5NR_RACH_Att_MSG3_CB,
  sum(S5NR_RACH_Att_MSG3_CF) S5NR_RACH_Att_MSG3_CF,
  sum(S5NR_RACH_Att_MSG5_CB) S5NR_RACH_Att_MSG5_CB,
  sum(S5NR_PUCCHAvgSINR_dB_NUM) S5NR_PUCCHAvgSINR_dB_NUM,
  sum(S5NR_PUCCHAvgSINR_dB_DENOM) S5NR_PUCCHAvgSINR_dB_DENOM,
  sum(S5NR_PUSCHAvgSINR_dB_NUM) S5NR_PUSCHAvgSINR_dB_NUM,
  sum(S5NR_PUSCHAvgSINR_dB_DENOM) S5NR_PUSCHAvgSINR_dB_DENOM,
  sum(Average_RSSI_Path0_3_Num) Average_RSSI_Path0_3_Num,
  sum(Average_RSSI_Path0_3_Denom) Average_RSSI_Path0_3_Denom,
  sum(S5NR_DLAvgAssignedMCS_NUM) S5NR_DLAvgAssignedMCS_NUM,
  sum(S5NR_DLAvgAssignedMCS_DENOM) S5NR_DLAvgAssignedMCS_DENOM,
  sum(S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Num) S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Num,
  sum(S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Denom) S5NR_AvgNumMuMimoLayerPerMuSlot_UL_Denom,
  sum(S5NR_AvgNumMuMimoUePerSlot_UL_Num) S5NR_AvgNumMuMimoUePerSlot_UL_Num,
  sum(S5NR_AvgNumMuMimoUePerSlot_UL_Denom) S5NR_AvgNumMuMimoUePerSlot_UL_Denom,
  sum(S5NR_MuMimoUsedPrbRatio_UL_PCT_Num) S5NR_MuMimoUsedPrbRatio_UL_PCT_Num,
  sum(S5NR_MuMimoUsedPrbRatio_UL_PCT_Denom) S5NR_MuMimoUsedPrbRatio_UL_PCT_Denom,
  sum(S5NR_AvgNumLayerPerSlot_UL_Num) S5NR_AvgNumLayerPerSlot_UL_Num,
  sum(S5NR_AvgNumLayerPerSlot_UL_Denom) S5NR_AvgNumLayerPerSlot_UL_Denom,
  max(RssiPathMax) RssiPathMax,
  sum(S5NR_PDCCH_SlotRationBlocking_DL_PCT_Num) S5NR_PDCCH_SlotRationBlocking_DL_PCT_Num,
  sum(S5NR_PDCCH_SlotRationBlocking_DL_PCT_Denom) S5NR_PDCCH_SlotRationBlocking_DL_PCT_Denom,
  sum(S5NR_PDCCH_SlotRationBlocking_UL_PCT_Num) S5NR_PDCCH_SlotRationBlocking_UL_PCT_Num,
  sum(S5NR_PDCCH_SlotRationBlocking_UL_PCT_Denom) S5NR_PDCCH_SlotRationBlocking_UL_PCT_Denom,
  sum(S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Num) S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Num,
  sum(S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Denom) S5NR_PDCCH_SlotRationBlocking_Tot_PCT_Denom,
  sum(S5NR_PDCCH_AggLvl16_DL_PCT_Num) S5NR_PDCCH_AggLvl16_DL_PCT_Num,
  sum(S5NR_PDCCH_AggLvl16_DL_PCT_Denom) S5NR_PDCCH_AggLvl16_DL_PCT_Denom,
  sum(S5NR_PDCCH_AggLvl16_UL_PCT_Num) S5NR_PDCCH_AggLvl16_UL_PCT_Num,
  sum(S5NR_PDCCH_AggLvl16_UL_PCT_Denom) S5NR_PDCCH_AggLvl16_UL_PCT_Denom,
  sum(S5NR_TotalDLRLCLayerDataVolume_MB_QCI8) S5NR_TotalDLRLCLayerDataVolume_MB_QCI8,
  sum(S5NR_TotalDLRLCLayerDataVolume_MB_QCI132) S5NR_TotalDLRLCLayerDataVolume_MB_QCI132,
  sum(S5NR_TotalULRLCLayerDataVolume_MB_QCI8) S5NR_TotalULRLCLayerDataVolume_MB_QCI8,
  sum(S5NR_TotalULRLCLayerDataVolume_MB_QCI132) S5NR_TotalULRLCLayerDataVolume_MB_QCI132,
  sum(S5NR_DLUserPerceivedTput_Mbps_QCI8_Num) S5NR_DLUserPerceivedTput_Mbps_QCI8_Num,
  sum(S5NR_DLUserPerceivedTput_Mbps_QCI8_Denom) S5NR_DLUserPerceivedTput_Mbps_QCI8_Denom,
  sum(S5NR_DLUserPerceivedTput_Mbps_QCI132_Num) S5NR_DLUserPerceivedTput_Mbps_QCI132_Num,
  sum(S5NR_DLUserPerceivedTput_Mbps_QCI132_Denom) S5NR_DLUserPerceivedTput_Mbps_QCI132_Denom,
  sum(Cell_Availability_Num) Cell_Availability_Num,
  sum(Cell_Availability_Denom) Cell_Availability_Denom,
  sum(S5NR_AvgRRCConnectionHoldTime_s_Num) S5NR_AvgRRCConnectionHoldTime_s_Num,
  sum(S5NR_AvgRRCConnectionHoldTime_s_Denom) S5NR_AvgRRCConnectionHoldTime_s_Denom,
  sum(S5NR_PUCCH_BLER_PCT_Num) S5NR_PUCCH_BLER_PCT_Num,
  sum(S5NR_PUCCH_BLER_PCT_Denom) S5NR_PUCCH_BLER_PCT_Denom,
  sum(S5NR_PDCCH_Fail_DL_PCT_Num) S5NR_PDCCH_Fail_DL_PCT_Num,
  sum(S5NR_PDCCH_Fail_DL_PCT_Denom) S5NR_PDCCH_Fail_DL_PCT_Denom,
  sum(S5NR_PDCCH_Fail_UL_PCT_Num) S5NR_PDCCH_Fail_UL_PCT_Num,
  sum(S5NR_PDCCH_Fail_UL_PCT_Denom) S5NR_PDCCH_Fail_UL_PCT_Denom,
  sum(S5NR_AvgNumMuMimoLayerPerMuTti_DL_Num) S5NR_AvgNumMuMimoLayerPerMuTti_DL_Num,
  sum(S5NR_AvgNumMuMimoLayerPerMuTti_DL_Denom) S5NR_AvgNumMuMimoLayerPerMuTti_DL_Denom,
  sum(S5NR_AvgNumMuMimoUePerMuTti_DL_Num) S5NR_AvgNumMuMimoUePerMuTti_DL_Num,
  sum(S5NR_AvgNumMuMimoUePerMuTti_DL_Denom) S5NR_AvgNumMuMimoUePerMuTti_DL_Denom,
  sum(S5NR_MuMimoUeRatio_DL_PCT_Num) S5NR_MuMimoUeRatio_DL_PCT_Num,
  sum(S5NR_MuMimoUeRatio_DL_PCT_Denom) S5NR_MuMimoUeRatio_DL_PCT_Denom,
  sum(S5NR_MuMimoUsedPrbRatio_DL_PCT_Num) S5NR_MuMimoUsedPrbRatio_DL_PCT_Num,
  sum(S5NR_MuMimoUsedPrbRatio_DL_PCT_Denom) S5NR_MuMimoUsedPrbRatio_DL_PCT_Denom,
  sum(ULRatioSuRank2UEs_Num) ULRatioSuRank2UEs_Num,
  sum(ULRatioSuRank2UEs_Denom) ULRatioSuRank2UEs_Denom,
  sum(S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Num) S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Num,
  sum(S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Denom) S5ND_RLCAggThpt_FR2_SANSA_DL_Mbps_Denom,
  sum(S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Num) S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Num,
  sum(S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Denom) S5ND_RLCAggThpt_FR2_SANSA_UL_Mbps_Denom,
  sum(S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Num) S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Num,
  sum(S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Denom) S5ND_RLCAggThpt_FR1FDD_SANSA_DL_Mbps_Denom,
  sum(S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Num) S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Num,
  sum(S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Denom) S5ND_RLCAggThpt_FR1FDD_SANSA_UL_Mbps_Denom,
  sum(S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Num) S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Num,
  sum(S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Denom) S5ND_RLCAggThpt_FR1DSS_SANSA_DL_Mbps_Denom,
  sum(S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Num) S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Num,
  sum(S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Denom) S5ND_RLCAggThpt_FR1DSS_SANSA_UL_Mbps_Denom,
  sum(S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Num) S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Num,
  sum(S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Denom) S5ND_RLCAggThpt_FR1TDD_SANSA_DL_Mbps_Denom,
  sum(S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Num) S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Num,
  sum(S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Denom) S5ND_RLCAggThpt_FR1TDD_SANSA_UL_Mbps_Denom
from
  apachedataingestion.nr.widetable_5g_cell_hr_gold2
where
   Hour24 > 5  
   and CalendarDate = date_format(date_add(now(), {{ days }}),"yyyy-MM-dd")
group by
  CalendarDate,  GNODEB_ID,  du_id,  GCELL_ID,  MARKET_NAME,  NR_TYPE,  SUB_MARKET_ID,  SUB_MARKET_NAME,  frequency_band_indicator;
