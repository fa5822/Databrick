-- %%
DECLARE InsertStr STRING;
DECLARE DeleteStr STRING;
DECLARE ColumnStr STRING;

SET VAR DeleteStr  = "  delete from apachedataingestion.nr.widetable_5g_spid_rfsp_dy_gold2 where CalendarDate = date_format(date_add(now()," || :days || "),'yyyy-MM-dd')";

EXECUTE IMMEDIATE DeleteStr;

SET VAR ColumnStr = "
					  SUM(S5NC_AvgUENo_SPID125_Num) S5NC_AvgUENo_SPID125_Num,
					  SUM(S5NC_AvgUENo_SPID125_Denom) S5NC_AvgUENo_SPID125_Denom,
					  MAX(UeNoMax_SPID125) UeNoMax_SPID125,
					  SUM(S5NC_AvgUENo_SPID115_Num) S5NC_AvgUENo_SPID115_Num,
					  SUM(S5NC_AvgUENo_SPID115_Denom) S5NC_AvgUENo_SPID115_Denom,
					  MAX(UeNoMax_SPID115) UeNoMax_SPID115,
					  SUM(S5ND_UEActiveDLAvg_SPID125_Num) S5ND_UEActiveDLAvg_SPID125_Num,
					  SUM(S5ND_UEActiveDLAvg_SPID125_Denom) S5ND_UEActiveDLAvg_SPID125_Denom,
					  SUM(S5ND_UEActiveDLAvg_SPID115_Num) S5ND_UEActiveDLAvg_SPID115_Num,
					  SUM(S5ND_UEActiveDLAvg_SPID115_Denom) S5ND_UEActiveDLAvg_SPID115_Denom,
					  SUM(S5ND_TotalMACDataVolumeDL_MB_SPID125) S5ND_TotalMACDataVolumeDL_MB_SPID125,
					  SUM(S5ND_TotalMACDataVolumeUL_MB_SPID125) S5ND_TotalMACDataVolumeUL_MB_SPID125,
					  SUM(S5ND_AirMacDLThruAvg_Mbps_SPID125_Num) S5ND_AirMacDLThruAvg_Mbps_SPID125_Num,
					  SUM(S5ND_AirMacDLThruAvg_Mbps_SPID125_Denom) S5ND_AirMacDLThruAvg_Mbps_SPID125_Denom,
					  SUM(S5ND_AirMacULThruAvg_Mbps_SPID125_Num) S5ND_AirMacULThruAvg_Mbps_SPID125_Num,
					  SUM(S5ND_AirMacULThruAvg_Mbps_SPID125_Denom) S5ND_AirMacULThruAvg_Mbps_SPID125_Denom,
					  SUM(S5ND_TotalMACDataVolumeDL_MB_SPID115) S5ND_TotalMACDataVolumeDL_MB_SPID115,
					  SUM(S5ND_TotalMACDataVolumeUL_MB_SPID115) S5ND_TotalMACDataVolumeUL_MB_SPID115,
					  SUM(S5ND_AirMacDLThruAvg_Mbps_SPID115_Num) S5ND_AirMacDLThruAvg_Mbps_SPID115_Num,
					  SUM(S5ND_AirMacDLThruAvg_Mbps_SPID115_Denom) S5ND_AirMacDLThruAvg_Mbps_SPID115_Denom,
					  SUM(S5ND_AirMacULThruAvg_Mbps_SPID115_Num) S5ND_AirMacULThruAvg_Mbps_SPID115_Num,
					  SUM(S5ND_AirMacULThruAvg_Mbps_SPID115_Denom) S5ND_AirMacULThruAvg_Mbps_SPID115_Denom,
					  SUM(S5ND_DLUeThru_Mbps_SPID125_Num) S5ND_DLUeThru_Mbps_SPID125_Num,
					  SUM(S5ND_DLUeThru_Mbps_SPID125_Denom) S5ND_DLUeThru_Mbps_SPID125_Denom,
					  SUM(S5ND_DLUeThru_Mbps_SPID115_Num) S5ND_DLUeThru_Mbps_SPID115_Num,
					  SUM(S5ND_DLUeThru_Mbps_SPID115_Denom) S5ND_DLUeThru_Mbps_SPID115_Denom,
					  SUM(S5NR_DLPRBUtilization_PCT_SPID125_Num) S5NR_DLPRBUtilization_PCT_SPID125_Num,
					  SUM(S5NR_DLPRBUtilization_PCT_SPID125_Denom) S5NR_DLPRBUtilization_PCT_SPID125_Denom,
					  SUM(S5NR_DLPRBUtilization_PCT_SPID115_Num) S5NR_DLPRBUtilization_PCT_SPID115_Num,
					  SUM(S5NR_DLPRBUtilization_PCT_SPID115_Denom) S5NR_DLPRBUtilization_PCT_SPID115_Denom,
					  SUM(S5NR_ULPRBUtilization_PCT_SPID125_Num) S5NR_ULPRBUtilization_PCT_SPID125_Num,
					  SUM(S5NR_ULPRBUtilization_PCT_SPID125_Denom) S5NR_ULPRBUtilization_PCT_SPID125_Denom,
					  SUM(S5NR_ULPRBUtilization_PCT_SPID115_Num) S5NR_ULPRBUtilization_PCT_SPID115_Num,
					  SUM(S5NR_ULPRBUtilization_PCT_SPID115_Denom) S5NR_ULPRBUtilization_PCT_SPID115_Denom,
					  SUM(S5NR_DLTTIUtilization_PCT_SPID125_Num) S5NR_DLTTIUtilization_PCT_SPID125_Num,
					  SUM(S5NR_DLTTIUtilization_PCT_SPID125_Denom) S5NR_DLTTIUtilization_PCT_SPID125_Denom,
					  SUM(S5ND_DLAvgNumSuMimoUEs_SPID125_Num) S5ND_DLAvgNumSuMimoUEs_SPID125_Num,
					  SUM(S5ND_DLAvgNumSuMimoUEs_SPID125_Denom) S5ND_DLAvgNumSuMimoUEs_SPID125_Denom,
					  SUM(S5ND_DLNumSuMimoUEsPCT_SPID125_Num) S5ND_DLNumSuMimoUEsPCT_SPID125_Num,
					  SUM(S5ND_DLNumSuMimoUEsPCT_SPID125_Denom) S5ND_DLNumSuMimoUEsPCT_SPID125_Denom,
					  SUM(S5NR_DLTTIUtilization_PCT_SPID115_Num) S5NR_DLTTIUtilization_PCT_SPID115_Num,
					  SUM(S5NR_DLTTIUtilization_PCT_SPID115_Denom) S5NR_DLTTIUtilization_PCT_SPID115_Denom,
					  SUM(S5ND_DLAvgNumSuMimoUEs_SPID115_Num) S5ND_DLAvgNumSuMimoUEs_SPID115_Num,
					  SUM(S5ND_DLAvgNumSuMimoUEs_SPID115_Denom) S5ND_DLAvgNumSuMimoUEs_SPID115_Denom,
					  SUM(S5ND_DLNumSuMimoUEsPCT_SPID115_Num) S5ND_DLNumSuMimoUEsPCT_SPID115_Num,
					  SUM(S5ND_DLNumSuMimoUEsPCT_SPID115_Denom) S5ND_DLNumSuMimoUEsPCT_SPID115_Denom,
					  SUM(S5NC_AvgRRC_RFSP125_Num) S5NC_AvgRRC_RFSP125_Num,
					  SUM(S5NC_AvgRRC_RFSP125_Denom) S5NC_AvgRRC_RFSP125_Denom,
					  MAX(S5NC_MaxRRC_RFSP125) S5NC_MaxRRC_RFSP125,
					  SUM(S5NC_AvgRRC_RFSP115_Num) S5NC_AvgRRC_RFSP115_Num,
					  SUM(S5NC_AvgRRC_RFSP115_Denom) S5NC_AvgRRC_RFSP115_Denom,
					  MAX(S5NC_MaxRRC_RFSP115) S5NC_MaxRRC_RFSP115,
					  SUM(S5ND_UEActiveDLAvg_RFSP125_Num) S5ND_UEActiveDLAvg_RFSP125_Num,
					  SUM(S5ND_UEActiveDLAvg_RFSP125_Denom) S5ND_UEActiveDLAvg_RFSP125_Denom,
					  SUM(S5ND_UEActiveDLAvg_RFSP115_Num) S5ND_UEActiveDLAvg_RFSP115_Num,
					  SUM(S5ND_UEActiveDLAvg_RFSP115_Denom) S5ND_UEActiveDLAvg_RFSP115_Denom,
					  SUM(S5ND_TotalMACDataVolumeDL_MB_RFSP125) S5ND_TotalMACDataVolumeDL_MB_RFSP125,
					  SUM(S5ND_TotalMACDataVolumeUL_MB_RFSP125) S5ND_TotalMACDataVolumeUL_MB_RFSP125,
					  SUM(S5ND_AirMacDLThruAvg_Mbps_RFSP125_Num) S5ND_AirMacDLThruAvg_Mbps_RFSP125_Num,
					  SUM(S5ND_AirMacDLThruAvg_Mbps_RFSP125_Denom) S5ND_AirMacDLThruAvg_Mbps_RFSP125_Denom,
					  SUM(S5ND_AirMacULThruAvg_Mbps_RFSP125_Num) S5ND_AirMacULThruAvg_Mbps_RFSP125_Num,
					  SUM(S5ND_AirMacULThruAvg_Mbps_RFSP125_Denom) S5ND_AirMacULThruAvg_Mbps_RFSP125_Denom,
					  SUM(S5ND_TotalMACDataVolumeDL_MB_RFSP115) S5ND_TotalMACDataVolumeDL_MB_RFSP115,
					  SUM(S5ND_TotalMACDataVolumeUL_MB_RFSP115) S5ND_TotalMACDataVolumeUL_MB_RFSP115,
					  SUM(S5ND_AirMacDLThruAvg_Mbps_RFSP115_Num) S5ND_AirMacDLThruAvg_Mbps_RFSP115_Num,
					  SUM(S5ND_AirMacDLThruAvg_Mbps_RFSP115_Denom) S5ND_AirMacDLThruAvg_Mbps_RFSP115_Denom,
					  SUM(S5ND_AirMacULThruAvg_Mbps_RFSP115_Num) S5ND_AirMacULThruAvg_Mbps_RFSP115_Num,
					  SUM(S5ND_AirMacULThruAvg_Mbps_RFSP115_Denom) S5ND_AirMacULThruAvg_Mbps_RFSP115_Denom,
					  SUM(S5ND_DLUeThru_Mbps_RFSP125_Num) S5ND_DLUeThru_Mbps_RFSP125_Num,
					  SUM(S5ND_DLUeThru_Mbps_RFSP125_Denom) S5ND_DLUeThru_Mbps_RFSP125_Denom,
					  SUM(S5ND_DLUeThru_Mbps_RFSP115_Num) S5ND_DLUeThru_Mbps_RFSP115_Num,
					  SUM(S5ND_DLUeThru_Mbps_RFSP115_Denom) S5ND_DLUeThru_Mbps_RFSP115_Denom,
					  SUM(S5NR_DLPRBUtilization_PCT_RFSP125_Num) S5NR_DLPRBUtilization_PCT_RFSP125_Num,
					  SUM(S5NR_DLPRBUtilization_PCT_RFSP125_Denom) S5NR_DLPRBUtilization_PCT_RFSP125_Denom,
					  SUM(S5NR_ULPRBUtilization_PCT_RFSP125_Num) S5NR_ULPRBUtilization_PCT_RFSP125_Num,
					  SUM(S5NR_ULPRBUtilization_PCT_RFSP125_Denom) S5NR_ULPRBUtilization_PCT_RFSP125_Denom,
					  SUM(S5NR_DLPRBUtilization_PCT_RFSP115_Num) S5NR_DLPRBUtilization_PCT_RFSP115_Num,
					  SUM(S5NR_DLPRBUtilization_PCT_RFSP115_Denom) S5NR_DLPRBUtilization_PCT_RFSP115_Denom,
					  SUM(S5NR_ULPRBUtilization_PCT_RFSP115_Num) S5NR_ULPRBUtilization_PCT_RFSP115_Num,
					  SUM(S5NR_ULPRBUtilization_PCT_RFSP115_Denom) S5NR_ULPRBUtilization_PCT_RFSP115_Denom,
					  SUM(S5NR_DLTTIUtilization_PCT_RFSP125_Num) S5NR_DLTTIUtilization_PCT_RFSP125_Num,
					  SUM(S5NR_DLTTIUtilization_PCT_RFSP125_Denom) S5NR_DLTTIUtilization_PCT_RFSP125_Denom,
					  SUM(S5ND_DLAvgNumSuMimoUEs_RFSP125_Num) S5ND_DLAvgNumSuMimoUEs_RFSP125_Num,
					  SUM(S5ND_DLAvgNumSuMimoUEs_RFSP125_Denom) S5ND_DLAvgNumSuMimoUEs_RFSP125_Denom,
					  SUM(S5ND_DLNumSuMimoUEsPCT_RFSP125_Num) S5ND_DLNumSuMimoUEsPCT_RFSP125_Num,
					  SUM(S5ND_DLNumSuMimoUEsPCT_RFSP125_Denom) S5ND_DLNumSuMimoUEsPCT_RFSP125_Denom,
					  SUM(S5NR_DLTTIUtilization_PCT_RFSP115_Num) S5NR_DLTTIUtilization_PCT_RFSP115_Num,
					  SUM(S5NR_DLTTIUtilization_PCT_RFSP115_Denom) S5NR_DLTTIUtilization_PCT_RFSP115_Denom,
					  SUM(S5ND_DLAvgNumSuMimoUEs_RFSP115_Num) S5ND_DLAvgNumSuMimoUEs_RFSP115_Num,
					  SUM(S5ND_DLAvgNumSuMimoUEs_RFSP115_Denom) S5ND_DLAvgNumSuMimoUEs_RFSP115_Denom,
					  SUM(S5ND_DLNumSuMimoUEsPCT_RFSP115_Num) S5ND_DLNumSuMimoUEsPCT_RFSP115_Num,
					  SUM(S5ND_DLNumSuMimoUEsPCT_RFSP115_Denom) S5ND_DLNumSuMimoUEsPCT_RFSP115_Denom,
					  SUM(S5NC_ERABSetupFailureRate_PCT_QCI132_NUM) S5NC_ERABSetupFailureRate_PCT_QCI132_NUM,
					  SUM(S5NC_ERABSetupFailureRate_PCT_QCI132_DENOM) S5NC_ERABSetupFailureRate_PCT_QCI132_DENOM,
					  SUM(S5NC_ERAB_Drop_Rate_QCI132_PCT_NUM) S5NC_ERAB_Drop_Rate_QCI132_PCT_NUM,
					  SUM(S5NC_ERAB_Drop_Rate_QCI132_PCT_DENOM) S5NC_ERAB_Drop_Rate_QCI132_PCT_DENOM,
					  SUM(5GNC_DRBSetupFail_5QI132_PCT_NUM) 5GNC_DRBSetupFail_5QI132_PCT_NUM,
					  SUM(5GNC_DRBSetupFail_5QI132_PCT_DENOM) 5GNC_DRBSetupFail_5QI132_PCT_DENOM,
					  SUM(S5NC_DRBDrop_5QI132_PCT_NUM) S5NC_DRBDrop_5QI132_PCT_NUM,
					  SUM(S5NC_DRBDrop_5QI132_PCT_DENOM) S5NC_DRBDrop_5QI132_PCT_DENOM,
					  SUM(S5NC_DRBDrop_5QI132_PCT_23B_NUM) S5NC_DRBDrop_5QI132_PCT_23B_NUM,
					  SUM(S5NC_DRBDrop_5QI132_PCT_23B_DENOM) S5NC_DRBDrop_5QI132_PCT_23B_DENOM,
					  SUM(S5NC_ERAB_Drop_Rate_QCI132_PCT_Alt_NUM) S5NC_ERAB_Drop_Rate_QCI132_PCT_Alt_NUM,
					  SUM(S5NC_ERAB_Drop_Rate_QCI132_PCT_Alt_DENOM) S5NC_ERAB_Drop_Rate_QCI132_PCT_Alt_DENOM,
					  --Added new KPIs as on 3/3/2025 DENG-2437
						SUM(S5NC_AvgUENo_SPID95_Num)	S5NC_AvgUENo_SPID95_Num,
						SUM(S5NC_AvgUENo_SPID95_Denom)	S5NC_AvgUENo_SPID95_Denom,
						MAX(UeNoMax_SPID95)	UeNoMax_SPID95,
						SUM(S5ND_UEActiveDLAvg_SPID95_Num)	S5ND_UEActiveDLAvg_SPID95_Num,
						SUM(S5ND_UEActiveDLAvg_SPID95_Denom)	S5ND_UEActiveDLAvg_SPID95_Denom,
						SUM(S5ND_TotalMACDataVolumeDL_MB_SPID95)	S5ND_TotalMACDataVolumeDL_MB_SPID95,
						SUM(S5ND_TotalMACDataVolumeUL_MB_SPID95)	S5ND_TotalMACDataVolumeUL_MB_SPID95,
						SUM(S5ND_AirMacDLThruAvg_Mbps_SPID95_Num)	S5ND_AirMacDLThruAvg_Mbps_SPID95_Num,
						SUM(S5ND_AirMacDLThruAvg_Mbps_SPID95_Denom)	S5ND_AirMacDLThruAvg_Mbps_SPID95_Denom,
						SUM(S5ND_AirMacULThruAvg_Mbps_SPID95_Num)	S5ND_AirMacULThruAvg_Mbps_SPID95_Num,
						SUM(S5ND_AirMacULThruAvg_Mbps_SPID95_Denom)	S5ND_AirMacULThruAvg_Mbps_SPID95_Denom,
						SUM(S5ND_DLUeThru_Mbps_SPID95_Num)	S5ND_DLUeThru_Mbps_SPID95_Num,
						SUM(S5ND_DLUeThru_Mbps_SPID95_Denom)	S5ND_DLUeThru_Mbps_SPID95_Denom,
						SUM(S5NR_DLPRBUtilization_PCT_SPID95_Num)	S5NR_DLPRBUtilization_PCT_SPID95_Num,
						SUM(S5NR_DLPRBUtilization_PCT_SPID95_Denom)	S5NR_DLPRBUtilization_PCT_SPID95_Denom,
						SUM(S5NR_ULPRBUtilization_PCT_SPID95_Num)	S5NR_ULPRBUtilization_PCT_SPID95_Num,
						SUM(S5NR_ULPRBUtilization_PCT_SPID95_Denom)	S5NR_ULPRBUtilization_PCT_SPID95_Denom,
						SUM(S5NR_DLTTIUtilization_PCT_SPID95_Num)	S5NR_DLTTIUtilization_PCT_SPID95_Num,
						SUM(S5NR_DLTTIUtilization_PCT_SPID95_Denom)	S5NR_DLTTIUtilization_PCT_SPID95_Denom,
						SUM(S5ND_DLAvgNumSuMimoUEs_SPID95_Num)	S5ND_DLAvgNumSuMimoUEs_SPID95_Num,
						SUM(S5ND_DLAvgNumSuMimoUEs_SPID95_Denom)	S5ND_DLAvgNumSuMimoUEs_SPID95_Denom,
						SUM(S5ND_DLNumSuMimoUEsPCT_SPID95_Num)	S5ND_DLNumSuMimoUEsPCT_SPID95_Num,
						SUM(S5ND_DLNumSuMimoUEsPCT_SPID95_Denom)	S5ND_DLNumSuMimoUEsPCT_SPID95_Denom,
						SUM(S5NC_AvgRRC_RFSP95_Num)	S5NC_AvgRRC_RFSP95_Num,
						SUM(S5NC_AvgRRC_RFSP95_Denom)	S5NC_AvgRRC_RFSP95_Denom,
						MAX(S5NC_MaxRRC_RFSP95)	S5NC_MaxRRC_RFSP95,
						SUM(S5ND_UEActiveDLAvg_RFSP95_Num)	S5ND_UEActiveDLAvg_RFSP95_Num,
						SUM(S5ND_UEActiveDLAvg_RFSP95_Denom)	S5ND_UEActiveDLAvg_RFSP95_Denom,
						SUM(S5ND_TotalMACDataVolumeDL_MB_RFSP95)	S5ND_TotalMACDataVolumeDL_MB_RFSP95,
						SUM(S5ND_TotalMACDataVolumeUL_MB_RFSP95)	S5ND_TotalMACDataVolumeUL_MB_RFSP95,
						SUM(S5ND_AirMacDLThruAvg_Mbps_RFSP95_Num)	S5ND_AirMacDLThruAvg_Mbps_RFSP95_Num,
						SUM(S5ND_AirMacDLThruAvg_Mbps_RFSP95_Denom)	S5ND_AirMacDLThruAvg_Mbps_RFSP95_Denom,
						SUM(S5ND_AirMacULThruAvg_Mbps_RFSP95_Num)	S5ND_AirMacULThruAvg_Mbps_RFSP95_Num,
						SUM(S5ND_AirMacULThruAvg_Mbps_RFSP95_Denom)	S5ND_AirMacULThruAvg_Mbps_RFSP95_Denom,
						SUM(S5ND_DLUeThru_Mbps_RFSP95_Num)	S5ND_DLUeThru_Mbps_RFSP95_Num,
						SUM(S5ND_DLUeThru_Mbps_RFSP95_Denom)	S5ND_DLUeThru_Mbps_RFSP95_Denom,
						SUM(S5NR_DLPRBUtilization_PCT_RFSP95_Num)	S5NR_DLPRBUtilization_PCT_RFSP95_Num,
						SUM(S5NR_DLPRBUtilization_PCT_RFSP95_Denom)	S5NR_DLPRBUtilization_PCT_RFSP95_Denom,
						SUM(S5NR_ULPRBUtilization_PCT_RFSP95_Num)	S5NR_ULPRBUtilization_PCT_RFSP95_Num,
						SUM(S5NR_ULPRBUtilization_PCT_RFSP95_Denom)	S5NR_ULPRBUtilization_PCT_RFSP95_Denom,
						SUM(S5NR_DLTTIUtilization_PCT_RFSP95_Num)	S5NR_DLTTIUtilization_PCT_RFSP95_Num,
						SUM(S5NR_DLTTIUtilization_PCT_RFSP95_Denom)	S5NR_DLTTIUtilization_PCT_RFSP95_Denom,
						SUM(S5ND_DLAvgNumSuMimoUEs_RFSP95_Num)	S5ND_DLAvgNumSuMimoUEs_RFSP95_Num,
						SUM(S5ND_DLAvgNumSuMimoUEs_RFSP95_Denom)	S5ND_DLAvgNumSuMimoUEs_RFSP95_Denom,
						SUM(S5ND_DLNumSuMimoUEsPCT_RFSP95_Num)	S5ND_DLNumSuMimoUEsPCT_RFSP95_Num,
						SUM(S5ND_DLNumSuMimoUEsPCT_RFSP95_Denom)	S5ND_DLNumSuMimoUEsPCT_RFSP95_Denom  
					";
SET VAR InsertStr  = "
                      Insert into apachedataingestion.nr.widetable_5g_spid_rfsp_dy_gold2
                      with v_widetable_5g_spid_rfsp_hr_gold2 as (
                        select * from apachedataingestion.nr.widetable_5g_spid_rfsp_hr_gold2 where CalendarDate = date_format(date_add(now(), " || :days ||"),'yyyy-MM-dd')  
                      )
                      select 
						  '24hr' MW_BH,
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME,
                          "|| ColumnStr ||"
					  from  v_widetable_5g_spid_rfsp_hr_gold2
					  group by 
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME
                union all
                      select 
                        'MW_Excluded' MW_BH,
                        frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME,
                          "|| ColumnStr ||"
					  from  v_widetable_5g_spid_rfsp_hr_gold2
					  where Hour24 >= 6
					  group by 
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME
                union all
                      select 
                        'FBH_20' MW_BH,
                        frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME,
                          "|| ColumnStr ||"
					  from  v_widetable_5g_spid_rfsp_hr_gold2
					  where Hour24=20
					  group by 
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME
                union all
                      select 
                        'FBH_15' MW_BH,
                        frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME,
                          "|| ColumnStr ||"
					  from  v_widetable_5g_spid_rfsp_hr_gold2
					  where Hour24=15
					  group by 
						  frequency_band_indicator,
						  CalendarDate,
						  GNODEB_ID,
						  du_id,
						  GCELL_ID,
						  MARKET_NAME,
						  NR_TYPE,
						  SUB_MARKET_ID,
						  SUB_MARKET_NAME
                              
                      ";


EXECUTE IMMEDIATE InsertStr;
